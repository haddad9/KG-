# %% [markdown]
# # Revise Turtle Map

# %%
import pandas as pd
import re

# %%
df = pd.read_csv('core/turtle_map.csv')
df
# Out:
#                  regulatory                                           ttl_file
# 0      Amandemen_1_UUD_1945  new_turtle_fileslain-lain1945uud1945perubahanp...
# 1      Amandemen_2_UUD_1945  new_turtle_fileslain-lain1945uud1945perubahank...
# 2      Amandemen_3_UUD_1945  new_turtle_fileslain-lain1945uud1945perubahank...
# 3      Amandemen_4_UUD_1945  new_turtle_fileslain-lain1945uud1945perubahank...
# 4      Kepmen_Hut_2002_8171                new_turtle_filesbn2008bn23-2008.ttl
# ...                     ...                                                ...
# 24968             UU_2019_4               new_turtle_filesln2019uu4-2019bt.ttl
# 24969             UU_2019_5               new_turtle_filesln2019uu5-2019bt.ttl
# 24970             UU_2019_7               new_turtle_filesln2019uu7-2019bt.ttl
# 24971             UU_2019_8               new_turtle_filesln2019uu8-2019bt.ttl
# 24972             UU_2019_9               new_turtle_filesln2019uu9-2019bt.ttl
#
# [24973 rows x 2 columns]

# %%
filtered_df = df[~df['ttl_file'].str.contains('ningg')]
filtered_df
# Out:
#                  regulatory                                           ttl_file
# 0      Amandemen_1_UUD_1945  new_turtle_fileslain-lain1945uud1945perubahanp...
# 1      Amandemen_2_UUD_1945  new_turtle_fileslain-lain1945uud1945perubahank...
# 2      Amandemen_3_UUD_1945  new_turtle_fileslain-lain1945uud1945perubahank...
# 3      Amandemen_4_UUD_1945  new_turtle_fileslain-lain1945uud1945perubahank...
# 4      Kepmen_Hut_2002_8171                new_turtle_filesbn2008bn23-2008.ttl
# ...                     ...                                                ...
# 24968             UU_2019_4               new_turtle_filesln2019uu4-2019bt.ttl
# 24969             UU_2019_5               new_turtle_filesln2019uu5-2019bt.ttl
# 24970             UU_2019_7               new_turtle_filesln2019uu7-2019bt.ttl
# 24971             UU_2019_8               new_turtle_filesln2019uu8-2019bt.ttl
# 24972             UU_2019_9               new_turtle_filesln2019uu9-2019bt.ttl
#
# [24811 rows x 2 columns]

# %%
def replace_strings_with_regex(string):
    pattern = r'(?P<root>new_turtle_files)(?P<prefix>bn|lain-lain|ln|perda|putusan)(?P<year>\d{4})'
    modified_string = re.sub(pattern, r'\g<root>/\g<prefix>/\g<year>/', string)
    return modified_string

# %%
modified_df = filtered_df.copy()
modified_df['ttl_file'] = modified_df['ttl_file'].apply(lambda x: replace_strings_with_regex(x))
modified_df
# Out:
#                  regulatory                                           ttl_file
# 0      Amandemen_1_UUD_1945  new_turtle_files/lain-lain/1945/uud1945perubah...
# 1      Amandemen_2_UUD_1945  new_turtle_files/lain-lain/1945/uud1945perubah...
# 2      Amandemen_3_UUD_1945  new_turtle_files/lain-lain/1945/uud1945perubah...
# 3      Amandemen_4_UUD_1945  new_turtle_files/lain-lain/1945/uud1945perubah...
# 4      Kepmen_Hut_2002_8171             new_turtle_files/bn/2008/bn23-2008.ttl
# ...                     ...                                                ...
# 24968             UU_2019_4            new_turtle_files/ln/2019/uu4-2019bt.ttl
# 24969             UU_2019_5            new_turtle_files/ln/2019/uu5-2019bt.ttl
# 24970             UU_2019_7            new_turtle_files/ln/2019/uu7-2019bt.ttl
# 24971             UU_2019_8            new_turtle_files/ln/2019/uu8-2019bt.ttl
# 24972             UU_2019_9            new_turtle_files/ln/2019/uu9-2019bt.ttl
#
# [24811 rows x 2 columns]

# %%
modified_df.to_csv("core/turtle_map_fin.csv", index=False)

# %% [markdown]
# # Ingest Turtle File Into Regulatory Map

# %%
df_1 = pd.read_csv('core/regulatory_map.csv')
df_2 = pd.read_csv('core/turtle_map_fin.csv')

df_1['a'] = df_1['regulatory'].str.lower()
df_2['a'] = df_2['regulatory'].str.lower()
df_2['file_ttl'] = df_2['ttl_file']

df_1 = df_1.drop('regulatory', axis=1)
df_2 = df_2.drop('ttl_file', axis=1)

merged_df = pd.merge(df_2, df_1, on='a', how='left')
merged_df = merged_df.drop('a', axis=1)

merged_df
# Out:
#                  regulatory  \
# 0      Amandemen_1_UUD_1945
# 1      Amandemen_2_UUD_1945
# 2      Amandemen_3_UUD_1945
# 3      Amandemen_4_UUD_1945
# 4      Kepmen_Hut_2002_8171
# ...                     ...
# 25449             UU_2019_4
# 25450             UU_2019_5
# 25451             UU_2019_7
# 25452             UU_2019_8
# 25453             UU_2019_9
#
#                                                 file_ttl  \
# 0      new_turtle_files/lain-lain/1945/uud1945perubah...
# 1      new_turtle_files/lain-lain/1945/uud1945perubah...
# 2      new_turtle_files/lain-lain/1945/uud1945perubah...
# 3      new_turtle_files/lain-lain/1945/uud1945perubah...
# 4                 new_turtle_files/bn/2008/bn23-2008.ttl
# ...                                                  ...
# 25449            new_turtle_files/ln/2019/uu4-2019bt.ttl
# 25450            new_turtle_files/ln/2019/uu5-2019bt.ttl
# 25451            new_turtle_files/ln/2019/uu7-2019bt.ttl
# 25452            new_turtle_files/ln/2019/uu8-2019bt.ttl
# 25453            new_turtle_files/ln/2019/uu9-2019bt.ttl
#
#                                     ttl_file  \
# 0        turtle_files/bn/2015/bn270-2015.ttl
# 1        turtle_files/bn/2015/bn270-2015.ttl
# 2        turtle_files/bn/2015/bn270-2015.ttl
# 3        turtle_files/bn/2015/bn270-2015.ttl
# 4         turtle_files/bn/2008/bn29-2008.ttl
# ...                                      ...
# 25449  turtle_files/bn/2019/bn_1235-2019.ttl
# 25450    turtle_files/ln/2019/pp8-2019bt.ttl
# 25451    turtle_files/bn/2019/bn662-2019.ttl
# 25452   turtle_files/bn/2019/bn_567-2019.ttl
# 25453    turtle_files/bn/2019/bn639-2019.ttl
#
#                                                 file_txt  \
# 0      new_1_text_files/lain-lain/1945/uud1945perubah...
# 1      new_1_text_files/lain-lain/1945/uud1945perubah...
# 2      new_1_text_files/lain-lain/1945/uud1945perubah...
# 3      new_1_text_files/lain-lain/1945/uud1945perubah...
# 4                 new_1_text_files/bn/2008/bn23-2008.txt
# ...                                                  ...
# 25449            new_1_text_files/ln/2019/uu4-2019bt.txt
# 25450            new_1_text_files/ln/2019/uu5-2019bt.txt
# 25451            new_1_text_files/ln/2019/uu7-2019bt.txt
# 25452            new_1_text_files/ln/2019/uu8-2019bt.txt
# 25453            new_1_text_files/ln/2019/uu9-2019bt.txt
#
#                                                file_json
# 0      new_parsed_files/lain-lain/1945/uud1945perubah...
# 1      new_parsed_files/lain-lain/1945/uud1945perubah...
# 2      new_parsed_files/lain-lain/1945/uud1945perubah...
# 3      new_parsed_files/lain-lain/1945/uud1945perubah...
# 4                new_parsed_files/bn/2008/bn23-2008.json
# ...                                                  ...
# 25449           new_parsed_files/ln/2019/uu4-2019bt.json
# 25450           new_parsed_files/ln/2019/uu5-2019bt.json
# 25451           new_parsed_files/ln/2019/uu7-2019bt.json
# 25452           new_parsed_files/ln/2019/uu8-2019bt.json
# 25453           new_parsed_files/ln/2019/uu9-2019bt.json
#
# [25454 rows x 5 columns]

# %%
with open('core/error.txt', 'r') as file:
    error_files = file.read().splitlines()
    
error_files
# Out:
# ['new_parsed_files/bn/2015/bn1947-2015.json',
#  'new_parsed_files/bn/2015/bn1309-2015.json',
#  'new_parsed_files/bn/2015/bn498-2015.json',
#  'new_parsed_files/ln/2018/ps140-2018.json',
#  'new_parsed_files/ln/1960/pp0271960.json',
#  'new_parsed_files/ln/1970/pp0061970.json',
#  'new_parsed_files/ln/2016/pbi18-6-2016bt.json',
#  'new_parsed_files/bn/2010/bn361-2010.json',
#  'new_parsed_files/bn/2011/bn808-2011.json',
#  'new_parsed_files/bn/2012/bn470-2012.json',
#  'new_parsed_files/bn/2012/bn623-2012.json',
#  'new_parsed_files/bn/2012/bn471-2012.json',
#  'new_parsed_files/perda/2014/perda_kabupaten_karawang_nomor_12_tahun_2014_11e586907aaaabae811c313031373539.json',
#  'new_parsed_files/perda/2013/perda_kabupaten_rokan_hulu_nomor_2_tahun_2013_11e568b63946532c894d313033323335.json',
#  'new_parsed_files/perda/2012/perda_kota_bandung_nomor_10_tahun_2012_11e57639e0be146a8fe4313531373436.json',
#  'new_parsed_files/bn/2015/bn1120-2015.json',
#  'new_parsed_files/bn/2011/bn388-2011.json',
#  'new_parsed_files/bn/2017/bn196-2017.json',
#  'new_parsed_files/bn/2012/bn189-2012.json',
#  'new_parsed_files/bn/2010/bn10-2010.json',
#  'new_parsed_files/bn/2015/bn1831-2015.json',
#  'new_parsed_files/bn/2017/bn1772-2017.json',
#  'new_parsed_files/bn/2013/bn1417-2013.json',
#  'new_parsed_files/bn/2014/bn678-2014.json',
#  'new_parsed_files/bn/2015/bn1432-2015.json',
#  'new_parsed_files/bn/2013/bn1098-2013.json',
#  'new_parsed_files/perda/2014/perda_no_1_tahun_2014.json']

# %%
duplicates = merged_df['regulatory'].value_counts()[lambda x: x > 1].index
filtered_merged_df = merged_df[merged_df['regulatory'].isin(duplicates)]
filtered_merged_df
# Out:
#                                               regulatory  \
# 10     PB_MA_Menhumham_Menkes_Mensos_Jagung_Kapolri_B...
# 11     PB_MA_Menhumham_Menkes_Mensos_Jagung_Kapolri_B...
# 39                           PERKAB_BANGKA_TENGAH_2011_2
# 40                           PERKAB_BANGKA_TENGAH_2011_2
# 45                                  PERKAB_BANTUL_2001_4
# ...                                                  ...
# 24772                                          UU_1990_8
# 24843                                         UU_1997_12
# 24844                                         UU_1997_12
# 25110                                         UU_2005_13
# 25111                                         UU_2005_13
#
#                                                 file_ttl  \
# 10               new_turtle_files/bn/2014/bn465-2014.ttl
# 11               new_turtle_files/bn/2014/bn465-2014.ttl
# 39     new_turtle_files/perda/2011/perda_kabupaten_ba...
# 40     new_turtle_files/perda/2011/perda_kabupaten_ba...
# 45     new_turtle_files/perda/2001/perda_kabupaten_ba...
# ...                                                  ...
# 24772              new_turtle_files/ln/1990/uu9-1990.ttl
# 24843             new_turtle_files/ln/1997/uu11-1997.ttl
# 24844             new_turtle_files/ln/1997/uu11-1997.ttl
# 25110             new_turtle_files/ln/2005/uu13-2005.ttl
# 25111             new_turtle_files/ln/2005/uu13-2005.ttl
#
#                                                 ttl_file  \
# 10                   turtle_files/ln/2014/ps103-2014.ttl
# 11                   turtle_files/ln/2014/ps103-2014.ttl
# 39     turtle_files/perda/2011/perda_kabupaten_bangka...
# 40     turtle_files/perda/2011/perda_kabupaten_bangka...
# 45     turtle_files/perda/2001/perda_kabupaten_solok_...
# ...                                                  ...
# 24772                 turtle_files/ln/1990/pp14-1990.ttl
# 24843                 turtle_files/ln/1997/pp16-1997.ttl
# 24844                 turtle_files/ln/1997/pp16-1997.ttl
# 25110                 turtle_files/ln/2005/pp18-2005.ttl
# 25111                 turtle_files/ln/2005/pp18-2005.ttl
#
#                                                 file_txt  \
# 10            new_1_text_files/bn/2014/pb_bn465-2014.txt
# 11               new_1_text_files/bn/2014/bn465-2014.txt
# 39     new_1_text_files/perda/2011/perda_kabupaten_ba...
# 40     new_1_text_files/perda/2011/perda_kabupaten_ba...
# 45     new_1_text_files/perda/2001/perda_kabupaten_ba...
# ...                                                  ...
# 24772              new_1_text_files/ln/1990/uu9-1990.txt
# 24843             new_1_text_files/ln/1997/uu12-1997.txt
# 24844             new_1_text_files/ln/1997/uu11-1997.txt
# 25110             new_1_text_files/ln/2006/uu14-2006.txt
# 25111             new_1_text_files/ln/2005/uu13-2005.txt
#
#                                                file_json
# 10           new_parsed_files/bn/2014/pb_bn465-2014.json
# 11              new_parsed_files/bn/2014/bn465-2014.json
# 39     new_parsed_files/perda/2011/perda_kabupaten_ba...
# 40     new_parsed_files/perda/2011/perda_kabupaten_ba...
# 45     new_parsed_files/perda/2001/perda_kabupaten_ba...
# ...                                                  ...
# 24772             new_parsed_files/ln/1990/uu9-1990.json
# 24843            new_parsed_files/ln/1997/uu12-1997.json
# 24844            new_parsed_files/ln/1997/uu11-1997.json
# 25110            new_parsed_files/ln/2006/uu14-2006.json
# 25111            new_parsed_files/ln/2005/uu13-2005.json
#
# [1110 rows x 5 columns]

# %%
duplicates = merged_df['regulatory'].value_counts()[lambda x: x > 1].index
filtered_merged_df = merged_df[~merged_df['regulatory'].isin(duplicates)]
filtered_merged_df
# Out:
#                  regulatory  \
# 0      Amandemen_1_UUD_1945
# 1      Amandemen_2_UUD_1945
# 2      Amandemen_3_UUD_1945
# 3      Amandemen_4_UUD_1945
# 4      Kepmen_Hut_2002_8171
# ...                     ...
# 25449             UU_2019_4
# 25450             UU_2019_5
# 25451             UU_2019_7
# 25452             UU_2019_8
# 25453             UU_2019_9
#
#                                                 file_ttl  \
# 0      new_turtle_files/lain-lain/1945/uud1945perubah...
# 1      new_turtle_files/lain-lain/1945/uud1945perubah...
# 2      new_turtle_files/lain-lain/1945/uud1945perubah...
# 3      new_turtle_files/lain-lain/1945/uud1945perubah...
# 4                 new_turtle_files/bn/2008/bn23-2008.ttl
# ...                                                  ...
# 25449            new_turtle_files/ln/2019/uu4-2019bt.ttl
# 25450            new_turtle_files/ln/2019/uu5-2019bt.ttl
# 25451            new_turtle_files/ln/2019/uu7-2019bt.ttl
# 25452            new_turtle_files/ln/2019/uu8-2019bt.ttl
# 25453            new_turtle_files/ln/2019/uu9-2019bt.ttl
#
#                                     ttl_file  \
# 0        turtle_files/bn/2015/bn270-2015.ttl
# 1        turtle_files/bn/2015/bn270-2015.ttl
# 2        turtle_files/bn/2015/bn270-2015.ttl
# 3        turtle_files/bn/2015/bn270-2015.ttl
# 4         turtle_files/bn/2008/bn29-2008.ttl
# ...                                      ...
# 25449  turtle_files/bn/2019/bn_1235-2019.ttl
# 25450    turtle_files/ln/2019/pp8-2019bt.ttl
# 25451    turtle_files/bn/2019/bn662-2019.ttl
# 25452   turtle_files/bn/2019/bn_567-2019.ttl
# 25453    turtle_files/bn/2019/bn639-2019.ttl
#
#                                                 file_txt  \
# 0      new_1_text_files/lain-lain/1945/uud1945perubah...
# 1      new_1_text_files/lain-lain/1945/uud1945perubah...
# 2      new_1_text_files/lain-lain/1945/uud1945perubah...
# 3      new_1_text_files/lain-lain/1945/uud1945perubah...
# 4                 new_1_text_files/bn/2008/bn23-2008.txt
# ...                                                  ...
# 25449            new_1_text_files/ln/2019/uu4-2019bt.txt
# 25450            new_1_text_files/ln/2019/uu5-2019bt.txt
# 25451            new_1_text_files/ln/2019/uu7-2019bt.txt
# 25452            new_1_text_files/ln/2019/uu8-2019bt.txt
# 25453            new_1_text_files/ln/2019/uu9-2019bt.txt
#
#                                                file_json
# 0      new_parsed_files/lain-lain/1945/uud1945perubah...
# 1      new_parsed_files/lain-lain/1945/uud1945perubah...
# 2      new_parsed_files/lain-lain/1945/uud1945perubah...
# 3      new_parsed_files/lain-lain/1945/uud1945perubah...
# 4                new_parsed_files/bn/2008/bn23-2008.json
# ...                                                  ...
# 25449           new_parsed_files/ln/2019/uu4-2019bt.json
# 25450           new_parsed_files/ln/2019/uu5-2019bt.json
# 25451           new_parsed_files/ln/2019/uu7-2019bt.json
# 25452           new_parsed_files/ln/2019/uu8-2019bt.json
# 25453           new_parsed_files/ln/2019/uu9-2019bt.json
#
# [24344 rows x 5 columns]

# %%
filtered_merged_df = filtered_merged_df[~filtered_merged_df['file_json'].isin(error_files)]
filtered_merged_df
# Out:
#                  regulatory  \
# 0      Amandemen_1_UUD_1945
# 1      Amandemen_2_UUD_1945
# 2      Amandemen_3_UUD_1945
# 3      Amandemen_4_UUD_1945
# 4      Kepmen_Hut_2002_8171
# ...                     ...
# 25449             UU_2019_4
# 25450             UU_2019_5
# 25451             UU_2019_7
# 25452             UU_2019_8
# 25453             UU_2019_9
#
#                                                 file_ttl  \
# 0      new_turtle_files/lain-lain/1945/uud1945perubah...
# 1      new_turtle_files/lain-lain/1945/uud1945perubah...
# 2      new_turtle_files/lain-lain/1945/uud1945perubah...
# 3      new_turtle_files/lain-lain/1945/uud1945perubah...
# 4                 new_turtle_files/bn/2008/bn23-2008.ttl
# ...                                                  ...
# 25449            new_turtle_files/ln/2019/uu4-2019bt.ttl
# 25450            new_turtle_files/ln/2019/uu5-2019bt.ttl
# 25451            new_turtle_files/ln/2019/uu7-2019bt.ttl
# 25452            new_turtle_files/ln/2019/uu8-2019bt.ttl
# 25453            new_turtle_files/ln/2019/uu9-2019bt.ttl
#
#                                     ttl_file  \
# 0        turtle_files/bn/2015/bn270-2015.ttl
# 1        turtle_files/bn/2015/bn270-2015.ttl
# 2        turtle_files/bn/2015/bn270-2015.ttl
# 3        turtle_files/bn/2015/bn270-2015.ttl
# 4         turtle_files/bn/2008/bn29-2008.ttl
# ...                                      ...
# 25449  turtle_files/bn/2019/bn_1235-2019.ttl
# 25450    turtle_files/ln/2019/pp8-2019bt.ttl
# 25451    turtle_files/bn/2019/bn662-2019.ttl
# 25452   turtle_files/bn/2019/bn_567-2019.ttl
# 25453    turtle_files/bn/2019/bn639-2019.ttl
#
#                                                 file_txt  \
# 0      new_1_text_files/lain-lain/1945/uud1945perubah...
# 1      new_1_text_files/lain-lain/1945/uud1945perubah...
# 2      new_1_text_files/lain-lain/1945/uud1945perubah...
# 3      new_1_text_files/lain-lain/1945/uud1945perubah...
# 4                 new_1_text_files/bn/2008/bn23-2008.txt
# ...                                                  ...
# 25449            new_1_text_files/ln/2019/uu4-2019bt.txt
# 25450            new_1_text_files/ln/2019/uu5-2019bt.txt
# 25451            new_1_text_files/ln/2019/uu7-2019bt.txt
# 25452            new_1_text_files/ln/2019/uu8-2019bt.txt
# 25453            new_1_text_files/ln/2019/uu9-2019bt.txt
#
#                                                file_json
# 0      new_parsed_files/lain-lain/1945/uud1945perubah...
# 1      new_parsed_files/lain-lain/1945/uud1945perubah...
# 2      new_parsed_files/lain-lain/1945/uud1945perubah...
# 3      new_parsed_files/lain-lain/1945/uud1945perubah...
# 4                new_parsed_files/bn/2008/bn23-2008.json
# ...                                                  ...
# 25449           new_parsed_files/ln/2019/uu4-2019bt.json
# 25450           new_parsed_files/ln/2019/uu5-2019bt.json
# 25451           new_parsed_files/ln/2019/uu7-2019bt.json
# 25452           new_parsed_files/ln/2019/uu8-2019bt.json
# 25453           new_parsed_files/ln/2019/uu9-2019bt.json
#
# [24331 rows x 5 columns]

# %%
null_counts = filtered_merged_df.isnull().sum()
print("Count of null values for each column:")
print(null_counts)
# Out:
# Count of null values for each column:
# regulatory    0
# file_ttl      0
# ttl_file      0
# file_txt      1
# file_json     1
# dtype: int64

# %%
filtered_merged_df = filtered_merged_df[filtered_merged_df['file_json'].isin(error_files)]
filtered_merged_df
# Out:
#                    regulatory  \
# 284                PP_1960_27
# 563                 PP_1970_6
# 3082     Peraturan_BI_2016_18
# 4033   Peraturan_BPOM_2010_03
# 4061   Peraturan_BPOM_2011_03
# 4068   Peraturan_BPOM_2012_03
# 4071   Peraturan_BPOM_2012_03
# 4072   Peraturan_BPOM_2012_03
# 8755       Perkab_Siak_2013_2
# 12286     Permen_Dagri_2017_4
# 14767   Permen_Humham_2010_01
# 21658      Permen_Tan_2011_20
# 21681      Permen_Tan_2011_93
# 21773      Permen_Tan_2013_85
#
#                                                 file_ttl  \
# 284               new_turtle_files/ln/1962/pp0271962.ttl
# 563               new_turtle_files/ln/1970/pp0461970.ttl
# 3082        new_turtle_files/ln/2016/pbi18-40-2016bt.ttl
# 4033             new_turtle_files/bn/2010/bn470-2010.ttl
# 4061             new_turtle_files/bn/2011/bn393-2011.ttl
# 4068             new_turtle_files/bn/2013/bn122-2013.ttl
# 4071             new_turtle_files/bn/2013/bn122-2013.ttl
# 4072             new_turtle_files/bn/2013/bn122-2013.ttl
# 8755   new_turtle_files/perda/2013/perda_kabupaten_si...
# 12286            new_turtle_files/bn/2018/bn173-2018.ttl
# 14767             new_turtle_files/bn/2010/bn12-2010.ttl
# 21658            new_turtle_files/bn/2011/bn180-2011.ttl
# 21681              new_turtle_files/bn/2012/bn6-2012.ttl
# 21773           new_turtle_files/bn/2013/bn1070-2013.ttl
#
#                                                 ttl_file  \
# 284                   turtle_files/ln/1960/pp0441960.ttl
# 563                   turtle_files/ln/1970/pp0551970.ttl
# 3082                 turtle_files/bn/2017/bn219-2017.ttl
# 4033                 turtle_files/bn/2010/bn735-2010.ttl
# 4061                  turtle_files/bn/2011/bn40-2011.ttl
# 4068                 turtle_files/bn/2012/bn397-2012.ttl
# 4071                 turtle_files/bn/2012/bn397-2012.ttl
# 4072                 turtle_files/bn/2012/bn397-2012.ttl
# 8755   turtle_files/perda/2013/perda_kabupaten_rokan_...
# 12286                turtle_files/bn/2018/bn186-2018.ttl
# 14767                 turtle_files/bn/2010/bn96-2010.ttl
# 21658                turtle_files/bn/2011/bn180-2011.ttl
# 21681                turtle_files/bn/2013/bn246-2013.ttl
# 21773               turtle_files/bn/2013/bn1171-2013.ttl
#
#                                                 file_txt  \
# 284               new_1_text_files/ln/1960/pp0271960.txt
# 563               new_1_text_files/ln/1970/pp0061970.txt
# 3082         new_1_text_files/ln/2016/pbi18-6-2016bt.txt
# 4033             new_1_text_files/bn/2010/bn361-2010.txt
# 4061             new_1_text_files/bn/2011/bn808-2011.txt
# 4068             new_1_text_files/bn/2012/bn470-2012.txt
# 4071             new_1_text_files/bn/2012/bn623-2012.txt
# 4072             new_1_text_files/bn/2012/bn471-2012.txt
# 8755   new_1_text_files/perda/2013/perda_kabupaten_ro...
# 12286            new_1_text_files/bn/2017/bn196-2017.txt
# 14767             new_1_text_files/bn/2010/bn10-2010.txt
# 21658            new_1_text_files/bn/2014/bn678-2014.txt
# 21681           new_1_text_files/bn/2015/bn1432-2015.txt
# 21773           new_1_text_files/bn/2013/bn1098-2013.txt
#
#                                                file_json
# 284              new_parsed_files/ln/1960/pp0271960.json
# 563              new_parsed_files/ln/1970/pp0061970.json
# 3082        new_parsed_files/ln/2016/pbi18-6-2016bt.json
# 4033            new_parsed_files/bn/2010/bn361-2010.json
# 4061            new_parsed_files/bn/2011/bn808-2011.json
# 4068            new_parsed_files/bn/2012/bn470-2012.json
# 4071            new_parsed_files/bn/2012/bn623-2012.json
# 4072            new_parsed_files/bn/2012/bn471-2012.json
# 8755   new_parsed_files/perda/2013/perda_kabupaten_ro...
# 12286           new_parsed_files/bn/2017/bn196-2017.json
# 14767            new_parsed_files/bn/2010/bn10-2010.json
# 21658           new_parsed_files/bn/2014/bn678-2014.json
# 21681          new_parsed_files/bn/2015/bn1432-2015.json
# 21773          new_parsed_files/bn/2013/bn1098-2013.json

# %%
duplicates = merged_df['regulatory'].value_counts()[lambda x: x > 1].index
filtered_merged_df = merged_df[~merged_df['regulatory'].isin(duplicates)]
filtered_merged_df = filtered_merged_df[~filtered_merged_df['file_json'].isin(error_files)]
filtered_merged_df.dropna(inplace=True)
filtered_merged_df.reset_index(drop=True)
# Out:
#                  regulatory  \
# 0      Amandemen_1_UUD_1945
# 1      Amandemen_2_UUD_1945
# 2      Amandemen_3_UUD_1945
# 3      Amandemen_4_UUD_1945
# 4      Kepmen_Hut_2002_8171
# ...                     ...
# 24325             UU_2019_4
# 24326             UU_2019_5
# 24327             UU_2019_7
# 24328             UU_2019_8
# 24329             UU_2019_9
#
#                                                 file_ttl  \
# 0      new_turtle_files/lain-lain/1945/uud1945perubah...
# 1      new_turtle_files/lain-lain/1945/uud1945perubah...
# 2      new_turtle_files/lain-lain/1945/uud1945perubah...
# 3      new_turtle_files/lain-lain/1945/uud1945perubah...
# 4                 new_turtle_files/bn/2008/bn23-2008.ttl
# ...                                                  ...
# 24325            new_turtle_files/ln/2019/uu4-2019bt.ttl
# 24326            new_turtle_files/ln/2019/uu5-2019bt.ttl
# 24327            new_turtle_files/ln/2019/uu7-2019bt.ttl
# 24328            new_turtle_files/ln/2019/uu8-2019bt.ttl
# 24329            new_turtle_files/ln/2019/uu9-2019bt.ttl
#
#                                     ttl_file  \
# 0        turtle_files/bn/2015/bn270-2015.ttl
# 1        turtle_files/bn/2015/bn270-2015.ttl
# 2        turtle_files/bn/2015/bn270-2015.ttl
# 3        turtle_files/bn/2015/bn270-2015.ttl
# 4         turtle_files/bn/2008/bn29-2008.ttl
# ...                                      ...
# 24325  turtle_files/bn/2019/bn_1235-2019.ttl
# 24326    turtle_files/ln/2019/pp8-2019bt.ttl
# 24327    turtle_files/bn/2019/bn662-2019.ttl
# 24328   turtle_files/bn/2019/bn_567-2019.ttl
# 24329    turtle_files/bn/2019/bn639-2019.ttl
#
#                                                 file_txt  \
# 0      new_1_text_files/lain-lain/1945/uud1945perubah...
# 1      new_1_text_files/lain-lain/1945/uud1945perubah...
# 2      new_1_text_files/lain-lain/1945/uud1945perubah...
# 3      new_1_text_files/lain-lain/1945/uud1945perubah...
# 4                 new_1_text_files/bn/2008/bn23-2008.txt
# ...                                                  ...
# 24325            new_1_text_files/ln/2019/uu4-2019bt.txt
# 24326            new_1_text_files/ln/2019/uu5-2019bt.txt
# 24327            new_1_text_files/ln/2019/uu7-2019bt.txt
# 24328            new_1_text_files/ln/2019/uu8-2019bt.txt
# 24329            new_1_text_files/ln/2019/uu9-2019bt.txt
#
#                                                file_json
# 0      new_parsed_files/lain-lain/1945/uud1945perubah...
# 1      new_parsed_files/lain-lain/1945/uud1945perubah...
# 2      new_parsed_files/lain-lain/1945/uud1945perubah...
# 3      new_parsed_files/lain-lain/1945/uud1945perubah...
# 4                new_parsed_files/bn/2008/bn23-2008.json
# ...                                                  ...
# 24325           new_parsed_files/ln/2019/uu4-2019bt.json
# 24326           new_parsed_files/ln/2019/uu5-2019bt.json
# 24327           new_parsed_files/ln/2019/uu7-2019bt.json
# 24328           new_parsed_files/ln/2019/uu8-2019bt.json
# 24329           new_parsed_files/ln/2019/uu9-2019bt.json
#
# [24330 rows x 5 columns]

# %%
filtered_merged_df.to_csv("core/regulatory_map_fin.csv", index=False)

# %% [markdown]
# # Ingest Turtle File (Surface Info) Into Regulatory Map

# %%
df = pd.read_csv('core/regulatory_map_fin.csv')
df
# Out:
#                  regulatory  \
# 0      Amandemen_1_UUD_1945
# 1      Amandemen_2_UUD_1945
# 2      Amandemen_3_UUD_1945
# 3      Amandemen_4_UUD_1945
# 4      Kepmen_Hut_2002_8171
# ...                     ...
# 24325             UU_2019_4
# 24326             UU_2019_5
# 24327             UU_2019_7
# 24328             UU_2019_8
# 24329             UU_2019_9
#
#                                                 file_ttl  \
# 0      new_turtle_files/lain-lain/1945/uud1945perubah...
# 1      new_turtle_files/lain-lain/1945/uud1945perubah...
# 2      new_turtle_files/lain-lain/1945/uud1945perubah...
# 3      new_turtle_files/lain-lain/1945/uud1945perubah...
# 4                 new_turtle_files/bn/2008/bn23-2008.ttl
# ...                                                  ...
# 24325            new_turtle_files/ln/2019/uu4-2019bt.ttl
# 24326            new_turtle_files/ln/2019/uu5-2019bt.ttl
# 24327            new_turtle_files/ln/2019/uu7-2019bt.ttl
# 24328            new_turtle_files/ln/2019/uu8-2019bt.ttl
# 24329            new_turtle_files/ln/2019/uu9-2019bt.ttl
#
#                                     ttl_file  \
# 0        turtle_files/bn/2015/bn270-2015.ttl
# 1        turtle_files/bn/2015/bn270-2015.ttl
# 2        turtle_files/bn/2015/bn270-2015.ttl
# 3        turtle_files/bn/2015/bn270-2015.ttl
# 4         turtle_files/bn/2008/bn29-2008.ttl
# ...                                      ...
# 24325  turtle_files/bn/2019/bn_1235-2019.ttl
# 24326    turtle_files/ln/2019/pp8-2019bt.ttl
# 24327    turtle_files/bn/2019/bn662-2019.ttl
# 24328   turtle_files/bn/2019/bn_567-2019.ttl
# 24329    turtle_files/bn/2019/bn639-2019.ttl
#
#                                                 file_txt  \
# 0      new_1_text_files/lain-lain/1945/uud1945perubah...
# 1      new_1_text_files/lain-lain/1945/uud1945perubah...
# 2      new_1_text_files/lain-lain/1945/uud1945perubah...
# 3      new_1_text_files/lain-lain/1945/uud1945perubah...
# 4                 new_1_text_files/bn/2008/bn23-2008.txt
# ...                                                  ...
# 24325            new_1_text_files/ln/2019/uu4-2019bt.txt
# 24326            new_1_text_files/ln/2019/uu5-2019bt.txt
# 24327            new_1_text_files/ln/2019/uu7-2019bt.txt
# 24328            new_1_text_files/ln/2019/uu8-2019bt.txt
# 24329            new_1_text_files/ln/2019/uu9-2019bt.txt
#
#                                                file_json
# 0      new_parsed_files/lain-lain/1945/uud1945perubah...
# 1      new_parsed_files/lain-lain/1945/uud1945perubah...
# 2      new_parsed_files/lain-lain/1945/uud1945perubah...
# 3      new_parsed_files/lain-lain/1945/uud1945perubah...
# 4                new_parsed_files/bn/2008/bn23-2008.json
# ...                                                  ...
# 24325           new_parsed_files/ln/2019/uu4-2019bt.json
# 24326           new_parsed_files/ln/2019/uu5-2019bt.json
# 24327           new_parsed_files/ln/2019/uu7-2019bt.json
# 24328           new_parsed_files/ln/2019/uu8-2019bt.json
# 24329           new_parsed_files/ln/2019/uu9-2019bt.json
#
# [24330 rows x 5 columns]

# %%
with open('error2.txt', 'r') as file:
    error_files = file.read().splitlines()
    
error_files
# Out:
# ['UU_2007_39 new_turtle_files/ln/2007/uu39-2007.ttl',
#  'UU_2001_20 new_turtle_files/ln/2001/uu20-2001.ttl',
#  'Perprov_Sumsel_2014_1 new_turtle_files/perda/2014/perda_provinsi_sumatera_selatan_nomor_1_tahun_2014_11e4e8bf8e941cdca11c313431363535.ttl',
#  'Perprov_Sumsel_2011_2 new_turtle_files/perda/2011/perda_provinsi_sumatera_selatan_nomor_2_tahun_2011_11e452bda17a20c08e56313634353133.ttl',
#  'Perprov_Sumbar_2011_12 new_turtle_files/perda/2011/perda_provinsi_sumatera_barat_nomor_12_tahun_2011_11e452bdaac74430adee313634353239.ttl',
#  'Perprov_Banten_2009_3 new_turtle_files/perda/2009/perda_provinsi_banten_nomor_3_tahun_2009_11e452bd826b2d80b2fa313634343231.ttl',
#  'Permen_Keu_2019_87 new_turtle_files/bn/2019/bn641-2019.ttl',
#  'Permen_Keu_2010_165 new_turtle_files/bn/2010/bn442-2010.ttl',
#  'Permen_Keu_2009_178 new_turtle_files/bn/2009/bn434-2009.ttl',
#  'Permen_KP_2012_20 new_turtle_files/bn/2012/bn1033-2012.ttl',
#  'Permen_Hut_2012_33 new_turtle_files/bn/2012/bn779-2012.ttl',
#  'Permen_Humham_2016_67 new_turtle_files/bn/2016/bn2134-2016.ttl',
#  'Permen_Humham_2014_27 new_turtle_files/bn/2014/bn1697-2014.ttl',
#  'Permen_Hub_2015_187 new_turtle_files/bn/2015/bn1825-2015.ttl',
#  'Permen_ESDM_2015_43 new_turtle_files/bn/2015/bn2014-2015.ttl',
#  'Permen_Dag_2009_21 new_turtle_files/bn/2009/bn205-2009.ttl',
#  'Permen_Agama_2015_59 new_turtle_files/bn/2015/bn1390-2015.ttl',
#  'Permen_Agama_2012_13 new_turtle_files/bn/2012/bn851-2012.ttl',
#  'Permen_Agama_2011_8 new_turtle_files/bn/2011/bn269-2011.ttl',
#  'Permen_Agama_2011_16 new_turtle_files/bn/2011/bn277-2011.ttl',
#  'Permen_Agama_2007_30 new_turtle_files/bn/2007/bn35-2007.ttl',
#  'Permen_Agama_2007_29 new_turtle_files/bn/2007/bn34-2007.ttl',
#  'Permen_Agama_2007_28 new_turtle_files/bn/2007/bn33-2007.ttl',
#  'Permen_Agama_2007_27 new_turtle_files/bn/2007/bn32-2007.ttl',
#  'Perkot_Tasikmalaya_2007_3 new_turtle_files/perda/2007/perda_kota_tasikmalaya_nomor_3_tahun_2007_11e452bd41e93850920e313634323333.ttl',
#  'Perkot_Depok_2009_2 new_turtle_files/perda/2009/perda_kota_depok_nomor_2_tahun_2009_11e452bd806fdcb08003313634343138.ttl',
#  'Perkab_Sleman_2013_1 new_turtle_files/perda/2013/perda_kabupaten_sleman_nomor_1_tahun_2013_tahun_2013_11e6c5b100f7a4208c15313330343239.ttl',
#  'Perkab_Sinjai_2012_35 new_turtle_files/perda/2012/perda_kabupaten_sinjai_nomor_35_tahun_2012_11e540995f8facdab1ba303932353138.ttl',
#  'Perkab_Purbalingga_2012_14 new_turtle_files/perda/2012/perda_kabupaten_purbalingga_nomor_14_tahun_2012_11e56c94dcd3d6fea55e303834333532.ttl',
#  'Perkab_Magelang_2010_15 new_turtle_files/perda/2010/perda_kabupaten_magelang_nomor_15_tahun_2010_11e452bd9e1b4110be55313634353038.ttl',
#  'Perkab_Jepara_2012_2 new_turtle_files/perda/2012/perda_kabupaten_jepara_nomor_2_tahun_2012_11e5415c689a39eebc24303834313235.ttl',
#  'Perkab_Jepara_2010_9 new_turtle_files/perda/2010/perda_kabupaten_jepara_nomor_9_tahun_2010_11e539a511a343609c81313330313233.ttl',
#  'Perkab_Garut_2012_11 new_turtle_files/perda/2012/perda_kabupaten_garut_nomor_11_tahun_2012_11e56ca60660dfec8c07313034363433.ttl',
#  'Perkab_Bantul_2007_08 new_turtle_files/perda/2007/perda_kabupaten_bantul_nomor_8_tahun_2007_11e452bd46d22d00bc00313634323431.ttl',
#  'Perkab_Bantul_2001_23 new_turtle_files/perda/2001/perda_kabupaten_bantul_nomor_23_tahun_2001_11e452bd042b5180925e313634303439.ttl',
#  'Perkab_Banggai_2009_9 new_turtle_files/perda/2009/perda_kabupaten_banggai_nomor_9_tahun_2009_11e577cea78532fabc65313533353136.ttl',
#  'PP_1983_13 new_turtle_files/ln/1983/pp13-1983.ttl']

# %%
error_files = [error.split(' ')[0] for error in error_files]
error_files
# Out:
# ['UU_2007_39',
#  'UU_2001_20',
#  'Perprov_Sumsel_2014_1',
#  'Perprov_Sumsel_2011_2',
#  'Perprov_Sumbar_2011_12',
#  'Perprov_Banten_2009_3',
#  'Permen_Keu_2019_87',
#  'Permen_Keu_2010_165',
#  'Permen_Keu_2009_178',
#  'Permen_KP_2012_20',
#  'Permen_Hut_2012_33',
#  'Permen_Humham_2016_67',
#  'Permen_Humham_2014_27',
#  'Permen_Hub_2015_187',
#  'Permen_ESDM_2015_43',
#  'Permen_Dag_2009_21',
#  'Permen_Agama_2015_59',
#  'Permen_Agama_2012_13',
#  'Permen_Agama_2011_8',
#  'Permen_Agama_2011_16',
#  'Permen_Agama_2007_30',
#  'Permen_Agama_2007_29',
#  'Permen_Agama_2007_28',
#  'Permen_Agama_2007_27',
#  'Perkot_Tasikmalaya_2007_3',
#  'Perkot_Depok_2009_2',
#  'Perkab_Sleman_2013_1',
#  'Perkab_Sinjai_2012_35',
#  'Perkab_Purbalingga_2012_14',
#  'Perkab_Magelang_2010_15',
#  'Perkab_Jepara_2012_2',
#  'Perkab_Jepara_2010_9',
#  'Perkab_Garut_2012_11',
#  'Perkab_Bantul_2007_08',
#  'Perkab_Bantul_2001_23',
#  'Perkab_Banggai_2009_9',
#  'PP_1983_13']

# %%
df = df[~df['regulatory'].isin(error_files)]
df.dropna(inplace=True)
df.reset_index(drop=True)
# Out:
# /tmp/ipykernel_42700/373013890.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
#                  regulatory  \
# 0      Amandemen_1_UUD_1945
# 1      Amandemen_2_UUD_1945
# 2      Amandemen_3_UUD_1945
# 3      Amandemen_4_UUD_1945
# 4      Kepmen_Hut_2002_8171
# ...                     ...
# 24288             UU_2019_4
# 24289             UU_2019_5
# 24290             UU_2019_7
# 24291             UU_2019_8
# 24292             UU_2019_9
#
#                                                 file_ttl  \
# 0      new_turtle_files/lain-lain/1945/uud1945perubah...
# 1      new_turtle_files/lain-lain/1945/uud1945perubah...
# 2      new_turtle_files/lain-lain/1945/uud1945perubah...
# 3      new_turtle_files/lain-lain/1945/uud1945perubah...
# 4                 new_turtle_files/bn/2008/bn23-2008.ttl
# ...                                                  ...
# 24288            new_turtle_files/ln/2019/uu4-2019bt.ttl
# 24289            new_turtle_files/ln/2019/uu5-2019bt.ttl
# 24290            new_turtle_files/ln/2019/uu7-2019bt.ttl
# 24291            new_turtle_files/ln/2019/uu8-2019bt.ttl
# 24292            new_turtle_files/ln/2019/uu9-2019bt.ttl
#
#                                     ttl_file  \
# 0        turtle_files/bn/2015/bn270-2015.ttl
# 1        turtle_files/bn/2015/bn270-2015.ttl
# 2        turtle_files/bn/2015/bn270-2015.ttl
# 3        turtle_files/bn/2015/bn270-2015.ttl
# 4         turtle_files/bn/2008/bn29-2008.ttl
# ...                                      ...
# 24288  turtle_files/bn/2019/bn_1235-2019.ttl
# 24289    turtle_files/ln/2019/pp8-2019bt.ttl
# 24290    turtle_files/bn/2019/bn662-2019.ttl
# 24291   turtle_files/bn/2019/bn_567-2019.ttl
# 24292    turtle_files/bn/2019/bn639-2019.ttl
#
#                                                 file_txt  \
# 0      new_1_text_files/lain-lain/1945/uud1945perubah...
# 1      new_1_text_files/lain-lain/1945/uud1945perubah...
# 2      new_1_text_files/lain-lain/1945/uud1945perubah...
# 3      new_1_text_files/lain-lain/1945/uud1945perubah...
# 4                 new_1_text_files/bn/2008/bn23-2008.txt
# ...                                                  ...
# 24288            new_1_text_files/ln/2019/uu4-2019bt.txt
# 24289            new_1_text_files/ln/2019/uu5-2019bt.txt
# 24290            new_1_text_files/ln/2019/uu7-2019bt.txt
# 24291            new_1_text_files/ln/2019/uu8-2019bt.txt
# 24292            new_1_text_files/ln/2019/uu9-2019bt.txt
#
#                                                file_json
# 0      new_parsed_files/lain-lain/1945/uud1945perubah...
# 1      new_parsed_files/lain-lain/1945/uud1945perubah...
# 2      new_parsed_files/lain-lain/1945/uud1945perubah...
# 3      new_parsed_files/lain-lain/1945/uud1945perubah...
# 4                new_parsed_files/bn/2008/bn23-2008.json
# ...                                                  ...
# 24288           new_parsed_files/ln/2019/uu4-2019bt.json
# 24289           new_parsed_files/ln/2019/uu5-2019bt.json
# 24290           new_parsed_files/ln/2019/uu7-2019bt.json
# 24291           new_parsed_files/ln/2019/uu8-2019bt.json
# 24292           new_parsed_files/ln/2019/uu9-2019bt.json
#
# [24293 rows x 5 columns]

# %%
def replace_strings_with_regex(string):
    pattern = r'(?P<root>new_turtle_files)'
    modified_string = re.sub(pattern, 'new_2_turtle_files', string)
    return modified_string

# %%
df['file_ttl'] = df['file_ttl'].apply(lambda x: replace_strings_with_regex(x))
df
# Out:
# /tmp/ipykernel_42700/2314662197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['file_ttl'] = df['file_ttl'].apply(lambda x: replace_strings_with_regex(x))
#                  regulatory  \
# 0      Amandemen_1_UUD_1945
# 1      Amandemen_2_UUD_1945
# 2      Amandemen_3_UUD_1945
# 3      Amandemen_4_UUD_1945
# 4      Kepmen_Hut_2002_8171
# ...                     ...
# 24325             UU_2019_4
# 24326             UU_2019_5
# 24327             UU_2019_7
# 24328             UU_2019_8
# 24329             UU_2019_9
#
#                                                 file_ttl  \
# 0      new_2_turtle_files/lain-lain/1945/uud1945perub...
# 1      new_2_turtle_files/lain-lain/1945/uud1945perub...
# 2      new_2_turtle_files/lain-lain/1945/uud1945perub...
# 3      new_2_turtle_files/lain-lain/1945/uud1945perub...
# 4               new_2_turtle_files/bn/2008/bn23-2008.ttl
# ...                                                  ...
# 24325          new_2_turtle_files/ln/2019/uu4-2019bt.ttl
# 24326          new_2_turtle_files/ln/2019/uu5-2019bt.ttl
# 24327          new_2_turtle_files/ln/2019/uu7-2019bt.ttl
# 24328          new_2_turtle_files/ln/2019/uu8-2019bt.ttl
# 24329          new_2_turtle_files/ln/2019/uu9-2019bt.ttl
#
#                                     ttl_file  \
# 0        turtle_files/bn/2015/bn270-2015.ttl
# 1        turtle_files/bn/2015/bn270-2015.ttl
# 2        turtle_files/bn/2015/bn270-2015.ttl
# 3        turtle_files/bn/2015/bn270-2015.ttl
# 4         turtle_files/bn/2008/bn29-2008.ttl
# ...                                      ...
# 24325  turtle_files/bn/2019/bn_1235-2019.ttl
# 24326    turtle_files/ln/2019/pp8-2019bt.ttl
# 24327    turtle_files/bn/2019/bn662-2019.ttl
# 24328   turtle_files/bn/2019/bn_567-2019.ttl
# 24329    turtle_files/bn/2019/bn639-2019.ttl
#
#                                                 file_txt  \
# 0      new_1_text_files/lain-lain/1945/uud1945perubah...
# 1      new_1_text_files/lain-lain/1945/uud1945perubah...
# 2      new_1_text_files/lain-lain/1945/uud1945perubah...
# 3      new_1_text_files/lain-lain/1945/uud1945perubah...
# 4                 new_1_text_files/bn/2008/bn23-2008.txt
# ...                                                  ...
# 24325            new_1_text_files/ln/2019/uu4-2019bt.txt
# 24326            new_1_text_files/ln/2019/uu5-2019bt.txt
# 24327            new_1_text_files/ln/2019/uu7-2019bt.txt
# 24328            new_1_text_files/ln/2019/uu8-2019bt.txt
# 24329            new_1_text_files/ln/2019/uu9-2019bt.txt
#
#                                                file_json
# 0      new_parsed_files/lain-lain/1945/uud1945perubah...
# 1      new_parsed_files/lain-lain/1945/uud1945perubah...
# 2      new_parsed_files/lain-lain/1945/uud1945perubah...
# 3      new_parsed_files/lain-lain/1945/uud1945perubah...
# 4                new_parsed_files/bn/2008/bn23-2008.json
# ...                                                  ...
# 24325           new_parsed_files/ln/2019/uu4-2019bt.json
# 24326           new_parsed_files/ln/2019/uu5-2019bt.json
# 24327           new_parsed_files/ln/2019/uu7-2019bt.json
# 24328           new_parsed_files/ln/2019/uu8-2019bt.json
# 24329           new_parsed_files/ln/2019/uu9-2019bt.json
#
# [24293 rows x 5 columns]

# %%
df.to_csv("core/regulatory_map_surface_info.csv", index=False)

# %% [markdown]
# # Cek

# %%
d = pd.read_csv('core/regulatory_list.csv')
d = d.drop_duplicates(subset='regulatory', keep=False)

df = pd.read_csv('core/turtle_map.csv')
filtered_df = df[~df['ttl_file'].str.contains('ningg')]
filtered_df
# Out:
#                  regulatory                                           ttl_file
# 0      Amandemen_1_UUD_1945  new_turtle_fileslain-lain1945uud1945perubahanp...
# 1      Amandemen_2_UUD_1945  new_turtle_fileslain-lain1945uud1945perubahank...
# 2      Amandemen_3_UUD_1945  new_turtle_fileslain-lain1945uud1945perubahank...
# 3      Amandemen_4_UUD_1945  new_turtle_fileslain-lain1945uud1945perubahank...
# 4      Kepmen_Hut_2002_8171                new_turtle_filesbn2008bn23-2008.ttl
# ...                     ...                                                ...
# 24968             UU_2019_4               new_turtle_filesln2019uu4-2019bt.ttl
# 24969             UU_2019_5               new_turtle_filesln2019uu5-2019bt.ttl
# 24970             UU_2019_7               new_turtle_filesln2019uu7-2019bt.ttl
# 24971             UU_2019_8               new_turtle_filesln2019uu8-2019bt.ttl
# 24972             UU_2019_9               new_turtle_filesln2019uu9-2019bt.ttl
#
# [24811 rows x 2 columns]

# %%
d = pd.read_csv('core/regulatory_list.csv')
d = d.drop_duplicates(subset='regulatory', keep=False)

df = pd.read_csv('core/turtle_map.csv')
filtered_df = df[~df['ttl_file'].str.contains('ningg')]

d['a'] = d['regulatory'].str.lower()
filtered_df['a'] = filtered_df['regulatory'].str.lower()

merged_df = pd.merge(d, filtered_df, on='a', how='inner')
merged_df = merged_df[['regulatory_x', 'ttl_file']]
merged_df.columns = ['regulatory', 'ttl_file']
merged_df.reset_index(drop=True, inplace=True)
merged_df
# Out:
# /tmp/ipykernel_38547/3915276772.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['a'] = filtered_df['regulatory'].str.lower()
#                   regulatory  \
# 0       Perkab_Bantul_1994_1
# 1      Perkab_Bantul_1994_13
# 2       Perkab_Bantul_1994_5
# 3      Perkab_Bantul_1994_11
# 4       Perkab_Bantul_1994_7
# ...                      ...
# 24338   Amandemen_1_UUD_1945
# 24339   Amandemen_3_UUD_1945
# 24340   Amandemen_4_UUD_1945
# 24341   Amandemen_2_UUD_1945
# 24342               UUD_1945
#
#                                                 ttl_file
# 0      new_turtle_filesperda1994perda_kabupaten_bantu...
# 1      new_turtle_filesperda1994perda_kabupaten_bantu...
# 2      new_turtle_filesperda1994perda_kabupaten_bantu...
# 3      new_turtle_filesperda1994perda_kabupaten_bantu...
# 4      new_turtle_filesperda1994perda_kabupaten_bantu...
# ...                                                  ...
# 24338  new_turtle_fileslain-lain1945uud1945perubahanp...
# 24339  new_turtle_fileslain-lain1945uud1945perubahank...
# 24340  new_turtle_fileslain-lain1945uud1945perubahank...
# 24341  new_turtle_fileslain-lain1945uud1945perubahank...
# 24342           new_turtle_fileslain-lain1945uud1945.ttl
#
# [24343 rows x 2 columns]

# %%
import pandas as pd

df_1 = pd.read_csv('core/regulatory_map.csv')
df_2 = pd.read_csv('core/turtle_map_tes.csv')

df_1['a'] = df_1['regulatory'].str.lower()
df_2['a'] = df_2['regulatory'].str.lower()
df_2['file_ttl'] = df_2['ttl_file']

df_1 = df_1.drop('regulatory', axis=1)
df_2 = df_2.drop('ttl_file', axis=1)

merged_df = pd.merge(df_2, df_1, on='a', how='left')
merged_df = merged_df.drop('a', axis=1)

merged_df
# Out:
#                   regulatory  \
# 0       Perkab_Bantul_1994_1
# 1      Perkab_Bantul_1994_13
# 2       Perkab_Bantul_1994_5
# 3      Perkab_Bantul_1994_11
# 4       Perkab_Bantul_1994_7
# ...                      ...
# 24338   Amandemen_1_UUD_1945
# 24339   Amandemen_3_UUD_1945
# 24340   Amandemen_4_UUD_1945
# 24341   Amandemen_2_UUD_1945
# 24342               UUD_1945
#
#                                                 file_ttl  \
# 0      new_turtle_filesperda1994perda_kabupaten_bantu...
# 1      new_turtle_filesperda1994perda_kabupaten_bantu...
# 2      new_turtle_filesperda1994perda_kabupaten_bantu...
# 3      new_turtle_filesperda1994perda_kabupaten_bantu...
# 4      new_turtle_filesperda1994perda_kabupaten_bantu...
# ...                                                  ...
# 24338  new_turtle_fileslain-lain1945uud1945perubahanp...
# 24339  new_turtle_fileslain-lain1945uud1945perubahank...
# 24340  new_turtle_fileslain-lain1945uud1945perubahank...
# 24341  new_turtle_fileslain-lain1945uud1945perubahank...
# 24342           new_turtle_fileslain-lain1945uud1945.ttl
#
#                                                 ttl_file  \
# 0      turtle_files/perda/1994/perda_kabupaten_bantul...
# 1                     turtle_files/ln/1994/pp0011994.ttl
# 2                     turtle_files/ln/1994/pp0011994.ttl
# 3                     turtle_files/ln/1994/pp0011994.ttl
# 4                     turtle_files/ln/1994/pp0011994.ttl
# ...                                                  ...
# 24338                turtle_files/bn/2015/bn270-2015.ttl
# 24339                turtle_files/bn/2015/bn270-2015.ttl
# 24340                turtle_files/bn/2015/bn270-2015.ttl
# 24341                turtle_files/bn/2015/bn270-2015.ttl
# 24342            turtle_files/lain-lain/1945/uud1945.ttl
#
#                                                 file_txt  \
# 0      new_1_text_files/perda/1994/perda_kabupaten_ba...
# 1      new_1_text_files/perda/1994/perda_kabupaten_ba...
# 2      new_1_text_files/perda/1994/perda_kabupaten_ba...
# 3      new_1_text_files/perda/1994/perda_kabupaten_ba...
# 4      new_1_text_files/perda/1994/perda_kabupaten_ba...
# ...                                                  ...
# 24338  new_1_text_files/lain-lain/1945/uud1945perubah...
# 24339  new_1_text_files/lain-lain/1945/uud1945perubah...
# 24340  new_1_text_files/lain-lain/1945/uud1945perubah...
# 24341  new_1_text_files/lain-lain/1945/uud1945perubah...
# 24342        new_1_text_files/lain-lain/1945/uud1945.txt
#
#                                                file_json
# 0      new_parsed_files/perda/1994/perda_kabupaten_ba...
# 1      new_parsed_files/perda/1994/perda_kabupaten_ba...
# 2      new_parsed_files/perda/1994/perda_kabupaten_ba...
# 3      new_parsed_files/perda/1994/perda_kabupaten_ba...
# 4      new_parsed_files/perda/1994/perda_kabupaten_ba...
# ...                                                  ...
# 24338  new_parsed_files/lain-lain/1945/uud1945perubah...
# 24339  new_parsed_files/lain-lain/1945/uud1945perubah...
# 24340  new_parsed_files/lain-lain/1945/uud1945perubah...
# 24341  new_parsed_files/lain-lain/1945/uud1945perubah...
# 24342       new_parsed_files/lain-lain/1945/uud1945.json
#
# [24343 rows x 5 columns]

# %%
filtered_merged_df = merged_df[~merged_df['file_json'].isin(error_files)]
filtered_merged_df
# Out:
#                   regulatory  \
# 0       Perkab_Bantul_1994_1
# 1      Perkab_Bantul_1994_13
# 2       Perkab_Bantul_1994_5
# 3      Perkab_Bantul_1994_11
# 4       Perkab_Bantul_1994_7
# ...                      ...
# 24338   Amandemen_1_UUD_1945
# 24339   Amandemen_3_UUD_1945
# 24340   Amandemen_4_UUD_1945
# 24341   Amandemen_2_UUD_1945
# 24342               UUD_1945
#
#                                                 file_ttl  \
# 0      new_turtle_filesperda1994perda_kabupaten_bantu...
# 1      new_turtle_filesperda1994perda_kabupaten_bantu...
# 2      new_turtle_filesperda1994perda_kabupaten_bantu...
# 3      new_turtle_filesperda1994perda_kabupaten_bantu...
# 4      new_turtle_filesperda1994perda_kabupaten_bantu...
# ...                                                  ...
# 24338  new_turtle_fileslain-lain1945uud1945perubahanp...
# 24339  new_turtle_fileslain-lain1945uud1945perubahank...
# 24340  new_turtle_fileslain-lain1945uud1945perubahank...
# 24341  new_turtle_fileslain-lain1945uud1945perubahank...
# 24342           new_turtle_fileslain-lain1945uud1945.ttl
#
#                                                 ttl_file  \
# 0      turtle_files/perda/1994/perda_kabupaten_bantul...
# 1                     turtle_files/ln/1994/pp0011994.ttl
# 2                     turtle_files/ln/1994/pp0011994.ttl
# 3                     turtle_files/ln/1994/pp0011994.ttl
# 4                     turtle_files/ln/1994/pp0011994.ttl
# ...                                                  ...
# 24338                turtle_files/bn/2015/bn270-2015.ttl
# 24339                turtle_files/bn/2015/bn270-2015.ttl
# 24340                turtle_files/bn/2015/bn270-2015.ttl
# 24341                turtle_files/bn/2015/bn270-2015.ttl
# 24342            turtle_files/lain-lain/1945/uud1945.ttl
#
#                                                 file_txt  \
# 0      new_1_text_files/perda/1994/perda_kabupaten_ba...
# 1      new_1_text_files/perda/1994/perda_kabupaten_ba...
# 2      new_1_text_files/perda/1994/perda_kabupaten_ba...
# 3      new_1_text_files/perda/1994/perda_kabupaten_ba...
# 4      new_1_text_files/perda/1994/perda_kabupaten_ba...
# ...                                                  ...
# 24338  new_1_text_files/lain-lain/1945/uud1945perubah...
# 24339  new_1_text_files/lain-lain/1945/uud1945perubah...
# 24340  new_1_text_files/lain-lain/1945/uud1945perubah...
# 24341  new_1_text_files/lain-lain/1945/uud1945perubah...
# 24342        new_1_text_files/lain-lain/1945/uud1945.txt
#
#                                                file_json
# 0      new_parsed_files/perda/1994/perda_kabupaten_ba...
# 1      new_parsed_files/perda/1994/perda_kabupaten_ba...
# 2      new_parsed_files/perda/1994/perda_kabupaten_ba...
# 3      new_parsed_files/perda/1994/perda_kabupaten_ba...
# 4      new_parsed_files/perda/1994/perda_kabupaten_ba...
# ...                                                  ...
# 24338  new_parsed_files/lain-lain/1945/uud1945perubah...
# 24339  new_parsed_files/lain-lain/1945/uud1945perubah...
# 24340  new_parsed_files/lain-lain/1945/uud1945perubah...
# 24341  new_parsed_files/lain-lain/1945/uud1945perubah...
# 24342       new_parsed_files/lain-lain/1945/uud1945.json
#
# [24330 rows x 5 columns]
