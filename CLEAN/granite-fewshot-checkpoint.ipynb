# %%
import pandas as pd
from tqdm import tqdm

# %%
# !nvidia-smi
# Out:
# Sun May 19 06:35:12 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          On  |   00000000:07:00.0 Off |                    0 |
# | N/A   43C    P0             78W /  400W |   22751MiB /  40960MiB |     42%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA A100-SXM4-40GB          On  |   00000000:0F:00.0 Off |                    0 |
# | N/A   25C    P0             54W /  400W |       3MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Enabled* |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA A100-SXM4-40GB          On  |   00000000:47:00.0 Off |                    0 |
# | N/A   24C    P0             54W /  400W |       3MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   3  NVIDIA A100-SXM4-40GB          On  |   00000000:4E:00.0 Off |                    0 |
# | N/A   25C    P0             53W /  400W |       3MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   4  NVIDIA A100-SXM4-40GB          On  |   00000000:87:00.0 Off |                    0 |
# | N/A   38C    P0             54W /  400W |       3MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   5  NVIDIA A100-SXM4-40GB          On  |   00000000:90:00.0 Off |                    0 |
# | N/A   52C    P0            312W /  400W |   19931MiB /  40960MiB |     37%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   6  NVIDIA A100-SXM4-40GB          On  |   00000000:B7:00.0 Off |                    0 |
# | N/A   29C    P0             53W /  400W |       3MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   7  NVIDIA A100-SXM4-40GB          On  |   00000000:BD:00.0 Off |                    0 |
# | N/A   48C    P0            297W /  400W |   25629MiB /  40960MiB |     87%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

torch.random.manual_seed(0)

model_phi = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-128k-instruct", 
    device_map="cuda", 
    torch_dtype="auto", 
    trust_remote_code=True, 
)
tokenizer_phi = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-128k-instruct")

pipe_phi = pipeline(
    "text-generation",
    model=model_phi,
    tokenizer=tokenizer_phi,
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
generation_args = {
    "max_new_tokens": 1000,
    "return_full_text": False,
    "do_sample": False,
}

# %%
messages = [
    {"role": "system", "content": "You are a helpful digital assistant. Please provide safe, ethical and accurate information to the user."},
    {"role": "user", "content": "Can you provide ways to eat combinations of bananas and dragonfruits?"},
    {"role": "assistant", "content": "Sure! Here are some ways to eat bananas and dragonfruits together: 1. Banana and dragonfruit smoothie: Blend bananas and dragonfruits together with some milk and honey. 2. Banana and dragonfruit salad: Mix sliced bananas and dragonfruits together with some lemon juice and honey."},
    {"role": "user", "content": "What about solving an 2x + 3 = 7 equation?"},
]



output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
#  To solve the equation 2x + 3 = 7, you need to isolate the variable x. Here are the steps:
#
# 1. Subtract 3 from both sides of the equation to get rid of the +3 on the left side. This gives you: 2x = 7 - 3, which simplifies to 2x = 4.
#
# 2. Now, divide both sides of the equation by 2 to solve for x. This gives you: x = 4 / 2, which simplifies to x = 2.
#
# So, the solution to the equation 2x + 3 = 7 is x = 2.

# %% [markdown]
# ### Closing

# %%
prompt_system = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date .
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
"""

# %%
prompt_user = """###regulatory: {regulatory}
###Teks: 
```
{teks}
```
###output:
"""

# %%
import pandas as pd
from tqdm import tqdm

df_closing = pd.read_csv('./dataset-fewshot/closing.csv')
df_closing
# Out:
#                       regulatory      label  \
# 0                      PP_2019_4         PP
# 1          Peraturan_BKPM_2017_8  Peraturan
# 2  Permenko_Perekonomian_2015_12   Permenko
# 3          Perprov_Papua_2013_26    Perprov
# 4       Perwali_Tangerang_2019_5    Perwali
# 5                      UU_1987_1         UU
#
#                                                 text  \
# 0  Peraturan Pemerintah ini mulai berlaku pada ta...
# 1  Peraturan Kepala Badan ini mulai berlaku pada ...
# 2  Peraturan Menteri ini mulai berlaku pada tangg...
# 3  Peraturan Daerah ini mulai berlaku pada tangga...
# 4  Peraturan Wali Kota ini mulai berlaku pada tan...
# 5  Undang-undang ini mulai berlaku pada tanggal d...
#
#                                              triples  __index_level_0__
# 0  lexid:Person_Joko_Widodo rdfs:label "Joko Wido...               2530
# 1  lexid:Position_Kepala_Badan_Koordinasi_Penanam...               2969
# 2  lexid:Person_Widodo_Ekatjahjana rdfs:label "Wi...              18632
# 3  lexid:Person_T_E_A_Hery_Dosinaen rdf:type lexi...              20280
# 4  lexid:Position_Wismansyah_Sekretaris_Daerah_Ko...              20582
# 5  lexid:UU_1987_1 lexid-s:hasEnactionOffice lexi...              20993

# %%
for i in range(10):
    print(df_closing.iloc[i]['regulatory'])
    print(df_closing.iloc[i]['triples'])
# Out:
# Permen_Ristekdikti_2016_110
# lexid:Permen_Ristekdikti_2016_110 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:Permen_Ristekdikti_2016_110 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:Person_Widodo_Ekatjahjana rdf:type lexid-s:Person .
# lexid:Permen_Ristekdikti_2016_110 lexid-s:hasPromulgationOffice lexid:Position_Direktur_Jenderal_Peraturan_Perundang_Undangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:Permen_Ristekdikti_2016_110 lexid-s:hasPromulgationOfficial lexid:Person_Widodo_Ekatjahjana .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:Person_Mohamad_Nasir rdfs:label "Mohamad Nasir"^^xsd:string .
# lexid:Position_Direktur_Jenderal_Peraturan_Perundang_Undangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Direktur Jenderal Peraturan Perundang Undangan Kementerian Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# lexid:Permen_Ristekdikti_2016_110 lexid-s:hasPromulgationDate "2016-12-27"^^xsd:date .
# lexid:Permen_Ristekdikti_2016_110 lexid-s:hasEnactionOfficial lexid:Person_Mohamad_Nasir .
# lexid:Person_Mohamad_Nasir rdf:type lexid-s:Person .
# lexid:Person_Widodo_Ekatjahjana rdfs:label "Widodo Ekatjahjana"^^xsd:string .
# lexid:Position_Direktur_Jenderal_Peraturan_Perundang_Undangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:Permen_Ristekdikti_2016_110 lexid-s:hasPromulgationPlace lexid:Berita_Negara .
# PP_1962_5
# lexid:Person_Mohd_Ichsan_ rdf:type lexid-s:Person .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:PP_1962_5 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:PP_1962_5 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
# lexid:PP_1962_5 lexid-s:hasPromulgationOfficial lexid:Person_Mohd_Ichsan_ .
# lexid:PP_1962_5 lexid-s:hasEnactionOfficial lexid:Person_Mohd_Ichsan_ .
# lexid:PP_1962_5 lexid-s:hasPromulgationDate "1962-04-03"^^xsd:date .
# lexid:Person_Mohd_Ichsan_ rdfs:label "Mohd Ichsan "^^xsd:string .
# Perkab_Ciamis_2011_27
# lexid:Perkab_Ciamis_2011_27 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Ciamis .
# lexid:Perkab_Ciamis_2011_27 lexid-s:hasEnactionOffice lexid:Position_Bupati_Ciamis .
# lexid:Perkab_Ciamis_2011_27 lexid-s:hasPromulgationLocation lexid:City_Ciamis .
# lexid:Person_H_Engkon_Komara rdf:type lexid-s:Person .
# lexid:Perkab_Ciamis_2011_27 lexid-s:hasPromulgationOffice lexid:Position_Km .
# lexid:Position_Km rdf:type lexid-s:Position .
# lexid:Position_Bupati_Ciamis rdfs:label "Bupati Ciamis"^^xsd:string .
# lexid:City_Ciamis rdf:type lexid-s:City .
# lexid:Perkab_Ciamis_2011_27 lexid-s:hasEnactionLocation lexid:City_Ciamis .
# lexid:Person_H_Engkon_Komara rdfs:label "H Engkon Komara"^^xsd:string .
# lexid:Position_Km rdfs:label "Km"^^xsd:string .
# lexid:Position_Bupati_Ciamis rdf:type lexid-s:Position .
# lexid:Perkab_Ciamis_2011_27 lexid-s:hasEnactionOfficial lexid:Person_H_Engkon_Komara .
# lexid:City_Ciamis rdfs:label "Ciamis"^^xsd:string .
# UU_2011_13
# lexid:UU_2011_13 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
# Perprov_Yogya_2008_7
# lexid:Position_Gubernur_Daerah_Istimewa_Yogyakarta rdf:type lexid-s:Position .
# lexid:Perprov_Yogya_2008_7 lexid-s:hasEnactionLocation lexid:City_Yogyakarta .
# lexid:Position_Gubernur_Daerah_Istimewa_Yogyakarta rdfs:label "Gubernur Daerah Istimewa Yogyakarta"^^xsd:string .
# lexid:Perprov_Yogya_2008_7 lexid-s:hasEnactionOffice lexid:Position_Gubernur_Daerah_Istimewa_Yogyakarta .
# lexid:City_Yogyakarta rdfs:label "Yogyakarta"^^xsd:string .
# lexid:Perprov_Yogya_2008_7 lexid-s:hasPromulgationLocation lexid:City_Yogyakarta .
# lexid:City_Yogyakarta rdf:type lexid-s:City .
# lexid:Perprov_Yogya_2008_7 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Provinsi_DI_Yogyakarta .
# Permen_Keu_2014_29
# lexid:Permen_Keu_2014_29 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# lexid:Permen_Keu_2014_29 lexid-s:hasPromulgationDate "2014-02-10"^^xsd:date .
# lexid:Permen_Keu_2014_29 lexid-s:hasPromulgationPlace lexid:Berita_Negara .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# Peraturan_Komnas_HAM_2015_001
# lexid:Peraturan_Komnas_HAM_2015_001 lexid-s:hasEnactionOffice lexid:Position_Ketua_Komisi_Nasional_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Person_Hafid_Abbas rdfs:label "Hafid Abbas"^^xsd:string .
# lexid:Peraturan_Komnas_HAM_2015_001 lexid-s:hasPromulgationPlace lexid:Berita_Negara .
# lexid:Peraturan_Komnas_HAM_2015_001 lexid-s:hasPromulgationDate "2015-11-16"^^xsd:date .
# lexid:Peraturan_Komnas_HAM_2015_001 lexid-s:hasPromulgationOffice lexid:Position_Direktur_Jenderal_Peraturan_Perundang_Undangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Person_Widodo_Ekatjahjana rdf:type lexid-s:Person .
# lexid:Position_Ketua_Komisi_Nasional_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Ketua Komisi Nasional Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# lexid:Person_Hafid_Abbas rdf:type lexid-s:Person .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:Peraturan_Komnas_HAM_2015_001 lexid-s:hasPromulgationOfficial lexid:Person_Widodo_Ekatjahjana .
# lexid:Peraturan_Komnas_HAM_2015_001 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:Position_Ketua_Komisi_Nasional_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:Person_Widodo_Ekatjahjana rdfs:label "Widodo Ekatjahjana"^^xsd:string .
# lexid:Peraturan_Komnas_HAM_2015_001 lexid-s:hasEnactionOfficial lexid:Person_Hafid_Abbas .
# lexid:Peraturan_Komnas_HAM_2015_001 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:Position_Direktur_Jenderal_Peraturan_Perundang_Undangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Direktur Jenderal Peraturan Perundang Undangan Kementerian Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:Position_Direktur_Jenderal_Peraturan_Perundang_Undangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# PP_2003_36
# lexid:PP_2003_36 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
# lexid:Position_Sekretaris_Negara_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2003_36 lexid-s:hasPromulgationOffice lexid:Position_Sekretaris_Negara_Republik_Indonesia .
# lexid:Position_Sekretaris_Negara_Republik_Indonesia rdfs:label "Sekretaris Negara Republik Indonesia"^^xsd:string .
# lexid:PP_2003_36 lexid-s:hasPromulgationDate "2003-07-08"^^xsd:date .
# Permen_Tan_2016_40
# lexid:Person_Widodo_Ekatjahjana rdf:type lexid-s:Person .
# lexid:Permen_Tan_2016_40 lexid-s:hasEnactionOffice lexid:Position_Menteri_Pertanian_Republik_Indonesia .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:Permen_Tan_2016_40 lexid-s:hasPromulgationDate "2016-09-06"^^xsd:date .
# lexid:Permen_Tan_2016_40 lexid-s:hasPromulgationOfficial lexid:Person_Widodo_Ekatjahjana .
# lexid:Person_Amran_Sulaiman rdfs:label "Amran Sulaiman"^^xsd:string .
# lexid:Person_Widodo_Ekatjahjana rdfs:label "Widodo Ekatjahjana"^^xsd:string .
# lexid:Permen_Tan_2016_40 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:Person_Amran_Sulaiman rdf:type lexid-s:Person .
# lexid:Permen_Tan_2016_40 lexid-s:hasEnactionOfficial lexid:Person_Amran_Sulaiman .
# lexid:Position_Direktur_Jenderal_Peraturan_Perundang_Undangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Direktur Jenderal Peraturan Perundang Undangan Kementerian Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:Permen_Tan_2016_40 lexid-s:hasPromulgationPlace lexid:Berita_Negara .
# lexid:Permen_Tan_2016_40 lexid-s:hasPromulgationOffice lexid:Position_Direktur_Jenderal_Peraturan_Perundang_Undangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Position_Menteri_Pertanian_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:Position_Menteri_Pertanian_Republik_Indonesia rdfs:label "Menteri Pertanian Republik Indonesia"^^xsd:string .
# lexid:Permen_Tan_2016_40 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:Position_Direktur_Jenderal_Peraturan_Perundang_Undangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# Peraturan_BKPM_2016_10
# lexid:Peraturan_BKPM_2016_10 lexid-s:hasPromulgationPlace lexid:Berita_Negara .
# lexid:Peraturan_BKPM_2016_10 lexid-s:hasPromulgationOffice lexid:Position_Direktur_Jenderal_Peraturan_Perundang_Undangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Person_Widodo_Ekatjahjana rdf:type lexid-s:Person .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:Peraturan_BKPM_2016_10 lexid-s:hasPromulgationOfficial lexid:Person_Widodo_Ekatjahjana .
# lexid:Peraturan_BKPM_2016_10 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:Peraturan_BKPM_2016_10 lexid-s:hasPromulgationDate "2016-12-27"^^xsd:date .
# lexid:Peraturan_BKPM_2016_10 lexid-s:hasEnactionOffice lexid:Position_Kepala_Badan_Koordinasi_Penanaman_Modal_Republik_Indonesia .
# lexid:Person_Widodo_Ekatjahjana rdfs:label "Widodo Ekatjahjana"^^xsd:string .
# lexid:Person_Thomas_Trikasih_Lembong rdf:type lexid-s:Person .
# lexid:Peraturan_BKPM_2016_10 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:Position_Direktur_Jenderal_Peraturan_Perundang_Undangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Direktur Jenderal Peraturan Perundang Undangan Kementerian Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:Peraturan_BKPM_2016_10 lexid-s:hasEnactionOfficial lexid:Person_Thomas_Trikasih_Lembong .
# lexid:Position_Kepala_Badan_Koordinasi_Penanaman_Modal_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:Person_Thomas_Trikasih_Lembong rdfs:label "Thomas Trikasih Lembong"^^xsd:string .
# lexid:Position_Direktur_Jenderal_Peraturan_Perundang_Undangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:Position_Kepala_Badan_Koordinasi_Penanaman_Modal_Republik_Indonesia rdfs:label "Kepala Badan Koordinasi Penanaman Modal Republik Indonesia"^^xsd:string .

# %%
messages = [
    {"role": "system", "content": prompt_system},
    {"role": "user", "content": prompt_user},
    {"role": "assistant", "content": prompt_assistant},
    {"role": "user", "content": prompt_test},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])

# %%
for x in tqdm(range(20)[10:]):
    data = df_closing.iloc[x]
    print(data)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 2524.41it/s]
# regulatory                                     Permen_KP_2014_8
# ttl_file                new_turtle_files/bn/2014/bn221-2014.ttl
# text          Pasal 25 \n\nPeraturan Menteri ini mulai berla...
# ttl           lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Man...
# Name: 0, dtype: object
# regulatory                                Permen_Dagri_2017_112
# ttl_file               new_turtle_files/bn/2017/bn1643-2017.ttl
# text          Pasal 5 \n\nPeraturan Menteri ini mulai berlak...
# ttl           lexid:Person_Widodo_Ekatjahjana rdf:type lexid...
# Name: 1, dtype: object
# regulatory                                           PP_2008_70
# ttl_file                 new_turtle_files/ln/2008/pp70-2008.ttl
# text          Pasal 4 \n\n \n\nPeraturan Pemerintah ini mula...
# ttl           lexid:PP_2008_70 lexid-s:hasPromulgationOffice...
# Name: 2, dtype: object
# regulatory                                Perprov_Sumsel_2009_5
# ttl_file      new_turtle_files/perda/2009/perda_provinsi_sum...
# text          Pasal 5 \n\n(1) Penyertaan modal daerah pada P...
# ttl           lexid:City_Palembang rdfs:label "Palembang"^^x...
# Name: 3, dtype: object
# regulatory                                           PP_1954_54
# ttl_file                 new_turtle_files/ln/1954/pp54-1954.ttl
# text          Pasal 2 \n\n \n\n Peraturan Pemerintah ini mul...
# ttl           lexid:PP_1954_54 lexid-s:hasEnactionLocation l...
# Name: 4, dtype: object
# regulatory                    Perkab_Kotawaringin_Barat_2012_16
# ttl_file      new_turtle_files/perda/2012/perda_kabupaten_ko...
# text          Pasal 37\n\nPeraturan Daerah ini mulai berlaku...
# ttl           lexid:Position_Bupati_Kotawaringin_Barat rdf:t...
# Name: 5, dtype: object
# regulatory                                    Permen_PDT_2014_1
# ttl_file                new_turtle_files/bn/2014/bn190-2014.ttl
# text          Pasal 5 \n\nPeraturan Menteri ini mulai berlak...
# ttl           lexid:Permen_PDT_2014_1 lexid-s:hasEnactionLoc...
# Name: 6, dtype: object
# regulatory                                           PP_2013_55
# ttl_file                 new_turtle_files/ln/2013/pp55-2013.ttl
# text          Pasal 4\n\nPeraturan Pemerintah ini mulai berl...
# ttl           lexid:PP_2013_55 lexid-s:hasPromulgationOffice...
# Name: 7, dtype: object
# regulatory                             Peraturan_Bapeten_2016_5
# ttl_file                new_turtle_files/bn/2016/bn788-2016.ttl
# text          Pasal 67\n\nPeraturan Kepala ini mulai berlaku...
# ttl           lexid:Person_Jazi_Eko_Istiyanto rdfs:label "Ja...
# Name: 8, dtype: object
# regulatory                                Permen_Dikbud_2017_37
# ttl_file               new_turtle_files/bn/2017/bn1739-2017.ttl
# text          Pasal 11 \n\nPeraturan Menteri ini mulai berla...
# ttl           lexid:Person_Muhadjir_Effendy rdf:type lexid-s...
# Name: 9, dtype: object

# %%
from datasets import load_from_disk

test_dataset_name = "dataset-surface-info/split/closing/test"
test_dataset = load_from_disk(test_dataset_name)
len(test_dataset)
# Out:
# 2163

# %%
# df_closing_fewshot = df_closing[df_closing['regulatory'].isin(train_dataset["regulatory"])].iloc[:10].reset_index(drop=True)
df_closing_fewshot = df_closing.iloc[:10].reset_index(drop=True)
df_closing_fewshot
# Out:
#                           regulatory  \
# 0                   Permen_KP_2014_8
# 1              Permen_Dagri_2017_112
# 2                         PP_2008_70
# 3              Perprov_Sumsel_2009_5
# 4                         PP_1954_54
# 5  Perkab_Kotawaringin_Barat_2012_16
# 6                  Permen_PDT_2014_1
# 7                         PP_2013_55
# 8           Peraturan_Bapeten_2016_5
# 9              Permen_Dikbud_2017_37
#
#                                             ttl_file  \
# 0            new_turtle_files/bn/2014/bn221-2014.ttl
# 1           new_turtle_files/bn/2017/bn1643-2017.ttl
# 2             new_turtle_files/ln/2008/pp70-2008.ttl
# 3  new_turtle_files/perda/2009/perda_provinsi_sum...
# 4             new_turtle_files/ln/1954/pp54-1954.ttl
# 5  new_turtle_files/perda/2012/perda_kabupaten_ko...
# 6            new_turtle_files/bn/2014/bn190-2014.ttl
# 7             new_turtle_files/ln/2013/pp55-2013.ttl
# 8            new_turtle_files/bn/2016/bn788-2016.ttl
# 9           new_turtle_files/bn/2017/bn1739-2017.ttl
#
#                                                 text  \
# 0  Pasal 25 \n\nPeraturan Menteri ini mulai berla...
# 1  Pasal 5 \n\nPeraturan Menteri ini mulai berlak...
# 2  Pasal 4 \n\n \n\nPeraturan Pemerintah ini mula...
# 3  Pasal 5 \n\n(1) Penyertaan modal daerah pada P...
# 4  Pasal 2 \n\n \n\n Peraturan Pemerintah ini mul...
# 5  Pasal 37\n\nPeraturan Daerah ini mulai berlaku...
# 6  Pasal 5 \n\nPeraturan Menteri ini mulai berlak...
# 7  Pasal 4\n\nPeraturan Pemerintah ini mulai berl...
# 8  Pasal 67\n\nPeraturan Kepala ini mulai berlaku...
# 9  Pasal 11 \n\nPeraturan Menteri ini mulai berla...
#
#                                                  ttl
# 0  lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Man...
# 1  lexid:Person_Widodo_Ekatjahjana rdf:type lexid...
# 2  lexid:PP_2008_70 lexid-s:hasPromulgationOffice...
# 3  lexid:City_Palembang rdfs:label "Palembang"^^x...
# 4  lexid:PP_1954_54 lexid-s:hasEnactionLocation l...
# 5  lexid:Position_Bupati_Kotawaringin_Barat rdf:t...
# 6  lexid:Permen_PDT_2014_1 lexid-s:hasEnactionLoc...
# 7  lexid:PP_2013_55 lexid-s:hasPromulgationOffice...
# 8  lexid:Person_Jazi_Eko_Istiyanto rdfs:label "Ja...
# 9  lexid:Person_Muhadjir_Effendy rdf:type lexid-s...

# %%
import time

results = pd.DataFrame()
results = pd.DataFrame(columns=['1', '2', '3', '4', '5', '6'])

for x in tqdm(range(len(test_dataset))[:5]):
#     if x % 100 == 0 and x > 0:
#         results.reset_index(inplace=True)
#         results.rename(columns={'index': 'regulatory'}, inplace=True)
#         results.to_csv(f'./result/fewshot_closing2_{x//100}.csv')
        
#         results = pd.DataFrame()
#         results = pd.DataFrame(columns=['1', '2', '3', '4', '5', '6'])
        
    data = test_dataset[x]
#     print(data)
    
    messages = [
        {"role": "system", "content": prompt_system},
    ]
    
    for k in range(6):
        data_fewshot = df_closing.iloc[k]
        messages += [
            {"role": "user", "content": prompt_user.format(regulatory=data_fewshot['regulatory'], teks=data_fewshot['text'])},
            {"role": "assistant", "content": data_fewshot['triples']},
            {"role": "user", "content": prompt_user.format(regulatory=data['regulatory'], teks=data['text'])},
        ]
#         print(messages)
        try:
            start_time = time.time()
            output = pipe_phi(messages, **generation_args)
            print(k, '-shot')
            print(output[0]['generated_text'])
            results.at[data['regulatory'], f'{k + 1}'] = output[0]['generated_text']
#             print(time.time() - start_time)
        except:
            results.at[data['regulatory'], f'{k + 1}'] = ''
        
        messages = messages[:-1]
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]You are not running the flash-attention implementation, expect numerical differences.
#  20%|██        | 1/5 [00:01<00:06,  1.57s/it]
# 0 -shot
#  lexid:Qanun_Aceh_Utara_2005_28 rdfs:label "Qanun Aceh Utara 2005 No.28"^^xsd:string.
# lexid:Date_15_Februari_2005 rdfs:label "15 Februari 2005"^^xsd:date.
# lexid:Date_18_Februari_2005 rdfs:label "18 Februari 2005"^^xsd:date.
# lexid:Capital_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:Bupati_Aceh_Utara lexid-s:hasOfficeLocation lexid:Capital_Lhokseumawe.
# lexid:H. Teuku Alamsyah Bantah lexid-s:hasHolder lexid:Capital_Lhokseumawe.
# lexid:H. Teuku Alamsyah Bantah lexid-s:hasDateOfAppointment lexid:Date_18_Februari_2005.
# lexid:H. Teuku Alamsyah Bantah lexid-s:hasDateOfAppointment lexid:Date_15_Februari_2005.
# lexid:Secretary_Daerah_Aceh_Utara lexid-s:hasHolder lexid:Capital_Lhokseumawe.
# lexid:T. Harman lexid-s:hasHolder lexid:Capital_Lhokseumawe.
# lexid:Secretary_Daerah_Aceh_Utara lexid-s:hasDateOfAppointment lexid:Date_18_Februari_2005.
# lexid:Secretary_Daerah_Aceh_Utara lexid-s:hasDateOfAppointment lexid:Date_15_Februari_2005.
# lexid:NIP_010_073_653 rdfs:label "NIP. 010 073 653"^^xsd:string.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara lexid-s:hasDate lexid:Date_2005_28.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara lexid-s:hasDate lexid:Date_2005_29.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara lexid-s:hasHolder lexid:Secretary_Daerah_Aceh_Utara.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara lexid-s:hasHolder lexid:H. Teuku Alamsyah Bantah.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara lexid-s:hasHolder lexid:T. Harman.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara lexid-s:hasHolder lexid:NIP_010_073_653.
# 1 -shot
#  lexid:Qanun_Perkab_Aceh_Utara_2005_28 rdfs:label "Qanun Perkab Aceh Utara 2005 No. 28"^^xsd:string.
# lexid:Cap_dto_Bupati_Aceh_Utara rdfs:label "Cap/dto H. Teuku Alamsyah Banta"^^xsd:string.
# lexid:Person_T. Harmawan rdfs:label "T. Harmawan"^^xsd:string.
# lexid:Person_H. Teuku_Alamsyah_Banta rdf:type lexid-s:Person.
# lexid:Lhokseumawe rdf:type lexid-s:City.
# lexid:Qanun_Perkab_Aceh_Utara_2005_28 lexid-s:hasEnactionOffice lexid:Cap_dto_Bupati_Aceh_Utara.
# lexid:Qanun_Perkab_Aceh_Utara_2005_28 lexid-s:hasEnactionLocation lexid:Lhokseumawe.
# lexid:Cap_dto_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:Person_T. Harmawan rdf:type lexid-s:Person.
# lexid:Person_H. Teuku_Alamsyah_Banta rdfs:label "H. Teuku Alamsyah Banta"^^xsd:string.
# lexid:Lhokseumawe rdf:type lexid-s:City.
# lexid:Qanun_Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationDate "2005-02-15"^^xsd:date.
# lexid:Qanun_Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:Qanun_Perkab_Aceh_Utara_2005_28 lexid-s:hasEnactionOfficial lexid:Cap_dto_Bupati_Aceh_Utara.
# lexid:Lhokseumawe rdf:type lexid-s:City.
# lexid:Person_T. Harmawan rdfs:label "T. Harmawan"^^xsd:string.
# lexid:Qanun_Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationOffice lexid:Cap_dto_Bupati_Aceh_Utara.
# lexid:Qanun_Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationLocation lexid:Lhokseumawe.
# lexid:Qanun_Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationDate "2005-02-15"^^xsd:date.
# lexid:Position_Cap_dto_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:Person_T. Harmawan rdf:type lexid-s:Person.
# lexid:Person_H. Teuku_Alamsyah_Banta rdfs:label "H. Teuku Alamsyah Banta"^^xsd:string.
# lexid:Lhokseumawe rdf:type lexid-s:City.
# lexid:Qanun_Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationDate "2005-02-15"^^xsd:date.
# lexid:Qanun_Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationPlace lexid:Lemb
# 2 -shot
#  lexid:Person_H_Teuku_Alamsyah_Banta rdfs:label "H. Teuku Alamsyah Banta"^^xsd:string.
# lexid:Person_T_Harmawan_Dr_MiSi rdfs:label "T. H. Harmawan, M.Si"^^xsd:string.
# lexid:Permen_Aceh_Utara_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H_Teuku_Alamsyah_Banta.
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:Permen_Aceh_Utara_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:Position_Penjabat_Bupati_Aceh_Utara rdfs:label "Penjabat Bupati Aceh Utara"^^xsd:string.
# lexid:Person_H_Teuku_Alamsyah_Banta rdf:type lexid-s:Person.
# lexid:Position_Penjabat_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:Permen_Aceh_Utara_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:Person_T_Harmawan_Dr_MiSi rdfs:label "T. H. Harmawan, M.Si"^^xsd:string.
# lexid:Permen_A
#
#
#
#
#
# ana
# y.
# y4
#
#
#
#
#
#
#
#
#
#
#
# yndo.
#
# n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# yja
# y.
# .
#
#
#
# ykk
#
# y0y
#
#
#
# anir0
#
#
# an.
#
# y1000pran
# anja.
# irja
#
# anana.
# an.nteranajaja
# y0	aj.
# terpedek		1//ter			dinjaja.
# 0	n0udududkkIerIudotan.
#
#
# ir
#
#
#
#
#
#
#
#
# otana.
#
#
#
# yaj000iran
# anotanyaan.
# anotean.
# an
#
#
#
#
#
# anijitiran.
# an
#
#
#
#
# an
# an.
# an
# an
# an.
# an	nI	9I
# anajIIanjaanidIII//0dinanotdinanjaja.
# 	I0an
# anote1ekIIIkkI3din00a//Iekitua
# an.din.d
# 0dinja
#
# eko.kkI.
# dinkkHkkIII//III//IIIII
# yaj
#
#
# yia_0an
# din2y0ya0yjaNYN
#
#
# yja0ud0din1y0,
#
#
#
# yjeja
#
#
#
#
#
# din
#
#
#
#
#
# //0jaja
#
#
#
#
#
#
# kkekan
#
#
# ana10
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# o
# irojia
#
# ogoja
#
#
#
#
#
#
#
#
#
#
#
# an
# an
# an
# iran
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# an
# an
# aniajaij
#
# anijia
#
# an
# an
#
#
#
#
#
#
#
#
#
#
# o
#
#
#
#
#
#
#
#
#
# an
#
#
#
#
#
#
#
#
#
#
# an
#
#
#
#
#
#
#
#
# an
#
# iran
#
#
#
#
# an
# anijanig00I0an
# iriairia
# an
#
#
#
#
#
#
#
#
# 1I
# iria
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 3 -shot
#  lexid:Qanun_Aceh_Utara_2005_28 rdfs:label "Qanun Kabupaten Aceh Utara 2005 No.28"^^xsd:string.
# lexid-s:hasEnactionOfficial lexid:Penjabat_Bupati_Aceh_Utara.
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:Position_Penjabat_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationDate "2005-02-15"^^xsd:date.
# lexid:Penjabat_Bupati_Aceh_Utara rdf:type lexid-s:Person.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:H. Teuku Alamsyaah Banta rdf:type lexid-s:Person.
# lexid:Position_Penjabat_Bupati_Aceh_Utara rdfs:label "H. Teuku Alamsyaah Banta"^^xsd:string.
# lexid:Position_Penjabat_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdf:type lexid-s:Lembaran.
# lexid:Drs. T. Harman rdf:type lexid-s:Person.
# lexid:Pembina_Utama_Muda rdf:type lexid-s:Position.
# lexid:NIP. 010 073 653 rdfs:label "NIP. 010 073 653"^^xsd:string.
# lexid:Position_Pembina_Utama_Muda rdfs:label "Pembina Utama Muda"^^xsd:string.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdfs:label "Lembaran Daerah Kabupaten Aceh Utara".
# lexid:Nomor_29 rdf:type lexid-s:NumericalItem.
# lexid:Nomor_29 lexid-s:hasValue "29"^^xsd:gxxdm:unqualifiedInteger.
# lexid:Position_Pembina_Utama_Muda rdfs:label "Nomor 29"^^xsd:string.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdf:type lexid-s:Lembaran.
# lexid:Drs. T. Harman rdfs:label "T. Harman"^^xsd:string.
# lexid:Pembina_Utama_Muda rdfs:label "Pembina Utama Muda"^^xsd:string.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdf:type lexid-s:Lembaran.
# lexid:SEKRETARIS_DAERAH rdf:type lexid-s:Organization.
# lexid:SEKRETARIS_DAERAH lexid-s:hasMember lexid:Position_Pembina_Utama_Muda.
# lexid:SEKRETARIS_DAERAH lexid-s:hasMember lexid:Position_Penjabat_Bupati_Aceh_Utara.
# lexid:H. Teuku Alamsyaah Banta rdfs:label "H. Teuku Alamsyaah Banta"^^xsd:string.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara
# 4 -shot
#  lexid:Qanun_Aceh_Utara_2005_28 rdfs:label "Qanun Aceh Utara 2005 No.28"^^xsd:string.
# lexid-s:hasEnactionDate "2005-02-15"^^xsd:date.
# lexid:Position_Penjabat_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:Person_H. Teuku Alamsyah Banta rdf:type lexid-s:Person.
# lexid:Position_Penjabat_Bupati_Aceh_Utara rdfs:label "Penjabat Bupati Aceh Utara"^^xsd:string.
# lexid:Perkab_Aceh_Utara_2005_28 lexid-s:hasEnactionOffice lexid:Position_Penjabat_Bupati_Aceh_Utara.
# lexid:Lhokseumawe rdf:type lexid-s:City.
# lexid:Position_Penjabat_Bupati_Aceh_Utara rdf:type lexid-s:City.
# lexid:Person_H. Teuku Alamsyah Banta rdfs:label "H. Teuku Alamsyah Banta"^^xsd:string.
# lexid:Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_H. Teuku Alamsyah Banta.
# lexid:Lhokseumawe rdf:type lexid-s:City.
# lexid:Position_Penjabat_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationDate "2005-02-15"^^xsd:date.
# lexid:Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:Drs_T. Harmawan, M.Si rdf:type lexid-s:Person.
# lexid:Position_Pembina_Utama_Muda rdfs:label "Pembina Utama Muda"^^xsd:string.
# lexid:NIP_010_073_653 rdf:type lexid-s:Person.
# lexid:Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationOffice lexid:Person_Drs_T. Harmawan, M.Si.
# lexid:Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationDate "2005-02-15"^^xsd:date.
# lexid:Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationLocation lexid:Lhokseumawe.
# lexid:Position_Pembina_Utama_Muda rdf:type lexid-s:Position.
# lexid:NIP_010_073_653 rdfs:label "NIP 010 073 653"^^xsd:string.
# lexid:Perkab_Aceh_Utara_2005_28 lexid-s:hasEnactionOffice lexid:Position_Pembina_Utama_Muda.
# lexid:Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationDate "2005-02-15"^^xsd:date.
# lexid:Perkab_Aceh_Utara_2005_28 lexid-s:hasPromulgationOffice lexid:Person_N
#  40%|████      | 2/5 [03:54<06:53, 137.71s/it]
# 5 -shot
#  lexid:Position_Pembina_Utama_Muda rdf:type lexid-s:Position.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasEnactionOfficial lexid:Person_T.Harmwan_Si_Pembina_Utama_Muda.
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationDate "2005-02-15"^^xsd:date.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationLocation lexid:City_Lhokseumawe.
# lexid:Person_H.Teuku_Alamysah rdf:type lexid-s:Person.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_H.Teuku_Alamysah.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasEnactionOffice lexid:Position_Pembina_Utama_Muda.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah.
# lexid:Position_Pembina_Utama_Muda rdfs:label "Pembina Utama Muda Kabupaten Aceh Utara"^^xsd:string.
# lexid:Person_H.Teuku_Alamysah rdfs:label "H. Teuku Alamysah"^^xsd:string.
# lexid:Position_Pembina_Utama_Muda rdf:type lexid-s:Person.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationDate "2005-02-15"^^xsd:date.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationLocation lexid:City_Lhokseumawe.
# lexid:Sektor_Pembina_Utama_Muda rdfs:label "Sektor Pembina Utama Muda"^^xsd:string.
# lexid:Capital_Kabupaten_Aceh_Utara rdf:type lexid-s:City.
# lexid:Capital_Kabupaten_Aceh_Utara lexid-s:hasEnactionOffice lexid:Position_Pembina_Utama_Muda.
# lexid:Sektor_Pembina_Utama_Muda rdfs:label "Sektor Pembina Utama Muda"^^xsd:string.
# lexid:Sektor_Pembina_Utama_Muda rdfs:label "Sektor Pembina Utama Muda Kabupaten Aceh Utara"^^xsd:string.
# lexid:Capital_Kabupaten_Aceh_Utara rdf:type lexid-s:City.
# lexid:Sektor_Pembina_Utama_Muda rdfs:label "Sektor Pembina Utama Muda Kabupaten Aceh Utara"^^xsd:string.
# lexid:Penjabat_Bupati_Aceh_Utara rdf:type lexid-s:Person.
# lexid:Penjabat_Bupati_Aceh_Utara rdfs:label "Drs. T. Harmwan Si Pembina Muda"^^xsd:string.
# lexid:Penjabat_Bupati_Aceh_Utara lexid-s:hasEnactionOfficial lexid:Position_Pembina_Utama_Muda.
# lexid:Penjabat_Bupati_Aceh_Utara lex
# 0 -shot
#  lexid:Perkab_Bantul_2001_5 rdfs:label "Peraturan Kabupaten Bantul Nomor 5 Tahun 2001"^^xsd:string.
# lexid:Bupati_Bantul rdfs:label "Bupati Kabupaten Bantul"^^xsd:string.
# lexid:Totok_Sudarto rdfs:label "Totok Sudarto"^^xsd:string.
# lexid:Bupati_Bantul lexid-s:hasPromulgationDate "2001-02-09"^^xsd:date.
# lexid:Bupati_Bantul lexid-s:hasPromulgationPlace lexid:Kota_Bantul.
# lexid:Bupati_Bantul lexid-s:hasPromulgationOfficial lexid:Totok_Sudarto.
# lexid:Kota_Bantul rdfs:label "Kota Bantul"^^xsd:string.
# lexid:Lurah rdfs:label "Lurah"^^xsd:string.
# lexid:Lurah rdf:type lexid-s:Position.
# lexid:Lurah rdf:type lexid-s:EnactionOfficial.
# lexid:Lurah rdf:type lexid-s:EnactionLocation.
# lexid:Lurah rdf:type lexid-s:EnactionOfficial.
# lexid:Carik rdfs:label "Carik"^^xsd:string.
# lexid:Carik rdf:type lexid-s:Position.
# lexid:Carik rdf:type lexid-s:EnactionOfficial.
# lexid:Kepala_Bagian rdfs:label "Kepala Bagian"^^xsd:string.
# lexid:Kepala_Bagian rdf:type lexid-s:Position.
# lexid:Kepala_Bagian rdf:type lexid-s:EnactionOfficial.
# lexid:Anggota_BPD rdfs:label "Anggota BPD"^^xsd:string.
# lexid:Anggota_BPD rdf:type lexid-s:Position.
# lexid:Anggota_BPD rdf:type lexid-s:EnactionOfficial.
# lexid:Sekretaris_BPD rdfs:label "Sekretaris BPD"^^xsd:string.
# lexid:Sekretaris_BPD rdf:type lexid-s:Position.
# lexid:Sekretaris_BPD rdf:type lexid-s:EnactionOfficial.
# lexid:Pasal_II lexid-s:hasTitle "Pasal II".
# lexid:Pasal_II lexid-s:hasPromulgationDate "2001-02-09"^^xsd:date.
# lexid:Pasal_II lexid-s:hasPromulgationPlace lexid:Kota_Bantul.
# lexid:Pasal_II lexid-s:hasPromulgationOfficial lexid:Totok_Sudarto.
# lexid:Pasal_II lexid-s:hasEnactionOfficial lexid:Totok_Sudarto.
# lexid:Pasal_II lexid-s:hasEnactionLocation lexid:Kota_Bantul.
# lexid:Pasal_II lexid-s:hasEnactionOfficial lexid:Totok_Sudarto.
# lexid:Pasal_II lexid-s:hasEnactionOfficial lexid:Totok_Sudarto.
# lexid:Pasal_II lexid-s:hasEnactionOfficial lexid:Totok_Sudarto.
# lexid:Pasal_II lexid-s:hasEnactionOfficial lexid:Totok_Sudarto.
# lexid:Pasal_II lexid-s:hasEnactionOfficial lexid:Totok_Sudarto.
# lexid:Pasal_II lexid-s:hasEnactionOfficial lexid:Totok_Sudarto.
# lexid:Pasal_II lexid-s
# 1 -shot
#  lexid:Position_Bupati_Bantul rdfs:label "Bupati Bantul"^^xsd:string.
# lexid:Position_Sekretaris_Daerah_Kabupaten_Bantul rdfs:label "Sekretaris Daerah Kabupaten Bantul"^^xsd:string.
# lexid:Person_Totok_Sudarto rdf:type lexid-s:Person.
# lexid:Person_Ashadi rdf:type lexid-s:Person.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasEnactionOffice lexid:Position_Bupati_Bantul.
# lexid:City_Bantul rdf:type lexid-s:City.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasEnactionLocation lexid:City_Bantul.
# lexid:Position_Bupati_Bantul rdf:type lexid-s:Position.
# lexid:Person_Totok_Sudarto rdf:type lexid-s:Person.
# lexid:Person_Ashadi rdf:type lexid-s:Person.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasPromulgationOfficial lexid:Person_Totok_Sudarto.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasPromulgationDate "2001-02-09"^^xsd:date.
# lexid:Position_Sekretaris_Daerah_Kabupaten_Bantul rdfs:label "Sekretaris Daerah Kabupaten Bantul"^^xsd:string.
# lexid:Person_Ashadi rdf:type lexid-s:Person.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasEnactionOfficial lexid:Position_Sekretaris_Daerah_Kabupaten_Bantul.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasPromulgationDate "2001-02-10"^^xsd:date.
# lexid:Position_Sekretaris_Daerah_Kabupaten_Bantul rdf:type lexid-s:Position.
# lexid:Person_Ashadi rdf:type lexid-s:Person.
# 2 -shot
#  lexid:Position_Bupati_Bantul rdfs:label "Bupati Bantul"^^xsd:string.
# lexid:Position_Sekretaris_Daerah_Kabupaten_Bantul rdfs:label "Sekretaris Daerah Kabupaten Bantul"^^xsd:string.
# lexid:Person_Totok_Sudarto rdfs:label "Totok Sudarto"^^xsd:string.
# lexid:Person_Ashadi rdfs:label "Ashadi"^^xsd:string.
# lexid:Position_Bupati_Bantul rdf:type lexid-s:Position.
# lexid:Position_Sekretaris_Daerah_Kabupaten_Bantul rdf:type lexid-s:Position.
# lexid:Person_Totok_Sudarto rdf:type lexid-s:Person.
# lexid:Person_Ashadi rdf:type lexid-s:Person.
# lexid:PERKAB_BANTUL_2001_5 lexid-s:hasEnactionOfficial lexid:Person_Totok_Sudarto.
# lexid:PERKAB_BANTUL_2001_5 lexid-s:hasEnactionOfficial lexid:Person_Ashadi.
# lexid:PERKAB_BANTUL_2001_5 lexid-s:hasEnactionLocation lexid:Kabupaten_Bantul.
# lexid:PERKAB_BANTUL_2001_5k0ajo00an
# 3 -shot
#  lexid:Position_Kepala_BPD_Bantul rdfs:label "Kepala BPD Bantul"^^xsd:string.
# lexid:Person_T_Sudarto rdf:type lexid-s:Person.
# lexid:Position_Drs_Ashadi rdf:type lexid-s:Person.
# lexid:Peraturan_Bupati_Bantul_2001_5 lexid-s:hasEnactionOffice lexid:Position_Kepala_BPD_Bantul.
# lexid:Peraturan_Bupati_Bantul_2001_5 lexid-s:hasPromulgationOfficial lexid:Person_T_Sudarto.
# lexid:Peraturan_Bupati_Bantul_2001_5 lexid-s:hasPromulgationDate "2001-02-09"^^xsd:date.
# lexid:Position_Drs_Ashadi rdf:type lexid-s:Position.
# lexid:Peraturan_Bupati_Bantul_2001_5 lexid-s:hasPromulgationLocation lexid:Kabupaten_Bantul.
# lexid:Lembaran_Daerah_Kabupaten_Bantul rdf:type lexid-s:Lembaran.
# lexid:Person_T_Sudarto rdfs:label "T Sudarto"^^xsd:string.
# lexid:Person_Drs_Ashadi rdfs:label "Drs Ashadi"^^xsd:string.
# lexid:Kabupaten_Bantul rdf:type lexid-s:Kabupaten.
# lexid:Lembaran_Daerah_Kabupaten_Bantul lexid-s:hasPromulgationPlace lexid:Kabupaten_Bantul.
# lexid:Peraturan_Bupati_Bantul_2001_5 lexid-s:hasEnactionOfficial lexid:Person_Drs_Ashadi.
# lexid:Peraturan_Bupati_Bantul_2001_5 lexid-s:hasEnactionLocation lexid:Kabupaten_Bantul.
# lexid:Lembaran_Daerah_Kabupaten_Bantul lexid-s:hasEnactionOfficial lexid:Person_T_Sudarto.
# lexid:Lembaran_Daerah_Kabupaten_Bantul lexid-s:hasEnactionDate "2001-02-10"^^xsd:date.
# lexid:Lembaran_Daerah_Kabupaten_Bantul lexid-s:hasEnactionLocation lexid:Kabupaten_Bantul.
# lexid:Position_Drs_Ashadi rdfs:label "Drs Ashadi"^^xsd:string.
# lexid:Kabupaten_Bantul rdf:type lexid-s:Kabupaten.
# lexid:Lembaran_Daerah_Kabupaten_Bantul lexid-s:hasEnactionDate "2001-02-10"^^xsd:date.
# lexid:Lembaran_Daerah_Kabupaten_Bantul lexid-s:hasEnactionLocation lexid:Kabupaten_Bantul.
# lexid:Position_Kepala_BPD_Bantul rdf:type lexid-s:Position.
# lexid:Position_Drs_Ashadi rdf:type lexid-s:Position.
# lexid:Lembaran_Daerah_Kabupaten_Bantul lexid-s:hasEnactionDate "2001-02-10"^^xsd:date.
# lexid:Lembaran_Daerah_Kabupaten_Bantul lexid-s:hasEnactionLocation lexid:Kabupaten_Bantul.
# lexid:Lembaran_Daerah_Kabupaten_Bantul lexid-s:hasEnactionOfficial lexid:Person_T_Sudarto.
# lexid:Lembaran_Daerah_K
# 4 -shot
#  lexid:Lurah rdf:type lexid-s:Position.
# lexid:Lurah rdfs:label "Lurah"^^xsd:string.
# lexid:Carik rdf:type lexid-s:Position.
# lexid:Kepala_Bagian_BPD rdf:type lexid-s:Position.
# lexid:Anggota_BPD rdf:type lexid-s:Position.
# lexid:Pasal_II rdfs:label "Pasal II"^^xsd:string.
# lexid:Peraturan_Bupati_2001_5 lexid-s:hasEnactionOffice lexid:Bupati_Bantul.
# lexid:Peraturan_Bupati_2001_5 lexid-s:hasEnactionLocation lexid:Kabupaten_Bantul.
# lexid:Bupati_Bantul rdfs:label "Bupati Kabupaten Bantul"^^xsd:string.
# lexid:Person_Totok_Sudarto rdf:type lexid-s:Person.
# lexid:Person_Totok_Sudarto rdfs:label "Totok Sudarto"^^xsd:string.
# lexid:SEKRETARIS_DAERAH_KABUPATEN_BANTUL lexid-s:hasPromulgationOfficial lexid:Person_Totok_Sudarto.
# lexid:SEKRETARIS_DAERAH_KABUPATEN_BANTUL lexid-s:hasPromulgationDate "2001-02-09"^^xsd:date.
# lexid:SEKRETARIS_DAERAH_KABUPATEN_BANTUL lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Bantul.
# lexid:Peraturan_Bupati_2001_5 lexid-s:hasPromulgationOffice lexid:SEKRETARIS_DAERAH_KABUPATEN_BANTUL.
# lexid:Peraturan_Bupati_2001_5 lexid-s:hasEnactionOffice lexid:Bupati_Bantul.
# lexid:Peraturan_Bupati_2001_5 lexid-s:hasPromulgationDate "2001-02-10"^^xsd:date.
# lexid:Pasal_II rdfs:label "Pasal II"^^xsd:string.
# lexid:Ketentuan_Pasal_II rdf:type lexid-s:Proposition.
# lexid:Ketentuan_Pasal_II rdfs:label "Ketentuan Pasal 24 ayat (3), (4), dan (6)"^^xsd:string.
# lexid:Lurah rdfs:label "Lurah"^^xsd:string.
# lexid:Carik rdfs:label "Carik"^^xsd:string.
# lexid:Kepala_Bagian_BPD rdfs:label "Kepala Bagian BPD"^^xsd:string.
# lexid:Anggota_BPD rdfs:label "Anggota BPD"^^xsd:string.
# lexid:Pasal_II rdfs:label "Pasal II"^^xsd:string.
# lexid:Ketentuan_Pasal_II rdfs:label "Pasal II"^^xsd:string.
# lexid:Ketentuan_Pasal_II rdfs:label "Pasal II"^^xsd:string.
# lexid:Kepala_Bagian_BPD rdfs:label "Kepala Bagian BPD"^^xsd:string.
# lexid:Anggota_BPD rdfs:label "Anggota BPD"^^xsd:string.
# lexid:Kepala_Bagian_BPD rdfs:label "Kepala Bagian BPD"^^xsd:string.
# lexid:Ketentuan_Pasal_II rdfs:label "Ketentuan Pasal 24 ayat (3), (4), dan (6)"^^xsd:string.
# lexid:Lurah r
#  60%|██████    | 3/5 [07:16<05:34, 167.20s/it]
# 5 -shot
#  lexid:Person_Sudarsono rdf:type lexid-s:Person.
# lexid:Position_Sudarsono rdfs:label "Sudarsono"^^xsd:string.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasEnactionOffice lexid:Position_Bupati_Bantul.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasEnactionLocation lexid:City_Bantul.
# lexid:Position_Sudarsono rdf:type lexid-s:Position.
# lexid:Lurah rdf:type lexid-s:Person.
# lexid:Lurah rdfs:label "Lurah"^^xsd:string.
# lexid:Carik rdf:type lexid-s:Person.
# lexid:Kepala_Bagian rdf:type lexid-s:Person.
# lexid:Anggota_BPD rdf:type lexid-s:Person.
# lexid:Position_Bupati_Bantul rdfs:label "Bupati Bantul"^^xsd:string.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasEnactionOfficial lexid:Person_Sudarsono.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasPromulgationDate "2001-02-09"^^xsd:date.
# lexid:Position_Bupati_Bantul rdf:type lexid-s:Position.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah.
# lexid:Bantul rdf:type lexid-s:City.
# lexid:Drs_Ashadi rdf:type lexid-s:Person.
# lexid:Position_Bupati_Bantul rdfs:label "Drs Ashadi"^^xsd:string.
# lexid:NIP_490018672 rdf:type lexid-s:Person.
# lexid:NIP_490018672 rdfs:label "NIP 490018672"^^xsd:string.
# lexid:Position_Bupati_Bantul rdfs:label "Bupati Bantul"^^xsd:string.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasEnactionOffice lexid:Position_Sekretaris_BPD.
# lexid:Position_Sekretaris_BPD rdfs:label "Sekretaris BPD"^^xsd:string.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasPromulgationOfficial lexid:Person_Sudarsono.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasPromulgationDate "2001-02-10"^^xsd:date.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasPromulgationLocation lexid:City_Bantul.
# lexid:Position_Sekretaris_BPD rdf:type lexid-s:Position.
# lexid:NIP_490018672 rdf:type lexid-s:Person.
# lexid:Position_Sekretaris_BPD rdfs:label "NIP 490018672"^^xsd:string.
# lexid:Perkab_Bantul_2001_5 lexid-s:hasEnactionOffice lexid:Position_Sekretaris_BPD.
# lexid:Lurah rdfs:label "Lurah"^^xsd:string.
# lexid:Carik rdfs:label "Carik"^^xsd:string.
# lexid:Kepala_Bagian rdfs:label "Kepala Bagian"^^xsd:string.
# lexid:Anggota_BPD rdfs:label "Anggota BPD"^^xsd:string.
# 0 -shot
#  lexid:Dinas_Perindustrian_Perdagangan_Koperasi_Dan_Usaha_Kecil_Menengah rdfs:label "Dinas Perindustrian, Perdagangan, Koperasi dan Usaha Kecil Menengah"^^xsd:string.
# lexid:Dinas_Cita_Karya_Kebersihan_Dan_Perumahan rdfs:label "Dinas Cita Karya, Kebersihan dan Perumahan"^^xsd:string.
# lexid:Bupati_Paser rdfs:label "Bupati Paser"^^xsd:string.
# lexid:H.M._Ridwani_Suwidi lexid-s:hasPromulgationDate "2011-04-01"^^xsd:date.
# lexid:H.M._Ridwani_Suwidi lexid-s:hasPromulgationOfficial lexid:Bupati_Paser.
# lexid:H.Helmy_Lathyf lexid-s:hasPromulgationDate "2011-04-01"^^xsd:date.
# lexid:H.Helmy_Lathyf lexid-s:hasPromulgationOfficial lexid:Bupati_Paser.
# lexid:Lembaran_Daerah_Kabupaten_Paser_2011_Nomor_4 lexid-s:hasPromulgationPlace lexid:Tanah_Grogot.
# lexid:Lembaran_Daerah_Kabupaten_Paser_2011_Nomor_4 lexid-s:hasPromulgationOfficial lexid:Bupati_Paser.
# lexid:Dinas_Perindustrian_Perdagangan_Koperasi_Dan_Usaha_Kecil_Menengah lexid-s:hasEnactionOfficial lexid:H.Andi_Azis_Kasubbag_Produk_Hukum_Daerah.
# lexid:Dinas_Cita_Karya_Kebersihan_Dan_Perumahan lexid-s:hasEnactionOfficial lexid:H.Suwardi_Kabag_Hukum.
# lexid:H.Andi_Azis_Kasubbag lexid-s:hasPosition lexid:H.Andi_Azis_Kasubbag.
# lexid:H.Suwardi_Kabag lexid-s:hasPosition lexid:H.Suwardi_Kabag.
# lexid:H.Helmy_Lathyf lexid-s:hasPosition lexid:H.Helmy_Lathyf.
# lexid:H.H.M._Ridwani_Suwidi lexid-s:hasPosition lexid:H.M._Ridwani_Suwidi.
# lexid:H.Helmy_Lathyf lexid-s:hasPosition lexid:H.Helmy_Lathyf.
# lexid:Bupati_Paser lexid-s:hasPosition lexid:H.Helmy_Lathyf.
# lexid:H.Andi_Azis_Kasubbag lexid-s:hasPosition lexid:H.Andi_Azis_Kasubbag.
# lexid:H.Suwardi_Kabag lexid-s:hasPosition lexid:H.Suwardi_Kabag.
# lexid:H.H.M._Ridwani_Suwidi lexid-s:hasPosition lexid:H.M._Ridwani_Suwidi.
# lexid:H.Andi_Azis_Kasubbag lexid-s:hasPosition lexid:H.Andi_Azis_Kasubbag.
# lexid:H.Suwardi_Kabag lexid-s:hasPosition lexid:H.Suwardi_Kabag.
# lexid:H.H.M._Ridwani_Suwidi lexid-s:hasPosition lexid:H.M._Ridwani_Suwidi.
# lexid:H.Andi_Azis_Kasubbag lexid-s:has
# 1 -shot
#  lexid:Dinas_Perindustrian_Perdagangan_Koperasi_Dan_Usaha_Kecil_Menengah_Kabupaten_Paser rdfs:label "Dinas Perindustrian, Perdagangan, Koperasi dan Usaha Kecil Menengah Kabupaten Paser"^^xsd:string.
# lexid:Dinas_Cita_Karya_Kebersihan_Dan_Perumahan_Kabupaten_Paser rdfs:label "Dinas Cita Karya, Kebersihan dan Perumahan Kabupaten Paser"^^xsd:string.
# lexid:Bupati_Paser rdfs:label "Bupati Paser"^^xsd:string.
# lexid:H.M._Ridwan_Suwidi lexid-s:hasEnactionOfficial lexid:Bupati_Paser.
# lexid:H.H._Helmy_Lathyf lexid-s:hasEnactionOfficial lexid:Sekretaris_Daerah_Kabupaten_Paser.
# lexid:Perkab_PASER_2011_4 lexid-s:hasEnactionOffice lexid:Bupati_Paser.
# lexid:Perkab_PASER_2011_4 lexid-s:hasEnactionLocation lexid:Tanah_Grogot.
# lexid:Perkab_PASER_2011_4 lexid-s:hasEnactionDate "2011-04-01"^^xsd:date.
# lexid:Lembaran_Daerah_Kabupaten_Paser Tahun_2011 No_4 lexid-s:hasEnactionOffice lexid:Bupati_Paser.
# lexid:Dinas_Perindustrian_Perdagangan_Koperasi_Dan_Usaha_Kecil_Menengah_Kabupaten_Paser lexid-s:hasPromulgationOffice lexid:Dinas_Cita_Karya_Kebersihan_Dan_Perumahan_Kabupaten_Paser.
# lexid:Dinas_Cita_Karya_Kebersihan_Dan_Perumahan_Kabupaten_Paser lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Paser.
# lexid:Dinas_Cita_Karya_Kebersihan_Dan_Perumahan_Kabupaten_Paser lexid-s:hasPromulgationDate "2011-04-01"^^xsd:date.
# lexid:Bupati_Paser lexid-s:hasPromulgationOfficial lexid:Lembaran_Daerah_Kabupaten_Paser.
# lexid:Bupati_Paser lexid-s:hasPromulgationPlace lexid:Tanah_Grogot.
# lexid:Bupati_Paser lexid-s:hasPromulgationDate "2011-04-01"^^xsd:date.
# lexid:Lembaran_Daerah_Kabupaten_Paser Tahun_2011 No_4 lexid-s:hasPromulgationOfficial lexid:Bupati_Paser.
# lexid:Lembaran_Daerah_Kabupaten_Paser Tahun_2011 No_4 lexid-s:hasPromulgationPlace lexid:Tanah_Grogot.
# lexid:Lembaran_Daerah_Kabupaten_Paser Tahun_2011 No_4 lexid-s:hasPromulgationDate "2011-04-01"^^xsd:date.
# lexid:Dinas_Perindustrian_Perdagangan_Koperasi_Dan_Usaha_Kecil_Menengah_Kabupaten_Paser lexid-s:hasPromulgationOffice lexid:Dinas_Cita_Karya_Kebersihan_Dan_Perumahan_Kabupaten_Paser.
# 2 -shot
#  lexid:Person_H_M_Ridwan_Suwidi rdfs:label "H.M. Ridwan Suwidi"^^xsd:string.
# lexid:Person_H_Helmy_Lathyf rdfs:label "H. Helmy Lathyf"^^xsd:string.
# lexid:Position_Secretaris_Daerah_Kabupaten_Paser rdfs:label "Secretaris Daerah Kabupaten Paser".
# lexid:Position_Sekretaris_Daerah_Kabupaten_Paser rdf:type lexid-s:Position.
# lexid:Position_Paraf_Kabupaten_Paser rdfs:label "Paraf Kabupaten Paser".
# lexid:Position_Paraf_Kabupaten_Paserkan0000000000000000000000004yang0000004000000000000000000000000000000okO000000000000000000000000000000000004kan000000a0000000000akaky00004400000000000ark000000,3 per0000a//at00angikuiku
# 044y4y00oangunyangat0y0yM00000o4yangikuik00//0y44y004444y0004,040000ik000444y0000000004angij0y0000kk,00KIO,y00000I0000O-4000idanib0yeliotik (y000004angiku,mik,e,00400,,0aaaikuember,0,,0,00,,0,en000aty0ot000,0,044y0y00ang4angangang03,4y04y4yang :y00M0y,kany0angemariyangemang,00a04i4ang00000i00erikanik0e00004y903444yang0angyangia00004il0000//000kemang30e000yangung000000000angikuem00000yper//00000000000y000003000000k0004KIII00000D0000000000Ke0000040000//y00ang00,,000//0, per000//I//0000,0,y0000,,0000330000e
# ang00ang3yangy000y0ang00,0a00000yk//y000e000y0,y0000//000,3//y00ang00//ng00500400.
# ,a//y0ang
# angy000otakanyangik000yikotan0000angik004iY0000,y0atilik000004y0404y0il00.0000,000000y,,,00,0ypere//I//000ililang0000000000kot00000ak00ak000enotunang0,-0,,0y0y-
# y00000000,,e00angikunyangojang00000005ik0000ang0yang000
# 3 -shot
#  lexid:Peraturan_Paser_2011_4 lexid-s:hasEnactionOffice lexid:Position_H.M.Ridwan_Sudui.
# lexid:Position_H.Suwardi Kabag.Hukum rdf:type lexid-s:Position.
# lexid:Position_H.Andi_Azis_Kasubbag rdf:type lexid-s:Person.
# lexid:Position_H.Suwardi_Kabag.Hukum rdfs:label "H. Suwardi Kabag.Hukum"^^xsd:string.
# lexid:Position_H.Andi_Azis_Kasubbag rdfs:label "H. Andi Azis Kasubbag"^^xsd:string.
# lexid:Position_H.Helmy_Lathyf rdf:type lexid-s:Person.
# lexid:Peraturan_Paser_2011_4 lexid-s:hasEnactionLocation lexid:Lembaran_Daerah_Kabupaten_Paser.
# lexid:Position_H.M.Ridwan_Sudui rdfs:label "H. M. Ridwan Sudui"^^xsd:string.
# lexid:Position_H.Suwardi_Kabag.Hukum rdf:type lexid-s:Position.
# lexid:Position_H.Helmy_Lathyf rdf:type lexid-s:Position.
# lexid:Lembaran_Daerah_Kabupaten_Paser lexid-s:hasPromulgationDate "2011-04-01"^^xsd:date.
# lexid:Lembaran_Daerah_Kabupaten_Paser lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Paser.
# lexid:Position_H.M.Ridwan_Sudui rdf:type lexid-s:Position.
# lexid:Position_H.Suwardi_Kabag.Hukum rdf:type lexid-s:Position.
# lexid:Position_H.Andi_Azis_Kasubbag rdfs:label "H. Andi Azis Kasubbag"^^xsd:string.
# lexid:Position_H.Suwardi_Kabag.Hukum rdfs:label "H. Suwardi Kabag.Hukum"^^xsd:string.
# lexid:Position_H.Helmy_Lathyf rdfs:label "H. Helmy Lathyf"^^xsd:string.
# lexid:Lembaran_Daerah_Kabupaten_Paser lexid-s:hasPromulgationOfficial lexid:Person_H.Suwardi_Kabag.Hukum.
# lexid:Lembaran_Daerah_Kabupaten_Paser lexid-s:hasPromulgationDate "2011-04-01"^^xsd:date.
# lexid:Lembaran_Daerah_Kabupaten_Paser lexid-s:hasPromulgationOfficial lexid:Person_H.Suwardi_Kabag.Hukum.
# lexid:Lembaran_Daerah_Kabupaten_Paser lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Paser.
# lexid:Position_H.Andi_Azis_Kasubbag rdfs:label "H. Andi Azis Kasubbag"^^xsd:string.
# lexid:Position_H.Suwardi_Kabag.Hukum rdfs:label "H. Suwardi Kabag.Hukum"^^xsd:string.
# lexid:Lembaran_Daerah_Kabupaten_Paser lexid-s:hasPromulgationDate "2011-04-01"^^xsd:date.
# lexid:Lembaran_Daerah_Kabupaten_Paser lexid-s:hasPromulgationOfficial lexid:Person_H.Suwardi_Kabag.Hukum.
# lexid:Lembaran_Daerah_Kabupaten_
# 4 -shot
#  lexid:Person_H.M.Ridwan_Suwidi rdf:type lexid-s:Person.
# lexid:Person_H.Suwardi_Kabag.Hukum rdf:type lexid-s:Person.
# lexid:Person_H.Andi_Azis_Kasubbag rdf:type lexid-s:Person.
# lexid:Person_H.Helmy_Lathyf rdf:type lexid-s:Person.
# lexid:Perkab_Paser_2011_4 lexid-s:hasEnactionOffice lexid:Position_H.M.Ridwan_Suwidi.
# lexid:Perkab_Paser_2011_4 lexid-s:hasEnactionLocation lexid:Tanah_Grogot.
# lexid:Perkab_Paser_2011_4 lexid-s:hasPromulgationDate "2011-04-01"^^xsd:date.
# lexid:Position_H.M.Ridwan_Suwidi rdf:type lexid-s:Position.
# lexid:Position_H.Suwardi_Kabag.Hukum rdf:type lexid-s:Position.
# lexid:Position_H.Andi_Azis_Kasubag rdf:type lexid-s:Position.
# lexid:Position_H.Suwardi_Kabag.Hukum rdf:type lexid-s:Position.
# lexid:Position_H.Helmy_Lathyf rdf:type lexid-s:Position.
# lexid:Perkab_Paser_2011_4 lexid-s:hasPromulgationOfficial lexid:Person_H.M.Ridwan_Suwidi.
# lexid:Perkab_Paser_2011_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Paser.
# lexid:Perkab_Paser_2011_4 lexid-s:hasPromulgationOffice lexid:Position_H.M.Ridwan_Suwidi.
# lexid:Perkab_Paser_2011_4 lexid-s:hasPromulgationLocation lexid:Tanah_Grogot.
# lexid:Perkab_Paser_2011_4 lexid-s:hasEnactionOffice lexid:Position_H.Suwardi_Kabag.Hukum.
# lexid:Perkab_Paser_2011_4 lexid-s:hasEnactionLocation lexid:Tanah_Grogot.
# lexid:Perkab_Paser_2011_4 lexid-s:hasEnactionOffice lexid:Position_H.Andi_Azis_Kasubag.
# lexid:Perkab_Paser_2011_4 lexid-s:hasEnactionOffice lexid:Position_H.Suwardi_Kabag.Hukum.
# lexid:Perkab_Paser_2011_4 lexid-s:hasEnactionOffice lexid:Position_H.Helmy_Lathyf.
# lexid:Perkab_Paser_2011_4 lexid-s:hasEnactionDate "2011-04-01"^^xsd:date.
# lexid:Position_H.M.Ridwan_Suwidi rdfs:label "Kepala Bidang Hukum Setda Kabupaten Paser"^^xsd:string.
# lexid:Position_H.Suwardi_Kabag.Hukum rdfs:label "Kabag Hukum"^^xsd:string.
# lexid:Position_H.Helmy_Lathyf rdfs:label "Sekretaris Daerah"^^xsd:string.
# lexid:Perkab_Paser_2011_4 lexid-s:hasPromulgationDate "2011-04-01"^^xsd:date.
# lexid:Position_H.Andi_Azis_Kasubag rdfs:label
#  80%|████████  | 4/5 [11:18<03:16, 196.54s/it]
# 5 -shot
#  lexid:Position_H.M.Ridwan_Sudwidi rdf:type lexid-s:Person.
# lexid:Position_H.Suwardi_Kabag.Hukum rdf:type lexid-s:Person.
# lexid:Position_H.Andi_Azis_Kasubbag rdf:type lexid-s:Person.
# lexid:Position_H.Suwardi_H.Helmy_Lathyf rdf:type lexid-s:Person.
# lexid:Peraturan_Paser_2011_4 lexid-s:hasEnactionOffice lexid:Position_H.M.Ridwan_Sudwidi.
# lexid:Peraturan_Paser_2011_4 lexid-s:hasEnactionLocation lexid:Tanah_Grogot.
# lexid:Peraturan_Paser_2011_4 lexid-s:hasEnactionOffice lexid:Position_H.Suwardi_Kabag.Hukum.
# lexid:Peraturan_Paser_2011_4 lexid-s:hasEnactionOfficial lexid:Person_H.M.Ridwan_Sudwidi.
# lexid:Peraturan_Paser_2011_4 lexid-s:hasPromulgationDate "2011-04-01"^^xsd:date.
# lexid:Position_H.Suwardi_Kabag.Hukum rdf:type lexid-s:Position.
# lexid:Position_H.Suwardi_Kabag.Hukum rdfs:label "H. Suwardi Kabag. Hukum"^^xsd:string.
# lexid:Position_H.Andi_Azis_Kasubbag rdfs:label "H. Andi Azis Kasubbag"^^xsd:string.
# lexid:Position_H.Suwardi_Kabag.Hukum rdfs:label "H. Suwardi Kabag. Hukum"^^xsd:string.
# lexid:Position_H.Helmy_Lathyf rdfs:label "H. Helmy Lathyf"^^xsd:string.
# lexid:Peraturan_Paser_2011_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Paser.
# lexid:Peraturan_Paser_2011_4 lexid-s:hasPromulgationOfficial lexid:Person_H.M.Ridwan_Sudwidi.
# lexid:Peraturan_Paser_2011_4 lexid-s:hasPromulgationLocation lexid:Tanah_Grogot.
# lexid:Peraturan_Paser_2011_4 lexid-s:hasEnactionLocation lexid:Tanah_Grogot.
# lexid:Position_H.Suwardi_Kabag.Hukum rdf:type lexid-s:Position.
# lexid:Position_H.Andi_Azis_Kasubbag rdf:type lexid-s:Position.
# lexid:Position_H.Suwardi_Kabag.Hukum rdf:type lexid-s:Position.
# lexid:Position_H.Helmy_Lathyf rdf:type lexid-s:Position.
# lexid:Peraturan_Paser_2011_4 lexid-s:hasEnactionOffice lexid:Position_H.Suwardi_Kabag.Hukum.
# lexid:Peraturan_Paser_2011_4 lexid-s:hasEnactionOffice lexid:Position_H.Helmy_Lathyf.
# lexid:Tanah_Grogot rdf:type lexid-s:City.
# lexid:Position_H.Suwardi_Kabag.Hukum rdfs:label "Kabupaten Paser"^^xsd:string.
# lexid:Position_H.Andi_Azis_Kasubbag rdfs:label "Kabupaten Paser"^^xsd:string.
# lexid:Position_H.Suward
# 0 -shot
#  lexid:Regulation_PERKAB_TRENGGALEK_2011_7 rdfs:label "PERKAB TRENGGALEK 2011 7"^^xsd:string.
# lexid:Tanggal_diundangkan "2011-05-10"^^xsd:date.
# lexid:Tanggal_diundangkan "2011-08-18"^^xsd:date.
# lexid:Tanggal_diundangkan "2011-10-27"^^xsd:date.
# lexid:Bupati_Trenggalek rdf:type lexid-s:Office.
# lexid:Bupati_Trenggalek rdfs:label "Bupati Trenggalek"^^xsd:string.
# lexid:Secretaris_daerah_Trenggalek rdf:type lexid-s:Office.
# lexid:Secretaris_daerah_Trenggalek rdfs:label "Secretaris Daerah Trenggalek"^^xsd:string.
# lexid:Cipto_Wiyono rdf:type lexid-s:Office.
# lexid:Cipto_Wiyono rdfs:label "Cipto Wiyono"^^xsd:string.
# lexid:Lembaran_daerah_Trenggalek rdf:type lexid-s:Document.
# lexid:Lembaran_daerah_Trenggalek rdfs:label "Lembaran Daerah Trenggalek"^^xsd:string.
# lexid:Reg_188.342/IV/406.013/2011 lexid-s:hasRegulationNumber "188.342/IV/406.013/2011"^^xsd:string.
# lexid:Reg_188.342/IV/406.013/2011 lexid-s:hasRegulationDate "2011-10-27"^^xsd:date.
# lexid:Bupati_Trenggalek lexid-s:hasOfficeLocation lexid:Kabupaten_Trenggalek.
# lexid:Secretaris_daerah_Trenggalek lexid-s:hasOfficeLocation lexid:Kabupaten_Trenggalek.
# lexid:Cipto_Wiyono lexid-s:hasOfficeLocation lexid:Kabupaten_Trenggalek.
# lexid:Bupati_Trenggalek rdfs:label "Bupati Trenggalek"^^xsd:string.
# lexid:Secretaris_daerah_Trenggalek rdfs:label "Secretaris Daerah Trenggalek"^^xsd:string.
# lexid:Cipto_Wiyono rdfs:label "Cipto Wiyono"^^xsd:string.
# lexid:Kabupaten_Trenggalek rdf:type lexid-s:Kabupaten.
# lexid:Kabupaten_Trenggalek rdfs:label "Kabupaten Trenggalek"^^xsd:string.
# 1 -shot
#  lexid:Position_Bupati_Trenggalek rdfs:label "Bupati Trenggalek"^^xsd:string.
# lexid:Position_Sekretaris_Daerah_Trenggalek rdfs:label "Sekretaris Daerah Trenggalek"^^xsd:string.
# lexid:Person_Bambang_Agus_Setyaji rdf:type lexid-s:Person.
# lexid:Perkab_Trenggalek_2011_7 lexid-s:hasEnactionOffice lexid:Position_Bupati_Trenggalek.
# lexid:Perkab_Trenggalek_2011_7 lexid-s:hasEnactionOffice lexid:Position_Sekretaris_Daerah_Trenggalek.
# lexid:Perkab_Trenggalek_2011_7 lexid-s:hasEnactionLocation lexid:Kabupaten_Trenggalek.
# lexid:Kabupaten_Trenggalek rdf:type lexid-s:Kabupaten.
# lexid:Perkab_Trenggalek_2011_7 lexid-s:hasPromulgationOfficial lexid:Person_Bambang_Agus_Setyaji.
# lexid:Perkab_Trenggalek_2011_7 lexid-s:hasPromulgationPlace lexid:Lembaran_daerah.
# lexid:Perkab_Trenggalek_2011_7 lexid-s:hasPromulgationDate "2011-10-27"^^xsd:date.
# lexid:Position_Bupati_Trenggalek rdf:type lexid-s:Position.
# lexid:Position_Sekretaris_Daerah_Trenggalek rdf:type lexid-s:Position.
# lexid:Perkab_Trenggalek_2011_7 lexid-s:hasPromulgationOffice lexid:Position_Bupati_Trenggalek.
# lexid:Perkab_Trenggalek_2011_7 lexid-s:hasPromulgationOffice lexid:Position_Sekretaris_Daerah_Trenggalek.
# lexid:Perkab_Trenggalek_2011_7 lexid-s:hasPromulgationLocation lexid:Kabupaten_Trenggalek.
# lexid:Lembaran_daerah rdf:type lexid-s:Lembaran.
# lexid:Perkab_Trenggalek_2011_7 lexid-s:hasPromulgationPlace lexid:Lembaran_daerah.
# lexid:Perkab_Trenggalek_2011_7 lexid-s:hasPromulgationDate "2011-10-27"^^xsd:date.
# 2 -shot
#  lexid:Person_Bambang_Agus_Setyaji rdfs:label "Bambang Agus Setyaji"^^xsd:string.
# lexid:Permenko_Perekonomian_2015_12 lexid-s:hasEnactionOfficial lexid:Person_Bambang_Agus_Setyaji.
# lexid:City_Trenggalek rdfs:label "Trenggalek"^^xsd:string.
# lexid:Permenko_Perekonomian_2015_12 lexid-s:hasEnactionLocation lexid:City_Trenggalek.
# lexid:Position_Bupati_Trenggalek rdfs:label "Bupati Trenggalek"^^xsd:string.
# lexid:Position_Sekretaris_Daerah_Kabupaten_Trenggalek rdfs:label "Sekretaris Daerah Kabupaten Trenggalek"^^xsd:string.
# lexid:Person_Bambang_Agus_Setyaji rdf:type lexid-s:Person.
# lexid:Position_Bupati_Trenggalek rdf:type lexid-s:Position.
# lexid:Position_Sekretaris_Daerah_Kabupaten_Trenggalek rdf:type lexid-s:Position.
# lexid:Permenko_Perekonomian_2011_7 lexid-s:hasPromulgationPlace lexid:
# iOD00000000000000D0000000000
#
#
# .
# 00000000000000i00000000000000i.
# 0000000000000000000000000000000000ji.iKIII.
# i0 teri.
# i
#
# I.
# .
# .D00I0000ki000000000ji0ki0II0000I00//0000.
# .
# .
#
#
#
# 000000.
# .
#
#
# .
#
# .
#
#
# .00000II0n.
# .00
# je
# 3 -shot
#  lexid:Position_Kepala_Biro_Hukum_Trenggalek rdf:type lexid-s:Position.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationOffice lexid:Position_Kepala_Biro_Hukum_Trenggalek.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasEnactionLocation lexid:Kabupaten_Trenggalek.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationDate "2011-08-18"^^xsd:date.
# lexid:Person_Bambang_Agus_Setyaji rdf:type lexid-s:Person.
# lexid:Position_Kepala_Biro_Hukum_Trenggalek rdfs:label "Kepala Biro Hukum Trenggalek"^^xsd:string.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationOfficial lexid:Person_Bambang_Agus_Setyaji.
# lexid:Kabupaten_Trenggalek rdfs:label "Kabupaten Trenggalek"^^xsd:string.
# lexid:Lembaran_Daerah_Kabupaten_Trenggalek lexid-s:hasPromulgationPlace lexid:Kabupaten_Trenggalek.
# lexid:Bupati_Trenggalek rdf:type lexid-s:Position.
# lexid:Bupati_Trenggalek rdfs:label "Bupati Trenggalek"^^xsd:string.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationOffice lexid:Bupati_Trenggalek.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationDate "2011-08-18"^^xsd:date.
# lexid:Bupati_Trenggalek rdf:type lexid-s:Person.
# lexid:Bupati_Trenggalek rdfs:label "Bupati Trenggalek"^^xsd:string.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationOfficial lexid:Person_Cipto_Wiyo_Ngo.
# lexid:Kabupaten_Trenggalek rdf:type lexid-s:City.
# lexid:Bupati_Trenggalek rdfs:label "Bupati Trenggalek"^^xsd:string.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationPlace lexid:Kabupaten_Trenggalek.
# lexid:Person_Cipto_Wiyo_Ngo rdf:type lexid-s:Person.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationDate "2011-08-18"^^xsd:date.
# 4 -shot
#  lexid:Position_Bagian_Hukum_Kabupaten_Trenggalek rdf:type lexid-s:Position.
# lexid:Perwali_Trenggalek_2011_7 lexid-s:hasEnactionOffice lexid:Position_Bagian_Hukum_Kabupaten_Trenggalek.
# lexid:Perwali_Trenggalek_2011_7 lexid-s:hasPromulgationDate "2011-10-27"^^xsd:date.
# lexid:Perwali_Trenggalek_2011_7 lexid-s:hasPromulgationOfficial lexid:Person_Bambang_Agus_Setyaji.
# lexid:Kabupaten_Trenggalek rdfs:label "Kabupaten Trenggalek"^^xsd:string.
# lexid:Lembaran_daerah_Trenggalek rdf:type lexid-s:Lembaran.
# lexid:Perwali_Trenggalek_2011_7 lexid-s:hasPromulgationPlace lexid:City_Trenggalek.
# lexid:Position_Bambang_Agus_Setyaji rdfs:label "Bambang Agus Setyaji"^^xsd:string.
# lexid:Kabupaten_Trenggalek rdf:type lexid-s:Kabupaten.
# lexid:Lembaran_daerah_Trenggalek rdf:type lexid-s:Lembaran.
# lexid:Perwali_Trenggalek_2011_7 lexid-s:hasPromulgationOffice lexid:Person_Bambang_Agus_Setyaji.
# lexid:Lembaran_daerah_Trenggalek lexid-s:hasPromulgationLocation lexid:City_Trenggalek.
# lexid:Perwali_Trenggalek_2011_7 lexid-s:hasEnactionOfficial lexid:Person_Bambang_Agus_Setyaji.
# lexid:Kabupaten_Trenggalek rdf:type lexid-s:Kabupaten.
# lexid:Lembaran_daerah_Trenggalek rdf:type lexid-s:Lembaran.
# lexid:Perwali_Trenggalek_2011_7 lexid-s:hasEnactionLocation lexid:City_Trenggalek.
# lexid:Person_Bambang_Agus_Setyaji rdf:type lexid-s:Person.
# lexid:Lembaran_daerah_Trenggalek lexid-s:hasEnactionOfficial lexid:Person_Bambang_Agus_Setyaji.
# lexid:Lembaran_daerah_Trenggalek lexid-s:hasPromulgationPlace lexid:Lembaran_daerah_Trenggalek.
# lexid:Perwali_Trenggalek_2011_7 lexid-s:hasEnactionOffice lexid:Person_Bambang_Agus_Setyaji.
# lexid:Kabupaten_Trenggalek rdf:type lexid-s:Kabupaten.
# lexid:Lembaran_daerah_Trenggalek rdf:type lexid-s:Lembaran.
# lexid:Perwali_Trenggalek_2011_7 lexid-s:hasEnactionLocation lexid:City_Trenggalek.
# lexid:Lembaran_daerah_Trenggalek lexid-s:hasPromulgationOfficial lexid:Person_Bambang_Agus_Setyaji.
# lexid:Kabupaten_Trenggalek rdf:type lexid-s:Kabupaten.
# lexid:Lembaran_daerah_Trenggalek rdf:type lexid-s:Lembaran.
# lexid:Perwali_Trenggalek_
# 100%|██████████| 5/5 [14:35<00:00, 175.14s/it]
# 5 -shot
#  lexid:Position_Bagian_Hukum_Kabupaten_Trenggalek rdf:type lexid-s:Position.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasEnactionOfficial lexid:Position_Bagian_Hukum_Kabupaten_Trenggalek.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasEnactionLocation lexid:City_Trenggalek.
# lexid:Position_Bamangas rdf:type lexid-s:Person.
# lexid:Person_Bamangas rdfs:label "Bamangas"^^xsd:string.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationDate "2011-08-27"^^xsd:date.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationOfficial lexid:Person_Bamangas.
# lexid:Position_Bamangas rdf:type lexid-s:Position.
# lexid:City_Trenggalek rdfs:label "Trenggalek"^^xsd:string.
# lexid:Position_Bamangas rdfs:label "Bamangas"^^xsd:string.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationPlace lexid:Lembaran_daerah.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasEnactionOffice lexid:Position_Bamangas.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationDate "2011-10-31"^^xsd:date.
# lexid:Person_Bamangas rdf:type lexid-s:Person.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationLocation lexid:City_Trenggalek.
# lexid:Position_Bamangas rdf:type lexid-s:Person.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationOfficial lexid:Person_Bamangas.
# lexid:City_Trenggalek rdf:type lexid-s:City.
# lexid:Position_Bamangas rdfs:label "Bamangas"^^xsd:string.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasEnactionOffice lexid:Position_Bagian_Hukum_Kabupaten_Trenggalek.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationDate "2011-08-27"^^xsd:date.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationLocation lexid:City_Trenggalek.
# lexid:Position_Bamangas rdf:type lexid-s:Person.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationPlace lexid:Lembaran_daerah.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasEnactionOfficial lexid:Person_Bamangas.
# lexid:Peraturan_Daerah_Trenggalek_2011_7 lexid-s:hasPromulgationOffice lexid:Position_Bagian_Hukum_Kabupaten_Trenggalek

# %%
import time

results = pd.DataFrame()
results = pd.DataFrame(columns=['1', '2', '3', '4', '5', '6'])

for x in tqdm(range(len(test_dataset))[1:2]):
#     if x % 100 == 0 and x > 0:
#         results.reset_index(inplace=True)
#         results.rename(columns={'index': 'regulatory'}, inplace=True)
#         results.to_csv(f'./result/fewshot_closing2_{x//100}.csv')
        
#         results = pd.DataFrame()
#         results = pd.DataFrame(columns=['1', '2', '3', '4', '5', '6'])
        
    data = test_dataset[x]
#     print(data)

    
    for k in range(6):              
        prompt = prompt_system + '\n'
        
        for i in range(k+1):
            data_fewshot = df_closing.iloc[i]
            prompt += prompt_user.format(regulatory=data_fewshot['regulatory'], teks=data_fewshot['text']) + '\n'
            prompt += data_fewshot['triples'] + '\n'
        
        prompt += prompt_user.format(regulatory=data['regulatory'], teks=data['text']) + '\n'
        
        messages = [
            {"role": "user", "content": prompt},
        ]
#         print(messages)
        try:
            print(k+1, '-shot')
            print(prompt)
            start_time = time.time()
            output = pipe_phi(messages, **generation_args)
            print(output[0]['generated_text'])
            results.at[data['regulatory'], f'{k + 1}'] = output[0]['generated_text']
#             print(time.time() - start_time)
        except:
            results.at[data['regulatory'], f'{k + 1}'] = ''
        
        break
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1 -shot
#
# Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
# - identifikasi sebanyak mungkin relation di antara entity
# - keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .
#
# Tipe entity paling penting adalah:
# - lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
# - lexid-s:Person, contoh: lexid:Person_Joko_Widodo
# - lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
# - lexid-s:City, contoh: lexid:City_Depok
#
# Relation paling penting adalah:
# - lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date .
# - lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
# - lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
# - lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
# - lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# - lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# - lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
# - lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# - lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
#
# JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
#
# ###regulatory: PP_2019_4
# ###Teks:
# ```
# Peraturan Pemerintah ini mulai berlaku pada tanggal
# diundangkan.
# www.peraturan.go.id
# 2019, No.12
# -9-
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Pemerintah ini dengan
# penempatannya dalam Lembaran Negara Republik
# Indonesia.
# Ditetapkan di Jakarta
# pada tanggal 23 Januari 2019
# PRESIDEN REPUBLIK INDONESIA,
# ttd
# JOKO WIDODO
# Diundangkan di Jakarta
# pada tanggal 28 Januari 2019
# MENTERI HUKUM DAN HAK ASASI MANUSIA
# REPUBLIK INDONESIA,
# ttd
# YASONNA H. LAOLLY
# www.peraturan.go.id
# ```
# ###output:
#
# lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
# lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
# lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
# lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
# lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
# lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
# lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# ###regulatory: PERKAB_ACEH_UTARA_2005_28
# ###Teks:
# ```
# Qanun ini berlaku pada tanggal diundangkan
# 28
# Agar setiap orang mengetahuinya memerintahkan
# pengundangan Qanun ini dengan penempatannya
# dalam Lembaran Daerah Kabupaten Aceh Utara.
# Ditetapkan di Lhokseumawe
# pada tanggal  15 Pebruari    2005 M
#                         6 Muharram 1426 H
# PENJABAT  BUPATI ACEH UTARA
# Cap/dto
# H. TEUKU  ALAMSYAH BANTA
# Diundangkan di Lhokseumawe
# pada tanggal   18 Februari     2005 M
#                          9 Muharram  1426 H
#  SEKRETARIS DAERAH,
# Drs. T. HARMAWAN, M.Si
#  Pembina Utama Muda
#        NIP. 010 073 653
# LEMBARAN DAERAH KABUPATEN ACEH UTARA TAHUN
# 2005 NOMOR  28
# 29
# ```
# ###output:
# 100%|██████████| 1/1 [00:22<00:00, 22.36s/it]
#  lexid:Person_H_Teuku_Alamsyah_Bantah rdfs:label "H. Teuku Alamsyah Bantah"^^xsd:string.
# lexid:Person_T_Harmawan_Drs_Mi rdfs:label "T. Harmawan, M.Si"^^xsd:string.
# lexid:Position_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:Position_Sekretaris_Daerah rdf:type lexid-s:Position.
# lexid:PP_2005_28 lexid-s:hasPromulgationDate "2005-02-18"^^xsd:date.
# lexid:PP_2005_28 lexid-s:hasEnactionDate "2005-02-15"^^xsd:date.
# lexid:PP_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_H_Teuku_Alamsyah_Bantah.
# lexid:PP_2005_28 lexid-s:hasEnactionOfficial lexid:Person_T_Harmawan_Drs_Mi.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:PP_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:PP_2005_28 lexid-s:hasPromulgationLocation lexid:City_Lhokseumawe.
# lexid:Position_Bupati_Aceh_Utara rdfs:label "Bupati Aceh Utara"^^xsd:string.
# lexid:Position_Sekretaris_Daerah rdfs:label "Sekretaris Daerah"^^xsd:string.
# lexid:PP_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:PP_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_T_Harmawan_Drs_Mi.

# %%
results.reset_index(inplace=True)
results.rename(columns={'index': 'regulatory'}, inplace=True)
results
# print(results.loc['PERKAB_TRENGGALEK_2011_7']['3'])
# Out:
#    level_0                 regulatory regulatory  \
# 0        0       PB_Menhut_BKN_2014_1        NaN
# 1        1  PERKAB_ACEH_UTARA_2005_28        NaN
# 2        2       PERKAB_BANTUL_2001_5        NaN
# 3        3        PERKAB_PASER_2011_4        NaN
# 4        4   PERKAB_TRENGGALEK_2011_7        NaN
#
#                                                    1  \
# 0
# 1   lexid:Perkab_Aceh_Utara_2005_28 lexid-s:hasPr...
# 2   lexid:PERKAB_BANTUL_2001_5 lexid-s:hasEnactio...
# 3   lexid:PERKAB_PASER_2011_4 lexid-s:hasPromulga...
# 4   lexid:PERKAB_TRENGGALEK_2011_7 lexid-s:hasPro...
#
#                                                    2  \
# 0
# 1   lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPro...
# 2   lexid:Perkab_Bantul_2001_5 lexid-s:hasPromulg...
# 3   lexid:Perkab_Paser_2011_4 lexid-s:hasPromulga...
# 4   lexid:Regulation_Trenggalek_2011_7 lexid-s:ha...
#
#                                                    3  \
# 0
# 1   lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPro...
# 2   lexid:Perkab_Bantul_2001_5 lexid-s:hasPromulg...
# 3   lexid:Perkab_Paser_2011_4 lexid-s:hasPromulga...
# 4   lexid:Perkab_Trenggalek_2011_7 lexid-s:hasPro...
#
#                                                    4 5 6 7 8 9 10
# 0
# 1   lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPro...
# 2   lexid:Perkab_Bantul_2001_5 lexid-s:hasPromulg...
# 3
# 4   lexid:Perkab_TRENGGALEK_2011_7 lexid-s:hasPro...

# %%
result = pd.read_csv('./result/fewshot_closing_5.csv')
print(result.iloc[1]['regulatory'])
print(result.iloc[1]['1'])
# Out:
# Peraturan_Basarnas_2014_6
#  lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationDate "2014-02-19"^^xsd:date.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasEnactionLocation lexid:Berita_Negara.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasEnactionOfficial lexid:Person_Muhammad_Alfan_Baharudin.
# lexid:Person_Muhammad_Alfan_Baharudin rdf:type lexid-s:Person.
# lexid:Person_Amir_Syamsudin rdf:type lexid-s:Person.
# lexid:Berita_Negara rdf:type lexid-s:Publication.
# lexid:City_Jakarta rdf:type lexid-s:City.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationOfficial lexid:Person_Amir_Syamsudin.
# lexid:Person_Amir_Syamsudin rdf:type lexid-s:Person.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationOffice lexid:Kepala_Badan_SAR_Nasional.
# lexid:Kepala_Badan_SAR_Nasional rdf:type lexid-s:Position.
# lexid:Person_Muhammad_Alfan_Baharudin rdfs:label "Muhammad Alfan Baharudin"^^xsd:string.
# lexid:Person_Amir_Syamsudin rdfs:label "Amir Syamsudin"^^xsd:string.
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum dan Hak Asasi Manusia Republik Indonesia"^^xsd:string.
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position.
# lexid:Berita_Negara rdfs:label "Berita Negara"^^xsd:string.
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string.

# %%
print(result.iloc[1]['2'])
# Out:
#  lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationDate "2014-02-19"^^xsd:date.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationOfficial lexid:Person_Muhammad_Alfandi_Baharudin.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationPlace lexid:Berita_Negara_Republik_Indonesia.
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationOfficial lexid:Kepala_BADAN_SAR_NASIONAL.
# lexid:Kepala_BADAN_SAR_NASIONAL rdfs:label "Muhammad Alfandi Baharudin"^^xsd:string.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationDate "2014-03-14"^^xsd:date.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationOfficial lexid:Amir_Syamsudin.
# lexid:Amir_Syamsudin rdfs:label "Amir Syamsudin"^^xsd:string.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationPlace lexid:Berita_Negara_Republik_Indonesia.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationOfficial lexid:Minister_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
# lexid:Minister_Hukum_Dan_Hak_Asasi_Manusia rdfs:label "Amir Syamsudin"^^xsd:string.

# %%
print(result.iloc[1]['3'])
# Out:
#  lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationPlace lexid:Berita_Negara_Republik_Indonesia.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationDate "2014-02-19"^^xsd:date.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationOfficial lexid:Person_Muhammad_Alfan_Baharudin.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
# lexid:Person_Muhammad_Alfan_Baharudin rdfs:label "Muhammad Alfan Baharudin"^^xsd:string.
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationDate "2014-03-14"^^xsd:date.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationOfficial lexid:Person_Amir_Syamsudin.
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia rdfs:label "Menteri Hukum dan Hak Asasi Manusia Republik Indonesia"^^xsd:string.
# lexid:City_Jakarta rdf:type lexid-s:City.
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationOfficial lexid:Person_Amir_Syamsudin.

# %%
print(test_dataset[401]['triples'])
# Out:
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasEnactionOffice lexid:Position_Kepala_Badan_Sar_Nasional .
# lexid:Position_Kepala_Badan_Sar_Nasional rdf:type lexid-s:Position .
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationPlace lexid:Berita_Negara .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Position_Kepala_Badan_Sar_Nasional rdfs:label "Kepala Badan Sar Nasional"^^xsd:string .
# lexid:Peraturan_Basarnas_2014_6 lexid-s:hasPromulgationDate "2014-03-14"^^xsd:date .

# %%
test_dataset
# Out:
# Dataset({
#     features: ['regulatory', 'label', 'text', 'triples', '__index_level_0__'],
#     num_rows: 2163
# })

# %%
### mencoba full prompt
prompt = f"""
Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date .
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.

Contoh:
###regulatory: PP_2019_4
###Teks: 
```
Peraturan Pemerintah ini mulai berlaku pada tanggal 
diundangkan. 
www.peraturan.go.id
2019, No.12 
-9- 
Agar setiap orang mengetahuinya, memerintahkan 
pengundangan Peraturan Pemerintah ini dengan 
penempatannya dalam Lembaran Negara Republik 
Indonesia. 
Ditetapkan di Jakarta 
pada tanggal 23 Januari 2019  
PRESIDEN REPUBLIK INDONESIA, 
ttd 
JOKO WIDODO 
Diundangkan di Jakarta 
pada tanggal 28 Januari 2019 
MENTERI HUKUM DAN HAK ASASI MANUSIA  
REPUBLIK INDONESIA,  
ttd 
YASONNA H. LAOLLY 
www.peraturan.go.id
```
###output:
lexid:Person_Joko_Widodo rdfs:label ""Joko Widodo""^^xsd:string .
lexid:City_Jakarta rdfs:label ""Jakarta""^^xsd:string .
lexid:PP_2019_4 lexid-s:hasPromulgationDate ""2019-01-28""^^xsd:date .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label ""Presiden Republik Indonesia""^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:Person_Yasonna_H_Laolly rdfs:label ""Yasonna H Laolly""^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label ""Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia""^^xsd:string .

###regulatory: {test_dataset[1]['regulatory']}
###Teks: 
```
{test_dataset[1]['text']}
```
###output:
"""

print(prompt)
# Out:
# Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
# - identifikasi sebanyak mungkin relation di antara entity
# - keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .
#
# Tipe entity paling penting adalah:
# - lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
# - lexid-s:Person, contoh: lexid:Person_Joko_Widodo
# - lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
# - lexid-s:City, contoh: lexid:City_Depok
#
# Relation paling penting adalah:
# - lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date .
# - lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
# - lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
# - lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
# - lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# - lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# - lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
# - lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# - lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
#
# JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
#
# Contoh:
# ###regulatory: PP_2019_4
# ###Teks:
# ```
# Peraturan Pemerintah ini mulai berlaku pada tanggal
# diundangkan.
# www.peraturan.go.id
# 2019, No.12
# -9-
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Pemerintah ini dengan
# penempatannya dalam Lembaran Negara Republik
# Indonesia.
# Ditetapkan di Jakarta
# pada tanggal 23 Januari 2019
# PRESIDEN REPUBLIK INDONESIA,
# ttd
# JOKO WIDODO
# Diundangkan di Jakarta
# pada tanggal 28 Januari 2019
# MENTERI HUKUM DAN HAK ASASI MANUSIA
# REPUBLIK INDONESIA,
# ttd
# YASONNA H. LAOLLY
# www.peraturan.go.id
# ```
# ###output:
# lexid:Person_Joko_Widodo rdfs:label ""Joko Widodo""^^xsd:string .
# lexid:City_Jakarta rdfs:label ""Jakarta""^^xsd:string .
# lexid:PP_2019_4 lexid-s:hasPromulgationDate ""2019-01-28""^^xsd:date .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
# lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Position_Presiden_Republik_Indonesia rdfs:label ""Presiden Republik Indonesia""^^xsd:string .
# lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
# lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
# lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
# lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
# lexid:Person_Yasonna_H_Laolly rdfs:label ""Yasonna H Laolly""^^xsd:string .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label ""Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia""^^xsd:string .
#
# ###regulatory: PERKAB_ACEH_UTARA_2005_28
# ###Teks:
# ```
# Qanun ini berlaku pada tanggal diundangkan
# 28
# Agar setiap orang mengetahuinya memerintahkan
# pengundangan Qanun ini dengan penempatannya
# dalam Lembaran Daerah Kabupaten Aceh Utara.
# Ditetapkan di Lhokseumawe
# pada tanggal  15 Pebruari    2005 M
#                         6 Muharram 1426 H
# PENJABAT  BUPATI ACEH UTARA
# Cap/dto
# H. TEUKU  ALAMSYAH BANTA
# Diundangkan di Lhokseumawe
# pada tanggal   18 Februari     2005 M
#                          9 Muharram  1426 H
#  SEKRETARIS DAERAH,
# Drs. T. HARMAWAN, M.Si
#  Pembina Utama Muda
#        NIP. 010 073 653
# LEMBARAN DAERAH KABUPATEN ACEH UTARA TAHUN
# 2005 NOMOR  28
# 29
# ```
# ###output:

# %%
messages = [
    {"role": "user", "content": prompt},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
#  lexid:Person_H_Teuku_Alamsyah_Bantah rdf:type lexid-s:Person.
# lexid:Person_T_Harmawan_MiSi rdf:type lexid-s:Person.
# lexid:Position_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:Position_Secretaris_Daerah rdf:type lexid-s:Position.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationDate ""2005-02-18""^^xsd:date.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_H_Teuku_Alamsyah_Bantah.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasEnactionDate ""2005-02-28""^^xsd:date.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationLocation lexid:City_Lhokseumawe.
# lexid:Position_Bupati_Aceh_Utara rdfs:label ""Bupati Aceh Utara""^^xsd:string.
# lexid:Position_Secretaris_Daerah rdfs:label ""Secretaris Daerah""^^xsd:string.
# lexid:City_Lhokseumawe rdfs:label ""Lhokseumawe""^^xsd:string.
# lexid:Person_H_Teuku_Alamsyah_Bantah rdf:type lexid-s:Person.
# lexid:Person_T_Harmawan_MiSi rdf:type lexid-s:Person.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasEnactionOfficial lexid:Person_T_Harmawan_MiSi.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasEnactionOffice lexid:Position_Bupati_Aceh_Utara.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationOffice lexid:Position_Secretaris_Daerah.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationDate lexid:Qanun_Aceh_Utara_2005_28.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_T_Harmawan_MiSi.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasEnactionDate lexid:Qanun_Aceh_Utara_2005_28.
# lexid:Qanun_Aceh_Utara_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H_Teuku_Alamsyah_Bantah.
# lexid:Qanun_Aceh_Utara_2

# %%
prompt1 = f"""
Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.

Ditetapkan di Jakarta pada tanggal 23 Januari 2019

PRESIDEN REPUBLIK INDONESIA,

ttd

JOKO WIDODO

Diundangkan di Jakarta pada tanggal 28 Januari 2019

MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,

ttd

YASONNA H. LAOLLY
```
###output:
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .

Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.

###regulatory:
{test_dataset[1]['regulatory']}
###prompt: 
```{test_dataset[1]['text']}```
###output:
"""
print(prompt1)
# Out:
# Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
# - identifikasi sebanyak mungkin relation di antara entity
# - keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .
#
# Tipe entity paling penting adalah:
# - lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
# - lexid-s:Person, contoh: lexid:Person_Joko_Widodo
# - lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
# - lexid-s:City, contoh: lexid:City_Depok
#
# Relation paling penting adalah:
# - lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
# - lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
# - lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
# - lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
# - lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
# - lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
# - lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
# - lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
# - lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.
#
# Contoh:
# ###regulatory: lexid:PP_2019_4
# ###prompt:
# ```
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Menteri ini dengan penempatannya
# dalam Berita Negara Republik Indonesia.
#
# Ditetapkan di Jakarta pada tanggal 23 Januari 2019
#
# PRESIDEN REPUBLIK INDONESIA,
#
# ttd
#
# JOKO WIDODO
#
# Diundangkan di Jakarta pada tanggal 28 Januari 2019
#
# MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,
#
# ttd
#
# YASONNA H. LAOLLY
# ```
# ###output:
# lexid:Person_Joko_Widodo rdfs:label ""Joko Widodo""^^xsd:string .
# lexid:City_Jakarta rdfs:label ""Jakarta""^^xsd:string .
# lexid:PP_2019_4 lexid-s:hasPromulgationDate ""2019-01-28""^^xsd:date .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
# lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Position_Presiden_Republik_Indonesia rdfs:label ""Presiden Republik Indonesia""^^xsd:string .
# lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
# lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
# lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
# lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
# lexid:Person_Yasonna_H_Laolly rdfs:label ""Yasonna H Laolly""^^xsd:string .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label ""Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia""^^xsd:string .
#
# Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.
#
# ###regulatory:
# PERKAB_ACEH_UTARA_2005_28
# ###prompt:
# ```Qanun ini berlaku pada tanggal diundangkan
# 28
# Agar setiap orang mengetahuinya memerintahkan
# pengundangan Qanun ini dengan penempatannya
# dalam Lembaran Daerah Kabupaten Aceh Utara.
# Ditetapkan di Lhokseumawe
# pada tanggal  15 Pebruari    2005 M
#                         6 Muharram 1426 H
# PENJABAT  BUPATI ACEH UTARA
# Cap/dto
# H. TEUKU  ALAMSYAH BANTA
# Diundangkan di Lhokseumawe
# pada tanggal   18 Februari     2005 M
#                          9 Muharram  1426 H
#  SEKRETARIS DAERAH,
# Drs. T. HARMAWAN, M.Si
#  Pembina Utama Muda
#        NIP. 010 073 653
# LEMBARAN DAERAH KABUPATEN ACEH UTARA TAHUN
# 2005 NOMOR  28
# 29```
# ###output:

# %%
messages = [
    {"role": "user", "content": prompt1},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
#  lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-18"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_H.TEUKU_ALAMSYAH_BANTA.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationLocation lexid:City_Lhokseumawe.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H.TEUKU_ALAMSYAH_BANTA.
# lexid:Person_H.TEUKU_ALAMSYAH_BANTA rdf:type lexid-s:Person.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:Person_H.TEUKU_ALAMSYAH_BANTA rdfs:label "H. Teuku Alaamsyah Bantah"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOffice lexid:Position_Bupati_Aceh_Utara.
# lexid:Position_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:Position_Bupati_Aceh_Utara rdfs:label "Bupati Aceh Utara"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdf:type lexid-s:Lembaran.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-28"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_T.HARMAWAN_DHS.
# lexid:Person_T.HARMAWAN_DHS rdf:type lexid-s:Person.
# lexid:Position_Bupati_Aceh_Utara rdfs:label "Bupati Aceh Utara"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_T.HARMAWAN_DHS.
# lexid:Person_T.HARMAWAN_DHS rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_T.HARMAWAN_DHS.
# lexid:Person_T.HARMAWAN_DHS rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionDate "2005-02-15"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial

# %%
messages = [
    {"role": "user", "content": prompt1},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
#  lexid:Person_H_Teuku_Alamsyah_Bantah rdfs:label ""H. Teuku Alamsyah Bantah""^^xsd:string.
# lexid:City_Lhokseumawe rdfs:label ""Lhokseumawe""^^xsd:string.
# lexid:PP_2005_28 lexid-s:hasPromulgationDate ""2005-02-15""^^xsd:date.
# lexid:Position_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:PP_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H_Teuku_Alamsyah_Bantah.
# lexid:PP_2005_28 lexid-s:hasPromulgationOffice lexid:Position_Bupati_Aceh_Utara.
# lexid:PP_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:Person_H_Teuku_Alamsyah_Bantah rdf:type lexid-s:Person.
# lexid:Secretary_Daerah rdfs:label ""Secretary Daerah""^^xsd:string.
# lexid:Drs_T_Harmawan rdfs:label ""Drs. T. Harmawan""^^xsd:string.
# lexid:NIP_010_073_653 rdf:type lexid-s:NIP.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah.
# lexid:PP_2005_28 lexid-s:hasPromulgationOfficial lexid:Secretary_Daerah.
# lexid:PP_2005_28 lexid-s:hasEnactionDate lexid:City_Lhokseumawe.
# lexid:PP_2005_28 lexid-s:hasPromulgationDate lexid:City_Lhokseumawe.
# lexid:Position_Bupati_Aceh_Utara rdfs:label ""Bupati Aceh Utara""^^xsd:string.
# lexid:PP_2005_28 lexid-s:hasEnactionOfficial lexid:Drs_T_Harmawan.
# lexid:PP_2005_28 lexid-s:hasPromulgationDate lexid:City_Lhokseumawe.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:NIP_010_073_653 rdf:type lexid-s:NIP.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara_2005_28 lexid-s:hasEnactionDate lexid:City_Lhokseumawe.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara_2005_28 lexid-s:hasEnactionOfficial lexid:Secretary_Daerah.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara_2005_28 lexid-s:hasPromulgationDate lexid:City_Lhokseumawe.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah.

# %%
prompt2 = f"""
Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.

Ditetapkan di Jakarta pada tanggal 23 Januari 2019

PRESIDEN REPUBLIK INDONESIA,

ttd

JOKO WIDODO

Diundangkan di Jakarta pada tanggal 28 Januari 2019

MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,

ttd

YASONNA H. LAOLLY
```
###output:
lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.

###regulatory:
{test_dataset[1]['regulatory']}
###prompt: 
```{test_dataset[1]['text']}```
###output:
"""
print(prompt2)
# Out:
# Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
# - identifikasi sebanyak mungkin relation di antara entity
# - keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .
#
# Tipe entity paling penting adalah:
# - lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
# - lexid-s:Person, contoh: lexid:Person_Joko_Widodo
# - lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
# - lexid-s:City, contoh: lexid:City_Depok
#
# Relation paling penting adalah:
# - lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
# - lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
# - lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
# - lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
# - lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
# - lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
# - lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
# - lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
# - lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.
#
# Contoh:
# ###regulatory: lexid:PP_2019_4
# ###prompt:
# ```
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Menteri ini dengan penempatannya
# dalam Berita Negara Republik Indonesia.
#
# Ditetapkan di Jakarta pada tanggal 23 Januari 2019
#
# PRESIDEN REPUBLIK INDONESIA,
#
# ttd
#
# JOKO WIDODO
#
# Diundangkan di Jakarta pada tanggal 28 Januari 2019
#
# MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,
#
# ttd
#
# YASONNA H. LAOLLY
# ```
# ###output:
# lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
# lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
# lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
# lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
# lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
# lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
# lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
# lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
# lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
# lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
# lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
#
#
#
#
# Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.
#
# ###regulatory:
# PERKAB_ACEH_UTARA_2005_28
# ###prompt:
# ```Qanun ini berlaku pada tanggal diundangkan
# 28
# Agar setiap orang mengetahuinya memerintahkan
# pengundangan Qanun ini dengan penempatannya
# dalam Lembaran Daerah Kabupaten Aceh Utara.
# Ditetapkan di Lhokseumawe
# pada tanggal  15 Pebruari    2005 M
#                         6 Muharram 1426 H
# PENJABAT  BUPATI ACEH UTARA
# Cap/dto
# H. TEUKU  ALAMSYAH BANTA
# Diundangkan di Lhokseumawe
# pada tanggal   18 Februari     2005 M
#                          9 Muharram  1426 H
#  SEKRETARIS DAERAH,
# Drs. T. HARMAWAN, M.Si
#  Pembina Utama Muda
#        NIP. 010 073 653
# LEMBARAN DAERAH KABUPATEN ACEH UTARA TAHUN
# 2005 NOMOR  28
# 29```
# ###output:

# %%
messages = [
    {"role": "user", "content": prompt2},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
#  lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionDate "2005-02-15"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-18"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H_Teuku_Alamsyah_Bantah.
# lexid:Person_H_Teuku_Alamsyah_Bantah rdfs:label "H. Teuku Alamsyah Bantah"^^xsd:string.
# lexid:Person_H_Teuku_Alamsyah_Bantah rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_T.Harmawan_Drs.
# lexid:Person_T.Harmawan_Drs rdfs:label "T. Harmawan Drs"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOffice lexid:Position_Bupati_Aceh_Utara.
# lexid:Position_Bupati_Aceh_Utara rdfs:label "Bupati Aceh Utara"^^xsd:string.
# lexid:Position_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdfs:label "Lembaran Daerah Kabupaten Aceh Utara"^^xsd:string.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdf:type lexid-s:Lembaran.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionDate "2005-02-15"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-18"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H_Teuku_Alamsyah_Bantah.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_T.Harmawan_Drs.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:Lembaran_Daerah_Kabupaten

# %%
prompt3 = f"""
Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.

Ditetapkan di Jakarta pada tanggal 23 Januari 2019

PRESIDEN REPUBLIK INDONESIA,

ttd

JOKO WIDODO

Diundangkan di Jakarta pada tanggal 28 Januari 2019

MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,

ttd

YASONNA H. LAOLLY
```
###output:
lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.

###regulatory:
{test_dataset[3]['regulatory']}
###prompt: 
```{test_dataset[3]['text']}```
###output:
"""
print(prompt3)
# Out:
# Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
# - identifikasi sebanyak mungkin relation di antara entity
# - keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .
#
# Tipe entity paling penting adalah:
# - lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
# - lexid-s:Person, contoh: lexid:Person_Joko_Widodo
# - lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
# - lexid-s:City, contoh: lexid:City_Depok
#
# Relation paling penting adalah:
# - lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
# - lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
# - lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
# - lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
# - lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
# - lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
# - lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
# - lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
# - lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.
#
# Contoh:
# ###regulatory: lexid:PP_2019_4
# ###prompt:
# ```
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Menteri ini dengan penempatannya
# dalam Berita Negara Republik Indonesia.
#
# Ditetapkan di Jakarta pada tanggal 23 Januari 2019
#
# PRESIDEN REPUBLIK INDONESIA,
#
# ttd
#
# JOKO WIDODO
#
# Diundangkan di Jakarta pada tanggal 28 Januari 2019
#
# MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,
#
# ttd
#
# YASONNA H. LAOLLY
# ```
# ###output:
# lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
# lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
# lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
# lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
# lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
# lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
# lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
# lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
# lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
# lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
# lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
#
# Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.
#
# ###regulatory:
# PERKAB_PASER_2011_4
# ###prompt:
# ```(1) Pembersihan sampah pedagang yang berada di dalam lokasi pasar yang wilayahnya
# telah ditentukan secara jelas dilakukan oleh Dinas Perindustrian, Perdagangan,
# Koperasi dan Usaha Kecil Menengah atau Badan Usaha Milik Daerah yang menangani
# pasar.
# (2) Penanganan sampah dari pasar sampai ke lokasi Tempat Pembuangan Akhir (TPA)
# dikelola oleh Dinas Cita Karya, Kebersihan dan Perumahan.
# Pasal II
# Peraturan Daerah ini mulai berlaku pada tanggal diundangkan.
# Agar setiap orang mengetahuinya, memerintahkan pengundangan Peraturan Daerah ini
# dengan penempatannya dalam Lembaran Daerah Kabupaten Paser.
# Ditetapkan di Tanah Grogot
# pada tanggal 1 April 2011
# BUPATI PASER
# TTD
# H.M. RIDWAN SUWIDI
# Diundangkan di Tanah Grogot
# pada tanggal 1 April 2011
# SEKRETARIS DAERAH KABUPATEN PASER
# TTD
# H. HELMY LATHYF
# LEMBARAN DAERAH KABUPATEN PASER TAHUN 2011 NOMOR 4
# Salinan sesuai dengan aslinya
# Kepala Bagian Hukum Setda Kab. Paser
# H. Suwardi, SH.,M.Si.
# Pembina
# NIP. 19620424 199303 1 011
# No. Nama Jabatan Paraf
# 1. H.Andi Azis Kasubbag.Produk Hukum Daerah
# 2. H.Suwardi Kabag.Hukum
# 3. H.Heriansyah Idris Plt. Asisten Tata Pemerintahan
# 4. H.Helmy Lathyf Sekretaris Daerah```
# ###output:

# %%
messages = [
    {"role": "user", "content": prompt3},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
#  lexid:PERKAB_PASER_2011_4 lexid-s:hasEnactionDate "2011-04-01"^^xsd:date.
# lexid:PERKAB_PASER_2011_4 lexid-s:hasPromulgationDate "2011-04-01"^^xsd:date.
# lexid:PERKAB_PASER_2011_4 lexid-s:hasEnactionOfficial lexid:Person_H_M_Ridwan_Suwidi.
# lexid:Person_H_M_Ridwan_Suwidi rdfs:label "H.M. Ridwan Suwidi"^^xsd:string.
# lexid:Person_H_M_Ridwan_Suwidi rdf:type lexid-s:Person.
# lexid:PERKAB_PASER_2011_4 lexid-s:hasPromulgationOfficial lexid:Person_H_Helmy_Lathyf.
# lexid:Person_H_Helmy_Lathyf rdfs:label "H. Helmy Lathyf"^^xsd:string.
# lexid:Person_H_Helmy_Lathyf rdf:type lexid-s:Person.
# lexid:PERKAB_PASER_2011_4 lexid-s:hasEnactionOffice lexid:Position_Bupati_Paser.
# lexid:Position_Bupati_Paser rdfs:label "Bupati Kabupaten Paser"^^xsd:string.
# lexid:Position_Bupati_Paser rdf:type lexid-s:Position.
# lexid:PERKAB_PASER_2011_4 lexid-s:hasPromulgationOffice lexid:Position_Sekretaris_Daerah_Kabupaten_Paser.
# lexid:Position_Sekretaris_Daerah_Kabupaten_Paser rdfs:label "Sekretaris Daerah Kabupaten Paser"^^xsd:string.
# lexid:Position_Sekretaris_Daerah_Kabupaten_Paser rdf:type lexid-s:Position.
# lexid:PERKAB_PASER_2011_4 lexid-s:hasEnactionLocation lexid:Tanah_Grogot.
# lexid:Tanah_Grogot rdf:type lexid-s:City.
# lexid:Tanah_Grogot rdfs:label "Tanah Grogot"^^xsd:string.
# lexid:PERKAB_PASER_2011_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Paser_Tahun_2011_Nomor_4.
# lexid:Lembaran_Daerah_Kabupaten_Paser_Tahun_2011_Nomor_4 rdfs:label "Lembaran Daerah Kabupaten Paser Tahun 2011 Nomor 4"^^xsd:string.
# lexid:Lembaran_Daerah_Kabupaten_Paser_Tahun_2011_Nomor_4 rdf:type lexid-s:Lembaran.
# lexid:PERKAB_PASER_2011_4 lexid-s:hasEnactionOfficial lexid:Person_H_Suwardi_Kabag.
# lexid:Person_H_Suwardi_Kabag rdfs:label "H. Suwardi Kabag"^^xsd:string.
# lexid:Person_H_Suwardi_Kabag rdf:type lexid-s:Person.
# lexid:PERKAB_PASER_2011_4 lexid-s:hasPromulgationOfficial lexid:Person_H_Andi_Azis_Kasubbag_Produk_Hukum_Daerah.
# lexid:Person_H_Andi_Azis_Kasubbag_Produk_Hukum_Daerah rdfs:label "H.

# %%
prompt4 = """Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.

Contoh:
###regulatory: lexid:PP_2019_4
###Teks: 
```
Peraturan Pemerintah ini mulai berlaku pada tanggal 
diundangkan. 
www.peraturan.go.id
2019, No.12 
-9- 
Agar setiap orang mengetahuinya, memerintahkan 
pengundangan Peraturan Pemerintah ini dengan 
penempatannya dalam Lembaran Negara Republik 
Indonesia. 
Ditetapkan di Jakarta 
pada tanggal 23 Januari 2019  
PRESIDEN REPUBLIK INDONESIA, 
ttd 
JOKO WIDODO 
Diundangkan di Jakarta 
pada tanggal 28 Januari 2019 
MENTERI HUKUM DAN HAK ASASI MANUSIA  
REPUBLIK INDONESIA,  
ttd 
YASONNA H. LAOLLY 
www.peraturan.go.id
```
###output:

lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

###regulatory: lexid:PERKAB_ACEH_UTARA_2005_28
###Teks: 
```
Qanun ini berlaku pada tanggal diundangkan
28
Agar setiap orang mengetahuinya memerintahkan
pengundangan Qanun ini dengan penempatannya
dalam Lembaran Daerah Kabupaten Aceh Utara.
Ditetapkan di Lhokseumawe
pada tanggal  15 Pebruari    2005 M
                        6 Muharram 1426 H
PENJABAT  BUPATI ACEH UTARA
Cap/dto
H. TEUKU  ALAMSYAH BANTA
Diundangkan di Lhokseumawe
pada tanggal   18 Februari     2005 M
                         9 Muharram  1426 H
 SEKRETARIS DAERAH,
Drs. T. HARMAWAN, M.Si
 Pembina Utama Muda
       NIP. 010 073 653
LEMBARAN DAERAH KABUPATEN ACEH UTARA TAHUN
2005 NOMOR  28
29
```
###output:
"""
messages = [
    {"role": "user", "content": prompt4},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
#  lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionDate "2005-02-15"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-18"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H_Teuku_Alamsyah_Bantah.
# lexid:Person_H_Teuku_Alamsyah_Bantah rdfs:label "H. Teuku Alamsyah Bantah"^^xsd:string.
# lexid:Person_H_Teuku_Alamsyah_Bantah rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_T_Harmawan_Drs.
# lexid:Person_T_Harmawan_Drs rdfs:label "T. Harmawan, M.Si"^^xsd:string.
# lexid:Person_T_Harmawan_Drs rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOffice lexid:Position_Bupati_Aceh_Utara.
# lexid:Position_Bupati_Aceh_Utara rdfs:label "Bupati Aceh Utara"^^xsd:string.
# lexid:Position_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOffice lexid:Position_Sekretaris_Daerah.
# lexid:Position_Sekretaris_Daerah rdfs:label "Sekretaris Daerah"^^xsd:string.
# lexid:Position_Sekretaris_Daerah rdf:type lexid-s:Position.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdfs:label "Lembaran Daerah Kabupaten Aceh Utara"^^xsd:string.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdf:type lexid-s:Lembaran.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdfs:label "2005 NOMOR  28"^^xsd:string.

# %%
prompt5 = """Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.

Contoh:
###regulatory: lexid:PP_2019_4
###Teks: 
```
Peraturan Pemerintah ini mulai berlaku pada tanggal 
diundangkan. 
www.peraturan.go.id
2019, No.12 
-9- 
Agar setiap orang mengetahuinya, memerintahkan 
pengundangan Peraturan Pemerintah ini dengan 
penempatannya dalam Lembaran Negara Republik 
Indonesia. 
Ditetapkan di Jakarta 
pada tanggal 23 Januari 2019  
PRESIDEN REPUBLIK INDONESIA, 
ttd 
JOKO WIDODO 
Diundangkan di Jakarta 
pada tanggal 28 Januari 2019 
MENTERI HUKUM DAN HAK ASASI MANUSIA  
REPUBLIK INDONESIA,  
ttd 
YASONNA H. LAOLLY 
www.peraturan.go.id
```
###output:

lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

###regulatory: lexid:PERKAB_ACEH_UTARA_2005_28
###Teks: 
```
Qanun ini berlaku pada tanggal diundangkan
28
Agar setiap orang mengetahuinya memerintahkan
pengundangan Qanun ini dengan penempatannya
dalam Lembaran Daerah Kabupaten Aceh Utara.
Ditetapkan di Lhokseumawe
pada tanggal  15 Pebruari    2005 M
                        6 Muharram 1426 H
PENJABAT  BUPATI ACEH UTARA
Cap/dto
H. TEUKU  ALAMSYAH BANTA
Diundangkan di Lhokseumawe
pada tanggal   18 Februari     2005 M
                         9 Muharram  1426 H
 SEKRETARIS DAERAH,
Drs. T. HARMAWAN, M.Si
 Pembina Utama Muda
       NIP. 010 073 653
LEMBARAN DAERAH KABUPATEN ACEH UTARA TAHUN
2005 NOMOR  28
29
```
###output:
"""
messages = [
    {"role": "user", "content": prompt5},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
#  lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionDate "2005-02-15"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-18"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H_Teuku_Alamsyah_Bantah.
# lexid:Person_H_Teuku_Alamsyah_Bantah rdfs:label "H. Teuku Alamsyah Bantah"^^xsd:string.
# lexid:Person_H_Teuku_Alamsyah_Bantah rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_T_Harmawan_Drs.
# lexid:Person_T_Harmawan_Drs rdfs:label "T. Harmawan, M.Si"^^xsd:string.
# lexid:Person_T_Harmawan_Drs rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOffice lexid:Position_Bupati_Aceh_Utara.
# lexid:Position_Bupati_Aceh_Utara rdfs:label "Bupati Aceh Utara"^^xsd:string.
# lexid:Position_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOffice lexid:Position_Sekretaris_Daerah.
# lexid:Position_Sekretaris_Daerah rdfs:label "Sekretaris Daerah"^^xsd:string.
# lexid:Position_Sekretaris_Daerah rdf:type lexid-s:Position.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdfs:label "Lembaran Daerah Kabupaten Aceh Utara"^^xsd:string.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdf:type lexid-s:Lembaran.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdfs:label "2005 NOMOR  28"^^xsd:string.

# %%
prompt6 = """Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.

Contoh:
###regulatory: lexid:PP_2019_4
###Teks: 
```
Peraturan Pemerintah ini mulai berlaku pada tanggal 
diundangkan. 
www.peraturan.go.id
2019, No.12 
-9- 
Agar setiap orang mengetahuinya, memerintahkan 
pengundangan Peraturan Pemerintah ini dengan 
penempatannya dalam Lembaran Negara Republik 
Indonesia. 
Ditetapkan di Jakarta 
pada tanggal 23 Januari 2019  
PRESIDEN REPUBLIK INDONESIA, 
ttd 
JOKO WIDODO 
Diundangkan di Jakarta 
pada tanggal 28 Januari 2019 
MENTERI HUKUM DAN HAK ASASI MANUSIA  
REPUBLIK INDONESIA,  
ttd 
YASONNA H. LAOLLY 
www.peraturan.go.id
```
###output:

lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

###regulatory: lexid:PERKAB_ACEH_UTARA_2005_28
###Teks: 
```
Qanun ini berlaku pada tanggal diundangkan
28
Agar setiap orang mengetahuinya memerintahkan
pengundangan Qanun ini dengan penempatannya
dalam Lembaran Daerah Kabupaten Aceh Utara.
Ditetapkan di Lhokseumawe
pada tanggal  15 Pebruari    2005 M
                        6 Muharram 1426 H
PENJABAT  BUPATI ACEH UTARA
Cap/dto
H. TEUKU  ALAMSYAH BANTA
Diundangkan di Lhokseumawe
pada tanggal   18 Februari     2005 M
                         9 Muharram  1426 H
 SEKRETARIS DAERAH,
Drs. T. HARMAWAN, M.Si
 Pembina Utama Muda
       NIP. 010 073 653
LEMBARAN DAERAH KABUPATEN ACEH UTARA TAHUN
2005 NOMOR  28
29
```
###output:
"""
messages = [
    {"role": "user", "content": prompt6},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
#  lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionDate "2005-02-15"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-18"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H_Teuku_Alamsyah_Bantah.
# lexid:Person_H_Teuku_Alamsyah_Bantah rdfs:label "H. Teuku Alamsyah Bantah"^^xsd:string.
# lexid:Person_H_Teuku_Alamsyah_Bantah rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_T_Harman_Muharram.
# lexid:Person_T_Harman_Muharram rdfs:label "T. Harman Muharram"^^xsd:string.
# lexid:Person_T_Harman_Muharram rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOffice lexid:Position_Sekretaris_Daerah.
# lexid:Position_Sekretaris_Daerah rdfs:label "Sekretaris Daerah"^^xsd:string.
# lexid:Position_Sekretaris_Daerah rdf:type lexid-s:Position.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdfs:label "Lembaran Daerah Kabupaten Aceh Utara"^^xsd:string.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdf:type lexid-s:Lembaran.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionDate "2005-02-15"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-18"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H_Teuku_Alamsyah_Bantah.
# lexid:Person_H_Teuku_Alamsyah_Bantah rdfs:label "H. Teuku Alamsyah Bantah"^^xsd:string.
# lexid:Person_H_Teuku_Alamsyah_Bantah rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_T_Harman_Muharram.
# lexid:Person_T_Harman_Muharram rdfs:label "T. Harman Muharram"^^xsd:string.
# lexid:Person_T_Harman_Muharram rdf:type

# %%
prompt7 = """Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.

Contoh:
###regulatory: lexid:PP_2019_4
###Teks: 
```
Peraturan Pemerintah ini mulai berlaku pada tanggal 
diundangkan. 
www.peraturan.go.id
2019, No.12 
-9- 
Agar setiap orang mengetahuinya, memerintahkan 
pengundangan Peraturan Pemerintah ini dengan 
penempatannya dalam Lembaran Negara Republik 
Indonesia. 
Ditetapkan di Jakarta 
pada tanggal 23 Januari 2019  
PRESIDEN REPUBLIK INDONESIA, 
ttd 
JOKO WIDODO 
Diundangkan di Jakarta 
pada tanggal 28 Januari 2019 
MENTERI HUKUM DAN HAK ASASI MANUSIA  
REPUBLIK INDONESIA,  
ttd 
YASONNA H. LAOLLY 
www.peraturan.go.id
```
###output:

lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

###regulatory: lexid:PERKAB_ACEH_UTARA_2005_28
###Teks: 
```
Qanun ini berlaku pada tanggal diundangkan
28
Agar setiap orang mengetahuinya memerintahkan
pengundangan Qanun ini dengan penempatannya
dalam Lembaran Daerah Kabupaten Aceh Utara.
Ditetapkan di Lhokseumawe
pada tanggal  15 Pebruari    2005 M
                        6 Muharram 1426 H
PENJABAT  BUPATI ACEH UTARA
Cap/dto
H. TEUKU  ALAMSYAH BANTA
Diundangkan di Lhokseumawe
pada tanggal   18 Februari     2005 M
                         9 Muharram  1426 H
 SEKRETARIS DAERAH,
Drs. T. HARMAWAN, M.Si
 Pembina Utama Muda
       NIP. 010 073 653
LEMBARAN DAERAH KABUPATEN ACEH UTARA TAHUN
2005 NOMOR  28
29
```
###output:
"""
messages = [
    {"role": "user", "content": prompt7},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
#  lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionDate "2005-02-15"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-18"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H_Teuku_Alamsyah_Bantah.
# lexid:Person_H_Teuku_Alamsyah_Bantah rdfs:label "H. Teuku Alamsyah Bantah"^^xsd:string.
# lexid:Person_H_Teuku_Alamsyah_Bantah rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_T._Harmawan_Drs._.
# lexid:Person_T._Harmawan_Drs._ rdfs:label "T. Harmawan, M.Si"^^xsd:string.
# lexid:Person_T._Harmawan_Drs._ rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOffice lexid:Position_Sekretaris_Daerah.
# lexid:Position_Sekretaris_Daerah rdfs:label "Sekretaris Daerah"^^xsd:string.
# lexid:Position_Sekretaris_Daerah rdf:type lexid-s:Position.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationLocation lexid:City_Lhokseumawe.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdf:type lexid-s:Lembaran.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdfs:label "Lembaran Daerah Kabupaten Aceh Utara"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_NIP.010_073_653.
# lexid:Person_NIP.010_073_653 rdfs:label "NIP. 010 073 653"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionDate "2005-02-15"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-18"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H_Teuku_Alamsyah_Bant

# %%
prompt8 = """Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.

Contoh:
###regulatory: lexid:PP_2019_4
###Teks: 
```
Peraturan Pemerintah ini mulai berlaku pada tanggal 
diundangkan. 
www.peraturan.go.id
2019, No.12 
-9- 
Agar setiap orang mengetahuinya, memerintahkan 
pengundangan Peraturan Pemerintah ini dengan 
penempatannya dalam Lembaran Negara Republik 
Indonesia. 
Ditetapkan di Jakarta 
pada tanggal 23 Januari 2019  
PRESIDEN REPUBLIK INDONESIA, 
ttd 
JOKO WIDODO 
Diundangkan di Jakarta 
pada tanggal 28 Januari 2019 
MENTERI HUKUM DAN HAK ASASI MANUSIA  
REPUBLIK INDONESIA,  
ttd 
YASONNA H. LAOLLY 
www.peraturan.go.id
```
###output:

lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

###regulatory: lexid:PERKAB_ACEH_UTARA_2005_28
###Teks: 
```
Qanun ini berlaku pada tanggal diundangkan
28
Agar setiap orang mengetahuinya memerintahkan
pengundangan Qanun ini dengan penempatannya
dalam Lembaran Daerah Kabupaten Aceh Utara.
Ditetapkan di Lhokseumawe
pada tanggal  15 Pebruari    2005 M
                        6 Muharram 1426 H
PENJABAT  BUPATI ACEH UTARA
Cap/dto
H. TEUKU  ALAMSYAH BANTA
Diundangkan di Lhokseumawe
pada tanggal   18 Februari     2005 M
                         9 Muharram  1426 H
 SEKRETARIS DAERAH,
Drs. T. HARMAWAN, M.Si
 Pembina Utama Muda
       NIP. 010 073 653
LEMBARAN DAERAH KABUPATEN ACEH UTARA TAHUN
2005 NOMOR  28
29
```
###output:
"""
messages = [
    {"role": "user", "content": prompt8},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#  lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionDate "2005-02-18"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H. TEUKU ALAMSYAH BANTA.
# lexid:Person_H. TEUKU ALAMSYAH BANTA rdfs:label "H. Teuku Alamsyah Bantah"^^xsd:string.
# lexid:Person_H. TEUKU ALAMSYAH BANTA rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOffice lexid:Position_Bupati_Aceh_Utara.
# lexid:Position_Bupati_Aceh_Utara rdfs:label "Bupati Aceh Utara"^^xsd:string.
# lexid:Position_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-15"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationLocation lexid:City_Lhokseumawe.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_T. HARMAWAN, Drs..
# lexid:Person_T. HARMAWAN, Drs. rdfs:label "Dr. T. Harmawan"^^xsd:string.
# lexid:Person_T. HARMAWAN, Drs. rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOffice lexid:Position_Sekretaris_Daerah.
# lexid:Position_Sekretaris_Daerah rdfs:label "Sekretaris Daerah"^^xsd:string.
# lexid:Position_Sekretaris_Daerah rdf:type lexid-s:Position.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdf:type lexid-s:Lembaran.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdfs:label "Lembaran Daerah Kabupaten Aceh Utara"^^xsd:string.

# %%
print(test_dataset[1]['triples'])
# Out:
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara .
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationLocation lexid:City_Lhokseumawe .
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-18"^^xsd:date .
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string .
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe .
# lexid:City_Lhokseumawe rdf:type lexid-s:City .

# %% [markdown]
# #### 1 shot, full prompt, sorted relationship, sorted triples

# %%
prompt_1_shot = """Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.

Contoh:
###regulatory: lexid:PP_2019_4
###Teks: 
```
Peraturan Pemerintah ini mulai berlaku pada tanggal 
diundangkan. 
www.peraturan.go.id
2019, No.12 
-9- 
Agar setiap orang mengetahuinya, memerintahkan 
pengundangan Peraturan Pemerintah ini dengan 
penempatannya dalam Lembaran Negara Republik 
Indonesia. 
Ditetapkan di Jakarta 
pada tanggal 23 Januari 2019  
PRESIDEN REPUBLIK INDONESIA, 
ttd 
JOKO WIDODO 
Diundangkan di Jakarta 
pada tanggal 28 Januari 2019 
MENTERI HUKUM DAN HAK ASASI MANUSIA  
REPUBLIK INDONESIA,  
ttd 
YASONNA H. LAOLLY 
www.peraturan.go.id
```
###output:

lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
"""
messages = [
    {"role": "user", "content": prompt_1_shot.format(regulatory = test_dataset[1]['regulatory'], text=test_dataset[1]['text'])},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
# You are not running the flash-attention implementation, expect numerical differences.
#  lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionDate "2005-02-18"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H. TEUKU ALAMSYAH BANTA.
# lexid:Person_H. TEUKU ALAMSYAH BANTA rdfs:label "H. Teuku Alamsyah Bantah"^^xsd:string.
# lexid:Person_H. TEUKU ALAMSYAH BANTA rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOffice lexid:Position_Bupati_Aceh_Utara.
# lexid:Position_Bupati_Aceh_Utara rdfs:label "Bupati Aceh Utara"^^xsd:string.
# lexid:Position_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-15"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationLocation lexid:City_Lhokseumawe.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_T. HARMAWAN, Drs..
# lexid:Person_T. HARMAWAN, Drs. rdfs:label "Dr. T. Harmawan"^^xsd:string.
# lexid:Person_T. HARMAWAN, Drs. rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOffice lexid:Position_Sekretaris_Daerah.
# lexid:Position_Sekretaris_Daerah rdfs:label "Sekretaris Daerah"^^xsd:string.
# lexid:Position_Sekretaris_Daerah rdf:type lexid-s:Position.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdf:type lexid-s:Lembaran.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdfs:label "Lembaran Daerah Kabupaten Aceh Utara"^^xsd:string.

# %%
import time

results = pd.DataFrame()
results = pd.DataFrame(columns=['1', '2', '3', '4', '5', '6'])

for x in tqdm(range(len(test_dataset))[:501]):
    if x % 100 == 0 and x > 0:
        results.reset_index(inplace=True)
        results.rename(columns={'index': 'regulatory'}, inplace=True)
        results.to_csv(f'./result/1shot_closing_{x//100}.csv')
        
        results = pd.DataFrame()
        results = pd.DataFrame(columns=['1'])
        
    messages = [
        {"role": "user", "content": prompt_1_shot.format(regulatory = test_dataset[x]['regulatory'], text=test_dataset[x]['text'])},
    ]
    
    try:
        output = pipe_phi(messages, **generation_args)
        results.at[test_dataset[x]['regulatory'], '1'] = output[0]['generated_text']
    except:
        results.at[test_dataset[x]['regulatory'], '1'] = ''
# Out:
#   2%|▏         | 8/501 [04:19<3:24:28, 24.89s/it]

# %%
res_1shot = pd.read_csv('./result/1shot_closing_1.csv')
print(test_dataset[1]['text'])
print()
print('LLM')
print(res_1shot.iloc[1]['1'])
print()
print('Lexid')
print(test_dataset[1]['triples'])
# Out:
# Qanun ini berlaku pada tanggal diundangkan
# 28
# Agar setiap orang mengetahuinya memerintahkan
# pengundangan Qanun ini dengan penempatannya
# dalam Lembaran Daerah Kabupaten Aceh Utara.
# Ditetapkan di Lhokseumawe
# pada tanggal  15 Pebruari    2005 M
#                         6 Muharram 1426 H
# PENJABAT  BUPATI ACEH UTARA
# Cap/dto
# H. TEUKU  ALAMSYAH BANTA
# Diundangkan di Lhokseumawe
# pada tanggal   18 Februari     2005 M
#                          9 Muharram  1426 H
#  SEKRETARIS DAERAH,
# Drs. T. HARMAWAN, M.Si
#  Pembina Utama Muda
#        NIP. 010 073 653
# LEMBARAN DAERAH KABUPATEN ACEH UTARA TAHUN
# 2005 NOMOR  28
# 29
#
# LLM
#  lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionDate "2005-02-18"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOfficial lexid:Person_H. TEUKU ALAMSYAH BANTA.
# lexid:Person_H. TEUKU ALAMSYAH BANTA rdfs:label "H. Teuku Alamsyah Bantah"^^xsd:string.
# lexid:Person_H. TEUKU ALAMSYAH BANTA rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionOffice lexid:Position_Bupati_Aceh_Utara.
# lexid:Position_Bupati_Aceh_Utara rdfs:label "Bupati Aceh Utara"^^xsd:string.
# lexid:Position_Bupati_Aceh_Utara rdf:type lexid-s:Position.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-15"^^xsd:date.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationLocation lexid:City_Lhokseumawe.
# lexid:City_Lhokseumawe rdf:type lexid-s:City.
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOfficial lexid:Person_T. HARMAWAN, Drs..
# lexid:Person_T. HARMAWAN, Drs. rdfs:label "Dr. T. Harmawan"^^xsd:string.
# lexid:Person_T. HARMAWAN, Drs. rdf:type lexid-s:Person.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationOffice lexid:Position_Sekretaris_Daerah.
# lexid:Position_Sekretaris_Daerah rdfs:label "Sekretaris Daerah"^^xsd:string.
# lexid:Position_Sekretaris_Daerah rdf:type lexid-s:Position.
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdf:type lexid-s:Lembaran.
# lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara rdfs:label "Lembaran Daerah Kabupaten Aceh Utara"^^xsd:string.
#
# Lexid
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationPlace lexid:Lembaran_Daerah_Kabupaten_Aceh_Utara .
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationLocation lexid:City_Lhokseumawe .
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasPromulgationDate "2005-02-18"^^xsd:date .
# lexid:City_Lhokseumawe rdfs:label "Lhokseumawe"^^xsd:string .
# lexid:PERKAB_ACEH_UTARA_2005_28 lexid-s:hasEnactionLocation lexid:City_Lhokseumawe .
# lexid:City_Lhokseumawe rdf:type lexid-s:City .

# %% [markdown]
# #### Few shot

# %%
df_fewshot = pd.read_csv('./dataset-fewshot/closing.csv')
df_fewshot
# Out:
#                        regulatory  \
# 0                       PP_2019_4
# 1           Peraturan_BKPM_2017_8
# 2           Peraturan_BNN_2017_14
# 3            Perkab_Tapin_2013_20
# 4          Perkot_Surabaya_2010_3
# 5              Permen_Sos_2018_29
# 6   Permenko_Perekonomian_2015_12
# 7                 Perpres_2019_88
# 8           Perprov_Papua_2013_26
# 9        Perwali_Tangerang_2019_5
# 10                      UU_1987_1
#
#                                              ttl_file  \
# 0             new_turtle_files/ln/2019/pp4-2019bt.ttl
# 1             new_turtle_files/bn/2017/bn859-2017.ttl
# 2             new_turtle_files/bn/2017/bn884-2017.ttl
# 3   new_turtle_files/perda/2013/perda_kabupaten_ta...
# 4   new_turtle_files/perda/2010/perda_kota_surabay...
# 5              new_turtle_files/bn/2019/bn18-2019.ttl
# 6              new_turtle_files/bn/2016/bn47-2016.ttl
# 7              new_turtle_files/ln/2019/ps88-2019.ttl
# 8   new_turtle_files/perda/2013/perda_provinsi_pap...
# 9   new_turtle_files/perda/2019/perwal_no_5_tahun_...
# 10              new_turtle_files/ln/1987/uu1-1987.ttl
#
#                                                  text  \
# 0   Pasal 18 \n\nPeraturan Pemerintah ini mulai be...
# 1   Pasal 14 \n\nPeraturan Kepala Badan ini mulai ...
# 2   Pasal 16 \n\nPeraturan Kepala Badan ini mulai ...
# 3   Pasal 18A \n\n(1) Untuk memberikan pendanaan t...
# 4   Pasal 10 \n\n \n\nPeraturan Daerah ini mulai b...
# 5   Pasal 3 \n\nPeraturan Menteri ini mulai berlak...
# 6   Pasal 4 \n\nPeraturan Menteri ini mulai berlak...
# 7   Pasal 13 \n\nPeraturan Presiden ini mulai berl...
# 8   Pasal 21\n\nPeraturan Daerah ini mulai berlaku...
# 9   Pasal 13 \n\nPeraturan Wali Kota ini mulai ber...
# 10  Pasal 14 \n\n \n\nUndang-undang ini mulai berl...
#
#                                               triples
# 0   lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-...
# 1   lexid:Peraturan_BKPM_2017_8 lexid-s:hasEnactio...
# 2   lexid:Peraturan_BNN_2017_14 lexid-s:hasEnactio...
# 3   lexid:Perkab_Tapin_2013_20 lexid-s:hasEnaction...
# 4   lexid:Perkot_Surabaya_2010_3 lexid-s:hasEnacti...
# 5   lexid:Permen_Sos_2018_29 lexid-s:hasEnactionDa...
# 6   lexid:Permenko_Perekonomian_2015_12 lexid-s:ha...
# 7   lexid:Perpres_2019_88 lexid-s:hasEnactionDate ...
# 8   lexid:Perprov_Papua_2013_26 lexid-s:hasEnactio...
# 9   lexid:Perwali_Tangerang_2019_5 lexid-s:hasEnac...
# 10  lexid:UU_1987_1 lexid-s:hasEnactionDate "1987-...

# %%
prompt_few_shot = """Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.

Contoh:
"""

prompt_regulatory = """
###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
"""

prompt = prompt_few_shot
prompt += prompt_regulatory.format(regulatory = df_fewshot.iloc[0]['regulatory'], text=df_fewshot.iloc[0]['text']) + df_fewshot.iloc[0]['triples'] + '\n' 
prompt += prompt_regulatory.format(regulatory = df_fewshot.iloc[1]['regulatory'], text=df_fewshot.iloc[1]['text']) + df_fewshot.iloc[1]['triples'] + '\n' 
prompt += prompt_regulatory.format(regulatory = df_fewshot.iloc[2]['regulatory'], text=df_fewshot.iloc[2]['text']) + df_fewshot.iloc[2]['triples'] + '\n' 
# prompt += prompt_regulatory.format(regulatory = df_fewshot.iloc[3]['regulatory'], text=df_fewshot.iloc[3]['text']) + df_fewshot.iloc[3]['triples'] + '\n' 
prompt += prompt_regulatory.format(regulatory = test_dataset[0]['regulatory'], text=test_dataset[0]['text'])
messages = [
    {"role": "user", "content": prompt},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[11], line 46
#      41 prompt += prompt_regulatory.format(regulatory = test_dataset[0]['regulatory'], text=test_dataset[0]['text'])
#      42 messages = [
#      43     {"role": "user", "content": prompt},
#      44 ]
# ---> 46 output = pipe_phi(messages, **generation_args)
#      47 print(output[0]['generated_text'])
#
# File /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py:258, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     253 if isinstance(
#     254     text_inputs, (list, tuple, KeyDataset) if is_torch_available() else (list, tuple)
#     255 ) and isinstance(text_inputs[0], (list, tuple, dict)):
#     256     # We have one or more prompts in list-of-dicts format, so this is chat mode
#     257     if isinstance(text_inputs[0], dict):
# --> 258         return super().__call__(Chat(text_inputs), **kwargs)
#     259     else:
#     260         chats = [Chat(chat) for chat in text_inputs]  # 🐈 🐈 🐈
#
# File /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1243, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1235     return next(
#    1236         iter(
#    1237             self.get_iterator(
#    (...)
#    1240         )
#    1241     )
#    1242 else:
# -> 1243     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1250, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1248 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1249     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1250     model_outputs = self.forward(model_inputs, **forward_params)
#    1251     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1252     return outputs
#
# File /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1150, in Pipeline.forward(self, model_inputs, **forward_params)
#    1148     with inference_context():
#    1149         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1150         model_outputs = self._forward(model_inputs, **forward_params)
#    1151         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1152 else:
#
# File /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py:350, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     347         generate_kwargs["min_length"] += prefix_length
#     349 # BS x SL
# --> 350 generated_sequence = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     351 out_b = generated_sequence.shape[0]
#     352 if self.framework == "pt":
#
# File /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1716, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1708     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1709         input_ids=input_ids,
#    1710         expand_size=generation_config.num_return_sequences,
#    1711         is_encoder_decoder=self.config.is_encoder_decoder,
#    1712         **model_kwargs,
#    1713     )
#    1715     # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 1716     result = self._sample(
#    1717         input_ids,
#    1718         logits_processor=prepared_logits_processor,
#    1719         logits_warper=prepared_logits_warper,
#    1720         stopping_criteria=prepared_stopping_criteria,
#    1721         generation_config=generation_config,
#    1722         synced_gpus=synced_gpus,
#    1723         streamer=streamer,
#    1724         **model_kwargs,
#    1725     )
#    1727 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    1728     # 11. prepare logits warper
#    1729     prepared_logits_warper = (
#    1730         self._get_logits_warper(generation_config) if generation_config.do_sample else None
#    1731     )
#
# File /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:2355, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2352 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2354 # forward pass to get next token
# -> 2355 outputs = self(
#    2356     **model_inputs,
#    2357     return_dict=True,
#    2358     output_attentions=output_attentions,
#    2359     output_hidden_states=output_hidden_states,
#    2360 )
#    2362 if synced_gpus and this_peer_finished:
#    2363     continue  # don't waste resources running the code we don't need
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/8a362e755d2faf8cec2bf98850ce2216023d178a/modeling_phi3.py:1286, in Phi3ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1283 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1285 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1286 outputs = self.model(
#    1287     input_ids=input_ids,
#    1288     attention_mask=attention_mask,
#    1289     position_ids=position_ids,
#    1290     past_key_values=past_key_values,
#    1291     inputs_embeds=inputs_embeds,
#    1292     use_cache=use_cache,
#    1293     output_attentions=output_attentions,
#    1294     output_hidden_states=output_hidden_states,
#    1295     return_dict=return_dict,
#    1296 )
#    1298 hidden_states = outputs[0]
#    1299 logits = self.lm_head(hidden_states)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/8a362e755d2faf8cec2bf98850ce2216023d178a/modeling_phi3.py:1164, in Phi3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1154     layer_outputs = self._gradient_checkpointing_func(
#    1155         decoder_layer.__call__,
#    1156         hidden_states,
#    (...)
#    1161         use_cache,
#    1162     )
#    1163 else:
# -> 1164     layer_outputs = decoder_layer(
#    1165         hidden_states,
#    1166         attention_mask=attention_mask,
#    1167         position_ids=position_ids,
#    1168         past_key_value=past_key_values,
#    1169         output_attentions=output_attentions,
#    1170         use_cache=use_cache,
#    1171     )
#    1173 hidden_states = layer_outputs[0]
#    1175 if use_cache:
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/8a362e755d2faf8cec2bf98850ce2216023d178a/modeling_phi3.py:885, in Phi3DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     882 hidden_states = self.input_layernorm(hidden_states)
#     884 # Self Attention
# --> 885 attn_outputs, self_attn_weights, present_key_value = self.self_attn(
#     886     hidden_states=hidden_states,
#     887     attention_mask=attention_mask,
#     888     position_ids=position_ids,
#     889     past_key_value=past_key_value,
#     890     output_attentions=output_attentions,
#     891     use_cache=use_cache,
#     892 )
#     894 hidden_states = residual + self.resid_attn_dropout(attn_outputs)
#     896 residual = hidden_states
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/8a362e755d2faf8cec2bf98850ce2216023d178a/modeling_phi3.py:405, in Phi3Attention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache)
#     402     attn_weights = attn_weights + attention_mask
#     404 # upcast attention to fp32
# --> 405 attn_weights = nn.functional.softmax(attn_weights, dim=-1, dtype=torch.float32).to(value_states.dtype)
#     406 attn_weights = nn.functional.dropout(attn_weights, p=self.attention_dropout, training=self.training)
#     408 attn_output = torch.matmul(attn_weights, value_states)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:1887, in softmax(input, dim, _stacklevel, dtype)
#    1885     ret = input.softmax(dim)
#    1886 else:
# -> 1887     ret = input.softmax(dim, dtype=dtype)
#    1888 return ret
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 7.35 GiB. GPU 0 has a total capacity of 39.38 GiB of which 5.11 GiB is free. Process 1737402 has 34.26 GiB memory in use. Of the allocated memory 22.77 GiB is allocated by PyTorch, and 11.00 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
prompt_few_shot = """Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
"""

prompt_regulatory = """
###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
"""

# prompt = prompt_few_shot
# prompt += prompt_regulatory.format(regulatory = df_fewshot.iloc[0]['regulatory'], text=df_fewshot.iloc[0]['text']) + df_fewshot.iloc[0]['triples'] + '\n' 
# prompt += prompt_regulatory.format(regulatory = df_fewshot.iloc[1]['regulatory'], text=df_fewshot.iloc[1]['text']) + df_fewshot.iloc[1]['triples'] + '\n' 
# prompt += prompt_regulatory.format(regulatory = df_fewshot.iloc[2]['regulatory'], text=df_fewshot.iloc[2]['text']) + df_fewshot.iloc[2]['triples'] + '\n' 
# prompt += prompt_regulatory.format(regulatory = df_fewshot.iloc[3]['regulatory'], text=df_fewshot.iloc[3]['text']) + df_fewshot.iloc[3]['triples'] + '\n' 
# prompt += prompt_regulatory.format(regulatory = test_dataset[0]['regulatory'], text=test_dataset[0]['text'])
messages = [
    {"role": "user", "content": prompt_few_shot + prompt_regulatory.format(regulatory = df_fewshot.iloc[0]['regulatory'], text=df_fewshot.iloc[0]['text'])},
    {"role": "assistant", "content": df_fewshot.iloc[0]['triples']},
    {"role": "user", "content": prompt_regulatory.format(regulatory = df_fewshot.iloc[1]['regulatory'], text=df_fewshot.iloc[1]['text'])},
    {"role": "assistant", "content": df_fewshot.iloc[1]['triples']},
    {"role": "user", "content": prompt_regulatory.format(regulatory = test_dataset[0]['regulatory'], text=test_dataset[0]['text'])},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
#  lexid:PB_Menhut_BKN_2014_1 lexid-s:hasEnactionDate "2014-03-03"^^xsd:date.
# lexid:PB_Menhut_BKN_2014_1 lexid-s:hasEnactionLocation lexid:City_Jakarta.
# lexid:City_Jakarta rdf:type lexid-s:City.
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string.
# lexid:PB_Menhut_BKN_2014_1 lexid-s:hasEnactionOfficial lexid:Person_Zulkifli_Hasan.
# lexid:Person_Zulkifli_Hasan rdfs:label "Zulkifli Hasan"^^xsd:string.
# lexid:Person_Zulkifli_Hasan rdf:type lexid-s:Person.
# lexid:PB_Menhut_BKN_2014_1 lexid-s:hasEnactionOffice lexid:Position_Kepala_Menteri_Kehutanan_Republik_Indonesia.
# lexid:Position_Kepala_Menteri_Kehutanan_Republik_Indonesia rdfs:label "Kepala Menteri Kehutanan Republik Indonesia"^^xsd:string.
# lexid:Position_00000000000000000000000000000	00000<00nd0000000000000000_ndo0an0000an.
# otot0000an_
# 000000#.
# oTan.
# .
# _
