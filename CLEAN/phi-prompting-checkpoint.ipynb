# %% [markdown]
# ## Teks

# %%
pp_opening = """LEMBARAN NEGARA
REPUBLIK INDONESIA
No.12, 2019 KESRA. Badan Perlindungan. Konsumen Nasional.
(Penjelasan dalam Tambahan Lembaran Negara
Republik Indonesia Nomor 6306)

PERATURAN PEMERINTAH REPUBLIK INDONESIA
NOMOR 4 TAHUN 2019
TENTANG
BADAN PERLINDUNGAN KONSUMEN NASIONAL

DENGAN RAHMAT TUHAN YANG MAHA ESA

PRESIDEN REPUBLIK INDONESIA,


Menimbang : a. bahwa untuk mendukung pelaksanaan tugas dan
wewenang Badan Perlindungan Konsumen Nasional,
perlu mengatur kembali Peraturan Pemerintah Nomor
57 Tahun 2001 tentang Badan Perlindungan Konsumen
Nasional;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Pemerintah tentang Badan Perlindungan Konsumen
Nasional;

Mengingat : 1. Pasal 5 ayat (2) Undang-Undang Dasar Negara Republik
Indonesia Tahun 1945;
  2. Undang-Undang Nomor 8 Tahun 1999 tentang
Perlindungan Konsumen (Lembaran Negara Republik
Indonesia Tahun 1999 Nomor 22, Tambahan Lembaran
Negara Republik Indonesia Nomor 3821);

MEMUTUSKAN:

Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN
PERLINDUNGAN KONSUMEN NASIONAL.


www.peraturan.go.id
2019, No.12 -2-
BAB I
KETENTUAN UMUM"""

# %%
# ln/2019/pp4-2019

pp_closing = """
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.

Ditetapkan di Jakarta pada tanggal 23 Januari 2019

PRESIDEN REPUBLIK INDONESIA,

ttd

JOKO WIDODO

Diundangkan di Jakarta pada tanggal 28 Januari 2019

MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,

ttd

YASONNA H. LAOLLY"""

# %%
permen_opening = """

BERITA NEGARA
REPUBLIK INDONESIA
No.1047, 2019 KEMENAG. Bidang Agama dan Keagamaan.
Penelitian dan Pengembangan.


PERATURAN MENTERI AGAMA REPUBLIK INDONESIA
NOMOR 18 TAHUN 2019
TENTANG
PENELITIAN DAN PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN

DENGAN RAHMAT TUHAN YANG MAHA ESA

MENTERI AGAMA REPUBLIK INDONESIA,


Menimbang  : a. bahwa untuk meningkatkan kualitas dan pemanfaatan
hasil penelitian dan pengembangan di bidang agama dan
keagamaan pada Kementerian Agama, perlu mengatur
mengenai penelitian dan pengembangan di bidang agama
dan keagamaan;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Menteri Agama tentang Penelitian dan Pengembangan di
Bidang Agama dan Keagamaan;

Mengingat : 1. Undang-Undang Nomor 18 Tahun 2002 tentang Sistem
Nasional Penelitian, Pengembangan, dan Penerapan Ilmu
Pengetahuan dan Teknologi (Lembaran Negara Republik
Indonesia Tahun 2002 Nomor 84, Tambahan Lembaran
Negara Republik Indonesia Nomor 4219);
  2. Peraturan Presiden Nomor 7 Tahun 2015 tentang
Organisasi Kementerian Negara (Lembaran Negara
Republik Indonesia Tahun 2015 Nomor 8);


www.peraturan.go.id
2019, No.1047 -2-
3. Peraturan Presiden Nomor 83 Tahun 2015 tentang
Kementerian Agama (Lembaran Negara Republik
Indonesia Tahun 2015 Nomor 168);
  4. Peraturan Presiden Nomor 38 Tahun 2018 tentang
Rencana Induk Riset Nasional (Lembaran Negara
Republik Indonesia Tahun 2018 Nomor 64);
  5. Peraturan Menteri Agama Nomor 42 Tahun 2016 tentang
Organisasi dan Tata Kerja Kementerian Agama (Berita
Negara Republik Indonesia Tahun 2016 Nomor 1495);

MEMUTUSKAN:
Menetapkan  : PERATURAN MENTERI AGAMA TENTANG PENELITIAN DAN
PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN.

BAB I
KETENTUAN UMUM """

# %%
permen_body = """
BAB I
KETENTUAN UMUM 

Pasal 1
Pasal 2
Pasal 3
BAB II
PENYELENGGARAAN PENELITIAN DAN PENGEMBANGAN 

Bagian Kesatu
Penyelenggara Penelitian dan Pengembangan 

Pasal 4
Bagian Kedua
Kegiatan Penelitian dan Pengembangan 

Paragraf 1
Umum 

Pasal 5
Pasal 6
Paragraf 2
Perencanaan 

Pasal 7
Pasal 8
Paragraf 3
Pelaksanaan 

Pasal 9
Pasal 10
Paragraf 4
Pemantauan dan Evaluasi 

Pasal 11
Paragraf 5
Pelaporan 

Pasal 12
BAB III
PEMANFAATAN PENELITIAN DAN PENGEMBANGAN 

Pasal 13
Pasal 14
Pasal 15
BAB IV
PEMBIAYAAN 

Pasal 16
BAB V
KETENTUAN PENUTUP 

Pasal 17
""".strip()

# %%
# bn/2019/bn1047-2019

permen_closing = """Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.


Ditetapkan di Jakarta
pada tanggal  12 September 2019

MENTERI AGAMA REPUBLIK INDONESIA,

ttd.

          LUKMAN HAKIM SAIFUDDIN

Diundangkan di Jakarta
pada tanggal 12 September 2019

DIREKTUR JENDERAL
PERATURAN PERUNDANG-UNDANGAN
KEMENTERIAN HUKUM DAN HAK ASASI MANUSIA
REPUBLIK INDONESIA,

ttd.

WIDODO EKATJAHJANA """

# %%
perwali_closing = """Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Wali Kota ini dengan penempatannya
dalam Berita Daerah Kota Cirebon.




     Ditetapkan di Cirebon
     pada tanggal 26 Pebruari 2019

WALI KOTA CIREBON,
ttd,

NASHRUDIN AZIS

Diundangkan di Cirebon
pada tanggal 28 Pebruari 2019

SEKRETARIS DAERAH KOTA CIREBON,
ttd,

ASEP DEDI




BERITA DAERAH KOTA CIREBON TAHUN  2019 NOMOR 7


Salinan sesuai dengan aslinya
KEPALA BAGIAN HUKUM
DAN HAK ASASI MANUSIA,


CHANDRA BIMA PRAMANA, SH., MM.
Pembina Tingkat I (IV/b)
NIP. 19621001 199703 1 003

 """

# %% [markdown]
# ## Intro

# %%
# !nvidia-smi
# Out:
# Mon May 20 06:11:40 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          On  |   00000000:07:00.0 Off |                    0 |
# | N/A   38C    P0            269W /  400W |   23071MiB /  40960MiB |     48%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA A100-SXM4-40GB          On  |   00000000:0F:00.0 Off |                    0 |
# | N/A   27C    P0             55W /  400W |       3MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Enabled* |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA A100-SXM4-40GB          On  |   00000000:47:00.0 Off |                    0 |
# | N/A   25C    P0             55W /  400W |       3MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   3  NVIDIA A100-SXM4-40GB          On  |   00000000:4E:00.0 Off |                    0 |
# | N/A   26C    P0             54W /  400W |       3MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   4  NVIDIA A100-SXM4-40GB          On  |   00000000:87:00.0 Off |                    0 |
# | N/A   68C    P0            393W /  400W |   26183MiB /  40960MiB |     97%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   5  NVIDIA A100-SXM4-40GB          On  |   00000000:90:00.0 Off |                    0 |
# | N/A   43C    P0            271W /  400W |   19931MiB /  40960MiB |     42%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   6  NVIDIA A100-SXM4-40GB          On  |   00000000:B7:00.0 Off |                    0 |
# | N/A   60C    P0            397W /  400W |   25949MiB /  40960MiB |     98%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   7  NVIDIA A100-SXM4-40GB          On  |   00000000:BD:00.0 Off |                    0 |
# | N/A   36C    P0             85W /  400W |   23819MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline, BitsAndBytesConfig

MODEL_NAME = "microsoft/Phi-3-mini-128k-instruct"

model_phi = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME, trust_remote_code=True, device_map="auto"
)
model_phi = model_phi.eval()

tokenizer_phi = AutoTokenizer.from_pretrained(MODEL_NAME)
print(f"Model device: {model_phi.device}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-128k-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-128k-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py:642: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Model device: cpu

# %%
pipe_phi = pipeline(
    "text-generation",
    model=model_phi,
    tokenizer=tokenizer_phi,
)

generation_args = {
    "max_new_tokens": 5000,
    "return_full_text": False,
    "temperature": 0.0,
    "do_sample": False,
}

# %% [markdown]
# ## Closing

# %%
prompt1 = """
Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.

Ditetapkan di Jakarta pada tanggal 23 Januari 2019

PRESIDEN REPUBLIK INDONESIA,

ttd

JOKO WIDODO

Diundangkan di Jakarta pada tanggal 28 Januari 2019

MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,

ttd

YASONNA H. LAOLLY
```
###output:
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .

Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.

###regulatory:
{regulatory}
###prompt: 
```{text}```
###output:
""".strip()

# %%
teks = '\n'.join([line for line in permen_closing.splitlines() if line.strip() != ''])
test = prompt1.format(regulatory='Permen_2019_18', text=permen_closing)

messages = [
    {"role": "user", "content": test},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:490: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# You are not running the flash-attention implementation, expect numerical differences.
#  lexid:PP_2019_18 lexid-s:hasPromulgationOfficial lexid:Person_Lukman_Haikal_Saifuddin.
# lexid:City_Jakarta rdf:type lexid-s:City.
# lexid:Person_Lukman_Haikal_Saifuddin rdf:type lexid-s:Person.
# lexid:PP_2019_18 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Agama_Republik_Indonesia.
# lexid:Position_Menteri_Agama_Republik_Indonesia rdf:type lexid-s:Position.
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string.
# lexid:PP_2019_18 lexid-s:hasPromulgationDate "2019-09-12"^^xsd:date.
# lexid:Position_Menteri_Agama_Republik_Indonesia rdfs:label "Menteri Agama Republik Indonesia"^^xsd:string.
# lexid:PP_2019_18 lexid-s:hasEnactionOfficial lexid:Person_Lukman_Haikal_Saifuddin.
# lexid:Person_Lukman_Haikal_Saifuddin rdf:type lexid-s:Person.
# lexid:PP_2019_18 lexid-s:hasEnactionLocation lexid:City_Jakarta.
# lexid:PP_2019_18 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

# %%
prompt_1_shot = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU.

Contoh:
###regulatory: lexid:PP_2019_4
###Teks: 
```
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.

Ditetapkan di Jakarta pada tanggal 23 Januari 2019

PRESIDEN REPUBLIK INDONESIA,

ttd

JOKO WIDODO

Diundangkan di Jakarta pada tanggal 28 Januari 2019

MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,

ttd

YASONNA H. LAOLLY
```
###output:

lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
""".strip()

# %%
teks = '\n'.join([line for line in permen_closing.splitlines() if line.strip() != ''])
test = prompt_1_shot.format(regulatory='Permen_2019_18', text=permen_closing)

messages = [
    {"role": "user", "content": test},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:490: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# You are not running the flash-attention implementation, expect numerical differences.
#  lexid:Permen_2019_18 lexid-s:hasEnactionDate "2019-09-12"^^xsd:date.
# lexid:Permen_2019_18 lexid-s:hasEnactionLocation lexid:City_Jakarta.
# lexid:City_Jakarta rdf:type lexid-s:City.
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string.
# lexid:Permen_2019_18 lexid-s:hasEnactionOfficial lexid:Person_Lukman_Haikal_Saiful_Fauzuddin.
# lexid:Person_Lukman_Haikal_Saiful_Fauzuddin rdfs:label "Lukman Hakim Saiful Fauzuddin"^^xsd:string.
# lexid:Person_Lukman_Haikal_Saiful_Fauzuddin rdf:type lexid-s:Person.
# lexid:Permen_2019_18 lexid-s:hasEnactionOffice lexid:Position_Menteri_Agama_Republik_Indonesia.
# lexid:Position_Menteri_Agama_Republik_Indonesia rdfs:label "Menteri Agama Republik Indonesia"^^xsd:string.
# lexid:Position_Menteri_Agama_Republik_Indonesia rdf:type lexid-s:Position.
# lexid:Permen_2019_18 lexid-s:hasPromulgationDate "2019-09-12"^^xsd:date.
# lexid:Permen_2019_18 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string.
# lexid:Permen_2019_18 lexid-s:hasPromulgationOfficial lexid:Person_Widodo_Ekatjahjana.
# lexid:Person_Widodo_Ekatjahjana rdfs:label "Widodo Ekatjahjana"^^xsd:string.
# lexid:Person_Widodo_Ekatjahjana rdf:type lexid-s:Person.
# lexid:Permen_2019_18 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string.
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position.
# lexid:Permen_2019_18 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.
#
# (Note: The output assumes that "Widodo Ekatjahjana" is a typo and should be "Widodo Ekakutjahjana" or "Widodo Ekatjahjana" without the space, as it is not a standard name. If this is not the case, the output should be adjusted accordingly.)

# %%
teks = '\n'.join([line for line in permen_closing.splitlines() if line.strip() != ''])
test = prompt_1_shot.format(regulatory='Permen_2019_18', text=permen_closing)

messages = [
    {"role": "user", "content": test},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:490: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# You are not running the flash-attention implementation, expect numerical differences.
#  lexid:Permen_2019_18 lexid-s:hasEnactionDate "2019-09-12"^^xsd:date.
# lexid:Permen_2019_18 lexid-s:hasEnactionLocation lexid:City_Jakarta.
# lexid:City_Jakarta rdf:type lexid-s:City.
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string.
# lexid:Permen_2019_18 lexid-s:hasEnactionOfficial lexid:Person_Lukman_Haikal_Saiful_Fauzuddin.
# lexid:Person_Lukman_Haikal_Saiful_Fauzuddin rdfs:label "Lukman Hakim Saiful Fauzuddin"^^xsd:string.
# lexid:Person_Lukman_Haikal_Saiful_Fauzuddin rdf:type lexid-s:Person.
# lexid:Permen_2019_18 lexid-s:hasEnactionOffice lexid:Position_Menteri_Agama_Republik_Indonesia.
# lexid:Position_Menteri_Agama_Republik_Indonesia rdfs:label "Menteri Agama Republik Indonesia"^^xsd:string.
# lexid:Position_Menteri_Agama_Republik_Indonesia rdf:type lexid-s:Position.
# lexid:Permen_2019_18 lexid-s:hasPromulgationDate "2019-09-12"^^xsd:date.
# lexid:Permen_2019_18 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string.
# lexid:Permen_2019_18 lexid-s:hasPromulgationOfficial lexid:Person_Widodo_Ekatjahjana.
# lexid:Person_Widodo_Ekatjahjana rdfs:label "Widodo Ekatjahjana"^^xsd:string.
# lexid:Person_Widodo_Ekatjahjana rdf:type lexid-s:Person.
# lexid:Permen_2019_18 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string.
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position.
# lexid:Permen_2019_18 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.
#
# (Note: The output assumes that "Widodo Ekatjahjana" is a typo and should be "Widodo Ekatjahjana 2019" or similar, as the original text does not provide a clear official name. If "Widodo Ekatjahjana" is indeed the correct name, it would need to be verified for accuracy.)

# %%
print(permen_closing)
# Out:
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Menteri ini dengan penempatannya
# dalam Berita Negara Republik Indonesia.
#
#
# Ditetapkan di Jakarta
# pada tanggal  12 September 2019
#
# MENTERI AGAMA REPUBLIK INDONESIA,
#
# ttd.
#
#           LUKMAN HAKIM SAIFUDDIN
#
# Diundangkan di Jakarta
# pada tanggal 12 September 2019
#
# DIREKTUR JENDERAL
# PERATURAN PERUNDANG-UNDANGAN
# KEMENTERIAN HUKUM DAN HAK ASASI MANUSIA
# REPUBLIK INDONESIA,
#
# ttd.
#
# WIDODO EKATJAHJANA

# %%
prompt_1_shot = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.

Contoh:
###regulatory: lexid:PP_2019_4
###Teks: 
```
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.

Ditetapkan di Jakarta pada tanggal 23 Januari 2019

PRESIDEN REPUBLIK INDONESIA,

ttd

JOKO WIDODO

Diundangkan di Jakarta pada tanggal 28 Januari 2019

MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,

ttd

YASONNA H. LAOLLY
```
###output:
lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
""".strip()

# %%
teks = '\n'.join([line for line in permen_closing.splitlines() if line.strip() != ''])
test = prompt_1_shot.format(regulatory='Permen_2019_18', text=permen_closing)

messages = [
    {"role": "user", "content": test},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
#  lexid:Permen_2019_18 lexid-s:hasEnactionDate "2019-09-12"^^xsd:date.
# lexid:Permen_2019_18 lexid-s:hasEnactionLocation lexid:City_Jakarta.
# lexid:City_Jakarta rdf:type lexid-s:City.
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string.
# lexid:Permen_2019_18 lexid-s:hasEnactionOfficial lexid:Person_Lukman_Haikal_Saifuluddin.
# lexid:Person_Lukman_Haikal_Saifuluddin rdfs:label "Lukman Hakim Saifuluddin"^^xsd:string.
# lexid:Person_Lukman_Haikal_Saifuluddin rdf:type lexid-s:Person.
# lexid:Permen_2019_18 lexid-s:hasEnactionOffice lexid:Position_Menteri_Agama_Republik_Indonesia.
# lexid:Position_Menteri_Agama_Republik_Indonesia rdfs:label "Menteri Agama Republik Indonesia"^^xsd:string.
# lexid:Position_Menteri_Agama_Republik_Indonesia rdf:type lexid-s:Position.
# lexid:Permen_2019_18 lexid-s:hasPromulgationDate "2019-09-12"^^xsd:date.
# lexid:Permen_2019_18 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string.
# lexid:Permen_2019_18 lexid-s:hasPromulgationOfficial lexid:Person_Widodo_Ekatjahjana.
# lexid:Person_Widodo_Ekatjahjana rdfs:label "Widodo Ekatjahjana"^^xsd:string.
# lexid:Person_Widodo_Ekatjahjana rdf:type lexid-s:Person.
# lexid:Permen_2019_18 lexid-s:hasPromulgationOffice lexid:Position_Direkrat_Jenjral_Peraturan_Pperundangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
# lexid:Position_Direkrat_Jenjral_Peraturan_Pperundangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Direkrat Jenjral Peraturan Pperundangan Kementerian Hukum dan Hak Asasi Manusia Republik Indonesia"^^xsd:string.
# lexid:Position_Direkrat_Jenjral_Peraturan_Pperundangan_Kementerian_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position.
# lexid:Permen_2019_18 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

# %% [markdown]
# ## Coba

# %%
Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
- Gunakan ATURAN EKSTRAKSI untuk menentukan output dalam format: <ENTITY 1> <RELATION 1> <ENTITY 2/OBJECT 1> .
- Setiap ATURAN pada ATURAN EKSTRAKSI adalah saling lepas, misalnya output pada ATURAN 1 hanya boleh dihasilkan oleh teks pada ATURAN 1.

# %%
pprompt1 = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .
- Setiap ATURAN pada ATURAN EKSTRAKSI adalah saling lepas, misalnya output pada ATURAN 1 hanya boleh dihasilkan oleh teks pada ATURAN 1.

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.

Ditetapkan di Jakarta pada tanggal 23 Januari 2019

PRESIDEN REPUBLIK INDONESIA,

ttd

JOKO WIDODO

Diundangkan di Jakarta pada tanggal 28 Januari 2019

MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,

ttd

YASONNA H. LAOLLY
```
###output:
lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .


Ini adalah ATURAN EKSTRAKSI yang digunakan, teks yang dibatasi oleh dua backticks akan digunakan untuk menghasilkan output. 
- ATURAN 1
teks: 
``
Diundangkan di Jakarta pada tanggal 28 Januari 2019

MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,

ttd

YASONNA H. LAOLLY
``
keyword: Diundangkan
output: 
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .

- ATURAN 2
teks:
``
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.
``
keyword: dengan penempatannya dalam
output: 
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Berita_Negara .

- ATURAN 3
teks:
``
Ditetapkan di Jakarta pada tanggal 23 Januari 2019

PRESIDEN REPUBLIK INDONESIA,

ttd

JOKO WIDODO
``
keyword: Ditetapkan
output: 
lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .


Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.

###regulatory:
{regulatory}
###prompt: 
```{text}```
###output:
""".strip()

print(pprompt1)
# Out:
# Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
# - identifikasi sebanyak mungkin relation di antara entity
# - keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .
# - Setiap ATURAN pada ATURAN EKSTRAKSI adalah saling lepas, misalnya output pada ATURAN 1 hanya boleh dihasilkan oleh teks pada ATURAN 1.
#
# Contoh:
# ###regulatory: lexid:PP_2019_4
# ###prompt:
# ```
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Menteri ini dengan penempatannya
# dalam Berita Negara Republik Indonesia.
#
# Ditetapkan di Jakarta pada tanggal 23 Januari 2019
#
# PRESIDEN REPUBLIK INDONESIA,
#
# ttd
#
# JOKO WIDODO
#
# Diundangkan di Jakarta pada tanggal 28 Januari 2019
#
# MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,
#
# ttd
#
# YASONNA H. LAOLLY
# ```
# ###output:
# lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
# lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
# lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
# lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
# lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
# lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
# lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
# lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
# lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
# lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
# lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
#
#
# Ini adalah ATURAN EKSTRAKSI yang digunakan, teks yang dibatasi oleh dua backticks akan digunakan untuk menghasilkan output.
# - ATURAN 1
# teks:
# ``
# Diundangkan di Jakarta pada tanggal 28 Januari 2019
#
# MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,
#
# ttd
#
# YASONNA H. LAOLLY
# ``
# keyword: Diundangkan
# output:
# lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
# lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
# lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
# lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
#
# - ATURAN 2
# teks:
# ``
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Menteri ini dengan penempatannya
# dalam Berita Negara Republik Indonesia.
# ``
# keyword: dengan penempatannya dalam
# output:
# lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Berita_Negara .
#
# - ATURAN 3
# teks:
# ``
# Ditetapkan di Jakarta pada tanggal 23 Januari 2019
#
# PRESIDEN REPUBLIK INDONESIA,
#
# ttd
#
# JOKO WIDODO
# ``
# keyword: Ditetapkan
# output:
# lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
# lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
# lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
# lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
# lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
# lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
# lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
#
#
# Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.
#
# ###regulatory:
# {regulatory}
# ###prompt:
# ```{text}```
# ###output:

# %%
test = pprompt1.format(regulatory='Permen_2019_18', text=permen_closing)

messages = [
    {"role": "user", "content": test},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(permen_closing)
# Out:
#  lexid:Permen_2019_18 lexid-s:hasEnactionDate "2019-09-12"^^xsd:date.
# lexid:Permen_2019_18 lexid-s:hasEnactionLocation lexid:City_Jakarta.
# lexid:City_Jakarta rdf:type lexid-s:City.
# lexid:Permen_2019_18 lexid-s:hasEnactionOfficial lexid:Person_Lukman_Haikal_Saiful_Fauzuddin.
# lexid:Person_Lukman_Haikal_Saiful_Fauzuddin rdfs:label "Lukman Hakim Saiful Fauzuddin"^^xsd:string.
# lexid:Person_Lukman_Haikal_Saiful_Fauzuddin rdf:type lexid-s:Person.
# lexid:Permen_2019_18 lexid-s:hasEnactionOffice lexid:Position_Menteri_Agama_Republik_Indonesia.
# lexid:Position_Menteri_Agama_Republik_Indonesia rdfs:label "Menteri Agama Republik Indonesia"^^xsd:string.
# lexid:Position_Menteri_Agama_Republik_Indonesia rdf:type lexid-s:Position.
# lexid:Permen_2019_18 lexid-s:hasEnactionPlace lexid:Berita_Negara.
# lexid:Berita_Negara rdf:type lexid-s:Berita.
# lexid:Permen_2019_18 lexid-s:hasEnactionOfficial lexid:Director_Jenderal_Peraturan_Undang-Undang_Perundangan.
# lexid:Director_Jenderal_Peraturan_Undang-Undang_Perundangan rdfs:label "Director General of the Regulation of Laws"^^xsd:string.
# lexid:Permen_2019_18 lexid-s:hasEnactionOfficial lexid:Person_Widodo_Ekatjahjana.
# lexid:Person_Widodo_Ekatjahjana rdfs:label "Widodo Ekatjahjana"^^xsd:string.
# lexid:Person_Widodo_Ekatjahjana rdf:type lexid-s:Person.
# lexid:Permen_2019_18 lexid-s:hasEnactionOfficial lexid:Position_Presiden_Republik_Indonesia.
# lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string.
# lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position.
#
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Menteri ini dengan penempatannya
# dalam Berita Negara Republik Indonesia.
#
#
# Ditetapkan di Jakarta
# pada tanggal  12 September 2019
#
# MENTERI AGAMA REPUBLIK INDONESIA,
#
# ttd.
#
#           LUKMAN HAKIM SAIFUDDIN
#
# Diundangkan di Jakarta
# pada tanggal 12 September 2019
#
# DIREKTUR JENDERAL
# PERATURAN PERUNDANG-UNDANGAN
# KEMENTERIAN HUKUM DAN HAK ASASI MANUSIA
# REPUBLIK INDONESIA,
#
# ttd.
#
# WIDODO EKATJAHJANA

# %%
pprompt2 = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.

Ditetapkan di Jakarta pada tanggal 23 Januari 2019

PRESIDEN REPUBLIK INDONESIA,

ttd

JOKO WIDODO

Diundangkan di Jakarta pada tanggal 28 Januari 2019

MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,

ttd

YASONNA H. LAOLLY
```
###intermediate output1:
teks:
``
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.
``
output: 
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Berita_Negara .
###intermediate output2:
teks: 
``
Diundangkan di Jakarta pada tanggal 28 Januari 2019

MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,

ttd

YASONNA H. LAOLLY
``
output: 
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
###intermediate output3:
teks:
``
Ditetapkan di Jakarta pada tanggal 23 Januari 2019

PRESIDEN REPUBLIK INDONESIA,

ttd

JOKO WIDODO
``
output: 
lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
###final output:
lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.

###regulatory:
{regulatory}
###prompt: 
```{text}```
###intermediate output1:
###intermediate output2:
###intermediate output3:
###final output:
""".strip()

print(pprompt2)
# Out:
# Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
# - identifikasi sebanyak mungkin relation di antara entity
# - keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .
#
# Contoh:
# ###regulatory: lexid:PP_2019_4
# ###prompt:
# ```
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Menteri ini dengan penempatannya
# dalam Berita Negara Republik Indonesia.
#
# Ditetapkan di Jakarta pada tanggal 23 Januari 2019
#
# PRESIDEN REPUBLIK INDONESIA,
#
# ttd
#
# JOKO WIDODO
#
# Diundangkan di Jakarta pada tanggal 28 Januari 2019
#
# MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,
#
# ttd
#
# YASONNA H. LAOLLY
# ```
# ###intermediate output1:
# teks:
# ``
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Menteri ini dengan penempatannya
# dalam Berita Negara Republik Indonesia.
# ``
# output:
# lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Berita_Negara .
# ###intermediate output2:
# teks:
# ``
# Diundangkan di Jakarta pada tanggal 28 Januari 2019
#
# MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,
#
# ttd
#
# YASONNA H. LAOLLY
# ``
# output:
# lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
# lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
# lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
# lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
# ###intermediate output3:
# teks:
# ``
# Ditetapkan di Jakarta pada tanggal 23 Januari 2019
#
# PRESIDEN REPUBLIK INDONESIA,
#
# ttd
#
# JOKO WIDODO
# ``
# output:
# lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
# lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
# lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
# lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
# lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
# lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
# lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
# ###final output:
# lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
# lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
# lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
# lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
# lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
# lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
# lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
# lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
# lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
# lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
# lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
#
# Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.
#
# ###regulatory:
# {regulatory}
# ###prompt:
# ```{text}```
# ###intermediate output1:
# ###intermediate output2:
# ###intermediate output3:
# ###final output:

# %%
test = pprompt2.format(regulatory='Permen_2019_18', text=permen_closing)

messages = [
    {"role": "user", "content": test},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(permen_closing)
# Out:
#  teks:
# ```
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Menteri ini dengan penempatannya
# dalam Berita Negara Republik Indonesia.
#
# Ditetapkan di Jakarta
# pada tanggal  12 September 2019
#
# MENTERI AGAMA REPUBLIK INDONESIA,
#
# ttd.
#
#           LUKMAN HAKIM SAIFUDDIN
#
# Diundangkan di Jakarta
# pada tanggal 12 September 2019
#
# DIREKTUR JENDERAL
# PERATURAN PERUNDANG-UNDANGAN
# KEMENTERIAN HUKUM DAN HAK ASASI MANUSIA
# REPUBLIK INDONESIA,
#
# ttd.
#
# WIDODO EKATJAHJANA ```
# output:
# lexid:PP_2019_18 lexid-s:hasPromulgationDate "2019-09-12"^^xsd:date.
# lexid:PP_2019_18 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
# lexid:City_Jakarta rdf:type lexid-s:City.
# lexid:PP_2019_18 lexid-s:hasPromulgationOfficial lexid:Person_Lukman_Hakim_Saiful_Fuddin.
# lexid:Person_Lukman_Hakim_Saiful_Fuddin rdfs:label "Lukman Hakim Saiful Fuddin"^^xsd:string.
# lexid:Person_Lukman_Hakim_Saiful_Fuddin rdf:type lexid-s:Person.
# lexid:PP_2019_18 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Agama_Republik_Indonesia.
# lexid:Position_Menteri_Agama_Republik_Indonesia rdfs:label "Menteri Agama Republik Indonesia"^^xsd:string.
# lexid:Position_Menteri_Agama_Republik_Indonesia rdf:type lexid-s:Position.
# lexid:PP_2019_18 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.
# lexid:Lembaran_Negara rdf:type lexid-s:Lembaran.
# lexid:PP_2019_18 lexid-s:hasPromulgationDate "2019-09-12"^^xsd:date.
# lexid:PP_2019_18 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
# lexid:PP_2019_18 lexid-s:hasPromulgationOfficial lexid:Person_Lukman_Hakim_Saiful_Fuddin.
# lexid:Person_Lukman_Hakim_Saiful_Fuddin rdfs:label "Lukman Hakim Saiful Fuddin"^^xsd:string.
# lexid:Person_Lukman_Hakim_Saiful_Fuddin rdf:type lexid-s:Person.
# lexid:PP_2019_18 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum dan Hak Asasi Manusia Republik Indonesia"^^xsd:string.
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position.
# lexid:PP_2019_18 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.
# lexid:Lembaran_Negara rdf:type lexid-s:Lembaran.
# lexid:PP_2019_18 lexid-s:hasPromulgationDate "2019-09-12"^^xsd:date.
# lexid:PP_2019_18 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
# lexid:PP_2019_18 lexid-s:hasPromulgationOfficial lexid:Person_Lukman_Hakim_Saiful_Fuddin.
# lexid:Person_Lukman_Hakim_Saiful_Fuddin rdfs:label "Lukman Hakim Saiful Fuddin"^^xsd:string.
# lexid:Person_Lukman_Hakim_Saiful_Fuddin rdf:type lexid-s:Person.
# lexid:PP_2019_18 lexid-s:hasPromulgationOffice lexid:Position_Widodo_Ekatjahaja.
# lexid:Position_Widodo_Ekatjahaja rdfs:label "Widodo Ekatjahaja"^^xsd:string.
# lexid:Position_Widodo_Ekatjahaja rdf:type lexid-s:Position.
# lexid:PP_2019_18 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.
# lexid:Lembaran_Negara rdf:type lexid-s:Lembaran.
# lexid:PP_2019_18 lexid-s:hasPromulgationDate "2019-09-12"^^xsd:date.
# lexid:PP_2019_18 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
# lexid:PP_2019_18 lexid-s:hasPromulgationOfficial lexid:Person_Widodo_Ekatjahaja.
# lexid:Person_Widodo_Ekatjahaja rdfs:label "Widodo Ekatjahaja"^^xsd:string.
# lexid:Person_Widodo_Ekatjahaja rdf:type lexid-s:Person.
# lexid:PP_2019_18 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum dan Hak Asasi Manusia Republik Indonesia"^^xsd:string.
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position.
# lexid:PP_2019_18 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.
# lexid:Lembaran_Negara rdf:type lexid-s:Lembaran.
# lexid:PP_2019_18 lexid-s:hasPromulgationDate "2019-09-12"^^xsd:date.
# lexid:PP_2019_18 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
# lexid:PP_2019_18 lexid-s:hasPromulgationOfficial lexid:Person_Widodo_Ekatjahaja.
# lexid:Person_Widodo_Ekatjahaja rdfs:label "Widodo Ekatjahaja"^^xsd:
# a.
# ia
# a
#
#
#
#
#
#
#
# .
# .
#
#
#
#
#
#
#
#
#
#
#
#
# a
#
# .
# ia
#
# a.ana.
# a
# an
# an
#
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Menteri ini dengan penempatannya
# dalam Berita Negara Republik Indonesia.
#
#
# Ditetapkan di Jakarta
# pada tanggal  12 September 2019
#
# MENTERI AGAMA REPUBLIK INDONESIA,
#
# ttd.
#
#           LUKMAN HAKIM SAIFUDDIN
#
# Diundangkan di Jakarta
# pada tanggal 12 September 2019
#
# DIREKTUR JENDERAL
# PERATURAN PERUNDANG-UNDANGAN
# KEMENTERIAN HUKUM DAN HAK ASASI MANUSIA
# REPUBLIK INDONESIA,
#
# ttd.
#
# WIDODO EKATJAHJANA

# %%
pprompt1 = """
Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
- identifikasi triple dari prompt tersebut
- tulis triple dalam format ENTITY11 RELATION-1 ENTITY-2/OBJECT-1 .

Aturan Ekstraksi:
- kata 'undang', seperti pengundangan atau diundangkan akan menghasilkan promulgation
- kata 'ditetapkan' akan menghasilkan enaction

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.
Ditetapkan di Jakarta pada tanggal 23 Januari 2019
PRESIDEN REPUBLIK INDONESIA,
ttd
JOKO WIDODO
Diundangkan di Jakarta pada tanggal 28 Januari 2019
MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,
ttd
YASONNA H. LAOLLY
```
###output:
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .

Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.

###regulatory:
{regulatory}
###prompt: 
```{text}```
###output:
""".strip()

print(pprompt1)
# Out:
# Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
# - identifikasi triple dari prompt tersebut
# - tulis triple dalam format ENTITY11 RELATION-1 ENTITY-2/OBJECT-1 .
#
# Aturan Ekstraksi:
# - kata 'undang', seperti pengundangan atau diundangkan akan menghasilkan promulgation
# - kata 'ditetapkan' akan menghasilkan enaction
#
# Contoh:
# ###regulatory: lexid:PP_2019_4
# ###prompt:
# ```
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Menteri ini dengan penempatannya
# dalam Berita Negara Republik Indonesia.
# Ditetapkan di Jakarta pada tanggal 23 Januari 2019
# PRESIDEN REPUBLIK INDONESIA,
# ttd
# JOKO WIDODO
# Diundangkan di Jakarta pada tanggal 28 Januari 2019
# MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,
# ttd
# YASONNA H. LAOLLY
# ```
# ###output:
# lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
# lexid:City_Jakarta rdf:type lexid-s:City .
# lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
# lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
# lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
# lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
# lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
# lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
# lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
# lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
# lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
# lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
# lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
# lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
# lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
#
# Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.
#
# ###regulatory:
# {regulatory}
# ###prompt:
# ```{text}```
# ###output:

# %%
print(permen_closing)
# Out:
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Menteri ini dengan penempatannya
# dalam Berita Negara Republik Indonesia.
#
#
# Ditetapkan di Jakarta
# pada tanggal  12 September 2019
#
# MENTERI AGAMA REPUBLIK INDONESIA,
#
# ttd.
#
#           LUKMAN HAKIM SAIFUDDIN
#
# Diundangkan di Jakarta
# pada tanggal 12 September 2019
#
# DIREKTUR JENDERAL
# PERATURAN PERUNDANG-UNDANGAN
# KEMENTERIAN HUKUM DAN HAK ASASI MANUSIA
# REPUBLIK INDONESIA,
#
# ttd.
#
# WIDODO EKATJAHJANA

# %%
test = prompt1.format(regulatory='Perwali_2019_12', text=perwali_closing)

messages = [
    {"role": "user", "content": test},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
#  lexid:PP_2019_7 lexid-s:hasPromulgationOfficial lexid:Person_Nasrudin_Azipin.
# lexid:City_Cirebon rdf:type lexid-s:City.
# lexid:Person_Nasrudin_Azipin rdf:type lexid-s:Person.
# lexid:PP_2019_7 lexid-s:hasPromulgationOffice lexid:Position_Wali_Kota_Cirebon.
# lexid:Position_Wali_Kota_Cirebon rdf:type lexid-s:Position.
# lexid:City_Cirebon rdfs:label "Cirebon"^^xsd:string.
# lexid:PP_2019_7 lexid-s:hasPromulgationDate "2019-02-26"^^xsd:date.
# lexid:Person_Nasrudin_Azipin rdfs:label "Nasrudin Azipin"^^xsd:string.
# lexid:Person_Nasrudin_Azipin rdf:type lexid-s:Person.
# lexid:WALI_KOTA_CIREBON rdf:type lexid-s:Position.
# lexid:SEKRETARIS_DAERAH_KOTA_CIREBON rdf:type lexid-s:Position.
# lexid:PP_2019_7 lexid-s:hasEnactionOfficial lexid:WALI_KOTA_CIREBON.
# lexid:WALI_KOTA_CIREBON rdf:type lexid-s:Person.
# lexid:PP_2019_7 lexid-s:hasEnactionDate "2019-02-28"^^xsd:date.
# lexid:SEKRETARIS_DAERAH_KOTA_CIREBON rdf:type lexid-s:Person.
# lexid:Berita_Daerah_Kota_Cirebon rdf:type lexid-s:Berita.
# lexid:Berita_Daerah_Kota_Cirebon rdfs:label "Berita Daerah Kota Cirebon"^^xsd:string.
# lexid:PP_2019_7 lexid-s:hasEnactionLocation lexid:City_Cirebon.
# lexid:PP_2019_7 lexid-s:hasEnactionOffice lexid:Position_Wali_Kota_Cirebon.
# lexid:Position_Wali_Kota_Cirebon rdfs:label "Wali Kota Cirebon"^^xsd:string.

# %%
print(perwali_closing)
# Out:
# Agar setiap orang mengetahuinya, memerintahkan
# pengundangan Peraturan Wali Kota ini dengan penempatannya
# dalam Berita Daerah Kota Cirebon.
#
#
#
#
#      Ditetapkan di Cirebon
#      pada tanggal 26 Pebruari 2019
#
# WALI KOTA CIREBON,
# ttd,
#
# NASHRUDIN AZIS
#
# Diundangkan di Cirebon
# pada tanggal 28 Pebruari 2019
#
# SEKRETARIS DAERAH KOTA CIREBON,
# ttd,
#
# ASEP DEDI
#
#
#
#
# BERITA DAERAH KOTA CIREBON TAHUN  2019 NOMOR 7
#
#
# Salinan sesuai dengan aslinya
# KEPALA BAGIAN HUKUM
# DAN HAK ASASI MANUSIA,
#
#
# CHANDRA BIMA PRAMANA, SH., MM.
# Pembina Tingkat I (IV/b)
# NIP. 19621001 199703 1 003

# %% [markdown]
# ## Opening

# %%
prompt2 = """
Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia

Relation paling penting adalah:
- lexid-s:regulationNumber, yaitu nomor dari peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:regulationNumber "12"^^xsd:string .
- lexid-s:regulationYear, yaitu tahun dari peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:regulationNumber "2019"^^xsd:string .
- lexid-s:considers, yaitu apa pertimbangan dari peraturan tersebut (ada di Menimbang), contoh: lexid:PP_2019_4 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Pemerintah tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
- lexid-s:hasLegalBasis, yaitu peraturan apa yang menjadi dasar dari peraturan tersebut (ada di Mengingat), contoh: lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
- lexid-s:LegalBasisOf, yaitu invers dari lexid-s:hasLegalBasis, contoh: lexid:UU_1999_8 lexid-s:LegalBasisOf contoh: lexid:PP_2019_4 .
- lexid-s:hasDictum, yaitu pernyataan tentang peraturan (ada di Menetapkan), contoh: lexid:PP_2019_4 lexid-s:hasDictum "Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN PERLINDUNGAN KONSUMEN NASIONAL."^^xsd:string .
- lexid-s:hasCreator, yaitu siapa yang membuat peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasCreator lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia .

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
LEMBARAN NEGARA
REPUBLIK INDONESIA
No.12, 2019 KESRA. Badan Perlindungan. Konsumen Nasional.
(Penjelasan dalam Tambahan Lembaran Negara
Republik Indonesia Nomor 6306)

PERATURAN PEMERINTAH REPUBLIK INDONESIA
NOMOR 4 TAHUN 2019
TENTANG
BADAN PERLINDUNGAN KONSUMEN NASIONAL

DENGAN RAHMAT TUHAN YANG MAHA ESA

PRESIDEN REPUBLIK INDONESIA,


Menimbang : a. bahwa untuk mendukung pelaksanaan tugas dan
wewenang Badan Perlindungan Konsumen Nasional,
perlu mengatur kembali Peraturan Pemerintah Nomor
57 Tahun 2001 tentang Badan Perlindungan Konsumen
Nasional;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Pemerintah tentang Badan Perlindungan Konsumen
Nasional;

Mengingat : 1. Pasal 5 ayat (2) Undang-Undang Dasar Negara Republik
Indonesia Tahun 1945;
  2. Undang-Undang Nomor 8 Tahun 1999 tentang
Perlindungan Konsumen (Lembaran Negara Republik
Indonesia Tahun 1999 Nomor 22, Tambahan Lembaran
Negara Republik Indonesia Nomor 3821);

MEMUTUSKAN:

Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN
PERLINDUNGAN KONSUMEN NASIONAL.


www.peraturan.go.id
2019, No.12 -2-
BAB I
KETENTUAN UMUM
```
###output:
lexid:PP_2019_4 rdfs:label "Peraturan Pemerintah Republik Indonesia Nomor 4 Tahun 2019"^^xsd:string .
lexid:PP_2019_4 lexid-s:name ""^^xsd:string .
lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:PP_2019_4 lexid-s:regulationNumber "4"^^xsd:string .
lexid:UUD_1945 rdf:type lexid-s:LegalDocument .
lexid:PP_2019_4 lexid-s:considers "bahwa untuk mendukung pelaksanaan tugas dan wewenang Badan Perlindungan Konsumen Nasional, perlu mengatur kembali Peraturan Pemerintah Nomor 57 Tahun 2001 tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
lexid:PP_2019_4 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Pemerintah tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .
lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
lexid:PP_2019_4 lexid-s:hasDictum "Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN PERLINDUNGAN KONSUMEN NASIONAL."^^xsd:string .
lexid:PP_2019_4 rdf:type lexid-s:LegalDocument .
lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia rdfs:label "Badan Perlindungan Konsumen Nasional Dengan Rahmat Tuhan Yang Maha Esa Presiden Republik Indonesia"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
lexid:PP_2019_4 lexid-s:hasCreator lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia .
lexid:PP_2019_4 lexid-s:regulationYear "2019"^^xsd:int .

Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.

###regulatory:
{regulatory}
###prompt: 
```{text}```
###output:
""".strip()

print(prompt2)
# Out:
# Diberikan sebuah prompt yang dibatasi oleh tiga backticks, lakukan tindakan berikut:
# - identifikasi sebanyak mungkin relation di antara entity
# - keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .
#
# Tipe entity paling penting adalah:
# - lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
# - lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
#
# Relation paling penting adalah:
# - lexid-s:regulationNumber, yaitu nomor dari peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:regulationNumber "12"^^xsd:string .
# - lexid-s:regulationYear, yaitu tahun dari peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:regulationNumber "2019"^^xsd:string .
# - lexid-s:considers, yaitu apa pertimbangan dari peraturan tersebut (ada di Menimbang), contoh: lexid:PP_2019_4 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Pemerintah tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
# - lexid-s:hasLegalBasis, yaitu peraturan apa yang menjadi dasar dari peraturan tersebut (ada di Mengingat), contoh: lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
# - lexid-s:LegalBasisOf, yaitu invers dari lexid-s:hasLegalBasis, contoh: lexid:UU_1999_8 lexid-s:LegalBasisOf contoh: lexid:PP_2019_4 .
# - lexid-s:hasDictum, yaitu pernyataan tentang peraturan (ada di Menetapkan), contoh: lexid:PP_2019_4 lexid-s:hasDictum "Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN PERLINDUNGAN KONSUMEN NASIONAL."^^xsd:string .
# - lexid-s:hasCreator, yaitu siapa yang membuat peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasCreator lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia .
#
# Contoh:
# ###regulatory: lexid:PP_2019_4
# ###prompt:
# ```
# LEMBARAN NEGARA
# REPUBLIK INDONESIA
# No.12, 2019 KESRA. Badan Perlindungan. Konsumen Nasional.
# (Penjelasan dalam Tambahan Lembaran Negara
# Republik Indonesia Nomor 6306)
#
# PERATURAN PEMERINTAH REPUBLIK INDONESIA
# NOMOR 4 TAHUN 2019
# TENTANG
# BADAN PERLINDUNGAN KONSUMEN NASIONAL
#
# DENGAN RAHMAT TUHAN YANG MAHA ESA
#
# PRESIDEN REPUBLIK INDONESIA,
#
#
# Menimbang : a. bahwa untuk mendukung pelaksanaan tugas dan
# wewenang Badan Perlindungan Konsumen Nasional,
# perlu mengatur kembali Peraturan Pemerintah Nomor
# 57 Tahun 2001 tentang Badan Perlindungan Konsumen
# Nasional;
#   b. bahwa berdasarkan pertimbangan sebagaimana
# dimaksud dalam huruf a, perlu menetapkan Peraturan
# Pemerintah tentang Badan Perlindungan Konsumen
# Nasional;
#
# Mengingat : 1. Pasal 5 ayat (2) Undang-Undang Dasar Negara Republik
# Indonesia Tahun 1945;
#   2. Undang-Undang Nomor 8 Tahun 1999 tentang
# Perlindungan Konsumen (Lembaran Negara Republik
# Indonesia Tahun 1999 Nomor 22, Tambahan Lembaran
# Negara Republik Indonesia Nomor 3821);
#
# MEMUTUSKAN:
#
# Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN
# PERLINDUNGAN KONSUMEN NASIONAL.
#
#
# www.peraturan.go.id
# 2019, No.12 -2-
# BAB I
# KETENTUAN UMUM
# ```
# ###output:
# lexid:PP_2019_4 rdfs:label "Peraturan Pemerintah Republik Indonesia Nomor 4 Tahun 2019"^^xsd:string .
# lexid:PP_2019_4 lexid-s:name ""^^xsd:string .
# lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:PP_2019_4 lexid-s:regulationNumber "4"^^xsd:string .
# lexid:UUD_1945 rdf:type lexid-s:LegalDocument .
# lexid:PP_2019_4 lexid-s:considers "bahwa untuk mendukung pelaksanaan tugas dan wewenang Badan Perlindungan Konsumen Nasional, perlu mengatur kembali Peraturan Pemerintah Nomor 57 Tahun 2001 tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
# lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
# lexid:PP_2019_4 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Pemerintah tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
# lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .
# lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
# lexid:PP_2019_4 lexid-s:hasDictum "Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN PERLINDUNGAN KONSUMEN NASIONAL."^^xsd:string .
# lexid:PP_2019_4 rdf:type lexid-s:LegalDocument .
# lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia rdfs:label "Badan Perlindungan Konsumen Nasional Dengan Rahmat Tuhan Yang Maha Esa Presiden Republik Indonesia"^^xsd:string .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
# lexid:PP_2019_4 lexid-s:hasCreator lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia .
# lexid:PP_2019_4 lexid-s:regulationYear "2019"^^xsd:int .
#
# Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.
#
# ###regulatory:
# {regulatory}
# ###prompt:
# ```{text}```
# ###output:

# %%
test2 = prompt2.format(regulatory='Permen_2019_18', text=permen_opening)

messages = [
    {"role": "user", "content": test2},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# You are not running the flash-attention implementation, expect numerical differences.
#  lexid:PM_2019_18 rdfs:label "Peraturan Menteri Agama Republik Indonesia Nomor 18 Tahun 2019"^^xsd:string.
# lexid:PM_2019_18 lexid-s:name ""^^xsd:string.
# lexid:UU_2002_01 rdfs:label "Undang-Undang Republik Indonesia Nomor 18 Tahun 2002 tentang Sistem Nasional Penelitian, Pengembangan, dan Penerapan Ilmu Pengetahuan dan Teknologi"^^xsd:string.
# lexid:PM_2019_18 lexid-s:regulationNumber "18"^^xsd:string.
# lexid:PM_2019_18 lexid-s:considers "bahwa untuk meningkatkan kualitas dan pemanfaatan hasil penelitian dan pengembangan di bidang agama dan keagamaan pada Kementerian Agama, perlu mengatur mengenai penelitian dan pengembangan di bidang agama dan keagamaan"^^xsd:string.
# lexid:PM_2019_18 lexid-s:hasLegalBasis lexid:UU_2002_01.
# lexid:PM_2019_18 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Menteri Agama tentang Penelitian dan Pengembangan di Bidang Agama dan Keagamaan"^^xsd:string.
# lexid:PM_2019_18 lexid-s:hasLegalBasis lexid:UU_2015_07 rdfs:label "Peraturan Presiden Republik Indonesia Nomor 7 Tahun 2015 tentang Organisasi Kementerian Negara"^^xsd:string.
# lexid:PM_2019_18 lexid-s:hasLegalBasis lexid:UU_2015_08 rdfs:label "Peraturan Presiden Republik Indonesia Nomor 8 Tahun 2015 tentang Kementerian Agama"^^xsd:string.
# lexid:PM_2019_18 lexid-s:hasLegalBasis lexid:UU_2015_38 rdfs:label "Peraturan Presiden Republik Indonesia Nomor 38 Tahun 2018 tentang Rencana Induk Riset Nasional"^^xsd:string.
# lexid:PM_2019_18 lexid-s:hasLegalBasis lexid:UU_2016_04 rdfs:label "Peraturan Menteri Agama Republik Indonesia Nomor 42 Tahun 2016 tentang Organisasi dan Tata Kerja Kementerian Agama"^^xsd:string.
# lexid:PM_2019_18 lexid-s:hasDictum "Menetapkan : PERATURAN MENTERI AGAMA TENTANG PENELITIAN DAN PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN."^^xsd:string.
# lexid:PM_2019_18 lexid-s:regulationYear "2019"^^xsd:int.
#
# Teks sebelum tiga backticks tidak boleh diinterpretasikan sebagai prompt.

# %%
print(permen_opening)
# Out:
# BERITA NEGARA
# REPUBLIK INDONESIA
# No.1047, 2019 KEMENAG. Bidang Agama dan Keagamaan.
# Penelitian dan Pengembangan.
#
#
# PERATURAN MENTERI AGAMA REPUBLIK INDONESIA
# NOMOR 18 TAHUN 2019
# TENTANG
# PENELITIAN DAN PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN
#
# DENGAN RAHMAT TUHAN YANG MAHA ESA
#
# MENTERI AGAMA REPUBLIK INDONESIA,
#
#
# Menimbang  : a. bahwa untuk meningkatkan kualitas dan pemanfaatan
# hasil penelitian dan pengembangan di bidang agama dan
# keagamaan pada Kementerian Agama, perlu mengatur
# mengenai penelitian dan pengembangan di bidang agama
# dan keagamaan;
#   b. bahwa berdasarkan pertimbangan sebagaimana
# dimaksud dalam huruf a, perlu menetapkan Peraturan
# Menteri Agama tentang Penelitian dan Pengembangan di
# Bidang Agama dan Keagamaan;
#
# Mengingat : 1. Undang-Undang Nomor 18 Tahun 2002 tentang Sistem
# Nasional Penelitian, Pengembangan, dan Penerapan Ilmu
# Pengetahuan dan Teknologi (Lembaran Negara Republik
# Indonesia Tahun 2002 Nomor 84, Tambahan Lembaran
# Negara Republik Indonesia Nomor 4219);
#   2. Peraturan Presiden Nomor 7 Tahun 2015 tentang
# Organisasi Kementerian Negara (Lembaran Negara
# Republik Indonesia Tahun 2015 Nomor 8);
#
#
# www.peraturan.go.id
# 2019, No.1047 -2-
# 3. Peraturan Presiden Nomor 83 Tahun 2015 tentang
# Kementerian Agama (Lembaran Negara Republik
# Indonesia Tahun 2015 Nomor 168);
#   4. Peraturan Presiden Nomor 38 Tahun 2018 tentang
# Rencana Induk Riset Nasional (Lembaran Negara
# Republik Indonesia Tahun 2018 Nomor 64);
#   5. Peraturan Menteri Agama Nomor 42 Tahun 2016 tentang
# Organisasi dan Tata Kerja Kementerian Agama (Berita
# Negara Republik Indonesia Tahun 2016 Nomor 1495);
#
# MEMUTUSKAN:
# Menetapkan  : PERATURAN MENTERI AGAMA TENTANG PENELITIAN DAN
# PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN.
#
# BAB I
# KETENTUAN UMUM

# %%
print(pp_opening)
# Out:
# LEMBARAN NEGARA
# REPUBLIK INDONESIA
# No.12, 2019 KESRA. Badan Perlindungan. Konsumen Nasional.
# (Penjelasan dalam Tambahan Lembaran Negara
# Republik Indonesia Nomor 6306)
#
# PERATURAN PEMERINTAH REPUBLIK INDONESIA
# NOMOR 4 TAHUN 2019
# TENTANG
# BADAN PERLINDUNGAN KONSUMEN NASIONAL
#
# DENGAN RAHMAT TUHAN YANG MAHA ESA
#
# PRESIDEN REPUBLIK INDONESIA,
#
#
# Menimbang : a. bahwa untuk mendukung pelaksanaan tugas dan
# wewenang Badan Perlindungan Konsumen Nasional,
# perlu mengatur kembali Peraturan Pemerintah Nomor
# 57 Tahun 2001 tentang Badan Perlindungan Konsumen
# Nasional;
#   b. bahwa berdasarkan pertimbangan sebagaimana
# dimaksud dalam huruf a, perlu menetapkan Peraturan
# Pemerintah tentang Badan Perlindungan Konsumen
# Nasional;
#
# Mengingat : 1. Pasal 5 ayat (2) Undang-Undang Dasar Negara Republik
# Indonesia Tahun 1945;
#   2. Undang-Undang Nomor 8 Tahun 1999 tentang
# Perlindungan Konsumen (Lembaran Negara Republik
# Indonesia Tahun 1999 Nomor 22, Tambahan Lembaran
# Negara Republik Indonesia Nomor 3821);
#
# MEMUTUSKAN:
#
# Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN
# PERLINDUNGAN KONSUMEN NASIONAL.
#
#
# www.peraturan.go.id
# 2019, No.12 -2-
# BAB I
# KETENTUAN UMUM

# %%
prompt_1_shot = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia

Relation paling penting adalah:
- lexid-s:regulationNumber, yaitu nomor dari peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:regulationNumber "12"^^xsd:string .
- lexid-s:regulationYear, yaitu tahun dari peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:regulationNumber "2019"^^xsd:string .
- lexid-s:considers, yaitu apa pertimbangan dari peraturan tersebut (ada di Menimbang), contoh: lexid:PP_2019_4 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Pemerintah tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
- lexid-s:hasLegalBasis, yaitu peraturan apa yang menjadi dasar dari peraturan tersebut (ada di Mengingat), contoh: lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
- lexid-s:LegalBasisOf, yaitu invers dari lexid-s:hasLegalBasis, contoh: lexid:UU_1999_8 lexid-s:LegalBasisOf contoh: lexid:PP_2019_4 .
- lexid-s:hasDictum, yaitu pernyataan tentang peraturan (ada di Menetapkan), contoh: lexid:PP_2019_4 lexid-s:hasDictum "Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN PERLINDUNGAN KONSUMEN NASIONAL."^^xsd:string .
- lexid-s:hasCreator, yaitu siapa yang membuat peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasCreator lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia .

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS. PASTIKAN MENGGUNAKAN regulatory.

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
LEMBARAN NEGARA
REPUBLIK INDONESIA
No.12, 2019 KESRA. Badan Perlindungan. Konsumen Nasional.
(Penjelasan dalam Tambahan Lembaran Negara
Republik Indonesia Nomor 6306)

PERATURAN PEMERINTAH REPUBLIK INDONESIA
NOMOR 4 TAHUN 2019
TENTANG
BADAN PERLINDUNGAN KONSUMEN NASIONAL

DENGAN RAHMAT TUHAN YANG MAHA ESA

PRESIDEN REPUBLIK INDONESIA,


Menimbang : a. bahwa untuk mendukung pelaksanaan tugas dan
wewenang Badan Perlindungan Konsumen Nasional,
perlu mengatur kembali Peraturan Pemerintah Nomor
57 Tahun 2001 tentang Badan Perlindungan Konsumen
Nasional;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Pemerintah tentang Badan Perlindungan Konsumen
Nasional;

Mengingat : 1. Pasal 5 ayat (2) Undang-Undang Dasar Negara Republik
Indonesia Tahun 1945;
  2. Undang-Undang Nomor 8 Tahun 1999 tentang
Perlindungan Konsumen (Lembaran Negara Republik
Indonesia Tahun 1999 Nomor 22, Tambahan Lembaran
Negara Republik Indonesia Nomor 3821);

MEMUTUSKAN:

Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN
PERLINDUNGAN KONSUMEN NASIONAL.


www.peraturan.go.id
2019, No.12 -2-
BAB I
KETENTUAN UMUM
```
###output:
lexid:PP_2019_4 lexid-s:regulationNumber "4"^^xsd:string .
lexid:PP_2019_4 lexid-s:regulationYear "2019"^^xsd:int .
lexid:PP_2019_4 rdfs:label "Peraturan Pemerintah Republik Indonesia Nomor 4 Tahun 2019"^^xsd:string .
lexid:PP_2019_4 lexid-s:name "BADAN PERLINDUNGAN KONSUMEN NASIONAL"^^xsd:string .
lexid:PP_2019_4 rdf:type lexid-s:LegalDocument .

lexid:PP_2019_4 lexid-s:hasCreator lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia .
lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia rdfs:label "Badan Perlindungan Konsumen Nasional Dengan Rahmat Tuhan Yang Maha Esa Presiden Republik Indonesia"^^xsd:string .

lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .

lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:UUD_1945 rdf:type lexid-s:LegalDocument .
lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .


lexid:PP_2019_4 lexid-s:considers "bahwa untuk mendukung pelaksanaan tugas dan wewenang Badan Perlindungan Konsumen Nasional, perlu mengatur kembali Peraturan Pemerintah Nomor 57 Tahun 2001 tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
lexid:PP_2019_4 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Pemerintah tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia rdf:type lexid-s:Position .

lexid:PP_2019_4 lexid-s:hasDictum "Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN PERLINDUNGAN KONSUMEN NASIONAL."^^xsd:string .


###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
""".strip()

# %%
# teks = '\n'.join([line for line in permen_closing.splitlines() if line.strip() != ''])
test = prompt_1_shot.format(regulatory='Permen_2019_18', text=permen_opening)

messages = [
    {"role": "user", "content": test},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
#  lexid:PM_2019_18 lexid-s:regulationNumber "18"^^xsd:string.
# lexid:PM_2019_18 lexid-s:regulationYear "2019"^^xsd:int.
# lexid:PM_2019_18 rdfs:label "Peraturan Menteri Agama Republik Indonesia Nomor 18 Tahun 2019"^^xsd:string.
# lexid:PM_2019_18 rdf:type lexid-s:LegalDocument.
# lexid:PM_2019_18 lexid-s:hasCreator lexid:Menteri_Agama_Republik_Indonesia.
# lexid:Menteri_Agama_Republik_Indonesia rdfs:label "Menteri Agama Republik Indonesia"^^xsd:string.
# lexid:PM_2019_18 lexid-s:hasLegalBasis lexid:Undang-Undang_Nr_18_2002.
# lexid:Undang-Undang_Nr_18_2002 rdf:type lexid-s:LegalDocument.
# lexid:PM_2019_18 lexid-s:hasLegalBasis lexid:Peraturan_Ppres_Nr_7_2015.
# lexid:Peraturan_Ppres_Nr_7_2015 rdf:type lexid-s:LegalDocument.
# lexid:PM_2019_18 lexid-s:hasLegalBasis lexid:Peraturan_Ppres_Nr_38_2018.
# lexid:Peraturan_Ppres_Nr_38_2018 rdf:type lexid-s:LegalDocument.
# lexid:PM_2019_18 lexid-s:hasLegalBasis lexid:Peraturan_Menteri_Agama_Nr_42_2016.
# lexid:Peraturan_Menteri_Agama_Nr_42_2016 rdf:type lexid-s:LegalDocument.
# lexid:PM_2019_18 lexid-s:hasDictum "Menetapkan : PERATURAN MENTERI AGAMA TENTANG PENELITIAN DAN PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN."^^xsd:string.
#
# lexid:PM_2019_18 lexid-s:considers "bahwa untuk meningkatkan kualitas dan pemanfaatan hasil penelitian dan pengembangan di bidang agama dan keagamaan pada Kementerian Agama, perlu mengatur mengenai penelitian dan pengembangan di bidang agama dan keagamaan"^^xsd:string.
# lexid:PM_2019_18 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Menteri Agama tentang Penelitian dan Pengembangan di Bidang Agama dan Keagamaan"^^xsd:string.

# %%
with open('dataset-final/new_3_turtle_files/bn/2019/bn1047-2019.ttl', 'r') as f:
    print(f.read())
# Out:
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix dbo: <http://dbpedia.org/ontology/> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix wd: <https://www.wikidata.org/wiki/> .
# @prefix lexid-s: <https://w3id.org/lex-id/schema/> .
# @prefix lexid: <https://w3id.org/lex-id/data/> .
#
# lexid:Perpres_2015_83 rdf:type lexid-s:LegalDocument .
# lexid:Perpres_2015_83 lexid-s:LegalBasisOf lexid:Permen_Agama_2019_18 .
# lexid:Permen_Agama_2019_18 rdfs:label "Peraturan Menteri Agama Republik Indonesia Nomor 18 Tahun 2019"^^xsd:string .
# lexid:Permen_Agama_2019_18 lexid-s:regulationYear "2019"^^xsd:int .
# lexid:Perpres_2015_7 rdfs:label "Peraturan Presiden Republik Indonesia Nomor 7 Tahun 2015"^^xsd:string .
# lexid:Permen_Agama_2019_18 lexid-s:hasLegalBasis lexid:Perpres_2018_38 .
# lexid:UU_2002_18 lexid-s:LegalBasisOf lexid:Permen_Agama_2019_18 .
# lexid:UU_2002_18 rdfs:label "Undang-Undang Republik Indonesia Nomor 18 Tahun 2002"^^xsd:string .
# lexid:Permen_Agama_2019_18 lexid-s:hasLegalBasis lexid:UU_2002_18 .
# lexid:Permen_Agama_2019_18 lexid-s:considers "bahwa untuk meningkatkan kualitas dan pemanfaatan hasil penelitian dan pengembangan di bidang agama dan keagamaan pada Kementerian Agama, perlu mengatur mengenai penelitian dan pengembangan di bidang agama dan keagamaan"^^xsd:string .
# lexid:Permen_Agama_2019_18 lexid-s:hasCreator lexid:Position_Menteri_Agama_Republik_Indonesia .
# lexid:Permen_Agama_2016_42 rdfs:label "Peraturan Menteri Agama Republik Indonesia Nomor 42 Tahun 2016"^^xsd:string .
# lexid:UU_2002_18 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Agama_2019_18 lexid-s:hasDictum "Menetapkan : PERATURAN MENTERI AGAMA TENTANG PENELITIAN DAN PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN."^^xsd:string .
# lexid:Perpres_2015_7 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Agama_2019_18 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Agama_2019_18 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Menteri Agama tentang Penelitian dan Pengembangan di Bidang Agama dan Keagamaan"^^xsd:string .
# lexid:Perpres_2018_38 lexid-s:LegalBasisOf lexid:Permen_Agama_2019_18 .
# lexid:Permen_Agama_2016_42 rdf:type lexid-s:LegalDocument .
# lexid:Perpres_2015_7 lexid-s:LegalBasisOf lexid:Permen_Agama_2019_18 .
# lexid:Perpres_2018_38 rdf:type lexid-s:LegalDocument .
# lexid:Perpres_2015_83 rdfs:label "Peraturan Presiden Republik Indonesia Nomor 83 Tahun 2015"^^xsd:string .
# lexid:Permen_Agama_2019_18 lexid-s:regulationNumber "18"^^xsd:string .
# lexid:Permen_Agama_2019_18 lexid-s:hasLegalBasis lexid:Perpres_2015_83 .
# lexid:Perpres_2018_38 rdfs:label "Peraturan Presiden Republik Indonesia Nomor 38 Tahun 2018"^^xsd:string .
# lexid:Position_Menteri_Agama_Republik_Indonesia rdf:type lexid-s:Position .
# lexid:Permen_Agama_2019_18 lexid-s:hasLegalBasis lexid:Permen_Agama_2016_42 .
# lexid:Permen_Agama_2019_18 lexid-s:hasLegalBasis lexid:Perpres_2015_7 .
# lexid:Permen_Agama_2016_42 lexid-s:LegalBasisOf lexid:Permen_Agama_2019_18 .
# lexid:Permen_Agama_2019_18 lexid-s:name "Penelitian Dan Pengembangan Di Bidang Agama Dan Keagamaan"^^xsd:string .
# lexid:Position_Menteri_Agama_Republik_Indonesia rdfs:label "Menteri Agama Republik Indonesia"^^xsd:string .

# %%
print(permen_opening)
# Out:
# BERITA NEGARA
# REPUBLIK INDONESIA
# No.1047, 2019 KEMENAG. Bidang Agama dan Keagamaan.
# Penelitian dan Pengembangan.
#
#
# PERATURAN MENTERI AGAMA REPUBLIK INDONESIA
# NOMOR 18 TAHUN 2019
# TENTANG
# PENELITIAN DAN PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN
#
# DENGAN RAHMAT TUHAN YANG MAHA ESA
#
# MENTERI AGAMA REPUBLIK INDONESIA,
#
#
# Menimbang  : a. bahwa untuk meningkatkan kualitas dan pemanfaatan
# hasil penelitian dan pengembangan di bidang agama dan
# keagamaan pada Kementerian Agama, perlu mengatur
# mengenai penelitian dan pengembangan di bidang agama
# dan keagamaan;
#   b. bahwa berdasarkan pertimbangan sebagaimana
# dimaksud dalam huruf a, perlu menetapkan Peraturan
# Menteri Agama tentang Penelitian dan Pengembangan di
# Bidang Agama dan Keagamaan;
#
# Mengingat : 1. Undang-Undang Nomor 18 Tahun 2002 tentang Sistem
# Nasional Penelitian, Pengembangan, dan Penerapan Ilmu
# Pengetahuan dan Teknologi (Lembaran Negara Republik
# Indonesia Tahun 2002 Nomor 84, Tambahan Lembaran
# Negara Republik Indonesia Nomor 4219);
#   2. Peraturan Presiden Nomor 7 Tahun 2015 tentang
# Organisasi Kementerian Negara (Lembaran Negara
# Republik Indonesia Tahun 2015 Nomor 8);
#
#
# www.peraturan.go.id
# 2019, No.1047 -2-
# 3. Peraturan Presiden Nomor 83 Tahun 2015 tentang
# Kementerian Agama (Lembaran Negara Republik
# Indonesia Tahun 2015 Nomor 168);
#   4. Peraturan Presiden Nomor 38 Tahun 2018 tentang
# Rencana Induk Riset Nasional (Lembaran Negara
# Republik Indonesia Tahun 2018 Nomor 64);
#   5. Peraturan Menteri Agama Nomor 42 Tahun 2016 tentang
# Organisasi dan Tata Kerja Kementerian Agama (Berita
# Negara Republik Indonesia Tahun 2016 Nomor 1495);
#
# MEMUTUSKAN:
# Menetapkan  : PERATURAN MENTERI AGAMA TENTANG PENELITIAN DAN
# PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN.
#
# BAB I
# KETENTUAN UMUM

# %% [markdown]
# ## Body

# %%
pp_body = '''
BAB I
KETENTUAN UMUM 

Pasal 1
BAB II
KEDUDUKAN, TUGAS, DAN FUNGSI 

Pasal 2
Pasal 3
BAB III
ORGANISASI DAN KEANGGOTAAN 

Bagian Kesatu
Keanggotaan 

Pasal 4
Pasal 5
Pasal 6
Pasal 7
Bagian Kedua
Sekretariat 

Pasal 8
BAB IV
PENGANGKATAN DAN PEMBERHENTIAN ANGGOTA BPKN 

Pasal 9
Pasal 10
Pasal 11
Pasal 12
Pasal 13
Pasal 14
BAB V
PENDANAAN 

Pasal 15
Pasal 16
BAB VI
KETENTUAN PENUTUP 

Pasal 17
Pasal 18
'''

# %%
pp_body_ans = '''
lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_III .
lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_IV .
lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_I .
lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_V .
lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_II .
lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_VI .
lexid:PP_2019_4_Chapter_II lexid-s:isContentOf lexid:PP_2019_4 .
lexid:PP_2019_4_Chapter_III lexid-s:isContentOf lexid:PP_2019_4 .
lexid:PP_2019_4_Chapter_V lexid-s:isContentOf lexid:PP_2019_4 .
lexid:PP_2019_4_Chapter_IV lexid-s:isContentOf lexid:PP_2019_4 .
lexid:PP_2019_4_Chapter_I lexid-s:isContentOf lexid:PP_2019_4 .
lexid:PP_2019_4_Chapter_VI lexid-s:isContentOf lexid:PP_2019_4 .
lexid:PP_2019_4_Chapter_II rdf:type lexid-s:Chapter .
lexid:PP_2019_4_Chapter_V rdf:type lexid-s:Chapter .
lexid:PP_2019_4_Chapter_III rdf:type lexid-s:Chapter .
lexid:PP_2019_4_Chapter_VI rdf:type lexid-s:Chapter .
lexid:PP_2019_4_Chapter_I rdf:type lexid-s:Chapter .
lexid:PP_2019_4_Chapter_IV rdf:type lexid-s:Chapter .
'''.strip()

# %%
prompt_body_1 = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Chapter, adalah Bab, contoh: lexid:PP_2019_4_Chapter_III

Relation paling penting adalah:
- lexid-s:isContentOf, yaitu bab yang merupakan bagian dari peraturan, contoh: lexid:PP_2019_4_Chapter_VI lexid-s:isContentOf lexid:PP_2019_4 .
- lexid-s:hasContent, yaitu peraturan memiliki bab apa saja, lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_VI .

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
BAB I
KETENTUAN UMUM 

Pasal 1
BAB II
KEDUDUKAN, TUGAS, DAN FUNGSI 

Pasal 2
Pasal 3
BAB III
ORGANISASI DAN KEANGGOTAAN 

Bagian Kesatu
Keanggotaan 

Pasal 4
Pasal 5
Pasal 6
Pasal 7
Bagian Kedua
Sekretariat 

Pasal 8
BAB IV
PENGANGKATAN DAN PEMBERHENTIAN ANGGOTA BPKN 

Pasal 9
Pasal 10
Pasal 11
Pasal 12
Pasal 13
Pasal 14
BAB V
PENDANAAN 

Pasal 15
Pasal 16
BAB VI
KETENTUAN PENUTUP 

Pasal 17
Pasal 18
```
###output:
lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_III .
lexid:PP_2019_4_Chapter_III lexid-s:isContentOf lexid:PP_2019_4 .
lexid:PP_2019_4_Chapter_III rdf:type lexid-s:Chapter .
lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_IV .
lexid:PP_2019_4_Chapter_IV lexid-s:isContentOf lexid:PP_2019_4 .
lexid:PP_2019_4_Chapter_IV rdf:type lexid-s:Chapter .
lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_I .
lexid:PP_2019_4_Chapter_I lexid-s:isContentOf lexid:PP_2019_4 .
lexid:PP_2019_4_Chapter_I rdf:type lexid-s:Chapter .
lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_V .
lexid:PP_2019_4_Chapter_V lexid-s:isContentOf lexid:PP_2019_4 .
lexid:PP_2019_4_Chapter_V rdf:type lexid-s:Chapter .
lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_II .
lexid:PP_2019_4_Chapter_II lexid-s:isContentOf lexid:PP_2019_4 .
lexid:PP_2019_4_Chapter_II rdf:type lexid-s:Chapter .
lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_VI .
lexid:PP_2019_4_Chapter_VI lexid-s:isContentOf lexid:PP_2019_4 .
lexid:PP_2019_4_Chapter_VI rdf:type lexid-s:Chapter .

###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
""".strip()

# %%
# teks = '\n'.join([line for line in permen_closing.splitlines() if line.strip() != ''])
test = prompt_body_1.format(regulatory='Permen_2019_18', text=permen_body)

messages = [
    {"role": "user", "content": test},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])

# %%
print(permen_body)
# Out:
# BAB I
# KETENTUAN UMUM
#
# Pasal 1
# Pasal 2
# Pasal 3
# BAB II
# PENYELENGGARAAN PENELITIAN DAN PENGEMBANGAN
#
# Bagian Kesatu
# Penyelenggara Penelitian dan Pengembangan
#
# Pasal 4
# Bagian Kedua
# Kegiatan Penelitian dan Pengembangan
#
# Paragraf 1
# Umum
#
# Pasal 5
# Pasal 6
# Paragraf 2
# Perencanaan
#
# Pasal 7
# Pasal 8
# Paragraf 3
# Pelaksanaan
#
# Pasal 9
# Pasal 10
# Paragraf 4
# Pemantauan dan Evaluasi
#
# Pasal 11
# Paragraf 5
# Pelaporan
#
# Pasal 12
# BAB III
# PEMANFAATAN PENELITIAN DAN PENGEMBANGAN
#
# Pasal 13
# Pasal 14
# Pasal 15
# BAB IV
# PEMBIAYAAN
#
# Pasal 16
# BAB V
# KETENTUAN PENUTUP
#
# Pasal 17

# %% [markdown]
# ## Opening

# %%
from datasets import load_from_disk

dataset_opening = load_from_disk('./dataset-surface-info/new-dataset/new-opening/new-opening')
dataset_opening
# Out:
# Dataset({
#     features: ['regulatory', 'label', 'text', 'text_1', 'text_2', 'triples'],
#     num_rows: 21164
# })

# %%
prompt_1_shot_opening_2 = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia

Relation paling penting adalah:
- lexid-s:regulationNumber, yaitu nomor dari peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:regulationNumber "12"^^xsd:string .
- lexid-s:regulationYear, yaitu tahun dari peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:regulationNumber "2019"^^xsd:string .
- lexid-s:name, yaitu tentang apa peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:name "BADAN PERLINDUNGAN KONSUMEN NASIONAL"^^xsd:string .
- lexid-s:hasCreator, yaitu siapa yang membuat peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasCreator lexid:Position_Presiden_Republik_Indonesia .
- lexid-s:considers, yaitu apa pertimbangan dari peraturan tersebut (ada di Menimbang), contoh: lexid:PP_2019_4 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Pemerintah tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
- lexid-s:hasDictum, yaitu pernyataan tentang peraturan (setelah Menimbang), contoh: lexid:PP_2019_4 lexid-s:hasDictum "Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN PERLINDUNGAN KONSUMEN NASIONAL."^^xsd:string .

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU. 

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
LEMBARAN NEGARA
REPUBLIK INDONESIA
No.12, 2019 KESRA. Badan Perlindungan. Konsumen Nasional.
(Penjelasan dalam Tambahan Lembaran Negara
Republik Indonesia Nomor 6306)

PERATURAN PEMERINTAH REPUBLIK INDONESIA
NOMOR 4 TAHUN 2019
TENTANG
BADAN PERLINDUNGAN KONSUMEN NASIONAL

DENGAN RAHMAT TUHAN YANG MAHA ESA

PRESIDEN REPUBLIK INDONESIA,

Menimbang : a. bahwa untuk mendukung pelaksanaan tugas dan
wewenang Badan Perlindungan Konsumen Nasional,
perlu mengatur kembali Peraturan Pemerintah Nomor
57 Tahun 2001 tentang Badan Perlindungan Konsumen
Nasional;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Pemerintah tentang Badan Perlindungan Konsumen
Nasional;

MEMUTUSKAN:

Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN
PERLINDUNGAN KONSUMEN NASIONAL.


www.peraturan.go.id
2019, No.12 -2-
BAB I
KETENTUAN UMUM
```
###output:
lexid:PP_2019_4 lexid-s:regulationNumber "4"^^xsd:string .
lexid:PP_2019_4 lexid-s:regulationYear "2019"^^xsd:int .
lexid:PP_2019_4 lexid-s:name "BADAN PERLINDUNGAN KONSUMEN NASIONAL"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasCreator lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Badan Perlindungan Konsumen Nasional Dengan Rahmat Tuhan Yang Maha Esa Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:considers "bahwa untuk mendukung pelaksanaan tugas dan wewenang Badan Perlindungan Konsumen Nasional, perlu mengatur kembali Peraturan Pemerintah Nomor 57 Tahun 2001 tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
lexid:PP_2019_4 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Pemerintah tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasDictum "Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN PERLINDUNGAN KONSUMEN NASIONAL."^^xsd:string .
lexid:PP_2019_4 rdfs:label "Peraturan Pemerintah Republik Indonesia Nomor 4 Tahun 2019"^^xsd:string .
lexid:PP_2019_4 rdf:type lexid-s:LegalDocument .

PASTIKAN OUTPUT HANYA DALAM BENTUK TRIPLE. DAN KELUARKAN HANYA BAGIAN ###output.

###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
""".strip()

# %%
prompt_1_shot_opening_2_1 = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia

Relation paling penting adalah:
- lexid-s:hasLegalBasis, yaitu peraturan apa yang menjadi dasar dari peraturan tersebut (ada di Mengingat), contoh: lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
- lexid-s:LegalBasisOf, yaitu invers dari lexid-s:hasLegalBasis, contoh: lexid:UU_1999_8 lexid-s:LegalBasisOf contoh: lexid:PP_2019_4 .

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU.

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
Mengingat : 1. Pasal 5 ayat (2) Undang-Undang Dasar Negara Republik
Indonesia Tahun 1945;
  2. Undang-Undang Nomor 8 Tahun 1999 tentang
Perlindungan Konsumen (Lembaran Negara Republik
Indonesia Tahun 1999 Nomor 22, Tambahan Lembaran
Negara Republik Indonesia Nomor 3821);
```
###output:
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:UUD_1945 rdf:type lexid-s:LegalDocument .
lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .

PASTIKAN OUTPUT HANYA DALAM BENTUK TRIPLE. DAN KELUARKAN HANYA BAGIAN ###output.

###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
""".strip()

# %%
teks = '\n'.join([line for line in dataset_opening[99]['text_2'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2.format(regulatory=dataset_opening[99]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

# %%
teks = '\n'.join([line for line in dataset_opening[99]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[99]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_phi(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# You are not running the flash-attention implementation, expect numerical differences.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 8
#       2 test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[99]['regulatory'], text=teks)
#       4 messages = [
#       5     {"role": "user", "content": test},
#       6 ]
# ----> 8 output = pipe_phi(messages, **generation_args)
#       9 print(output[0]['generated_text'])
#      10 print()
#
# File /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py:235, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     232 if isinstance(text_inputs, (list, tuple)) and isinstance(text_inputs[0], (list, tuple, dict)):
#     233     # We have one or more prompts in list-of-dicts format, so this is chat mode
#     234     if isinstance(text_inputs[0], dict):
# --> 235         return super().__call__(Chat(text_inputs), **kwargs)
#     236     else:
#     237         chats = [Chat(chat) for chat in text_inputs]  # 🐈 🐈 🐈
#
# File /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1242, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1234     return next(
#    1235         iter(
#    1236             self.get_iterator(
#    (...)
#    1239         )
#    1240     )
#    1241 else:
# -> 1242     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1249, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1247 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1248     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1249     model_outputs = self.forward(model_inputs, **forward_params)
#    1250     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1251     return outputs
#
# File /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1149, in Pipeline.forward(self, model_inputs, **forward_params)
#    1147     with inference_context():
#    1148         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1149         model_outputs = self._forward(model_inputs, **forward_params)
#    1150         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1151 else:
#
# File /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py:327, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     324         generate_kwargs["min_length"] += prefix_length
#     326 # BS x SL
# --> 327 generated_sequence = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     328 out_b = generated_sequence.shape[0]
#     329 if self.framework == "pt":
#
# File /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1576, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1559     result = self._assisted_decoding(
#    1560         input_ids,
#    1561         candidate_generator=candidate_generator,
#    (...)
#    1572         **model_kwargs,
#    1573     )
#    1574 if generation_mode == GenerationMode.GREEDY_SEARCH:
#    1575     # 11. run greedy search
# -> 1576     result = self._greedy_search(
#    1577         input_ids,
#    1578         logits_processor=prepared_logits_processor,
#    1579         stopping_criteria=prepared_stopping_criteria,
#    1580         pad_token_id=generation_config.pad_token_id,
#    1581         output_scores=generation_config.output_scores,
#    1582         output_logits=generation_config.output_logits,
#    1583         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1584         synced_gpus=synced_gpus,
#    1585         streamer=streamer,
#    1586         **model_kwargs,
#    1587     )
#    1589 elif generation_mode == GenerationMode.CONTRASTIVE_SEARCH:
#    1590     if not model_kwargs["use_cache"]:
#
# File /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:2494, in GenerationMixin._greedy_search(self, input_ids, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, output_logits, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2491 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2493 # forward pass to get next token
# -> 2494 outputs = self(
#    2495     **model_inputs,
#    2496     return_dict=True,
#    2497     output_attentions=output_attentions,
#    2498     output_hidden_states=output_hidden_states,
#    2499 )
#    2501 if synced_gpus and this_peer_finished:
#    2502     continue  # don't waste resources running the code we don't need
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/bbd531db4632bb631b0c44d98172894a0c594dd0/modeling_phi3.py:1286, in Phi3ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1283 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1285 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1286 outputs = self.model(
#    1287     input_ids=input_ids,
#    1288     attention_mask=attention_mask,
#    1289     position_ids=position_ids,
#    1290     past_key_values=past_key_values,
#    1291     inputs_embeds=inputs_embeds,
#    1292     use_cache=use_cache,
#    1293     output_attentions=output_attentions,
#    1294     output_hidden_states=output_hidden_states,
#    1295     return_dict=return_dict,
#    1296 )
#    1298 hidden_states = outputs[0]
#    1299 logits = self.lm_head(hidden_states)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/bbd531db4632bb631b0c44d98172894a0c594dd0/modeling_phi3.py:1164, in Phi3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1154     layer_outputs = self._gradient_checkpointing_func(
#    1155         decoder_layer.__call__,
#    1156         hidden_states,
#    (...)
#    1161         use_cache,
#    1162     )
#    1163 else:
# -> 1164     layer_outputs = decoder_layer(
#    1165         hidden_states,
#    1166         attention_mask=attention_mask,
#    1167         position_ids=position_ids,
#    1168         past_key_value=past_key_values,
#    1169         output_attentions=output_attentions,
#    1170         use_cache=use_cache,
#    1171     )
#    1173 hidden_states = layer_outputs[0]
#    1175 if use_cache:
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/bbd531db4632bb631b0c44d98172894a0c594dd0/modeling_phi3.py:885, in Phi3DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     882 hidden_states = self.input_layernorm(hidden_states)
#     884 # Self Attention
# --> 885 attn_outputs, self_attn_weights, present_key_value = self.self_attn(
#     886     hidden_states=hidden_states,
#     887     attention_mask=attention_mask,
#     888     position_ids=position_ids,
#     889     past_key_value=past_key_value,
#     890     output_attentions=output_attentions,
#     891     use_cache=use_cache,
#     892 )
#     894 hidden_states = residual + self.resid_attn_dropout(attn_outputs)
#     896 residual = hidden_states
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-128k-instruct/bbd531db4632bb631b0c44d98172894a0c594dd0/modeling_phi3.py:391, in Phi3Attention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache)
#     387 value_states = repeat_kv(value_states, self.num_key_value_groups)
#     389 attn_weights = torch.matmul(query_states, key_states.transpose(2, 3)) / math.sqrt(self.head_dim)
# --> 391 if attn_weights.size() != (bsz, self.num_heads, q_len, kv_seq_len):
#     392     raise ValueError(
#     393         f"Attention weights should be of size {(bsz, self.num_heads, q_len, kv_seq_len)}, but is"
#     394         f" {attn_weights.size()}"
#     395     )
#     397 if attention_mask is not None:
#
# KeyboardInterrupt:
