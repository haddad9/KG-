# %% [markdown]
# ## Teks

# %%
# ln/2019/pp4-2019

pp_opening = """LEMBARAN NEGARA
REPUBLIK INDONESIA
No.12, 2019 KESRA. Badan Perlindungan. Konsumen Nasional.
(Penjelasan dalam Tambahan Lembaran Negara
Republik Indonesia Nomor 6306)

PERATURAN PEMERINTAH REPUBLIK INDONESIA
NOMOR 4 TAHUN 2019
TENTANG
BADAN PERLINDUNGAN KONSUMEN NASIONAL

DENGAN RAHMAT TUHAN YANG MAHA ESA

PRESIDEN REPUBLIK INDONESIA,


Menimbang : a. bahwa untuk mendukung pelaksanaan tugas dan
wewenang Badan Perlindungan Konsumen Nasional,
perlu mengatur kembali Peraturan Pemerintah Nomor
57 Tahun 2001 tentang Badan Perlindungan Konsumen
Nasional;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Pemerintah tentang Badan Perlindungan Konsumen
Nasional;

Mengingat : 1. Pasal 5 ayat (2) Undang-Undang Dasar Negara Republik
Indonesia Tahun 1945;
  2. Undang-Undang Nomor 8 Tahun 1999 tentang
Perlindungan Konsumen (Lembaran Negara Republik
Indonesia Tahun 1999 Nomor 22, Tambahan Lembaran
Negara Republik Indonesia Nomor 3821);

MEMUTUSKAN:

Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN
PERLINDUNGAN KONSUMEN NASIONAL.


www.peraturan.go.id
2019, No.12 -2-
BAB I
KETENTUAN UMUM"""

# %%
pp_closing = """
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.
Ditetapkan di Jakarta pada tanggal 23 Januari 2019
PRESIDEN REPUBLIK INDONESIA,
ttd
JOKO WIDODO
Diundangkan di Jakarta pada tanggal 28 Januari 2019
MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,
ttd
YASONNA H. LAOLLY"""

# %%
# bn/2019/bn1047-2019

permen_opening = """

BERITA NEGARA
REPUBLIK INDONESIA
No.1047, 2019 KEMENAG. Bidang Agama dan Keagamaan.
Penelitian dan Pengembangan.


PERATURAN MENTERI AGAMA REPUBLIK INDONESIA
NOMOR 18 TAHUN 2019
TENTANG
PENELITIAN DAN PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN

DENGAN RAHMAT TUHAN YANG MAHA ESA

MENTERI AGAMA REPUBLIK INDONESIA,


Menimbang  : a. bahwa untuk meningkatkan kualitas dan pemanfaatan
hasil penelitian dan pengembangan di bidang agama dan
keagamaan pada Kementerian Agama, perlu mengatur
mengenai penelitian dan pengembangan di bidang agama
dan keagamaan;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Menteri Agama tentang Penelitian dan Pengembangan di
Bidang Agama dan Keagamaan;

Mengingat : 1. Undang-Undang Nomor 18 Tahun 2002 tentang Sistem
Nasional Penelitian, Pengembangan, dan Penerapan Ilmu
Pengetahuan dan Teknologi (Lembaran Negara Republik
Indonesia Tahun 2002 Nomor 84, Tambahan Lembaran
Negara Republik Indonesia Nomor 4219);
  2. Peraturan Presiden Nomor 7 Tahun 2015 tentang
Organisasi Kementerian Negara (Lembaran Negara
Republik Indonesia Tahun 2015 Nomor 8);


www.peraturan.go.id
2019, No.1047 -2-
3. Peraturan Presiden Nomor 83 Tahun 2015 tentang
Kementerian Agama (Lembaran Negara Republik
Indonesia Tahun 2015 Nomor 168);
  4. Peraturan Presiden Nomor 38 Tahun 2018 tentang
Rencana Induk Riset Nasional (Lembaran Negara
Republik Indonesia Tahun 2018 Nomor 64);
  5. Peraturan Menteri Agama Nomor 42 Tahun 2016 tentang
Organisasi dan Tata Kerja Kementerian Agama (Berita
Negara Republik Indonesia Tahun 2016 Nomor 1495);

MEMUTUSKAN:
Menetapkan  : PERATURAN MENTERI AGAMA TENTANG PENELITIAN DAN
PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN.

BAB I
KETENTUAN UMUM """

# %%
permen_closing = """Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.
Ditetapkan di Jakarta
pada tanggal  12 September 2019
MENTERI AGAMA REPUBLIK INDONESIA,
ttd.
          LUKMAN HAKIM SAIFUDDIN
Diundangkan di Jakarta
pada tanggal 12 September 2019
DIREKTUR JENDERAL
PERATURAN PERUNDANG-UNDANGAN
KEMENTERIAN HUKUM DAN HAK ASASI MANUSIA
REPUBLIK INDONESIA,
ttd.
WIDODO EKATJAHJANA """

# %%
# Perwali_Cirebon_2019_7
# perda/2019/perwal72019

perwali_opening = """
        WALI KOTA CIREBON 
      PROVINSI JAWA BARAT 

                                  PERATURAN WALI KOTA CIREBON                 
                     NOMOR   7   TAHUN 2019 

   TENTANG 

PEDOMAN PEMBERIAN TAMBAHAN PENGHASILAN PEGAWAI 
BAGI PEGAWAI NEGERI SIPIL DI LINGKUNGAN PEMERINTAH 
DAERAH KOTA CIREBON  

DENGAN RAHMAT TUHAN YANG MAHA ESA 
WALI KOTA CIREBON, 

Menimbang   : a. bahwa   Pegawai   Negeri   Sipil   di    Lingkungan 
Pemerintah Daerah Kota  Cirebon, diberikan tambahan 
penghasilan pegawai berdasarkan prestasi kerja  
pegawai secara objektif, transparan, dan akuntabel; 
 b. bahwa berdasarkan pertimbangan sebagaimana 
dimaksud pada huruf a, perlu menetapkan Peraturan 
Wali Kota Cirebon tentang Pedoman Pemberian 
Tambahan Penghasilan Pegawai bagi Pegawai Negeri 
Sipil di Lingkungan Pemerintah Daerah Kota Cirebon; 

Mengingat     :  1.  Undang-Undang Nomor 16 Tahun 1950 tentang 
Pembentukan Daerah-daerah Kota Besar dalam 
Lingkungan Propinsi Djawa Timur, Djawa Tengah, 
Djawa Barat, dan  dalam Daerah Istimewa Yogyakarta     
(Berita   Negara  Republik  Indonesia Tahun 1950 
Nomor 45), sebagaimana telah diubah dengan 
Undang-Undang Nomor 13 Tahun 1954 tentang  
Pengubahan  Undang-Undang Nomor  16 dan Nomor 
17 Tahun 1950 (Republik Indonesia Dahulu)  tentang   
Pembentukan Kota-kota Besar dan Kota-kota Kecil di 
Djawa (Lembaran Negara Republik Indonesia                       
-2-  
Tahun 1954  Nomor 40, Tambahan Lembaran Negara 
Republik Indonesia Nomor 551); 
 2. Undang-Undang Nomor 17 Tahun 2003 tentang 
Keuangan Negara (Lembaran Negara Republik 
Indonesia Tahun 2003  Nomor  47,  Tambahan 
Lembaran   Negara  Republik   Indonesia  Nomor 4286); 
 3. Undang-Undang Nomor 1 Tahun  2004  tentang 
Perbendaharaan Negara (Lembaran  Negara Republik 
Indonesia Tahun 2004  Nomor 5, Tambahan Lembaran 
Negara Republik Indonesia Nomor 4355); 
 4. Undang-Undang Nomor 5 Tahun 2014 tentang 
Aparatur    Sipil Negara (Lembaran Negara Republik 
Indonesia Tahun 2014  Nomor 6, Tambahan Lembaran 
Negara Republik Indonesia Nomor 5494); 
 5. Undang-Undang Nomor 23 Tahun 2014 tentang 
Pemerintahan Daerah (Lembaran Negara Republik 
Indonesia Tahun 2014 Nomor 244, Tambahan 
Lembaran Negara Republik Indonesia Nomor 5587) 
sebagaimana telah  beberapa kali diubah, terakhir 
dengan  Undang-Undang Nomor 9 Tahun 2015 tentang 
Perubahan Kedua Atas Undang-Undang   Nomor 23 
Tahun  2014 tentang  Pemerintahan Daerah (Lembaran 
Negara Republik Indonesia Tahun 2015 Nomor 58,  
Tambahan Lembaran Negara Republik Indonesia  
Nomor 5679); 
 6. Undang-Undang Nomor 30 Tahun 2014 tentang 
Administrasi Pemerintahan (Lembaran Negara 
Republik Indonesia Tahun 2014 Nomor 268, Tambahan 
Lembaran Negara Republik Indonesia Nomor 5601); 
 7. Peraturan Pemerintah  Nomor  56  Tahun  2005 tentang 
Sistem Informasi Keuangan Daerah (Lembaran Negara 
Republik Indonesia Tahun 2005 Nomor 138, Tambahan 
Lembaran Negara Republik Indonesia Nomor 4576) 
sebagaimana telah diubah dengan Peraturan  
Pemerintah Nomor 65 Tahun 2010  tentang  Perubahan 
atas Peraturan Pemerintah Nomor 56 Tahun 2005 
-3-  
tentang Sistem Informasi Keuangan Daerah (Lembaran 
Negara Republik Indonesia Tahun  2010 Nomor 110, 
Tambahan Lembaran Negara Republik Indonesia 
Nomor 5155); 
 8. Peraturan  Pemerintah Nomor  58  Tahun  2005 tentang 
Pengelolaan Keuangan Daerah (Lembaran Negara  
Republik Indonesia Tahun 2005 Nomor 140,   
Tambahan    Lembaran    Negara    Republik Indonesia  
Nomor 4578); 
 9.  Peraturan Pemerintah  Nomor  41  Tahun  2009 tentang 
Tunjangan Profesi Guru dan Dosen, Tunjangan Khusus 
Guru dan Dosen, Serta Tunjangan Kehormatan Profesor 
(Lembaran Negara Republik Indonesia Tahun 2009  
Nomor 85, Tambahan Lembaran Negara Repub1ik 
Indonesia Nomor 5016); 
10.  Peraturan Pemerintah Nomor  53 Tahun  2010 tentang 
Disiplin Pegawai Negeri Sipil (Lembaran Negara 
Republik  Indonesia Tahun 2010 Nomor 74, Tambahan 
Lembaran Negara Republik Indonesia Nomor 5135); 
11.  Peraturan  Pemerintah   Nomor  69  Tahun  2010 
tentang Tata Cara Pemberian dan Pemanfaatan Insentif 
Pemungutan Pajak Daerah dan Retribusi Daerah 
(Lembaran Negara  Republik Indonesia Tahun  2010  
Nomor  119,   Tambahan  Lembaran Negara Republik 
Indonesia  Nomor 5161); 
12. Peraturan    Pemerintah   Nomor  46  Tahun  2011 
tentang  Penilaian  Prestasi  Kerja   Pegawai  Negeri 
Sipil (Lembaran Negara Republik Indonesia Tahun 2011  
Nomor  121,  Tambahan  Lembaran  Negara Republik 
Indonesia  Nomor 5258); 
13.  Peraturan Pemerintah Nomor 18 Tahun 2016 tentang 
Perangkat Daerah  (Lembaran Negara Republik 
Indonesia Tahun  2016 Nomor 114, Tambahan 
Lembaran Negara Republik Indonesia Nomor 5887); 
14.  Peraturan Pemerintah   Nomor  11  Tahun  2017 
tentang  Manajemen Pegawai Negeri Sipil (Lembaran 
-4-  
Negara Republik Indonesia Tahun 2017 Nomor 63, 
Tambahan Lembaran Negara Republik Indonesia  
Nomor 6037); 
15.  Peraturan    Pemerintah   Nomor  12  Tahun  2017 
tentang Pembinaan dan Pengawasan Penyelenggaraan 
Pemerintahan Daerah (Lembaran Negara Republik  
Indonesia Tahun 2017 Nomor 73, Tambahan Lembaran 
Negara Republik Indonesia Nomor 6041); 
16. Peraturan Presiden Nomor 52 Tahun 2009 tentang 
Tambahan Penghasilan bagi Guru Pegawai Negeri Sipil; 
17.  Peraturan Menteri Dalam Negeri Nomor 13 Tahun 2006 
tentang  Pedoman Pengelolaan Keuangan Daerah 
sebagaimana telah diubah beberapa kali terakhir 
dengan Peraturan Menteri Dalam Negeri Nomor 21 
Tahun 2011  tentang Perubahan Kedua atas Peraturan  
Menteri Dalam Negeri Nomor 13 Tahun 2006 tentang 
Pedoman Pengelolaan Keuangan Daerah  (Berita  Negara    
Republik Indonesia Tahun 2011 Nomor 310); 
18. Peraturan Kepala Badan Kepegawaian Negara                 
Nomor 1 Tahun 2013 tentang Ketentuan Pelaksanaan   
Peraturan Pemerintah  Nomor   46 Tahun  2011 tentang 
Penilaian Prestasi Kerja Pegawai Negeri Sipil  (Berita 
Negara Republik Indonesia Tahun 2013                     
Nomor 33); 
19. Peraturan Kepala Badan Kepegawaian Negara                   
Nomor 24 Tahun 2017 tentang Tata Cara Pemberian 
Cuti Pegawai Negeri Sipil;  
20.  Peraturan Daerah Kota Cirebon Nomor 12 Tahun 2015 
tentang Pokok-Pokok Pengelolaan Keuangan Daerah  
(Lembaran Daerah Kota Cirebon Tahun 2015 Nomor  12 
Seri A, Tambahan Lembaran Daerah Kota Cirebon 
Nomor 63); 
 21.  Peraturan  Daerah Kota Cirebon Nomor 6 Tahun 2016  
tentang Rincian Urusan Pemerintahan yang 
Diselenggarakan oleh  Pemerintah   Daerah  Kota 
Cirebon  (Lembaran  Daerah  Kota Cirebon  Tahun 2016  
-5-  
Nomor  6  Seri  D, Tambahan  Lembaran Daerah                 
Kota Cirebon Nomor 69); 
 22. Peraturan  Daerah Kota Cirebon Nomor 7 Tahun 2016 
tentang Pembentukan  dan Susunan Perangkat Daerah  
Kota Cirebon (Lembaran Daerah Kota  Cirebon  Nomor  
7   Tahun  2016  Seri  D, Tambahan Lembaran Daerah      
Kota  Cirebon Nomor 70); 
 23. Peraturan  Daerah Kota Cirebon Nomor 9 Tahun 2016   
tentang Pembentukan Produk Hukum Daerah  
(Lembaran  Daerah  Kota Cirebon Tahun 2016 Nomor 9 
Seri E); 
 24.  Peraturan  Wali Kota Cirebon  Nomor  66 Tahun 2016   
tentang  Kedudukan,  Struktur  Organisasi, Tugas dan 
Fungsi, serta Tata Kerja Badan Kepegawaian, 
Pendidikan dan Pelatihan Daerah Kota Cirebon         
(Berita Daerah Kota Cirebon Tahun 2016 Nomor 66);  
 25.  Peraturan  Wali Kota Cirebon  Nomor  12 Tahun 2018  
tentang Hari Kerja dan Jam Kerja di Lingkungan 
Pemerintah Daerah Kota Cirebon (Berita Daerah                     
Kota Cirebon Tahun 2018 Nomor 12 );  
 

MEMUTUSKAN: 
Menetapkan : PERATURAN WALI KOTA CIREBON TENTANG PEDOMAN 
PEMBERIAN TAMBAHAN PENGHASILAN PEGAWAI BAGI 
PEGAWAI NEGERI DI LINGKUNGAN PEMERINTAH 
DAERAH KOTA CIREBON. 
 

BAB I 

KETENTUAN UMUM  
"""

# %%
perwali_closing = """Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Wali Kota ini dengan penempatannya
dalam Berita Daerah Kota Cirebon.




     Ditetapkan di Cirebon
     pada tanggal 26 Pebruari 2019

WALI KOTA CIREBON,
ttd,

NASHRUDIN AZIS

Diundangkan di Cirebon
pada tanggal 28 Pebruari 2019

SEKRETARIS DAERAH KOTA CIREBON,
ttd,

ASEP DEDI




BERITA DAERAH KOTA CIREBON TAHUN  2019 NOMOR 7


Salinan sesuai dengan aslinya
KEPALA BAGIAN HUKUM
DAN HAK ASASI MANUSIA,


CHANDRA BIMA PRAMANA, SH., MM.
Pembina Tingkat I (IV/b)
NIP. 19621001 199703 1 003

 """

# %% [markdown]
# ## Intro

# %%
# !nvidia-smi
# Out:
# Thu May 23 13:23:15 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          On  |   00000000:07:00.0 Off |                    0 |
# | N/A   38C    P0            297W /  400W |   17381MiB /  40960MiB |     57%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'

# %%
from huggingface_hub import login

login(token = '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')
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# import torch
# from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline, BitsAndBytesConfig, GPTQConfig

# MODEL_NAME = "google/codegemma-7b-it"

# compute_dtype = getattr(torch, "float16")
# bnb_config = BitsAndBytesConfig(
#         load_in_4bit=True,
#         bnb_4bit_quant_type="nf4",
#         bnb_4bit_compute_dtype=compute_dtype,
#         bnb_4bit_use_double_quant=True,
#         llm_int8_enable_fp32_cpu_offload=True,
# )

# model_f7 = AutoModelForCausalLM.from_pretrained(
#         MODEL_NAME, trust_remote_code=True, device_map="auto", quantization_config=bnb_config
# )

# tokenizer_f7 = AutoTokenizer.from_pretrained(MODEL_NAME, trust_remote_code=True)
# print(f"Model device: {model_f7.device}")

# %%
# import torch
# from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline, BitsAndBytesConfig, GPTQConfig

# MODEL_NAME = "google/codegemma-7b-it"

# model_f7 = AutoModelForCausalLM.from_pretrained(
#     MODEL_NAME, trust_remote_code=True, device_map="auto"
# ).half()
# model_f7 = model_f7.eval()

# tokenizer_f7 = AutoTokenizer.from_pretrained(MODEL_NAME, trust_remote_code=True)
# print(f"Model device: {model_f7.device}")

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

torch.random.manual_seed(0)

# MODEL_NAME = 'microsoft/Phi-3-small-8k-instruct'
MODEL_NAME = 'microsoft/Phi-3-mini-128k-instruct'

model_f7 = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME, 
    device_map="cuda", 
    torch_dtype="auto",
    trust_remote_code=True, 
)

tokenizer_f7 = AutoTokenizer.from_pretrained(MODEL_NAME, trust_remote_code=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# import torch
# from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# torch.random.manual_seed(0)

# MODEL_NAME = "google/codegemma-7b-it"

# model_f7 = AutoModelForCausalLM.from_pretrained(
#     MODEL_NAME, 
#     device_map="cuda", 
#     torch_dtype="auto",
#     trust_remote_code=True, 
# ).half()

# tokenizer_f7 = AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
pipe_f7 = pipeline(
    "text-generation",
    model=model_f7,
    tokenizer=tokenizer_f7,
    framework="pt",
)

generation_args = {
    "max_new_tokens": 5000,
    "return_full_text": False,
    "temperature": 0.0,
    "do_sample": False,
#     "repetition_penalty": 1.7,
#     "bos_token_id": 11,
#     "eos_token_id": 11,
#     "pad_token_id": 11,
#     "use_cache": False,
}

# %%
generator = pipeline(
    task = "text-generation",
    model = model_f7,
    tokenizer =tokenizer_f7,
    max_new_tokens=5000,
    framework = 'pt',
    use_fast = True
)

# %% [markdown]
# ## Closing

# %%
from datasets import load_from_disk

dataset_opening = load_from_disk('./dataset-surface-info/new-dataset/new-opening/new-opening-1')
dataset_opening
# Out:
# Dataset({
#     features: ['regulatory', 'label', 'text', 'text_1', 'text_2', 'triples'],
#     num_rows: 2639
# })

# %%
from datasets import load_from_disk

dataset_closing = load_from_disk('./dataset-surface-info/new-dataset/new-closing/new-closing-1')
dataset_closing
# Out:
# Dataset({
#     features: ['regulatory', 'label', 'text', 'triples'],
#     num_rows: 2639
# })

# %%
prompt_1_shot = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU.

Contoh:
###regulatory: lexid:PP_2019_4
###Teks: 
```
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.

Ditetapkan di Jakarta pada tanggal 23 Januari 2019

PRESIDEN REPUBLIK INDONESIA,

ttd

JOKO WIDODO

Diundangkan di Jakarta pada tanggal 28 Januari 2019

MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,

ttd

YASONNA H. LAOLLY
```
###output:

lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
""".strip()

# %%
# quantized

import time

start = time.time()

test = prompt_1_shot.format(regulatory='Permen_2019_18', text=permen_closing)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])

end = time.time()
print(end-start)

# %%
# not quantized

import time

start = time.time()

test = prompt_1_shot.format(regulatory='Permen_2019_18', text=permen_closing)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])

end = time.time()
print(end-start)

# %%
prompt_1_shot_closing_2 = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOfficial, yaitu siapa nama orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasEnactionOffice, yaitu apa jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationOfficial, yaitu siapa nama orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasPromulgationOffice, yaitu apa jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU. IDENTIFIKASI TRIPLE SEBANYAK MUNGKIN.

Contoh:
###regulatory: lexid:PP_2019_4
###Teks: 
```
Agar setiap orang mengetahuinya, memerintahkan
pengundangan Peraturan Menteri ini dengan penempatannya
dalam Berita Negara Republik Indonesia.

Ditetapkan di Jakarta pada tanggal 23 Januari 2019

PRESIDEN REPUBLIK INDONESIA,

ttd

JOKO WIDODO

Diundangkan di Jakarta pada tanggal 28 Januari 2019

MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA,

ttd

YASONNA H. LAOLLY
```
###output:

lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .

###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
""".strip()

# %%
teks = '\n'.join([line for line in dataset_closing[2034]['text'].splitlines() if line.strip() != ''])

test = prompt_1_shot_closing_2.format(regulatory=dataset_closing[2034]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])

# %%
prompt_1_shot_closing_3 = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOfficial, yaitu siapa saja nama orang yang menetapkan peraturan tersebut (bisa lebih dari satu), contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasEnactionOffice, yaitu apa saja jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationOfficial, yaitu siapa saja nama orang yang mengundangkan peraturan tersebut (bisa lebih dari satu), contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasPromulgationOffice, yaitu apa saja jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU.

Contoh:
###regulatory: lexid:PP_2019_4
###Teks: 
```
Peraturan Pemerintah ini mulai berlaku pada tanggal 
diundangkan. 
www.peraturan.go.id
2019, No.12 
-9- 
Agar setiap orang mengetahuinya, memerintahkan 
pengundangan Peraturan Pemerintah ini dengan 
penempatannya dalam Lembaran Negara Republik 
Indonesia. 
Ditetapkan di Jakarta 
pada tanggal 23 Januari 2019  
PRESIDEN REPUBLIK INDONESIA, 
ttd 
JOKO WIDODO 
Diundangkan di Jakarta 
pada tanggal 28 Januari 2019 
MENTERI HUKUM DAN HAK ASASI MANUSIA  
REPUBLIK INDONESIA,  
ttd 
YASONNA H. LAOLLY 
www.peraturan.go.id
```
###output:
lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-23"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo .
lexid:Person_Joko_Widodo rdfs:label "Joko Widodo"^^xsd:string .
lexid:Person_Joko_Widodo rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date .
lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly .
lexid:Person_Yasonna_H_Laolly rdfs:label "Yasonna H Laolly"^^xsd:string .
lexid:Person_Yasonna_H_Laolly rdf:type lexid-s:Person .
lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdfs:label "Menteri Hukum Dan Hak Asasi Manusia Republik Indonesia"^^xsd:string .
lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia rdf:type lexid-s:Position .

PASTIKAN OUTPUT HANYA DALAM BENTUK TRIPLE.

###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
""".strip()

# %%
prompt_1_shot_closing_3_1 = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Person, contoh: lexid:Person_Joko_Widodo
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia
- lexid-s:City, contoh: lexid:City_Depok

Relation paling penting adalah:
- lexid-s:hasPromulgationPlace, yaitu dimana pengundangan peraturan tersebut ditempatkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara.
- lexid-s:hasEnactionDate, yaitu kapan peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionDate "2019-01-28"^^xsd:date.
- lexid-s:hasEnactionLocation, yaitu dimana peraturan tersebut ditetapkan, contoh: lexid:PP_2019_4 lexid-s:hasEnactionLocation lexid:City_Jakarta.
- lexid-s:hasEnactionOfficial, yaitu siapa saja nama orang yang menetapkan peraturan tersebut (bisa lebih dari satu), contoh: lexid:PP_2019_4 lexid-s:hasEnactionOfficial lexid:Person_Joko_Widodo.
- lexid-s:hasEnactionOffice, yaitu apa saja jabatan dari orang yang menetapkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia.
- lexid-s:hasPromulgationDate, yaitu kapan peraturan tersebut diudangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationDate "2019-01-28"^^xsd:date.
- lexid-s:hasPromulgationLocation, yaitu dimana peraturan tersebut diundangkan, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationLocation lexid:City_Jakarta.
- lexid-s:hasPromulgationOfficial, yaitu siapa saja nama orang yang mengundangkan peraturan tersebut (bisa lebih dari satu), contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOfficial lexid:Person_Yasonna_H_Laolly.
- lexid-s:hasPromulgationOffice, yaitu apa saja jabatan dari orang yang mengundangkan peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasPromulgationOffice lexid:Position_Menteri_Hukum_Dan_Hak_Asasi_Manusia_Republik_Indonesia.

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU.

Contoh:
###regulatory: lexid:PP_1954_51
###Teks: 
```
Pasal 14 

Peraturan Pemerintah ini mulai berlaku pada hari diundangkan. 

Agar supaya setiap orang dapat mengetahuinya, memerintahkan pengundangan Peraturan 

Pemerintah ini dengan penempatan dalam Lembaran Negara Republik Indonesia. 

Ditetapkan di Jakarta 

pada tanggal 7 September 1954. 

PRESIDEN REPUBLIK INDONESIA, 

ttd. 

SUKARNO. 

WAKIL PERDANA MENTERI II, 

ttd. 

ZAINUL ARIFIN. 

Diundangkan 

pada tanggal 5 Oktober 1954. 

MENTERI KEHAKIMAN, 

ttd. 

DJODY GONDOKUSUMO. 

MENTERI KEUANGAN a.i., 

ttd. 

ISKAQ TJOKROHADISURJO 

LEMBARAN NEGARA NOMOR 92 TAHUN 1954
```
###output:
lexid:PP_1954_51 lexid-s:hasPromulgationPlace lexid:Lembaran_Negara .
lexid:PP_1954_51 lexid-s:hasEnactionDate "1954-09-07"^^xsd:date .
lexid:PP_1954_51 lexid-s:hasEnactionLocation lexid:City_Jakarta .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_1954_51 lexid-s:hasEnactionOfficial lexid:Person_Sukarno .
lexid:Person_Sukarno rdfs:label "Sukarno"^^xsd:string .
lexid:Person_Sukarno rdf:type lexid-s:Person .
lexid:PP_1954_51 lexid-s:hasEnactionOfficial lexid:Person_Zainul_Arifin .
lexid:Person_Zainul_Arifin rdfs:label "Zainul Arifin"^^xsd:string .
lexid:Person_Zainul_Arifin rdf:type lexid-s:Person .
lexid:PP_1954_51 lexid-s:hasEnactionOffice lexid:Position_Presiden_Republik_Indonesia .
lexid:Position_Presiden_Republik_Indonesia rdfs:label "Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_1954_51 lexid-s:hasEnactionOffice lexid:Position_Wakil_Perdana_Menteri_II .
lexid:Position_Wakil_Perdana_Menteri_II rdfs:label "Wakil Perdana Menteri II"^^xsd:string .
lexid:Position_Wakil_Perdana_Menteri_II rdf:type lexid-s:Position .
lexid:PP_1954_51 lexid-s:hasPromulgationDate "1954-10-05"^^xsd:date .
lexid:PP_1954_51 lexid-s:hasPromulgationLocation lexid:City_Jakarta .
lexid:City_Jakarta rdf:type lexid-s:City .
lexid:City_Jakarta rdfs:label "Jakarta"^^xsd:string .
lexid:PP_1954_51 lexid-s:hasPromulgationOfficial lexid:Person_Djody_Gondokusumo .
lexid:Person_Djody_Gondokusumo rdf:type lexid-s:Person .
lexid:Person_Djody_Gondokusumo rdfs:label "Djody Gondokusumo"^^xsd:string .
lexid:PP_1954_51 lexid-s:hasPromulgationOfficial lexid:Person_Iskaq_Tjokrohadisurjo .
lexid:Person_Iskaq_Tjokrohadisurjo rdf:type lexid-s:Person .

PASTIKAN OUTPUT HANYA DALAM BENTUK TRIPLE.

###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
""".strip()

# %%
teks = '\n'.join([line for line in dataset_closing[93]['text'].splitlines() if line.strip() != ''])

test = prompt_1_shot_closing_3.format(regulatory=dataset_closing[93]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

# %%
teks = '\n'.join([line for line in dataset_closing[93]['text'].splitlines() if line.strip() != ''])

test = prompt_1_shot_closing_3_1.format(regulatory=dataset_closing[93]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

# %%
test = prompt_1_shot_closing_3.format(regulatory='Perkot_Cirebon_2019_7', text=perwali_closing)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(perwali_closing)

# %%
test = prompt_1_shot_closing_3.format(regulatory='PP_2019_4', text=pp_closing)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(pp_closing)

# %% [markdown]
# # Closing Code

# %%
prompt_code_closing = '''
You are a helpful assistant. Lanjutkan extraction dari code yang diberikan. 

from typing import List

class Rel:
    def __init__(self, name: str):
        self.name = name
class hasEnactionOfficial(Rel):
    # Siapa nama orang yang menetapkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasEnactionDate(Rel):
    # Kapan peraturan ditetapkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasEnactionLocation(Rel):
    # Dimana peraturan ditetapkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasEnactionOffice(Rel):
    # Apa jabatan dari orang yang menetapkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationOfficial(Rel):
    # Siapa nama orang yang mengundangkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationDate(Rel):
    # Kapan peraturan diundangkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationLocation(Rel):
    # Dimana peraturan diundangkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationOffice(Rel):
    # Apa jabatan dari orang yang mengundangkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationPlace(Rel):
    # Dimana pengundangan peraturan ditempatkan
    def __init__(self, name: str):
        super.__init__(name=name)

class Entity:
    def __init__(self, name: str):
        self.name = name
class Person(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class Date(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class City(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class Positon(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class Place(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
        
class Triple:
    def __init__(self, relation: Rel, tail: Entity):
        self.relation = relation
        self.tail = tail
class Extract:
    def __init__(self, triples: List[Triple] = []):
        self.triples = triples

###Prompt
```
Agar setiap orang mengetahuinya, memerintahkan 
pengundangan Peraturan Menteri ini dengan penempatannya 
dalam Berita Negara Republik Indonesia. 
 
 
Ditetapkan di Jakarta 
pada tanggal  12 September 2019 
 
MENTERI AGAMA REPUBLIK INDONESIA, 
 
ttd. 
 
          LUKMAN HAKIM SAIFUDDIN 
 
Diundangkan di Jakarta 
pada tanggal 12 September 2019 
 
DIREKTUR JENDERAL 
PERATURAN PERUNDANG-UNDANGAN 
KEMENTERIAN HUKUM DAN HAK ASASI MANUSIA 
REPUBLIK INDONESIA, 
 
ttd. 
 
WIDODO EKATJAHJANA 
```
###Output
extract = Extract([Triple(Rel('hasEnactionOfficial'), Person('LUKMAN HAKIM SAIFUDDIN')),
                   Triple(Rel('hasEnactionDate'), Date('2019-09-12')),
                   Triple(Rel('hasEnactionLocation'), City('Jakarta')),
                   Triple(Rel('hasEnactionOffice'), Position('MENTERI AGAMA REPUBLIK INDONESIA')),
                   Triple(Rel('hasPromulgationOfficial'), Person('WIDODO EKATJAHJANA')),
                   Triple(Rel('hasPromulgationDate'), Date('2019-09-12')),
                   Triple(Rel('hasPromulgationLocation'), City('Jakarta')),
                   Triple(Rel('hasPromulgationOffice'), Position('DIREKTUR JENDERAL PERATURAN PERUNDANG-UNDANGAN KEMENTERIAN HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA')),
                   Triple(Rel('hasPromulgationPlace'), Place('Berita Negara')),])
                   
IDENTIFIKASI SEBANYAK MUNGKIN TRIPLE SESUAI RELATION DAN ENTITY. JANGAN MELAKUKAN EKSTRAKSI SELAIN RELATION YANG DITENTUKAN.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU. IDENTIFIKASI SEMUA ENTITY DAN RELATION YANG ADA.

###Prompt
```
{prompt}
```
###Output
'''

# %%
prompt_code_closing_2 = '''
You are a helpful assistant. Lanjutkan extraction dari code yang diberikan. 

from typing import List

class Rel:
    def __init__(self, name: str):
        self.name = name
class hasEnactionDate(Rel):
    # Kapan peraturan ditetapkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasEnactionLocation(Rel):
    # Dimana peraturan ditetapkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasEnactionOfficial(Rel):
    # Siapa nama orang yang menetapkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasEnactionOffice(Rel):
    # Apa jabatan dari orang yang menetapkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationDate(Rel):
    # Kapan peraturan diundangkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationLocation(Rel):
    # Dimana peraturan diundangkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationOfficial(Rel):
    # Siapa nama orang yang mengundangkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationOffice(Rel):
    # Apa jabatan dari orang yang mengundangkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationPlace(Rel):
    # Dimana pengundangan peraturan ditempatkan
    def __init__(self, name: str):
        super.__init__(name=name)

class Entity:
    def __init__(self, name: str):
        self.name = name
class Person(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class Date(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class City(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class Positon(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class Place(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
        
class Triple:
    def __init__(self, relation: Rel, tail: Entity):
        self.relation = relation
        self.tail = tail
class Extract:
    def __init__(self, triples: List[Triple] = []):
        self.triples = triples

###Prompt
```
Agar setiap orang mengetahuinya, memerintahkan 
pengundangan Peraturan Menteri ini dengan penempatannya 
dalam Berita Negara Republik Indonesia. 
 
 
Ditetapkan di Jakarta 
pada tanggal  12 September 2019 
 
MENTERI AGAMA REPUBLIK INDONESIA, 
 
ttd. 
 
          LUKMAN HAKIM SAIFUDDIN 
 
Diundangkan di Jakarta 
pada tanggal 12 September 2019 
 
DIREKTUR JENDERAL 
PERATURAN PERUNDANG-UNDANGAN 
KEMENTERIAN HUKUM DAN HAK ASASI MANUSIA 
REPUBLIK INDONESIA, 
 
ttd. 
 
WIDODO EKATJAHJANA 
```
###Output
extract = Extract([Triple(Rel('hasEnactionDate'), Date('2019-09-12')),
                   Triple(Rel('hasEnactionLocation'), City('Jakarta')),
                   Triple(Rel('hasEnactionOfficial'), Person('LUKMAN HAKIM SAIFUDDIN')),
                   Triple(Rel('hasEnactionOffice'), Position('MENTERI AGAMA REPUBLIK INDONESIA')),
                   Triple(Rel('hasPromulgationDate'), Date('2019-09-12')),
                   Triple(Rel('hasPromulgationLocation'), City('Jakarta')),
                   Triple(Rel('hasPromulgationOfficial'), Person('WIDODO EKATJAHJANA')),
                   Triple(Rel('hasPromulgationOffice'), Position('DIREKTUR JENDERAL PERATURAN PERUNDANG-UNDANGAN KEMENTERIAN HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA')),
                   Triple(Rel('hasPromulgationPlace'), Place('Berita Negara')),])
                   
IDENTIFIKASI SEBANYAK MUNGKIN TRIPLE. JANGAN MELAKUKAN EKSTRAKSI SELAIN RELATION YANG DITENTUKAN.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU.

###Prompt
```
{prompt}
```
###Output
'''

# %%
prompt_code_closing_3 = '''
You are a helpful assistant. Lanjutkan extraction dari code yang diberikan. 

from typing import List

class Rel:
    def __init__(self, name: str):
        self.name = name
class hasEnactionDate(Rel):
    # Kapan peraturan ditetapkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasEnactionLocation(Rel):
    # Dimana peraturan ditetapkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasEnactionOfficial(Rel):
    # Siapa nama orang yang menetapkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasEnactionOffice(Rel):
    # Apa jabatan dari orang yang menetapkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationDate(Rel):
    # Kapan peraturan diundangkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationLocation(Rel):
    # Dimana peraturan diundangkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationOfficial(Rel):
    # Siapa nama orang yang mengundangkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationOffice(Rel):
    # Apa jabatan dari orang yang mengundangkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationPlace(Rel):
    # Dimana pengundangan peraturan ditempatkan
    def __init__(self, name: str):
        super.__init__(name=name)

class Entity:
    def __init__(self, name: str):
        self.name = name
class Person(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class Date(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class City(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class Positon(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class Place(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
        
class Triple:
    def __init__(self, relation: Rel, tail: Entity):
        self.relation = relation
        self.tail = tail
class Extract:
    def __init__(self, triples: List[Triple] = []):
        self.triples = triples

###Prompt
```
Agar setiap orang mengetahuinya, memerintahkan 
pengundangan Peraturan Menteri ini dengan penempatannya 
dalam Berita Negara Republik Indonesia. 
 
 
Ditetapkan di Jakarta 
pada tanggal  12 September 2019 
 
MENTERI AGAMA REPUBLIK INDONESIA, 
 
ttd. 
 
          LUKMAN HAKIM SAIFUDDIN 
 
Diundangkan di Jakarta 
pada tanggal 12 September 2019 
 
DIREKTUR JENDERAL 
PERATURAN PERUNDANG-UNDANGAN 
KEMENTERIAN HUKUM DAN HAK ASASI MANUSIA 
REPUBLIK INDONESIA, 
 
ttd. 
 
WIDODO EKATJAHJANA 
```
###Output
extract = Extract([Triple(Rel('hasEnactionDate'), Date('2019-09-12')),
                   Triple(Rel('hasEnactionLocation'), City('Jakarta')),
                   Triple(Rel('hasEnactionOfficial'), Person('LUKMAN HAKIM SAIFUDDIN')),
                   Triple(Rel('hasEnactionOffice'), Position('MENTERI AGAMA REPUBLIK INDONESIA')),
                   Triple(Rel('hasPromulgationDate'), Date('2019-09-12')),
                   Triple(Rel('hasPromulgationLocation'), City('Jakarta')),
                   Triple(Rel('hasPromulgationOfficial'), Person('WIDODO EKATJAHJANA')),
                   Triple(Rel('hasPromulgationOffice'), Position('DIREKTUR JENDERAL PERATURAN PERUNDANG-UNDANGAN KEMENTERIAN HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA')),
                   Triple(Rel('hasPromulgationPlace'), Place('Berita Negara')),])
                   
###Prompt
```
(1) Lembaga Musyawarah Desa yang ada sekarang tetap melaksanakan tugas dan 
fungsinya sampai terbentuk Badan Perwakilan desa. 
http://www.bphn.go.id/
(2) Unsur dari BPD dalam anggota pemilihan sebagaimana dimaksud pasal 8 ayat (1) 
huruf b, untuk BPD yang dibentuk pertama kali dilaksanakan oleh unsur dari LMD 
selain Kepala Dusun. 
(3) Sebelum terbentuknya BPD, dalam hal terjadi pemberhentian lurah dan pamong 
desa maka mekanisme pemberhentiannya menggunakan peraturan perundang-
undangan yang berlaku. 
8. Pada penjelasan pasal demi pasal : 
Pasal 62 ayat (2) yang domaksud dengan peraturan perundang-undangan yang 
berlaku adalah ketentuan atau peraturan yang berlaku pada saat pengangkatannya. 
Pasal II 
Peraturan Bupati ini mulai berlaku pada tanggal ditetapkan 
Agar setiap orang dapat mengetahuinya memerintahkan pengundangan Peraturan Bupati 
ini dengan penempatannya dalam Lembaran Daerah Kabupaten Bantul. 
Ditetapkan di Bantul, 
pada tanggal 9 Feb 2001 
BUPATI BANTUL, 
TOTOK SUDARTO 
Diundangkan di Bantul 
Tanggal 10 Feb 2001 
SEKRETARIS DAERAH KABUPATEN BANTUL, 
                   Drs ASHADI, MSi 
(Pembina Utama Muda, IV/c) 
NIP. 490018672 
LEMBARAN DAERAH KABUPATEN BANTUL 
SERI A NOMOR 1 TAHUN 2001 
http://www.bphn.go.id/
 4
http://www.bphn.go.id/
 
```
###Output
extract = Extract([Triple(Rel('hasEnactionDate'), Date('2001-02-09')),
                   Triple(Rel('hasEnactionLocation'), City('Bantul')),
                   Triple(Rel('hasEnactionOfficial'), Person('TOTOK SUDARTO')),
                   Triple(Rel('hasEnactionOffice'), Position('BUPATI BANTUL')),
                   Triple(Rel('hasPromulgationDate'), Date('2001-02-10')),
                   Triple(Rel('hasPromulgationLocation'), City('Bantul')),
                   Triple(Rel('hasPromulgationOfficial'), Person('Drs ASHADI, MSi')),
                   Triple(Rel('hasPromulgationOffice'), Position('SEKRETARIS DAERAH KABUPATEN BANTUL')),
                   Triple(Rel('hasPromulgationPlace'), Place('Lembaran Daerah Kabupaten Bantul')),])
                   
###Prompt
```
Pasal 18 

Peraturan Pemerintah ini mulai berlaku pada tanggal 

diundangkan. 


www.peraturan.go.id

2019, No.12 

-9- 

Agar setiap orang mengetahuinya, memerintahkan 

pengundangan Peraturan Pemerintah ini dengan 

penempatannya dalam Lembaran Negara Republik 

Indonesia. 

 

Ditetapkan di Jakarta 

pada tanggal 23 Januari 2019  

 

PRESIDEN REPUBLIK INDONESIA, 

 

ttd 

 

JOKO WIDODO 

 

Diundangkan di Jakarta 

pada tanggal 28 Januari 2019 

 

MENTERI HUKUM DAN HAK ASASI MANUSIA  

REPUBLIK INDONESIA,  

 

ttd 

 

YASONNA H. LAOLLY 

www.peraturan.go.id

```
###Output
extract = Extract([Triple(Rel('hasEnactionDate'), Date('2019-01-23')),
                   Triple(Rel('hasEnactionLocation'), City('Jakarta')),
                   Triple(Rel('hasEnactionOfficial'), Person('JOKO WIDODO')),
                   Triple(Rel('hasEnactionOffice'), Position('PRESIDEN REPUBLIK INDONESIA')),
                   Triple(Rel('hasPromulgationDate'), Date('2019-01-28')),
                   Triple(Rel('hasPromulgationLocation'), City('Jakarta')),
                   Triple(Rel('hasPromulgationOfficial'), Person('YASONNA H. LAOLLY')),
                   Triple(Rel('hasPromulgationOffice'), Position('MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA')),
                   Triple(Rel('hasPromulgationPlace'), Place('Lembaran Negara')),])                   
                   
                   
                   
IDENTIFIKASI SEBANYAK MUNGKIN TRIPLE. JANGAN MELAKUKAN EKSTRAKSI SELAIN RELATION YANG DITENTUKAN.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU.

###Prompt
```
{prompt}
```
###Output
'''

# %%
prompt_code_closing_4 = '''
You are a helpful assistant. Lanjutkan extraction dari code yang diberikan. 

from typing import List

class Rel:
    def __init__(self, name: str):
        self.name = name
class hasEnactionDate(Rel):
    # Kapan peraturan ditetapkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasEnactionLocation(Rel):
    # Dimana peraturan ditetapkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasEnactionOfficial(Rel):
    # Siapa nama orang yang menetapkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasEnactionOffice(Rel):
    # Apa jabatan dari orang yang menetapkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationDate(Rel):
    # Kapan peraturan diundangkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationLocation(Rel):
    # Dimana peraturan diundangkan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationOfficial(Rel):
    # Siapa nama orang yang mengundangkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationOffice(Rel):
    # Apa jabatan dari orang yang mengundangkan peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class hasPromulgationPlace(Rel):
    # Dimana pengundangan peraturan ditempatkan
    def __init__(self, name: str):
        super.__init__(name=name)

class Entity:
    def __init__(self, name: str):
        self.name = name
class Person(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class Date(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class City(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class Positon(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class Place(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
        
class Triple:
    def __init__(self, relation: Rel, tail: Entity):
        self.relation = relation
        self.tail = tail
class Extract:
    def __init__(self, triples: List[Triple] = []):
        self.triples = triples

###Prompt
```
Pasal 18 

Peraturan Pemerintah ini mulai berlaku pada tanggal 

diundangkan. 
 

www.peraturan.go.id

2019, No.12 

-9- 

Agar setiap orang mengetahuinya, memerintahkan 

pengundangan Peraturan Pemerintah ini dengan 

penempatannya dalam Lembaran Negara Republik 

Indonesia. 


Ditetapkan di Jakarta 

pada tanggal 23 Januari 2019  


PRESIDEN REPUBLIK INDONESIA, 


ttd 
 

JOKO WIDODO 


Diundangkan di Jakarta 

pada tanggal 28 Januari 2019 
 

MENTERI HUKUM DAN HAK ASASI MANUSIA  

REPUBLIK INDONESIA,  


ttd 


YASONNA H. LAOLLY 

www.peraturan.go.id
```
###Output
extract = Extract([Triple(Rel('hasEnactionOfficial'), Person('JOKO WIDODO')),
                   Triple(Rel('hasEnactionDate'), Date('2019-01-23')),
                   Triple(Rel('hasEnactionLocation'), City('Jakarta')),
                   Triple(Rel('hasEnactionOffice'), Position('PRESIDEN REPUBLIK INDONESIA')),
                   Triple(Rel('hasPromulgationOfficial'), Person('YASONNA H. LAOLLY')),
                   Triple(Rel('hasPromulgationDate'), Date('2019-01-28')),
                   Triple(Rel('hasPromulgationLocation'), City('Jakarta')),
                   Triple(Rel('hasPromulgationOffice'), Position('MENTERI HUKUM DAN HAK ASASI MANUSIA REPUBLIK INDONESIA')),
                   Triple(Rel('hasPromulgationPlace'), Place('Lembaran Negara')),])
                   
IDENTIFIKASI SEBANYAK MUNGKIN TRIPLE. JANGAN MELAKUKAN EKSTRAKSI SELAIN RELATION YANG DITENTUKAN.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU.

###Prompt
```
{prompt}
```
###Output
'''

# %%
# sebelum ditambahin IDENTIFIKASI SEMUA ENTITY DAN RELATION YANG ADA.

teks = '\n'.join([line for line in dataset_closing[5217]['text'].splitlines() if line.strip() != ''])

test = prompt_code_closing.format(prompt=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print(teks)

# %%
teks = '\n'.join([line for line in dataset_closing[5217]['text'].splitlines() if line.strip() != ''])

test = prompt_code_closing_4.format(prompt=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print(teks)

# %%
teks = '\n'.join([line for line in dataset_closing[93]['text'].splitlines() if line.strip() != ''])

test = prompt_code_closing_4.format(prompt=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print(teks)

# %%
teks = '\n'.join([line for line in dataset_closing[93]['text'].splitlines() if line.strip() != ''])

test = prompt_code_closing_3.format(prompt=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print(teks)

# %%
# sebelum ditambahin PASTIKAN IDENTIFIKASI SEMUA ENTITY DAN RELATION JIKA MEMANG ADA.

teks = '\n'.join([line for line in dataset_closing[93]['text'].splitlines() if line.strip() != ''])

test = prompt_code_closing.format(prompt=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print(teks)

# %%
teks = '\n'.join([line for line in dataset_closing[870]['text'].splitlines() if line.strip() != ''])

test = prompt_code_closing_2.format(prompt=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print(teks)

# %% [markdown]
# # Opening

# %%
prompt_1_shot_2 = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia

Relation paling penting adalah:
- lexid-s:regulationNumber, yaitu nomor dari peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:regulationNumber "12"^^xsd:string .
- lexid-s:regulationYear, yaitu tahun dari peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:regulationNumber "2019"^^xsd:string .
- lexid-s:considers, yaitu apa pertimbangan dari peraturan tersebut (ada di Menimbang), contoh: lexid:PP_2019_4 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Pemerintah tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
- lexid-s:hasLegalBasis, yaitu peraturan apa yang menjadi dasar dari peraturan tersebut (ada di Mengingat), contoh: lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
- lexid-s:LegalBasisOf, yaitu invers dari lexid-s:hasLegalBasis, contoh: lexid:UU_1999_8 lexid-s:LegalBasisOf contoh: lexid:PP_2019_4 .
- lexid-s:hasDictum, yaitu pernyataan tentang peraturan (ada di Menetapkan), contoh: lexid:PP_2019_4 lexid-s:hasDictum "Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN PERLINDUNGAN KONSUMEN NASIONAL."^^xsd:string .
- lexid-s:hasCreator, yaitu siapa yang membuat peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasCreator lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia .

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU.

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
LEMBARAN NEGARA
REPUBLIK INDONESIA
No.12, 2019 KESRA. Badan Perlindungan. Konsumen Nasional.
(Penjelasan dalam Tambahan Lembaran Negara
Republik Indonesia Nomor 6306)

PERATURAN PEMERINTAH REPUBLIK INDONESIA
NOMOR 4 TAHUN 2019
TENTANG
BADAN PERLINDUNGAN KONSUMEN NASIONAL

DENGAN RAHMAT TUHAN YANG MAHA ESA

PRESIDEN REPUBLIK INDONESIA,


Menimbang : a. bahwa untuk mendukung pelaksanaan tugas dan
wewenang Badan Perlindungan Konsumen Nasional,
perlu mengatur kembali Peraturan Pemerintah Nomor
57 Tahun 2001 tentang Badan Perlindungan Konsumen
Nasional;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Pemerintah tentang Badan Perlindungan Konsumen
Nasional;

Mengingat : 1. Pasal 5 ayat (2) Undang-Undang Dasar Negara Republik
Indonesia Tahun 1945;
  2. Undang-Undang Nomor 8 Tahun 1999 tentang
Perlindungan Konsumen (Lembaran Negara Republik
Indonesia Tahun 1999 Nomor 22, Tambahan Lembaran
Negara Republik Indonesia Nomor 3821);

MEMUTUSKAN:

Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN
PERLINDUNGAN KONSUMEN NASIONAL.


www.peraturan.go.id
2019, No.12 -2-
BAB I
KETENTUAN UMUM
```
###output:
lexid:PP_2019_4 lexid-s:regulationNumber "4"^^xsd:string .
lexid:PP_2019_4 lexid-s:regulationYear "2019"^^xsd:int .
lexid:PP_2019_4 rdfs:label "Peraturan Pemerintah Republik Indonesia Nomor 4 Tahun 2019"^^xsd:string .
lexid:PP_2019_4 lexid-s:name "BADAN PERLINDUNGAN KONSUMEN NASIONAL"^^xsd:string .
lexid:PP_2019_4 rdf:type lexid-s:LegalDocument .
lexid:PP_2019_4 lexid-s:hasCreator lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia .
lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia rdfs:label "Badan Perlindungan Konsumen Nasional Dengan Rahmat Tuhan Yang Maha Esa Presiden Republik Indonesia"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:UUD_1945 rdf:type lexid-s:LegalDocument .
lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .
lexid:PP_2019_4 lexid-s:considers "bahwa untuk mendukung pelaksanaan tugas dan wewenang Badan Perlindungan Konsumen Nasional, perlu mengatur kembali Peraturan Pemerintah Nomor 57 Tahun 2001 tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
lexid:PP_2019_4 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Pemerintah tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:hasDictum "Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN PERLINDUNGAN KONSUMEN NASIONAL."^^xsd:string .


###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
""".strip()

# %%
# teks = '\n'.join([line for line in permen_closing.splitlines() if line.strip() != ''])
test = prompt_1_shot_2.format(regulatory='Permen_2019_18', text=permen_opening)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])

# %%
prompt_1_shot_opening_2 = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17
- lexid-s:Position, contoh: lexid:Position_Menteri_Agama_Republik_Indonesia

Relation paling penting adalah:
- lexid-s:considers, yaitu apa pertimbangan dari peraturan tersebut (ada di Menimbang), contoh: lexid:PP_2019_4 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Pemerintah tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
- lexid-s:hasDictum, yaitu pernyataan tentang peraturan (ada di Menetapkan), contoh: lexid:PP_2019_4 lexid-s:hasDictum "Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN PERLINDUNGAN KONSUMEN NASIONAL."^^xsd:string .
- lexid-s:regulationNumber, yaitu nomor dari peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:regulationNumber "12"^^xsd:string .
- lexid-s:regulationYear, yaitu tahun dari peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:regulationNumber "2019"^^xsd:string .
- lexid-s:hasCreator, yaitu siapa yang membuat peraturan tersebut, contoh: lexid:PP_2019_4 lexid-s:hasCreator lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia .

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU. 

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
LEMBARAN NEGARA
REPUBLIK INDONESIA
No.12, 2019 KESRA. Badan Perlindungan. Konsumen Nasional.
(Penjelasan dalam Tambahan Lembaran Negara
Republik Indonesia Nomor 6306)
PERATURAN PEMERINTAH REPUBLIK INDONESIA
NOMOR 4 TAHUN 2019
TENTANG
BADAN PERLINDUNGAN KONSUMEN NASIONAL
DENGAN RAHMAT TUHAN YANG MAHA ESA
PRESIDEN REPUBLIK INDONESIA,
Menimbang : a. bahwa untuk mendukung pelaksanaan tugas dan
wewenang Badan Perlindungan Konsumen Nasional,
perlu mengatur kembali Peraturan Pemerintah Nomor
57 Tahun 2001 tentang Badan Perlindungan Konsumen
Nasional;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Pemerintah tentang Badan Perlindungan Konsumen
Nasional;
MEMUTUSKAN:
Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN
PERLINDUNGAN KONSUMEN NASIONAL.
www.peraturan.go.id
2019, No.12 -2-
BAB I
KETENTUAN UMUM
```
###output:
lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia rdfs:label "Badan Perlindungan Konsumen Nasional Dengan Rahmat Tuhan Yang Maha Esa Presiden Republik Indonesia"^^xsd:string .
lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia rdf:type lexid-s:Position .
lexid:PP_2019_4 lexid-s:considers "bahwa untuk mendukung pelaksanaan tugas dan wewenang Badan Perlindungan Konsumen Nasional, perlu mengatur kembali Peraturan Pemerintah Nomor 57 Tahun 2001 tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
lexid:PP_2019_4 lexid-s:considers "bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Pemerintah tentang Badan Perlindungan Konsumen Nasional"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasDictum "Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN PERLINDUNGAN KONSUMEN NASIONAL."^^xsd:string .
lexid:PP_2019_4 lexid-s:regulationNumber "4"^^xsd:string .
lexid:PP_2019_4 lexid-s:regulationYear "2019"^^xsd:int .
lexid:PP_2019_4 rdfs:label "Peraturan Pemerintah Republik Indonesia Nomor 4 Tahun 2019"^^xsd:string .
lexid:PP_2019_4 lexid-s:name "BADAN PERLINDUNGAN KONSUMEN NASIONAL"^^xsd:string .
lexid:PP_2019_4 rdf:type lexid-s:LegalDocument .
lexid:PP_2019_4 lexid-s:hasCreator lexid:Position_Badan_Perlindungan_Konsumen_Nasional_Dengan_Rahmat_Tuhan_Yang_Maha_Esa_Presiden_Republik_Indonesia .

PASTIKAN OUTPUT DALAM BENTUK TRIPLE. DAN KELUARKAN HANYA BAGIAN ###output.

###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
""".strip()

# %%
prompt_1_shot_opening_2_1_2 = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17

Relation paling penting adalah:
- lexid-s:hasLegalBasis, yaitu peraturan apa yang menjadi dasar dari peraturan tersebut (ada di Mengingat), contoh: lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
- lexid-s:LegalBasisOf, yaitu invers dari lexid-s:hasLegalBasis, contoh: lexid:UU_1999_8 lexid-s:LegalBasisOf contoh: lexid:PP_2019_4 .

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU.

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
Mengingat : 1. Pasal 5 ayat (2) Undang-Undang Dasar Negara Republik
Indonesia Tahun 1945;
  2. Undang-Undang Nomor 8 Tahun 1999 tentang
Perlindungan Konsumen (Lembaran Negara Republik
Indonesia Tahun 1999 Nomor 22, Tambahan Lembaran
Negara Republik Indonesia Nomor 3821);
```
###output:
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:UUD_1945 rdf:type lexid-s:LegalDocument .
lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .

PASTIKAN OUTPUT HANYA DALAM BENTUK TRIPLE. DAN KELUARKAN HANYA BAGIAN ###output.

###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
""".strip()

# %%
prompt_1_shot_opening_2_1 = """
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity

Tipe entity paling penting adalah:
- lexid-s:LegalDocument, contoh: lexid:Permen_Agama_2019_17

Relation paling penting adalah:
- lexid-s:hasLegalBasis, yaitu peraturan apa yang menjadi dasar dari peraturan tersebut (ada di Mengingat), contoh: lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
- lexid-s:LegalBasisOf, yaitu kebalikan dari lexid-s:hasLegalBasis, contoh: lexid:UU_1999_8 lexid-s:LegalBasisOf contoh: lexid:PP_2019_4 .
- rdfs:label, yaitu keterangan dari sebuah entity, contoh: lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .
- rdf:type, yaitu tipe dari sebuah entity, contoh lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .

JANGAN UBAH APAPUN YANG ADA PADA TEKS. GUNAKAN BAHASA INDONESIA SEPERTI YANG ADA PADA TEKS.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU.

Contoh:
###regulatory: lexid:PP_2019_4
###prompt: 
```
Mengingat : 1. Pasal 5 ayat (2) Undang-Undang Dasar Negara Republik
Indonesia Tahun 1945;
  2. Undang-Undang Nomor 8 Tahun 1999 tentang
Perlindungan Konsumen (Lembaran Negara Republik
Indonesia Tahun 1999 Nomor 22, Tambahan Lembaran
Negara Republik Indonesia Nomor 3821);
```
###output:
lexid:PP_2019_4 rdf:type lexid-s:LegalDocument .
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
lexid:UUD_1945 rdf:type lexid-s:LegalDocument .
lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .
lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .

PASTIKAN OUTPUT DALAM BENTUK TRIPLE. DAN KELUARKAN HANYA BAGIAN ###output.

###regulatory: lexid:{regulatory}
###Teks: 
```
{text}
```
###output:
""".strip()

# %%
import time

start = time.time()

teks = '\n'.join([line for line in dataset_opening[0]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1_2.format(regulatory=dataset_opening[0]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

end = time.time()
print()
print(end-start)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# You are not running the flash-attention implementation, expect numerical differences.
#  lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2005_14
# lexid:UU_2005_14 lexid-s:LegalBasisOf lexid:Permen_Ristekdikti_2017_20.
# lexid:UU_2005_14 rdf:type lexid-s:LegalDocument.
# lexid:UU_2005_14 rdfs:label "Undang-Undang Nomor 14 Tahun 2005 tentang Guru dan Dosen"^^xsd:string.
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2012_12
# lexid:UU_2012_12 lexid-s:LegalBasisOf lexid:Permen_Ristekdikti_2017_20.
# lexid:UU_2012_12 rdf:type lexid-s:LegalDocument.
# ...

# %%
import time

start = time.time()

teks = '\n'.join([line for line in dataset_opening[783]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1_2.format(regulatory=dataset_opening[783]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

end = time.time()
print()
print(end-start)
# Out:
#  lexid:Permen_Bappenas_2017_7 lexid-s:hasLegalBasis lexid:UU_2015_7.
# lexid:UU_2015_7 lexid-s:LegalBasisOf lexid:Permen_Bappenas_2017_7.
# lexid:UU_2015_7 rdf:type lexid-s:LegalDocument.
# lexid:UU_2015_7 rdfs:label "Peraturan Presiden Nomor 7 Tahun 2015 tentang Organisasi Kementerian Negara"^^xsd:string.
# lexid:Permen_Bappenas_2017_7 lexid-s:hasLegalBasis lexid:UU_2015_7.
# lexid:UU_2015_7 rdfs:label "Undang-Undang Republik Indonesia Nomor 7 Tahun 2015"^^xsd:string.
# lexid:Permen_Bappenas_2017_7 rdf:type lexid-s:LegalDocument.
# lexid:Permen_Bappenas_2017_7 rdfs:label "Permen Presiden Nomor 7 Tahun 2015 tentang Organisasi Kementerian Negara"^^xsd:string.
# lexid:UU_2015_65 lexid-s:hasLegalBasis lexid:Permen_Bappenas_2017_7.
# lexid:UU_2015_65 lexid-s:LegalBasisOf lexid:Permen_Bappenas_2017_7.
# lexid:UU_2015_65 rdf:type lexid-s:LegalDocument.
# lexid:UU_2015_65 rdfs:label "Peraturan Presiden Nomor 65 Tahun 2015 tentang Kementerian Perencanaan Pembangunan Nasional"^^xsd:string.
# ...

# %%
import time

start = time.time()

teks = '\n'.join([line for line in dataset_opening[783]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[783]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

end = time.time()
print()
print(end-start)
# Out:
# Setting `pad_token_id` to `eos_token_id`:100257 for open-end generation.
# lexid:Permen_Bappenas_2017_7 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Bappenas_2017_7 lexid-s:hasLegalBasis lexid:Perpres_2015_7 .
# lexid:Permen_Bappenas_2017_7 lexid-s:hasLegalBasis lexid:Perpres_2015_65 .
# lexid:Permen_Bappenas_2017_7 lexid-s:hasLegalBasis lexid:Perpres_2015_66 .
# lexid:Permen_Bappenas_2017_7 lexid-s:hasLegalBasis lexid:Perpres_2016_91 .
# lexid:Permen_Bappenas_2017_7 lexid-s:hasLegalBasis lexid:Keputusan_Menteri_2016_4 .
# lexid:Perpres_2015_7 rdf:type lexid-s:LegalDocument .
# lexid:Perpres_2015_7 rdfs:label "Peraturan Presiden Nomor 7 Tahun 2015 tentang Organisasi Kementerian Negara"^^xsd:string .
# lexid:Perpres_2015_65 rdf:type lexid-s:LegalDocument .
# lexid:Perpres_2015_65 rdfs:label "Peraturan Presiden Nomor 65 Tahun 2015 tentang Kementerian Perencanaan Pembangunan Nasional"^^xsd:string .
# lexid:Perpres_2015_66 rdf:type lexid-s:LegalDocument .
# ...

# %%
import time

start = time.time()

teks = '\n'.join([line for line in dataset_opening[783]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[783]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

end = time.time()
print()
print(end-start)
# Out:
#  lexid:Permen_Bappenas_2017_7 rdf:type lexid-s:LegalDocument.
# lexid:Permen_Bappenas_2017_7 lexid-s:hasLegalBasis lexid:UU_2015_7.
# lexid:UU_2015_7 rdf:type lexid-s:LegalDocument.
# lexid:UU_2015_7 rdfs:label "Peraturan Presiden Nomor 7 Tahun 2015 tentang Organisasi Kementerian Negara"^^xsd:string.
# lexid:Permen_Bappenas_2017_7 lexid-s:hasLegalBasis lexid:UU_2015_65.
# lexid:UU_2015_65 rdf:type lexid-s:LegalDocument.
# lexid:UU_2015_65 rdfs:label "Peraturan Presiden Nomor 65 Tahun 2015 tentang Kementerian Perencanaan Pembangunan Nasional"^^xsd:string.
# lexid:Permen_Bappenas_2017_7 lexid-s:hasLegalBasis lexid:UU_2015_66.
# lexid:UU_2015_66 rdf:type lexid-s:LegalDocument.
# lexid:UU_2015_66 rdfs:label "Peraturan Presiden Nomor 66 Tahun 2015 tentang Badan Perencanaan Pembangunan Nasional"^^xsd:string.
# lexid:Permen_Bappenas_2017_7 lexid-s:hasLegalBasis lexid:UU_2016_20.
# lexid:UU_2016_20 rdf:type lexid-s:LegalDocument.
# ...

# %%
# # lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
# # lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# # lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
# # lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
# # lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
# # lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# # lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .
# # lexid:UUD_1945 rdf:type lexid-s:LegalDocument .

# import time

# start = time.time()

# teks = '\n'.join([line for line in dataset_opening[0]['text_1'].splitlines() if line.strip() != ''])
# test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[0]['regulatory'], text=teks)

# messages = [
#     {"role": "user", "content": test},
# ]

# output = pipe_f7(messages, **generation_args)
# print(output[0]['generated_text'])
# print()
# print(teks)

# end = time.time()
# print()
# print(end-start)
# Out:
# Setting `pad_token_id` to `eos_token_id`:100257 for open-end generation.
# lexid:Permen_Ristekdikti_2017_20 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2005_14 .
# lexid:UU_2005_14 lexid-s:LegalBasisOf lexid:Permen_Ristekdikti_2017_20 .
# lexid:UU_2005_14 rdfs:label "Undang-Undang Republik Indonesia Nomor 14 Tahun 2005"^^xsd:string .
# lexid:UU_2005_14 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2012_12 .
# lexid:UU_2012_12 lexid-s:LegalBasisOf lexid:Permen_Ristekdikti_2017_20 .
# lexid:UU_2012_12 rdfs:label "Undang-Undang Republik Indonesia Nomor 12 Tahun 2012"^^xsd:string .
# lexid:UU_2012_12 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:Perpres_2015_13 .
# lexid:Perpres_2015_13 lexid-s:LegalBasisOf lexid:Permen_Ristekdikti_2017_20 .
# lexid:Perpres_2015_13 rdfs:label "Peraturan Presiden Nomor 13 Tahun 2015"^^xsd:string .
# ...

# %%
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
# lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
# lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
# lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .
# lexid:UUD_1945 rdf:type lexid-s:LegalDocument .

import time

start = time.time()

teks = '\n'.join([line for line in dataset_opening[862]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[862]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

end = time.time()
print()
print(end-start)
# Out:
# Setting `pad_token_id` to `eos_token_id`:100257 for open-end generation.
# lexid:UU_1957_17 rdf:type lexid-s:LegalDocument .
# lexid:UU_1957_17 lexid-s:hasLegalBasis lexid:UU_1957_16 .
# lexid:UU_1957_16 lexid-s:LegalBasisOf lexid:UU_1957_17 .
# lexid:UU_1957_16 rdfs:label "Undang-Undang Dasar Sementara Republik Indonesia Tahun 1957"^^xsd:string .
# lexid:UU_1957_16 rdf:type lexid-s:LegalDocument .
#
# Mengingat : Pasal 113 dan Pasal 114 Undang-undang Dasar Sementara Republik
# Indonesia;
# Dengan persetujuan Dewan Perwakilan Rakyat;
#
# 7.737774133682251

# %%
# lexid:PP_2019_4 rdf:type lexid-s:LegalDocument .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
# lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
# lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
# lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .
# lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UUD_1945 rdf:type lexid-s:LegalDocument .

import time

start = time.time()

teks = '\n'.join([line for line in dataset_opening[0]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[0]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

end = time.time()
print()
print(end-start)
# Out:
# Setting `pad_token_id` to `eos_token_id`:100257 for open-end generation.
# lexid:Permen_Ristekdikti_2017_20 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2005_14 .
# lexid:UU_2005_14 rdfs:label "Undang-Undang Republik Indonesia Nomor 14 Tahun 2005 tentang Guru dan Dosen"^^xsd:string .
# lexid:UU_2005_14 lexid-s:LegalBasisOf lexid:Permen_Ristekdikti_2017_20 .
# lexid:UU_2005_14 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2012_12 .
# lexid:UU_2012_12 rdfs:label "Undang-Undang Republik Indonesia Nomor 12 Tahun 2012 tentang Pendidikan Tinggi"^^xsd:string .
# lexid:UU_2012_12 lexid-s:LegalBasisOf lexid:Permen_Ristekdikti_2017_20 .
# lexid:UU_2012_12 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:Perpres_2015_13 .
# ...

# %%
# lexid:PP_2019_4 rdf:type lexid-s:LegalDocument .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
# lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
# lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
# lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .
# lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UUD_1945 rdf:type lexid-s:LegalDocument .

import time

start = time.time()

teks = '\n'.join([line for line in dataset_opening[0]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[0]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

end = time.time()
print()
print(end-start)
# Out:
# Setting `pad_token_id` to `eos_token_id`:100257 for open-end generation.
# lexid:Permen_Ristekdikti_2017_20 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2005_14 .
# lexid:UU_2005_14 lexid-s:LegalBasisOf lexid:Permen_Ristekdikti_2017_20 .
# lexid:UU_2005_14 rdfs:label "Undang-Undang Republik Indonesia Nomor 14 Tahun 2005"^^xsd:string .
# lexid:UU_2005_14 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2012_12 .
# lexid:UU_2012_12 lexid-s:LegalBasisOf lexid:Permen_Ristekdikti_2017_20 .
# lexid:UU_2012_12 rdfs:label "Undang-Undang Republik Indonesia Nomor 12 Tahun 2012"^^xsd:string .
# lexid:UU_2012_12 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:Perpres_2015_13 .
# lexid:Perpres_2015_13 lexid-s:LegalBasisOf lexid:Permen_Ristekdikti_2017_20 .
# lexid:Perpres_2015_13 rdfs:label "Peraturan Presiden Nomor 13 Tahun 2015"^^xsd:string .
# ...

# %%
# lexid:PP_2019_4 rdf:type lexid-s:LegalDocument .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
# lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
# lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
# lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .
# lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UUD_1945 rdf:type lexid-s:LegalDocument .

import time

start = time.time()

teks = '\n'.join([line for line in dataset_opening[101]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[101]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

end = time.time()
print()
print(end-start)
# Out:
# Setting `pad_token_id` to `eos_token_id`:100257 for open-end generation.
# lexid:Permen_LHK_2019_21 rdf:type lexid-s:LegalDocument .
# lexid:Permen_LHK_2019_21 lexid-s:hasLegalBasis lexid:UU_1960_5 .
# lexid:UU_1960_5 rdfs:label "Undang-Undang Nomor 5 Tahun 1960 tentang Peraturan Dasar Pokok-Pokok Agraria"^^xsd:string .
# lexid:Permen_LHK_2019_21 lexid-s:hasLegalBasis lexid:UU_1990_5 .
# lexid:UU_1990_5 rdfs:label "Undang-Undang Nomor 5 Tahun 1990 tentang Konservasi Sumber Daya Alam Hayati dan Ekosistemnya"^^xsd:string .
# lexid:Permen_LHK_2019_21 lexid-s:hasLegalBasis lexid:UU_1999_41 .
# lexid:UU_1999_41 rdfs:label "Undang-Undang Nomor 41 Tahun 1999 tentang Kehutanan"^^xsd:string .
# lexid:UU_1999_41 lexid-s:hasLegalBasis lexid:UU_2004_19 .
# lexid:UU_2004_19 rdfs:label "Undang-Undang Nomor 19 Tahun 2004 tentang Penetapan Peraturan Pemerintah Pengganti Undang-Undang Nomor 1 Tahun 2004 tentang Perubahan atas Undang-Undang Nomor 41 Tahun 1999 tentang Kehutanan"^^xsd:string .
# ...

# %%
# lexid:PP_2019_4 rdf:type lexid-s:LegalDocument .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
# lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
# lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .
# lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
# lexid:UUD_1945 rdf:type lexid-s:LegalDocument .

import time

start = time.time()

teks = '\n'.join([line for line in dataset_opening[0]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[0]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

end = time.time()
print()
print(end-start)
# Out:
# Setting `pad_token_id` to `eos_token_id`:100257 for open-end generation.
# lexid:Permen_Ristekdikti_2017_20 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2005_14 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2012_12 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2009_37 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2009_41 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2015_13 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2010_164 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2015_15 .
# lexid:UU_2005_14 rdf:type lexid-s:LegalDocument .
# lexid:UU_2012_12 rdf:type lexid-s:LegalDocument .
# lexid:PP_2009_37 rdf:type lexid-s:LegalDocument .
# lexid:PP_2009_41 rdf:type lexid-s:LegalDocument .
# lexid:PP_2015_13 rdf:type lexid-s:LegalDocument .
# lexid:PP_2010_164 rdf:type lexid-s:LegalDocument .
# ...

# %%
# lexid:PP_2019_4 rdf:type lexid-s:LegalDocument .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
# lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
# lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .
# lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
# lexid:UUD_1945 rdf:type lexid-s:LegalDocument .

import time

start = time.time()

teks = '\n'.join([line for line in dataset_opening[0]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[0]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

end = time.time()
print()
print(end-start)
# Out:
# Setting `pad_token_id` to `eos_token_id`:100257 for open-end generation.
# lexid:Permen_Ristekdikti_2017_20 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2005_14 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2012_12 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2009_37 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2009_41 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2015_13 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2010_164 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2015_15 .
# lexid:UU_2005_14 rdfs:label "Undang-Undang Nomor 14 Tahun 2005 tentang Guru dan Dosen"^^xsd:string .
# lexid:UU_2012_12 rdfs:label "Undang-Undang Nomor 12 Tahun 2012 tentang Pendidikan Tinggi"^^xsd:string .
# lexid:PP_2009_37 rdfs:label "Peraturan Pemerintah Nomor 37 Tahun 2009 tentang Dosen"^^xsd:string .
# ...

# %%
# lexid:PP_2019_4 rdf:type lexid-s:LegalDocument .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
# lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
# lexid:UUD_1945 rdf:type lexid-s:LegalDocument .
# lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
# lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .

import time

start = time.time()

teks = '\n'.join([line for line in dataset_opening[0]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[0]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

end = time.time()
print()
print(end-start)
# Out:
# Setting `pad_token_id` to `eos_token_id`:100257 for open-end generation.
# lexid:Permen_Ristekdikti_2017_20 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2005_14 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2012_12 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2009_37 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2009_41 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2015_13 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2010_164 .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:PP_2015_15 .
# lexid:UU_2005_14 rdf:type lexid-s:LegalDocument .
# lexid:UU_2012_12 rdf:type lexid-s:LegalDocument .
# lexid:PP_2009_37 rdf:type lexid-s:LegalDocument .
# lexid:PP_2009_41 rdf:type lexid-s:LegalDocument .
# lexid:PP_2015_13 rdf:type lexid-s:LegalDocument .
# lexid:PP_2010_164 rdf:type lexid-s:LegalDocument .
# ...

# %%
# lexid:PP_2019_4 rdf:type lexid-s:LegalDocument .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
# lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
# lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
# lexid:UUD_1945 rdf:type lexid-s:LegalDocument .
# lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .

import time

start = time.time()

teks = '\n'.join([line for line in dataset_opening[0]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[0]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

end = time.time()
print()
print(end-start)
# Out:
# Setting `pad_token_id` to `eos_token_id`:100257 for open-end generation.
# lexid:Permen_Ristekdikti_2017_20 rdf:type lexid-s:LegalDocument .
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2005_14 .
# lexid:UU_2005_14 rdf:type lexid-s:LegalDocument .
# lexid:UU_2005_14 lexid-s:LegalBasisOf lexid:Permen_Ristekdikti_2017_20 .
# lexid:UU_2005_14 rdfs:label "Undang-Undang Republik Indonesia Nomor 14 Tahun 2005"^^xsd:string .
# lexid:UU_2012_12 rdf:type lexid-s:LegalDocument .
# lexid:UU_2012_12 lexid-s:hasLegalBasis lexid:Permen_Ristekdikti_2017_20 .
# lexid:UU_2012_12 rdfs:label "Undang-Undang Republik Indonesia Nomor 12 Tahun 2012"^^xsd:string .
# lexid:Permen_PK_2009_37 rdf:type lexid-s:LegalDocument .
# lexid:Permen_PK_2009_37 lexid-s:hasLegalBasis lexid:Permen_Ristekdikti_2017_20 .
# lexid:Permen_PK_2009_37 rdfs:label "Peraturan Pemerintah Nomor 37 Tahun 2009"^^xsd:string .
# lexid:Permen_PK_2009_41 rdf:type lexid-s:LegalDocument .
# ...

# %%
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_1999_8 .
# lexid:UU_1999_8 rdfs:label "Undang-Undang Republik Indonesia Nomor 8 Tahun 1999"^^xsd:string .
# lexid:UU_1999_8 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UUD_1945 .
# lexid:UUD_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .
# lexid:UUD_1945 lexid-s:LegalBasisOf lexid:PP_2019_4 .
# lexid:UU_1999_8 rdf:type lexid-s:LegalDocument .
# lexid:UUD_1945 rdf:type lexid-s:LegalDocument .

import time

start = time.time()

teks = '\n'.join([line for line in dataset_opening[0]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[0]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

end = time.time()
print()
print(end-start)
# Out:
# Setting `pad_token_id` to `eos_token_id`:100257 for open-end generation.
# lexid:Permen_Ristekdikti_2017_20 lexid-s:hasLegalBasis lexid:UU_2005_14 .
# lexid:UU_2005_14 rdfs:label "Undang-Undang Republik Indonesia Nomor 14 Tahun 2005 tentang Guru dan Dosen"^^xsd:string .
# lexid:UU_2005_14 lexid-s:LegalBasisOf lexid:Permen_Ristekdikti_2017_20 .
# lexid:Permen_Ristekdikti_2017_20 rdf:type lexid-s:LegalDocument .
# lexid:UU_2012_12 lexid-s:hasLegalBasis lexid:Permen_Ristekdikti_2017_20 .
# lexid:UU_2012_12 rdfs:label "Undang-Undang Republik Indonesia Nomor 12 Tahun 2012 tentang Pendidikan Tinggi"^^xsd:string .
# lexid:UU_2012_12 lexid-s:LegalBasisOf lexid:Permen_Ristekdikti_2017_20 .
# lexid:Permen_PK_2009_37 lexid-s:hasLegalBasis lexid:Permen_Ristekdikti_2017_20 .
# lexid:Permen_PK_2009_37 rdfs:label "Peraturan Pemerintah Nomor 37 Tahun 2009 tentang Dosen"^^xsd:string .
# lexid:Permen_PK_2009_37 lexid-s:LegalBasisOf lexid:Permen_Ristekdikti_2017_20 .
# ...

# %%
teks = '\n'.join([line for line in dataset_opening[0]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[0]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)
# Out:
# Setting `pad_token_id` to `eos_token_id`:100257 for open-end generation.
# lexid:PP_1954_61 lexid-s:hasLegalBasis lexid:UU_1999_41/lexid:UU_1999_41 rdf:type lexid-s:LegalDocument .
# lexid:PP_1954_61 lexid-s:hasLegalBasis lexid:UU_1999_41/lexid:UU_2004_19 .
# lexid:UU_1999_41 lexid-s:LegalBasisOf lexid:PP_1954_61 .
# lexid:UU_1999_41/lexid:UU_1999_41 rdf:type lexid-s:LegalDocument .
# lexid:UU_1999_41/lexid:UU_1999_41 rdfs:label "Undang-Undang Republik Indonesia Nomor 41 Tahun 1999 tentang Kehutanan"^^xsd:string .
# lexid:UU_2004_19 lexid-s:hasLegalBasis lexid:UU_1999_41/lexid:UU_1999_41 rdf:type lexid-s:LegalDocument .
# lexid:UU_2004_19/lexid:UU_2004_19 rdfs:label "Undang-Undang Republik Indonesia Nomor 19 Tahun 2004 tentang Perubahan atas Undang-Undang Nomor 41 Tahun 1999 tentang Kehutanan"^^xsd:string .
# lexid:UU_2007_6 lexid-s:hasLegalBasis lexid:PP_1954_61/lexid:PP_1954_61/lexid:UU_2007_6 rdf:type lexid-s:LegalDocument .
# ...

# %%
teks = '\n'.join([line for line in dataset_opening[981]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[981]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)
# Out:
# Setting `pad_token_id` to `eos_token_id`:100257 for open-end generation.
# lexid:PP_1954_61 lexid-s:hasLegalBasis lexid:UU_1945 .
# lexid:UU_1945 lexid-s:LegalBasisOf lexid:PP_1954_61 .
# lexid:UU_1945 rdf:type lexid-s:LegalDocument .
# lexid:UU_1945 rdfs:label "Undang-Undang Dasar Negara Republik Indonesia  Tahun 1945"^^xsd:string .
# lexid:Staatsblad_1847_23 lexid-s:hasLegalBasis lexid:UU_1945 .
# lexid:UU_1945 lexid-s:LegalBasisOf lexid:Staatsblad_1847_23 .
# lexid:Staatsblad_1847_23 rdf:type lexid-s:LegalDocument .
# lexid:Staatsblad_1847_23 rdfs:label "Staatsblad Tahun 1847 Nomor 23"^^xsd:string .
# lexid:UU_1969_9 lexid-s:hasLegalBasis lexid:UU_1945 .
# lexid:UU_1945 lexid-s:LegalBasisOf lexid:UU_1969_9 .
# lexid:UU_1969_9 rdf:type lexid-s:LegalDocument .
# lexid:UU_1969_9 rdfs:label "Undang-undang Nomor 9 Tahun 1969"^^xsd:string .
# lexid:UU_1969_40 lexid-s:hasLegalBasis lexid:UU_1945 .
# lexid:UU_1945 lexid-s:LegalBasisOf lexid:UU_1969_40 .
# ...

# %%
teks = '\n'.join([line for line in dataset_opening[981]['text_2'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2.format(regulatory=dataset_opening[981]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:100257 for open-end generation.
# /root/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-small-8k-instruct/1adb635233ffce9e13385862a4111606d4382762/triton_flash_blocksparse_attn.py:88: UserWarning: Sparse CSR tensor support is in beta state. If you miss a functionality in the sparse tensor support, please submit a feature request to https://github.com/pytorch/pytorch/issues. (Triggered internally at /opt/pytorch/pytorch/aten/src/ATen/SparseCsrTensorImpl.cpp:53.)
#   x = [xi.to_sparse_csr() for xi in x]
# lexid:Position_President_República_Indonesia rdfs:label "PRESIDEN REPUBLIK INDONESIA"^^xsd:string .
# ...

# %%
teks = '\n'.join([line for line in dataset_opening[20186]['text_2'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2.format(regulatory=dataset_opening[20186]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

# %%
teks = '\n'.join([line for line in dataset_opening[20186]['text_1'].splitlines() if line.strip() != ''])
test = prompt_1_shot_opening_2_1.format(regulatory=dataset_opening[20186]['regulatory'], text=teks)

messages = [
    {"role": "user", "content": test},
]

output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

# %% [markdown]
# ## Opening Code

# %%
prompt = '''
You are a helpful assistant. Lanjutkan extraction dari code yang diberikan

from typing import List
class Rel:
    def __init__(self, name: str):
        self.name = name
class hasLegalBasis(Rel):
    # Apa yang mendasari peraturan (mengingat)
    def __init__(self, name: str):
        super.__init__(name=name)

class Entity:
    def __init__(self, name: str):
        self.name = name
class LegalDocument(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)

class Triple:
    def __init__(self, relation: Rel, tail: Entity):
        self.relation = relation
        self.tail = tail
class Extract:
    def __init__(self, triples: List[Triple] = []):
        self.triples = triples
"""
LEMBARAN NEGARA
REPUBLIK INDONESIA
No.12, 2019 KESRA. Badan Perlindungan. Konsumen Nasional.
(Penjelasan dalam Tambahan Lembaran Negara
Republik Indonesia Nomor 6306)

PERATURAN PEMERINTAH REPUBLIK INDONESIA
NOMOR 4 TAHUN 2019
TENTANG
BADAN PERLINDUNGAN KONSUMEN NASIONAL

DENGAN RAHMAT TUHAN YANG MAHA ESA

PRESIDEN REPUBLIK INDONESIA,


Menimbang : a. bahwa untuk mendukung pelaksanaan tugas dan
wewenang Badan Perlindungan Konsumen Nasional,
perlu mengatur kembali Peraturan Pemerintah Nomor
57 Tahun 2001 tentang Badan Perlindungan Konsumen
Nasional;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Pemerintah tentang Badan Perlindungan Konsumen
Nasional;

Mengingat : 1. Pasal 5 ayat (2) Undang-Undang Dasar Negara Republik
Indonesia Tahun 1945;
  2. Undang-Undang Nomor 8 Tahun 1999 tentang
Perlindungan Konsumen (Lembaran Negara Republik
Indonesia Tahun 1999 Nomor 22, Tambahan Lembaran
Negara Republik Indonesia Nomor 3821);

MEMUTUSKAN:

Menetapkan : PERATURAN PEMERINTAH TENTANG BADAN
PERLINDUNGAN KONSUMEN NASIONAL.


www.peraturan.go.id
2019, No.12 -2-
BAB I
KETENTUAN UMUM"""
extract = Extract([Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Dasar Negara Republik Indonesia Tahun 1945')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 8 Tahun 1999')),])
"""
BERITA NEGARA
REPUBLIK INDONESIA
No.1047, 2019 KEMENAG. Bidang Agama dan Keagamaan.
Penelitian dan Pengembangan.


PERATURAN MENTERI AGAMA REPUBLIK INDONESIA
NOMOR 18 TAHUN 2019
TENTANG
PENELITIAN DAN PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN

DENGAN RAHMAT TUHAN YANG MAHA ESA

MENTERI AGAMA REPUBLIK INDONESIA,


Menimbang  : a. bahwa untuk meningkatkan kualitas dan pemanfaatan
hasil penelitian dan pengembangan di bidang agama dan
keagamaan pada Kementerian Agama, perlu mengatur
mengenai penelitian dan pengembangan di bidang agama
dan keagamaan;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Menteri Agama tentang Penelitian dan Pengembangan di
Bidang Agama dan Keagamaan;

Mengingat : 1. Undang-Undang Nomor 18 Tahun 2002 tentang Sistem
Nasional Penelitian, Pengembangan, dan Penerapan Ilmu
Pengetahuan dan Teknologi (Lembaran Negara Republik
Indonesia Tahun 2002 Nomor 84, Tambahan Lembaran
Negara Republik Indonesia Nomor 4219);
  2. Peraturan Presiden Nomor 7 Tahun 2015 tentang
Organisasi Kementerian Negara (Lembaran Negara
Republik Indonesia Tahun 2015 Nomor 8);


www.peraturan.go.id
2019, No.1047 -2-
3. Peraturan Presiden Nomor 83 Tahun 2015 tentang
Kementerian Agama (Lembaran Negara Republik
Indonesia Tahun 2015 Nomor 168);
  4. Peraturan Presiden Nomor 38 Tahun 2018 tentang
Rencana Induk Riset Nasional (Lembaran Negara
Republik Indonesia Tahun 2018 Nomor 64);
  5. Peraturan Menteri Agama Nomor 42 Tahun 2016 tentang
Organisasi dan Tata Kerja Kementerian Agama (Berita
Negara Republik Indonesia Tahun 2016 Nomor 1495);

MEMUTUSKAN:
Menetapkan  : PERATURAN MENTERI AGAMA TENTANG PENELITIAN DAN
PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN.

BAB I
KETENTUAN UMUM"""
extract = Extract([Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 18 Tahun 2002')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 7 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 83 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 38 Tahun 2018')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Menteri Agama Nomor 42 Tahun 2016')),])
'''

# %%
messages = [
#     {"role": "system", "content": "You are a helpful assistant. Lanjutkan extraction dari code yang diberikan"},
    {"role": "user", "content": f'''{prompt}
"""
{perwali_opening}
"""
'''},
]


output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])

# %%
prompt_2 = '''
You are a helpful assistant. Lanjutkan extraction dari code yang diberikan. 

from typing import List
class Rel:
    def __init__(self, name: str):
        self.name = name
class hasLegalBasis(Rel):
    # Apa yang mendasari peraturan (mengingat)
    def __init__(self, name: str):
        super.__init__(name=name)

class Entity:
    def __init__(self, name: str):
        self.name = name
class LegalDocument(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)

class Triple:
    def __init__(self, relation: Rel, tail: Entity):
        self.relation = relation
        self.tail = tail
class Extract:
    def __init__(self, triples: List[Triple] = []):
        self.triples = triples
                   
###Prompt
```
BERITA NEGARA
REPUBLIK INDONESIA
No.1047, 2019 KEMENAG. Bidang Agama dan Keagamaan.
Penelitian dan Pengembangan.


PERATURAN MENTERI AGAMA REPUBLIK INDONESIA
NOMOR 18 TAHUN 2019
TENTANG
PENELITIAN DAN PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN

DENGAN RAHMAT TUHAN YANG MAHA ESA

MENTERI AGAMA REPUBLIK INDONESIA,


Menimbang  : a. bahwa untuk meningkatkan kualitas dan pemanfaatan
hasil penelitian dan pengembangan di bidang agama dan
keagamaan pada Kementerian Agama, perlu mengatur
mengenai penelitian dan pengembangan di bidang agama
dan keagamaan;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Menteri Agama tentang Penelitian dan Pengembangan di
Bidang Agama dan Keagamaan;

Mengingat : 1. Undang-Undang Nomor 18 Tahun 2002 tentang Sistem
Nasional Penelitian, Pengembangan, dan Penerapan Ilmu
Pengetahuan dan Teknologi (Lembaran Negara Republik
Indonesia Tahun 2002 Nomor 84, Tambahan Lembaran
Negara Republik Indonesia Nomor 4219);
  2. Peraturan Presiden Nomor 7 Tahun 2015 tentang
Organisasi Kementerian Negara (Lembaran Negara
Republik Indonesia Tahun 2015 Nomor 8);


www.peraturan.go.id
2019, No.1047 -2-
3. Peraturan Presiden Nomor 83 Tahun 2015 tentang
Kementerian Agama (Lembaran Negara Republik
Indonesia Tahun 2015 Nomor 168);
  4. Peraturan Presiden Nomor 38 Tahun 2018 tentang
Rencana Induk Riset Nasional (Lembaran Negara
Republik Indonesia Tahun 2018 Nomor 64);
  5. Peraturan Menteri Agama Nomor 42 Tahun 2016 tentang
Organisasi dan Tata Kerja Kementerian Agama (Berita
Negara Republik Indonesia Tahun 2016 Nomor 1495);

MEMUTUSKAN:
Menetapkan  : PERATURAN MENTERI AGAMA TENTANG PENELITIAN DAN
PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN.

BAB I
KETENTUAN UMUM
```
###Output
extract = Extract([Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 18 Tahun 2002')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 7 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 83 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 38 Tahun 2018')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Menteri Agama Nomor 42 Tahun 2016')),])

IDENTIFIKASI SEBANYAK MUNGKIN TRIPLE. JANGAN MELAKUKAN EKSTRAKSI SELAIN RELATION YANG DITENTUKAN.

###Prompt
```
{prompt}
```
###Output
'''

# %%
test = prompt_2.format(prompt=perwali_opening)

messages = [
    {"role": "user", "content": test},
]


output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])

# %%
prompt_2_1 = '''
You are a helpful assistant. Lanjutkan extraction dari code yang diberikan. 

from typing import List
class Rel:
    def __init__(self, name: str):
        self.name = name
class hasLegalBasis(Rel):
    # Apa yang mendasari peraturan (mengingat)
    def __init__(self, name: str):
        super.__init__(name=name)
class considers(Rel):
    # Apa pertimbangan dari peraturan (menimbang)
    def __init__(self, name: str):
        super.__init__(name=name)
class hasDictum(Rel):
    # Pernyataan tentang peraturan (Menetapkan)
    def __init__(self, name: str):
        super.__init__(name=name)
class hasCreator(Rel):
    # Siapa yang membuat peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class regulationNumber(Rel):
    # Nomor dari peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class regulationYear(Rel):
    # Tahun dari peraturan
    def __init__(self, name: str):
        super.__init__(name=name) 

class Entity:
    def __init__(self, name: str):
        self.name = name
class LegalDocument(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class Position(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class Literal(Entity):
    def __init__(self, name: str, type: str):
        super.__init__(name=name)
        self.type = type

class Triple:
    def __init__(self, relation: Rel, tail: Entity):
        self.relation = relation
        self.tail = tail
class Extract:
    def __init__(self, triples: List[Triple] = []):
        self.triples = triples
                   
###Prompt
```
BERITA NEGARA
REPUBLIK INDONESIA
No.1047, 2019 KEMENAG. Bidang Agama dan Keagamaan.
Penelitian dan Pengembangan.


PERATURAN MENTERI AGAMA REPUBLIK INDONESIA
NOMOR 18 TAHUN 2019
TENTANG
PENELITIAN DAN PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN

DENGAN RAHMAT TUHAN YANG MAHA ESA

MENTERI AGAMA REPUBLIK INDONESIA,


Menimbang  : a. bahwa untuk meningkatkan kualitas dan pemanfaatan
hasil penelitian dan pengembangan di bidang agama dan
keagamaan pada Kementerian Agama, perlu mengatur
mengenai penelitian dan pengembangan di bidang agama
dan keagamaan;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Menteri Agama tentang Penelitian dan Pengembangan di
Bidang Agama dan Keagamaan;

Mengingat : 1. Undang-Undang Nomor 18 Tahun 2002 tentang Sistem
Nasional Penelitian, Pengembangan, dan Penerapan Ilmu
Pengetahuan dan Teknologi (Lembaran Negara Republik
Indonesia Tahun 2002 Nomor 84, Tambahan Lembaran
Negara Republik Indonesia Nomor 4219);
  2. Peraturan Presiden Nomor 7 Tahun 2015 tentang
Organisasi Kementerian Negara (Lembaran Negara
Republik Indonesia Tahun 2015 Nomor 8);


www.peraturan.go.id
2019, No.1047 -2-
3. Peraturan Presiden Nomor 83 Tahun 2015 tentang
Kementerian Agama (Lembaran Negara Republik
Indonesia Tahun 2015 Nomor 168);
  4. Peraturan Presiden Nomor 38 Tahun 2018 tentang
Rencana Induk Riset Nasional (Lembaran Negara
Republik Indonesia Tahun 2018 Nomor 64);
  5. Peraturan Menteri Agama Nomor 42 Tahun 2016 tentang
Organisasi dan Tata Kerja Kementerian Agama (Berita
Negara Republik Indonesia Tahun 2016 Nomor 1495);

MEMUTUSKAN:
Menetapkan  : PERATURAN MENTERI AGAMA TENTANG PENELITIAN DAN
PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN.

BAB I
KETENTUAN UMUM
```
###Output
extract = Extract([Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 18 Tahun 2002')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 7 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 83 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 38 Tahun 2018')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Menteri Agama Nomor 42 Tahun 2016')),
                   Triple(Rel('hasCreator'), Position('Menteri Agama Republik Indonesia')),
                   Triple(Rel('considers'), Literal('bahwa untuk meningkatkan kualitas dan pemanfaatan hasil penelitian dan pengembangan di bidang agama dan keagamaan pada Kementerian Agama, perlu mengatur mengenai penelitian dan pengembangan di bidang agama dan keagamaan', 'string')),
                   Triple(Rel('considers'), Literal('bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Menteri Agama tentang Penelitian dan Pengembangan di Bidang Agama dan Keagamaan', 'string')),
                   Triple(Rel('hasDictum'), Literal('Menetapkan : PERATURAN MENTERI AGAMA TENTANG PENELITIAN DAN PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN.', 'string')),
                   Triple(Rel('regulationNumber'), Literal('18', 'string')),
                   Triple(Rel('regulationYear'), Literal('2019', 'int')),])

IDENTIFIKASI SEBANYAK MUNGKIN TRIPLE. JANGAN MELAKUKAN EKSTRAKSI SELAIN RELATION YANG DITENTUKAN.

###Prompt
```
{prompt}
```
###Output
'''

# %%
test = prompt_2_1.format(prompt=perwali_opening)

messages = [
    {"role": "user", "content": test},
]


output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])

# %%
prompt_2_2 = '''
You are a helpful assistant. Lanjutkan extraction dari code yang diberikan. 

from typing import List
class Rel:
    def __init__(self, name: str):
        self.name = name
class considers(Rel):
    # Apa pertimbangan dari peraturan (menimbang)
    def __init__(self, name: str):
        super.__init__(name=name)
class hasDictum(Rel):
    # Pernyataan tentang peraturan (Memutuskan)
    def __init__(self, name: str):
        super.__init__(name=name)
class hasCreator(Rel):
    # Siapa yang membuat peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class regulationNumber(Rel):
    # Nomor dari peraturan
    def __init__(self, name: str):
        super.__init__(name=name)
class regulationYear(Rel):
    # Tahun dari peraturan
    def __init__(self, name: str):
        super.__init__(name=name) 

class Entity:
    def __init__(self, name: str):
        self.name = name
class Position(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)
class String(Entity):
    def __init__(self, name: str, type: str):
        super.__init__(name=name)
class Int(Entity):
    def __init__(self, name: str, type: str):
        super.__init__(name=name)

class Triple:
    def __init__(self, relation: Rel, tail: Entity):
        self.relation = relation
        self.tail = tail
class Extract:
    def __init__(self, triples: List[Triple] = []):
        self.triples = triples
                   
###Prompt
```
BERITA NEGARA
REPUBLIK INDONESIA
No.1047, 2019 KEMENAG. Bidang Agama dan Keagamaan.
Penelitian dan Pengembangan.


PERATURAN MENTERI AGAMA REPUBLIK INDONESIA
NOMOR 18 TAHUN 2019
TENTANG
PENELITIAN DAN PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN

DENGAN RAHMAT TUHAN YANG MAHA ESA

MENTERI AGAMA REPUBLIK INDONESIA,


Menimbang  : a. bahwa untuk meningkatkan kualitas dan pemanfaatan
hasil penelitian dan pengembangan di bidang agama dan
keagamaan pada Kementerian Agama, perlu mengatur
mengenai penelitian dan pengembangan di bidang agama
dan keagamaan;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Menteri Agama tentang Penelitian dan Pengembangan di
Bidang Agama dan Keagamaan;

Mengingat : 1. Undang-Undang Nomor 18 Tahun 2002 tentang Sistem
Nasional Penelitian, Pengembangan, dan Penerapan Ilmu
Pengetahuan dan Teknologi (Lembaran Negara Republik
Indonesia Tahun 2002 Nomor 84, Tambahan Lembaran
Negara Republik Indonesia Nomor 4219);
  2. Peraturan Presiden Nomor 7 Tahun 2015 tentang
Organisasi Kementerian Negara (Lembaran Negara
Republik Indonesia Tahun 2015 Nomor 8);


www.peraturan.go.id
2019, No.1047 -2-
3. Peraturan Presiden Nomor 83 Tahun 2015 tentang
Kementerian Agama (Lembaran Negara Republik
Indonesia Tahun 2015 Nomor 168);
  4. Peraturan Presiden Nomor 38 Tahun 2018 tentang
Rencana Induk Riset Nasional (Lembaran Negara
Republik Indonesia Tahun 2018 Nomor 64);
  5. Peraturan Menteri Agama Nomor 42 Tahun 2016 tentang
Organisasi dan Tata Kerja Kementerian Agama (Berita
Negara Republik Indonesia Tahun 2016 Nomor 1495);

MEMUTUSKAN:
Menetapkan  : PERATURAN MENTERI AGAMA TENTANG PENELITIAN DAN
PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN.

BAB I
KETENTUAN UMUM
```
###Output
extract = Extract([Triple(Rel('hasCreator'), Position('Menteri Agama Republik Indonesia')),
                   Triple(Rel('considers'), String('bahwa untuk meningkatkan kualitas dan pemanfaatan hasil penelitian dan pengembangan di bidang agama dan keagamaan pada Kementerian Agama, perlu mengatur mengenai penelitian dan pengembangan di bidang agama dan keagamaan')),
                   Triple(Rel('considers'), String('bahwa berdasarkan pertimbangan sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Menteri Agama tentang Penelitian dan Pengembangan di Bidang Agama dan Keagamaan')),
                   Triple(Rel('hasDictum'), String('Menetapkan : PERATURAN MENTERI AGAMA TENTANG PENELITIAN DAN PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN.')),
                   Triple(Rel('regulationNumber'), String('18')),
                   Triple(Rel('regulationYear'), Int('2019')),])

IDENTIFIKASI SEBANYAK MUNGKIN TRIPLE. JANGAN MELAKUKAN EKSTRAKSI SELAIN RELATION YANG DITENTUKAN.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU.

###Prompt
```
{prompt}
```
###Output
'''

# %%
prompt_2_2_1 = '''
You are a helpful assistant. Lanjutkan extraction dari code yang diberikan. 

from typing import List
class Rel:
    def __init__(self, name: str):
        self.name = name
class hasLegalBasis(Rel):
    # Apa nama peraturan yang mendasari peraturan (mengingat)
    def __init__(self, name: str):
        super.__init__(name=name)

class Entity:
    def __init__(self, name: str):
        self.name = name
class LegalDocument(Entity):
    def __init__(self, name: str):
        super.__init__(name=name)

class Triple:
    def __init__(self, relation: Rel, tail: Entity):
        self.relation = relation
        self.tail = tail
class Extract:
    def __init__(self, triples: List[Triple] = []):
        self.triples = triples
                   
###Prompt
```
BERITA NEGARA
REPUBLIK INDONESIA
No.1047, 2019 KEMENAG. Bidang Agama dan Keagamaan.
Penelitian dan Pengembangan.


PERATURAN MENTERI AGAMA REPUBLIK INDONESIA
NOMOR 18 TAHUN 2019
TENTANG
PENELITIAN DAN PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN

DENGAN RAHMAT TUHAN YANG MAHA ESA

MENTERI AGAMA REPUBLIK INDONESIA,


Menimbang  : a. bahwa untuk meningkatkan kualitas dan pemanfaatan
hasil penelitian dan pengembangan di bidang agama dan
keagamaan pada Kementerian Agama, perlu mengatur
mengenai penelitian dan pengembangan di bidang agama
dan keagamaan;
  b. bahwa berdasarkan pertimbangan sebagaimana
dimaksud dalam huruf a, perlu menetapkan Peraturan
Menteri Agama tentang Penelitian dan Pengembangan di
Bidang Agama dan Keagamaan;

Mengingat : 1. Undang-Undang Nomor 18 Tahun 2002 tentang Sistem
Nasional Penelitian, Pengembangan, dan Penerapan Ilmu
Pengetahuan dan Teknologi (Lembaran Negara Republik
Indonesia Tahun 2002 Nomor 84, Tambahan Lembaran
Negara Republik Indonesia Nomor 4219);
  2. Peraturan Presiden Nomor 7 Tahun 2015 tentang
Organisasi Kementerian Negara (Lembaran Negara
Republik Indonesia Tahun 2015 Nomor 8);


www.peraturan.go.id
2019, No.1047 -2-
3. Peraturan Presiden Nomor 83 Tahun 2015 tentang
Kementerian Agama (Lembaran Negara Republik
Indonesia Tahun 2015 Nomor 168);
  4. Peraturan Presiden Nomor 38 Tahun 2018 tentang
Rencana Induk Riset Nasional (Lembaran Negara
Republik Indonesia Tahun 2018 Nomor 64);
  5. Peraturan Menteri Agama Nomor 42 Tahun 2016 tentang
Organisasi dan Tata Kerja Kementerian Agama (Berita
Negara Republik Indonesia Tahun 2016 Nomor 1495);

MEMUTUSKAN:
Menetapkan  : PERATURAN MENTERI AGAMA TENTANG PENELITIAN DAN
PENGEMBANGAN DI BIDANG AGAMA DAN KEAGAMAAN.

BAB I
KETENTUAN UMUM
```
###Output
extract = Extract([Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 18 Tahun 2002')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 7 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 83 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 38 Tahun 2018')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Menteri Agama Nomor 42 Tahun 2016')),])

IDENTIFIKASI SEBANYAK MUNGKIN TRIPLE. JANGAN MELAKUKAN EKSTRAKSI SELAIN RELATION YANG DITENTUKAN.
JANGAN UBAH RELATION ATAU MENAMBAHKAN RELATION BARU.

###Prompt
```
{prompt}
```
###Output
'''

# %%
teks = '\n'.join([line for line in dataset_opening[517]['text_2'].splitlines() if line.strip() != ''])

test = prompt_2_2.format(prompt=teks)

messages = [
    {"role": "user", "content": test},
]


output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

# %%
teks = '\n'.join([line for line in dataset_opening[517]['text_1'].splitlines() if line.strip() != ''])

test = prompt_2_2_1.format(prompt=teks)

messages = [
    {"role": "user", "content": test},
]


output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

# %%
teks = '\n'.join([line for line in dataset_opening[1229]['text_2'].splitlines() if line.strip() != ''])

test = prompt_2_2.format(prompt=teks)

messages = [
    {"role": "user", "content": test},
]


output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

# %%
teks = '\n'.join([line for line in dataset_opening[1229]['text_1'].splitlines() if line.strip() != ''])

test = prompt_2_2_1.format(prompt=teks)

messages = [
    {"role": "user", "content": test},
]


output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])
print()
print(teks)

# %%
ans2 = """
extract = Extract([Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 16 Tahun 1950')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 17 Tahun 2003')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 1 Tahun 2004')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 5 Tahun 2014')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 23 Tahun 2014')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 30 Tahun 2014')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 56 Tahun 2005')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 58 Tahun 2005')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 41 Tahun 2009')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 53 Tahun 2010')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 69 Tahun 2010')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 46 Tahun 2011')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 18 Tahun 2016')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 11 Tahun 2017')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 12 Tahun 2017')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 52 Tahun 2009')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Menteri Dalam Negeri Nomor 13 Tahun 2006')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Kepala Badan Kepegawaian Negara Nomor 1 Tahun 2013')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Kepala Badan Kepegawaian Negara Nomor 24 Tahun 2017')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Daerah Kota Cirebon Nomor 12 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Daerah Kota Cirebon Nomor 6 Tahun 2016')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Daerah Kota Cirebon Nomor 7 Tahun 2016')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Daerah Kota Cirebon Nomor 9 Tahun 2016')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Wali Kota Cirebon Nomor 66 Tahun 2016')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Wali Kota Cirebon Nomor 12 Tahun 2018')),])
"""

# %%
prompt_3_1 = '''
Anda adalah pembuat knowledge graph. Anda akan diberikan entity regulatory dan teks, dari teks tersebut lakukan tindakan berikut:
- identifikasi sebanyak mungkin relation di antara entity
- keluarkan daftar dalam format triple turtle ENTITY 1 RELATION 1 OBJECT 1/ENTITY 2 .

Relation yang paling penting:
- rdfs:label
- lexid-s:LegalBasisOf
- lexid-s:hasLegalBasis
- rdf:type

Singkatan yang paling penting:
- Peraturan Kabupaten -> Perkab
- Peraturan Kota -> Perkot
- Peraturan Menteri Koordinator Bidang -> Permenko
- Politik, Hukum, Dan Keamanan -> Polhukam
- Perekonomian -> Perekonomian
- Kesejahteraan Rakyat -> Kesra
- Kemaritiman -> Maritim
- Pembangunan Manusia Dan Kebudayaan -> PMK
- Peraturan Wali Kota -> Perwali
- Peraturan Bupati -> Perbup
- Peraturan Presiden -> Perpres
- Peraturan Daerah -> Perda
- Peraturan Pemerintah -> PP
- Undang-Undang Dasar -> UUD
- Undang-Undang -> UU
- Ketetapan Presiden -> Tapres
- Keputusan Presiden -> Keppres
- Peraturan Daerah Provinsi -> Perprov
- Jawa Timur -> Jatim
- Jawa Tengah -> Jateng
- Irian Jaya Barat -> Irba
- Jawa Barat -> Jabar
- Nusa Tenggara Timur -> NTT
- Sulawesi Utara -> Sulut
- Daerah Istimewa Yogyakarta -> Yogya
- Kalimantan Barat -> Kalbar
- Sulawesi Barat -> Sulbar
- Daerah Khusus Ibukota Jakarta -> DKI_Jakarta
- Kalimantan Tengah -> Kalteng
- Kepulauan Riau -> Kep_Riau
- Kalimantan Timur -> Kaltim
- Sumatera Selatan -> Sumsel
- Sumatera Barat -> Sumbar
- Sulawesi Tengah -> Sulteng
- Kalimantan Selatan -> Kalsel
- Nusa Tenggara Barat -> NTB
- Sumatera Utara -> Sumut
- Sulawesi Selatan -> Sulsel
- Kepulauan Bangka Belitung -> Kep_Babel
- Keputusan Menteri -> Kepmen
- Peraturan Menteri -> Permen
- Peraturan Bersama -> PB
- Menteri -> Men
- Ketua -> 
- Kepala -> 
- Kelautan Dan Perikanan -> KP
- Kehutanan -> Hut
- Lingkungan Hidup Dan Kehutanan -> LHK
- Badan Usaha Milik Negara -> BUMN
- Perencanaan Pembangunan Nasional/ Kepala Badan Perencanaan Pembangunan Nasional -> Bappenas
- Perhubungan -> Hub
- Pendayagunaan Aparatur Negara Dan Reformasi Birokrasi -> PANRB
- Pertanian -> Tan
- Energi Dan Sumber Daya Mineral -> ESDM
- Riset Dan Teknologi -> Ristek
- Pemuda Dan Olahraga -> Pora
- Keuangan -> Keu
- Pariwisata -> Par
- Pertahanan -> Han
- Kebudayaan Dan Pariwisata -> Budpar
- Desa, Pembangunan Daerah Tertinggal, Dan Transmigrasi -> Desa
- Perdagangan -> Dag
- Riset Teknologi Dan Pendidikan Tinggi -> Ristekdikti
- Agraria Dan Tata Ruang/ Kepala Badan Pertanahan Nasional -> ATRBPN
- Pekerjaan Umum Dan Perumahan Rakyat -> PUPR
- Pekerjaan Umum -> PU
- Pendidikan Dan Kebudayaan -> Dikbud
- Kesehatan -> Kes
- Perindustrian -> Perin
- Tenaga Kerja Dan Transmigrasi -> Nakertrans
- Pariwisata Dan Ekonomi Kreatif -> Parekraf
- Pembangunan Daerah Tertinggal -> PDT
- Hukum Dan Hak Asasi Manusia -> Humham
- Perumahan Rakyat -> PR
- Pendidikan Nasional -> Dik
- Dalam Negeri -> Dagri
- Komunikasi Dan Informatika -> Kominfo
- Sosial -> Sos
- Koperasi Dan Usaha Kecil Dan Menengah -> Kopukm
- Pemberdayaan Perempuan Dan Perlindungan Anak -> PPPA
- Lingkungan Hidup -> LH
- Luar Negeri -> LU
- Republik Indonesia -> RI
- Sekretaris Negara -> Sesneg
- Ketenagakerjaan -> Naker
- Badan Pengawas Perdagangan Berjangka Komoditi -> Bappebti
- Badan Pusat Statistik -> BPS
- Lembaga Kebijakan Pengadaan Barang/jasa Pemerintah -> LKPP
- Perpustakaan Nasional -> Perpusnas
- Badan Tenaga Nuklir Nasional -> Batan
- Komisi Nasional Hak Asasi Manusia -> Komnas_HAM
- Badan Narkotika Nasional -> BNN
- Badan Pengawas Tenaga Nuklir -> Bapeten
- Komisi Pengawas Persaingan Usaha -> KPPU
- Komisi Informasi -> KI
- Badan Nasional Penanggulangan Bencana -> BNPB
- Pusat Pelaporan Dan Analisis Transaksi Keuangan -> PPATK
- Lembaga Ilmu Pengetahuan Indonesia -> LIPI
- Komisi Pemilihan Umum -> KPU
- Badan Pengatur Hilir Minyak Dan Gas Bumi -> BPH_Migas
- Badan Pengelola Keuangan Haji -> BPKH
- Badan Standardisasi Nasional -> BSN
- Badan Meteorologi, Klimatologi, Dan Geofisika -> BMKG
- Badan Nasional Penanggulangan Terorisme -> BNPT
- Arsip Nasional -> ANRI
- Lembaga Administrasi Negara -> LAN
- Sekretaris Jenderal Ombudsman -> Ombudsman
- Lembaga Perlindungan Saksi Dan Korban -> LPSK
- Badan Wakaf Indonesia -> BWI
- Dewan Perwakilan Daerah -> DPD
- Lembaga Penjamin Simpanan -> LPS
- Badan Pengkajian Dan Penerapan Teknologi -> BPPT
- Badan Siber Dan Sandi Negara -> BSSN
- Jaksa Agung -> Jagung
- Badan Kependudukan Dan Keluarga Berencana Nasional -> BKKBN
- Dewan Perwakilan Rakyat -> DPR
- Badan Nasional Penempatan Dan Perlindungan Tenaga Kerja Indonesia -> BNP2TKI
- Badan Pengawas Obat Dan Makanan -> BPOM
- Badan Pengawas Pemilihan Umum -> Bawaslu
- Komisi Aparatur Sipil Negara -> KASN
- Badan Nasional Pencarian Dan Pertolongan -> Basarnas
- Badan Kepegawaian Negara -> BKN
- Dewan Jaminan Sosial Nasional -> DJSN
- Badan Nasional Pengelola Perbatasan -> BNPP
- Badan Keamanan Laut -> Bakamla
- Badan Ekonomi Kreatif -> Bekraf
- Badan Pengawasan Keuangan Dan Pembangunan -> BPKP
- Kepolisian Negara -> Polri
- Komisi Pemberantasan Korupsi -> KPK
- Mahkamah Agung -> MA
- Badan Informasi Geospasial -> BIG
- Konsil Kedokteran Indonesia -> KKI
- Dewan Kawasan Perdagangan Bebas Dan Pelabuhan Bebas Batam -> PBBATAM
- Lembaga Penerbangan Dan Antariksa Nasional -> Lapan
- Sekretaris Kabinet -> Setkab
- Badan Koordinasi Penanaman Modal -> BKPM
- Otoritas Jasa Keuangan -> OJK
- Badan Amil Zakat Nasional -> Baznas
- Badan Pembinaan Ideologi Pancasila -> BPIP
- Badan Penyelenggara Jaminan Sosial Kesehatan Reppublik Indonesia -> BPJSKES
- Badan Pertanahan Nasional -> BPN
- Bank Indonesia -> BI
- Badan Pemeriksa Keuangan -> BPK
- Komisi Yudisial -> KY
- Dewan Kehormatan Penyelenggara Pemilihan Umum -> DKPP
- Badan Penyelenggara Jaminan Sosial Ketenagakerjaan -> BPJSTK

###Regulatory: lexid:PP_2019_4
###Prompt
```
extract = Extract([Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 18 Tahun 2002')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 7 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 83 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 38 Tahun 2018')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Menteri Agama Nomor 42 Tahun 2016')),])
```
###Output
lexid:UU_2002_18 rdfs:label "Undang-Undang Nomor 18 Tahun 2002"^^xsd:string .
lexid:Perpres_2015_7 rdfs:label "Peraturan Presiden Nomor 7 Tahun 2015"^^xsd:string .
lexid:Perpres_2015_83 rdfs:label "Peraturan Presiden Nomor 83 Tahun 2015"^^xsd:string .
lexid:Perpres_2015_38 rdfs:label "Peraturan Presiden Nomor 38 Tahun 2018"^^xsd:string .
lexid:Permen_Agama_2016_42 rdfs:label "Peraturan Menteri Agama Nomor 42 Tahun 2016"^^xsd:string .
lexid:UU_2002_18 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:Perpres_2015_7 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:Perpres_2015_83 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:Perpres_2015_38 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:Permen_Agama_2016_42 lexid-s:LegalBasisOf lexid:PP_2019_4 .
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:UU_2002_18 .
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:Perpres_2015_7 .
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:Perpres_2015_83 .
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:Perpres_2015_38 .
lexid:PP_2019_4 lexid-s:hasLegalBasis lexid:Permen_Agama_2016_42 .
lexid:UU_2002_18 rdf:type lexid-s:LegalDocument .
lexid:Perpres_2015_7 rdf:type lexid-s:LegalDocument .
lexid:Perpres_2015_83 rdf:type lexid-s:LegalDocument .
lexid:Perpres_2015_38 rdf:type lexid-s:LegalDocument .
lexid:Permen_Agama_2016_42 rdf:type lexid-s:LegalDocument .


IDENTIFIKASI SEBANYAK MUNGKIN TRIPLE. JANGAN MELAKUKAN EKSTRAKSI SELAIN RELATION YANG DITENTUKAN.


###Regulatory: lexid:{regulatory}
###Prompt
```
{prompt}
```
###Output
'''

# %%
test = prompt_3_1.format(regulatory="Perwali_Cirebon_2019_7", prompt=ans2)

messages = [
    {"role": "user", "content": test},
]


output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])

# %%
prompt_3 = '''
You are a helpful assistant. Lanjutkan abbreviation dari code yang diberikan. 

from typing import List

def abbreviate_name(name: str) -> str:
    if "Peraturan Kabupaten" in name:
        name = name.replace("Peraturan Kabupaten", "Perkab")
    elif "Peraturan Kota" in name:
        name = name.replace("Peraturan Kota", "Perkot")
    elif "Peraturan Walikota" in name:
        name = name.replace("Peraturan Walikota", "Perwali")
        name = name.replace("Kota", "")
    elif "Peraturan Bupati" in name:
        name = name.replace("Peraturan Bupati", "Perbup")
    elif "Peraturan Presiden" in name:
        name = name.replace("Peraturan Presiden", "Perpres")
    elif "Peraturan Daerah" in name:
        name = name.replace("Peraturan Daerah", "Perda")
        name = name.replace("Kota", "")
        name = name.replace("Kabupaten", "")
    elif "Peraturan Pemerintah" in name:
        name = name.replace("Peraturan Pemerintah", "PP")
    elif "Undang-Undang Dasar" in name:
        name = name.replace("Undang-Undang Dasar", "UUD")
    elif "Keputusan Presiden" in name:
        name = name.replace("Keputusan Presiden", "Keppres")
    elif "Undang-Undang" in name:
        name = name.replace("Undang-Undang", "UU")
    elif "Ketetapan Presiden" in name:
        name = name.replace("Ketetapan Presiden", "Tapres")
    elif "Peraturan Menteri Koordinator Bidang" in name:
        name = name.replace("Peraturan Menteri Koordinator Bidang", "Permenko")
        name = name.replace("Politik, Hukum, Dan Keamanan Republik Indonesia", "Polhukam")
        name = name.replace("Perekonomian Republik Indonesia", "Perekonomian")
        name = name.replace("Kesejahteraan Rakyat Republik Indonesia", "Kesra")
        name = name.replace("Kemaritiman Republik Indonesia", "Maritim")
        name = name.replace("Pembangunan Manusia Dan Kebudayaan Republik Indonesia", "PMK")
    return name
    
class Rel:
    def __init__(self, name: str):
        self.name = name
class hasLegalBasis(Rel):
    # Apa yang mendasari peraturan (mengingat)
    def __init__(self, name: str):
        super.__init__(name=name)

class Entity:
    def __init__(self, name: str):
        self.name = name
class LegalDocument(Entity):
    def __init__(self, name: str):
        super.__init__(name=new_name)

class Triple:
    def __init__(self, relation: Rel, tail: Entity):
        self.relation = relation
        self.tail = tail
        
class Extract:
    def __init__(self, triples: List[Triple] = []):
        self.triples = triples
        
class Abbrev:
    def __init__(self, triples: List[Triple] = []):
        for triple in triples:
            relation = triple.relation
            tail = triple.tail
            tail = new LegalDocument(abbreviate_name(tail.name))
            triple = new Triple(relation, tail)
        self.triples = triples
                   
###Prompt
```
extract = Extract([Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 18 Tahun 2002')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 7 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 83 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 38 Tahun 2018')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Menteri Agama Nomor 42 Tahun 2016')),])
```
###Output
abbrev = Abbrev([Triple(Rel('hasLegalBasis'), LegalDocument('UU Nomor 18 Tahun 2002')),
                 Triple(Rel('hasLegalBasis'), LegalDocument('Perpres Nomor 7 Tahun 2015')),
                 Triple(Rel('hasLegalBasis'), LegalDocument('Perpres Nomor 83 Tahun 2015')),
                 Triple(Rel('hasLegalBasis'), LegalDocument('Perpres Nomor 38 Tahun 2018')),
                 Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Menteri Agama Nomor 42 Tahun 2016')),])

IDENTIFIKASI SEBANYAK MUNGKIN TRIPLE. JANGAN MELAKUKAN EKSTRAKSI SELAIN RELATION YANG DITENTUKAN.
JANGAN UBAH TRIPLE YANG TIDAK MEMILIKI ABBREV YANG SESUAI.

###Prompt
```
{prompt}
```
###Output
'''

# %%
test = prompt_3.format(prompt=ans2)

messages = [
    {"role": "user", "content": test},
]


output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])

# %%
prompt_3_2 = '''
You are a helpful assistant. Lanjutkan abbreviation dari code yang diberikan. 

from typing import List

def abbreviate_name(name: str) -> str:
    name = name.replace("Peraturan Kabupaten", "Perkab")
    name = name.replace("Peraturan Kota", "Perkot")
    name = name.replace("Peraturan Menteri Koordinator Bidang", "Permenko")
    name = name.replace("Politik, Hukum, Dan Keamanan", "Polhukam")
    name = name.replace("Perekonomian", "Perekonomian")
    name = name.replace("Kesejahteraan Rakyat", "Kesra")
    name = name.replace("Kemaritiman", "Maritim")
    name = name.replace("Pembangunan Manusia Dan Kebudayaan", "PMK")
    name = name.replace("Peraturan Wali Kota", "Perwali")
    name = name.replace("Peraturan Bupati", "Perbup")
    name = name.replace("Peraturan Presiden", "Perpres")
    name = name.replace("Peraturan Daerah", "Perda")
    name = name.replace("Peraturan Pemerintah", "PP")
    name = name.replace("Undang-Undang Dasar", "UUD")
    name = name.replace("Undang-Undang", "UU")
    name = name.replace("Ketetapan Presiden", "Tapres")
    name = name.replace("Keputusan Presiden", "Keppres")
    name = name.replace("Peraturan Daerah Provinsi", "Perprov")
    name = name.replace("Jawa Timur", "Jatim")
    name = name.replace("Jawa Tengah", "Jateng")
    name = name.replace("Irian Jaya Barat", "Irba")
    name = name.replace("Jawa Barat", "Jabar")
    name = name.replace("Nusa Tenggara Timur", "NTT")
    name = name.replace("Sulawesi Utara", "Sulut")
    name = name.replace("Daerah Istimewa Yogyakarta", "Yogya")
    name = name.replace("Kalimantan Barat", "Kalbar")
    name = name.replace("Sulawesi Barat", "Sulbar")
    name = name.replace("Daerah Khusus Ibukota Jakarta", "DKI_Jakarta")
    name = name.replace("Kalimantan Tengah", "Kalteng")
    name = name.replace("Kepulauan Riau", "Kep_Riau")
    name = name.replace("Kalimantan Timur", "Kaltim")
    name = name.replace("Sumatera Selatan", "Sumsel")
    name = name.replace("Sumatera Barat", "Sumbar")
    name = name.replace("Sulawesi Tengah", "Sulteng")
    name = name.replace("Kalimantan Selatan", "Kalsel")
    name = name.replace("Nusa Tenggara Barat", "NTB")
    name = name.replace("Sumatera Utara", "Sumut")
    name = name.replace("Sulawesi Selatan", "Sulsel")
    name = name.replace("Kepulauan Bangka Belitung", "Kep_Babel")
    name = name.replace("Keputusan Menteri", "Kepmen")
    name = name.replace("Peraturan Menteri", "Permen")
    name = name.replace("Peraturan Bersama", "PB")
    name = name.replace("Menteri", "Men")
    name = name.replace("Ketua", "")
    name = name.replace("Kepala", "")
    name = name.replace("Kelautan Dan Perikanan", "KP")
    name = name.replace("Kehutanan", "Hut")
    name = name.replace("Lingkungan Hidup Dan Kehutanan", "LHK")
    name = name.replace("Badan Usaha Milik Negara", "BUMN")
    name = name.replace("Perencanaan Pembangunan Nasional/ Kepala Badan Perencanaan Pembangunan Nasional", "Bappenas")
    name = name.replace("Perhubungan", "Hub")
    name = name.replace("Pendayagunaan Aparatur Negara Dan Reformasi Birokrasi", "PANRB")
    name = name.replace("Pertanian", "Tan")
    name = name.replace("Energi Dan Sumber Daya Mineral", "ESDM")
    name = name.replace("Riset Dan Teknologi", "Ristek")
    name = name.replace("Pemuda Dan Olahraga", "Pora")
    name = name.replace("Keuangan", "Keu")
    name = name.replace("Pariwisata", "Par")
    name = name.replace("Pertahanan", "Han")
    name = name.replace("Kebudayaan Dan Pariwisata", "Budpar")
    name = name.replace("Desa, Pembangunan Daerah Tertinggal, Dan Transmigrasi", "Desa")
    name = name.replace("Perdagangan", "Dag")
    name = name.replace("Riset Teknologi Dan Pendidikan Tinggi", "Ristekdikti")
    name = name.replace("Agraria Dan Tata Ruang/ Kepala Badan Pertanahan Nasional", "ATRBPN")
    name = name.replace("Pekerjaan Umum Dan Perumahan Rakyat", "PUPR")
    name = name.replace("Pekerjaan Umum", "PU")
    name = name.replace("Pendidikan Dan Kebudayaan", "Dikbud")
    name = name.replace("Kesehatan", "Kes")
    name = name.replace("Perindustrian", "Perin")
    name = name.replace("Tenaga Kerja Dan Transmigrasi", "Nakertrans")
    name = name.replace("Pariwisata Dan Ekonomi Kreatif", "Parekraf")
    name = name.replace("Pembangunan Daerah Tertinggal", "PDT")
    name = name.replace("Hukum Dan Hak Asasi Manusia", "Humham")
    name = name.replace("Perumahan Rakyat", "PR")
    name = name.replace("Pendidikan Nasional", "Dik")
    name = name.replace("Dalam Negeri", "Dagri")
    name = name.replace("Komunikasi Dan Informatika", "Kominfo")
    name = name.replace("Sosial", "Sos")
    name = name.replace("Koperasi Dan Usaha Kecil Dan Menengah", "Kopukm")
    name = name.replace("Pemberdayaan Perempuan Dan Perlindungan Anak", "PPPA")
    name = name.replace("Lingkungan Hidup", "LH")
    name = name.replace("Luar Negeri", "LU")
    name = name.replace("Republik Indonesia", "RI")
    name = name.replace("Sekretaris Negara", "Sesneg")
    name = name.replace("Ketenagakerjaan", "Naker")
    name = name.replace("Badan Pengawas Perdagangan Berjangka Komoditi", "Bappebti")
    name = name.replace("Badan Pusat Statistik", "BPS")
    name = name.replace("Lembaga Kebijakan Pengadaan Barang/jasa Pemerintah", "LKPP")
    name = name.replace("Perpustakaan Nasional", "Perpusnas")
    name = name.replace("Badan Tenaga Nuklir Nasional", "Batan")
    name = name.replace("Komisi Nasional Hak Asasi Manusia", "Komnas_HAM")
    name = name.replace("Badan Narkotika Nasional", "BNN")
    name = name.replace("Badan Pengawas Tenaga Nuklir", "Bapeten")
    name = name.replace("Komisi Pengawas Persaingan Usaha", "KPPU")
    name = name.replace("Komisi Informasi", "KI")
    name = name.replace("Badan Nasional Penanggulangan Bencana", "BNPB")
    name = name.replace("Pusat Pelaporan Dan Analisis Transaksi Keuangan", "PPATK")
    name = name.replace("Lembaga Ilmu Pengetahuan Indonesia", "LIPI")
    name = name.replace("Komisi Pemilihan Umum", "KPU")
    name = name.replace("Badan Pengatur Hilir Minyak Dan Gas Bumi", "BPH_Migas")
    name = name.replace("Badan Pengelola Keuangan Haji", "BPKH")
    name = name.replace("Badan Standardisasi Nasional", "BSN")
    name = name.replace("Badan Meteorologi, Klimatologi, Dan Geofisika", "BMKG")
    name = name.replace("Badan Nasional Penanggulangan Terorisme", "BNPT")
    name = name.replace("Arsip Nasional", "ANRI")
    name = name.replace("Lembaga Administrasi Negara", "LAN")
    name = name.replace("Sekretaris Jenderal Ombudsman", "Ombudsman")
    name = name.replace("Lembaga Perlindungan Saksi Dan Korban", "LPSK")
    name = name.replace("Badan Wakaf Indonesia", "BWI")
    name = name.replace("Dewan Perwakilan Daerah", "DPD")
    name = name.replace("Lembaga Penjamin Simpanan", "LPS")
    name = name.replace("Badan Pengkajian Dan Penerapan Teknologi", "BPPT")
    name = name.replace("Badan Siber Dan Sandi Negara", "BSSN")
    name = name.replace("Jaksa Agung", "Jagung")
    name = name.replace("Badan Kependudukan Dan Keluarga Berencana Nasional", "BKKBN")
    name = name.replace("Dewan Perwakilan Rakyat", "DPR")
    name = name.replace("Badan Nasional Penempatan Dan Perlindungan Tenaga Kerja Indonesia", "BNP2TKI")
    name = name.replace("Badan Pengawas Obat Dan Makanan", "BPOM")
    name = name.replace("Badan Pengawas Pemilihan Umum", "Bawaslu")
    name = name.replace("Komisi Aparatur Sipil Negara", "KASN")
    name = name.replace("Badan Nasional Pencarian Dan Pertolongan", "Basarnas")
    name = name.replace("Badan Kepegawaian Negara", "BKN")
    name = name.replace("Dewan Jaminan Sosial Nasional", "DJSN")
    name = name.replace("Badan Nasional Pengelola Perbatasan", "BNPP")
    name = name.replace("Badan Keamanan Laut", "Bakamla")
    name = name.replace("Badan Ekonomi Kreatif", "Bekraf")
    name = name.replace("Badan Pengawasan Keuangan Dan Pembangunan", "BPKP")
    name = name.replace("Kepolisian Negara", "Polri")
    name = name.replace("Komisi Pemberantasan Korupsi", "KPK")
    name = name.replace("Mahkamah Agung", "MA")
    name = name.replace("Badan Informasi Geospasial", "BIG")
    name = name.replace("Konsil Kedokteran Indonesia", "KKI")
    name = name.replace("Dewan Kawasan Perdagangan Bebas Dan Pelabuhan Bebas Batam", "PBBATAM")
    name = name.replace("Lembaga Penerbangan Dan Antariksa Nasional", "Lapan")
    name = name.replace("Sekretaris Kabinet", "Setkab")
    name = name.replace("Badan Koordinasi Penanaman Modal", "BKPM")
    name = name.replace("Otoritas Jasa Keuangan", "OJK")
    name = name.replace("Badan Amil Zakat Nasional", "Baznas")
    name = name.replace("Badan Pembinaan Ideologi Pancasila", "BPIP")
    name = name.replace("Badan Penyelenggara Jaminan Sosial Kesehatan Reppublik Indonesia", "BPJSKES")
    name = name.replace("Badan Pertanahan Nasional", "BPN")
    name = name.replace("Bank Indonesia", "BI")
    name = name.replace("Badan Pemeriksa Keuangan", "BPK")
    name = name.replace("Komisi Yudisial", "KY")
    name = name.replace("Dewan Kehormatan Penyelenggara Pemilihan Umum", "DKPP")
    name = name.replace("Badan Penyelenggara Jaminan Sosial Ketenagakerjaan", "BPJSTK")
    return name
    
class Rel:
    def __init__(self, name: str):
        self.name = name
class hasLegalBasis(Rel):
    # Apa yang mendasari peraturan (mengingat)
    def __init__(self, name: str):
        super.__init__(name=name)

class Entity:
    def __init__(self, name: str):
        self.name = name
class LegalDocument(Entity):
    def __init__(self, name: str):
        super.__init__(name=new_name)

class Triple:
    def __init__(self, relation: Rel, tail: Entity):
        self.relation = relation
        self.tail = tail
        
class Extract:
    def __init__(self, triples: List[Triple] = []):
        self.triples = triples
        
class Abbrev:
    def __init__(self, triples: List[Triple] = []):
        for triple in triples:
            relation = triple.relation
            tail = triple.tail
            tail = new LegalDocument(abbreviate_name(tail.name))
            triple = new Triple(relation, tail)
        self.triples = triples
                   
###Prompt
```
extract = Extract([Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 18 Tahun 2002')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 7 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 83 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 38 Tahun 2018')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Menteri Agama Nomor 42 Tahun 2016')),])
```
###Output
abbrev = Abbrev([Triple(Rel('hasLegalBasis'), LegalDocument('UU Nomor 18 Tahun 2002')),
                 Triple(Rel('hasLegalBasis'), LegalDocument('Perpres Nomor 7 Tahun 2015')),
                 Triple(Rel('hasLegalBasis'), LegalDocument('Perpres Nomor 83 Tahun 2015')),
                 Triple(Rel('hasLegalBasis'), LegalDocument('Perpres Nomor 38 Tahun 2018')),
                 Triple(Rel('hasLegalBasis'), LegalDocument('Permen Agama Nomor 42 Tahun 2016')),])

JANGAN UBAH TRIPLE YANG TIDAK MEMILIKI ABBREV YANG SESUAI.

###Prompt
```
{prompt}
```
###Output
'''

# %%
test = prompt_3_2.format(prompt=ans2)

messages = [
    {"role": "user", "content": test},
]


output = pipe_f7(messages, **generation_args)
print(output[0]['generated_text'])

# %%
print(perwali_opening)

# %%
prompt_4 = '''
You are a helpful assistant. Lanjutkan extraction dari code yang diberikan. 

from typing import List

def abbreviate_name(name: str) -> str:
    if "Peraturan Kabupaten" in name:
        name = name.replace("Peraturan Kabupaten", "Perkab")
    elif "Peraturan Kota" in name:
        name = name.replace("Peraturan Kota", "Perkot")
    elif "Peraturan Menteri Koordinator Bidang" in name:
        name = name.replace("Peraturan Menteri Koordinator Bidang", "Permenko")
        name = name.replace("Politik, Hukum, Dan Keamanan Republik Indonesia", "Polhukam")
        name = name.replace("Perekonomian Republik Indonesia", "Perekonomian")
        name = name.replace("Kesejahteraan Rakyat Republik Indonesia", "Kesra")
        name = name.replace("Kemaritiman Republik Indonesia", "Maritim")
        name = name.replace("Pembangunan Manusia Dan Kebudayaan Republik Indonesia", "PMK")
    elif "Peraturan Menteri" in name or "Keputusan Menteri" in name or "Peraturan Bersama" in name or "Peraturan" in name:
        name = name.replace("Keputusan Menteri", "Kepmen")
        name = name.replace("Peraturan Menteri", "Permen")
        name = name.replace("Peraturan Bersama", "PB")
        name = name.replace("Menteri", "Men")
        name = name.replace("Ketua", "")
        name = name.replace("Kepala", "")
        name = name.replace("Agama Republik Indonesia", "Agama")
        name = name.replace("Kelautan Dan Perikanan Republik Indonesia", "KP")
        name = name.replace("Kehutanan Republik Indonesia", "Hut")
        name = name.replace("Lingkungan Hidup Dan Kehutanan Republik Indonesia", "LHK")
        name = name.replace("Badan Usaha Milik Negara Republik Indonesia", "BUMN")
        name = name.replace("Perencanaan Pembangunan Nasional/ Kepala Badan Perencanaan Pembangunan Nasional Republik Indonesia", "Bappenas")
        name = name.replace("Perhubungan Republik Indonesia", "Hub")
        name = name.replace("Pendayagunaan Aparatur Negara Dan Reformasi Birokrasi Republik Indonesia", "PANRB")
        name = name.replace("Pertanian Republik Indonesia", "Tan")
        name = name.replace("Energi Dan Sumber Daya Mineral Republik Indonesia", "ESDM")
        name = name.replace("Riset Dan Teknologi Republik Indonesia", "Ristek")
        name = name.replace("Pemuda Dan Olahraga Republik Indonesia", "Pora")
        name = name.replace("Keuangan Republik Indonesia", "Keu")
        name = name.replace("Pariwisata Republik Indonesia", "Par")
        name = name.replace("Pertahanan Republik Indonesia", "Han")
        name = name.replace("Kebudayaan Dan Pariwisata Republik Indonesia", "Budpar")
        name = name.replace("Desa, Pembangunan Daerah Tertinggal, Dan Transmigrasi Republik Indonesia", "Desa")
        name = name.replace("Perdagangan Republik Indonesia", "Dag")
        name = name.replace("Riset Teknologi Dan Pendidikan Tinggi Republik Indonesia", "Ristekdikti")
        name = name.replace("Agraria Dan Tata Ruang/ Kepala Badan Pertanahan Nasional Republik Indonesia", "ATRBPN")
        name = name.replace("Pekerjaan Umum Dan Perumahan Rakyat Republik Indonesia", "PUPR")
        name = name.replace("Pekerjaan Umum Republik Indonesia", "PU")
        name = name.replace("Pendidikan Dan Kebudayaan Republik Indonesia", "Dikbud")
        name = name.replace("Kesehatan Republik Indonesia", "Kes")
        name = name.replace("Perindustrian Republik Indonesia", "Perin")
        name = name.replace("Tenaga Kerja Dan Transmigrasi Republik Indonesia", "Nakertrans")
        name = name.replace("Pariwisata Dan Ekonomi Kreatif Republik Indonesia", "Parekraf")
        name = name.replace("Pembangunan Daerah Tertinggal Republik Indonesia", "PDT")
        name = name.replace("Hukum Dan Hak Asasi Manusia Republik Indonesia", "Humham")
        name = name.replace("Perumahan Rakyat Republik Indonesia", "PR")
        name = name.replace("Pendidikan Nasional Republik Indonesia", "Dik")
        name = name.replace("Dalam Negeri Republik Indonesia", "Dagri")
        name = name.replace("Komunikasi Dan Informatika Republik Indonesia", "Kominfo")
        name = name.replace("Sosial Republik Indonesia", "Sos")
        name = name.replace("Koperasi Dan Usaha Kecil Dan Menengah Republik Indonesia", "Kopukm")
        name = name.replace("Pemberdayaan Perempuan Dan Perlindungan Anak Republik Indonesia", "PPPA")
        name = name.replace("Lingkungan Hidup Republik Indonesia", "LH")
        name = name.replace("Luar Negeri Republik Indonesia", "LU")
        name = name.replace("Republik Indonesia", "RI")
        name = name.replace("Sekretaris Negara Republik Indonesia", "Sesneg")
        name = name.replace("Ketenagakerjaan Republik Indonesia", "Naker")
        name = name.replace("Badan Pengawas Perdagangan Berjangka Komoditi Republik Indonesia", "Bappebti")
        name = name.replace("Badan Pusat Statistik Republik Indonesia", "BPS")
        name = name.replace("Lembaga Kebijakan Pengadaan Barang/jasa Pemerintah Republik Indonesia", "LKPP")
        name = name.replace("Perpustakaan Nasional Republik Indonesia", "Perpusnas")
        name = name.replace("Badan Tenaga Nuklir Nasional Republik Indonesia", "Batan")
        name = name.replace("Komisi Nasional Hak Asasi Manusia Republik Indonesia", "Komnas_HAM")
        name = name.replace("Badan Narkotika Nasional Republik Indonesia", "BNN")
        name = name.replace("Badan Pengawas Tenaga Nuklir Republik Indonesia", "Bapeten")
        name = name.replace("Komisi Pengawas Persaingan Usaha Republik Indonesia", "KPPU")
        name = name.replace("Komisi Informasi Republik Indonesia", "KI")
        name = name.replace("Badan Nasional Penanggulangan Bencana Republik Indonesia", "BNPB")
        name = name.replace("Pusat Pelaporan Dan Analisis Transaksi Keuangan Republik Indonesia", "PPATK")
        name = name.replace("Lembaga Ilmu Pengetahuan Indonesia Republik Indonesia", "LIPI")
        name = name.replace("Komisi Pemilihan Umum Republik Indonesia", "KPU")
        name = name.replace("Badan Pengatur Hilir Minyak Dan Gas Bumi Republik Indonesia", "BPH_Migas")
        name = name.replace("Badan Pengelola Keuangan Haji Republik Indonesia", "BPKH")
        name = name.replace("Badan Standardisasi Nasional Republik Indonesia", "BSN")
        name = name.replace("Badan Meteorologi, Klimatologi, Dan Geofisika Republik Indonesia", "BMKG")
        name = name.replace("Badan Nasional Penanggulangan Terorisme Republik Indonesia", "BNPT")
        name = name.replace("Arsip Nasional Republik Indonesia", "ANRI")
        name = name.replace("Lembaga Administrasi Negara Republik Indonesia", "LAN")
        name = name.replace("Sekretaris Jenderal Ombudsman Republik Indonesia", "Ombudsman")
        name = name.replace("Lembaga Perlindungan Saksi Dan Korban Republik Indonesia", "LPSK")
        name = name.replace("Badan Wakaf Indonesia", "BWI")
        name = name.replace("Dewan Perwakilan Daerah Republik Indonesia", "DPD")
        name = name.replace("Lembaga Penjamin Simpanan Republik Indonesia", "LPS")
        name = name.replace("Badan Pengkajian Dan Penerapan Teknologi Republik Indonesia", "BPPT")
        name = name.replace("Badan Siber Dan Sandi Negara Republik Indonesia", "BSSN")
        name = name.replace("Jaksa Agung Republik Indonesia", "Jagung")
        name = name.replace("Badan Kependudukan Dan Keluarga Berencana Nasional Republik Indonesia", "BKKBN")
        name = name.replace("Dewan Perwakilan Rakyat Republik Indonesia", "DPR")
        name = name.replace("Badan Nasional Penempatan Dan Perlindungan Tenaga Kerja Indonesia Republik Indonesia", "BNP2TKI")
        name = name.replace("Badan Pengawas Obat Dan Makanan Republik Indonesia", "BPOM")
        name = name.replace("Badan Pengawas Pemilihan Umum Republik Indonesia", "Bawaslu")
        name = name.replace("Komisi Aparatur Sipil Negara Republik Indonesia", "KASN")
        name = name.replace("Badan Nasional Pencarian Dan Pertolongan Republik Indonesia", "Basarnas")
        name = name.replace("Badan Kepegawaian Negara Republik Indonesia", "BKN")
        name = name.replace("Dewan Jaminan Sosial Nasional Republik Indonesia", "DJSN")
        name = name.replace("Badan Nasional Pengelola Perbatasan Republik Indonesia", "BNPP")
        name = name.replace("Badan Keamanan Laut Republik Indonesia", "Bakamla")
        name = name.replace("Badan Ekonomi Kreatif Republik Indonesia", "Bekraf")
        name = name.replace("Badan Pengawasan Keuangan Dan Pembangunan Republik Indonesia", "BPKP")
        name = name.replace("Kepolisian Negara Republik Indonesia", "Polri")
        name = name.replace("Komisi Pemberantasan Korupsi Republik Indonesia", "KPK")
        name = name.replace("Mahkamah Agung Republik Indonesia", "MA")
        name = name.replace("Badan Informasi Geospasial Republik Indonesia", "BIG")
        name = name.replace("Konsil Kedokteran Indonesia Republik Indonesia", "KKI")
        name = name.replace("Dewan Kawasan Perdagangan Bebas Dan Pelabuhan Bebas Batam", "PBBATAM")
        name = name.replace("Lembaga Penerbangan Dan Antariksa Nasional Republik Indonesia", "Lapan")
        name = name.replace("Sekretaris Kabinet Republik Indonesia", "Setkab")
        name = name.replace("Badan Koordinasi Penanaman Modal Republik Indonesia", "BKPM")
        name = name.replace("Otoritas Jasa Keuangan Republik Indonesia", "OJK")
        name = name.replace("Badan Amil Zakat Nasional Republik Indonesia", "Baznas")
        name = name.replace("Badan Pembinaan Ideologi Pancasila Republik Indonesia", "BPIP")
        name = name.replace("Badan Penyelenggara Jaminan Sosial Kesehatan Reppublik Indonesia", "BPJSKES")
        name = name.replace("Kepala Badan Pertanahan Nasional Republik Indonesia", "BPN")
        name = name.replace("Bank Indonesia", "BI")
        name = name.replace("Badan Pemeriksa Keuangan Republik Indonesia", "BPK")
        name = name.replace("Komisi Yudisial Republik Indonesia", "KY")
        name = name.replace("Dewan Kehormatan Penyelenggara Pemilihan Umum Republik Indonesia", "DKPP")
        name = name.replace("Badan Penyelenggara Jaminan Sosial Ketenagakerjaan Republik Indonesia", "BPJSTK")
        name = name.replace("Dan", "")
    elif "Peraturan Daerah Provinsi" in name:
        name = name.replace("Peraturan Daerah Provinsi", "Perprov")
        name = name.replace("Jawa Timur", "Jatim")
        name = name.replace("Jawa Tengah", "Jateng")
        name = name.replace("Irian Jaya Barat", "Irba")
        name = name.replace("Jawa Barat", "Jabar")
        name = name.replace("Nusa Tenggara Timur", "NTT")
        name = name.replace("Sulawesi Utara", "Sulut")
        name = name.replace("Daerah Istimewa Yogyakarta", "Yogya")
        name = name.replace("Kalimantan Barat", "Kalbar")
        name = name.replace("Sulawesi Barat", "Sulbar")
        name = name.replace("Daerah Khusus Ibukota Jakarta", "DKI_Jakarta")
        name = name.replace("Kalimantan Tengah", "Kalteng")
        name = name.replace("Kepulauan Riau", "Kep_Riau")
        name = name.replace("Kalimantan Timur", "Kaltim")
        name = name.replace("Sumatera Selatan", "Sumsel")
        name = name.replace("Sumatera Barat", "Sumbar")
        name = name.replace("Sulawesi Tengah", "Sulteng")
        name = name.replace("Kalimantan Selatan", "Kalsel")
        name = name.replace("Nusa Tenggara Barat", "NTB")
        name = name.replace("Sumatera Utara", "Sumut")
        name = name.replace("Sulawesi Selatan", "Sulsel")
        name = name.replace("Kepulauan Bangka Belitung", "Kep_Babel")
    elif "Peraturan Walikota" in name:
        name = name.replace("Peraturan Walikota", "Perwali")
    elif "Peraturan Bupati" in name:
        name = name.replace("Peraturan Bupati", "Perbup")
    elif "Peraturan Presiden" in name:
        name = name.replace("Peraturan Presiden", "Perpres")
    elif "Peraturan Daerah" in name:
        name = name.replace("Peraturan Daerah", "Perda")
    elif "Peraturan Pemerintah" in name:
        name = name.replace("Peraturan Pemerintah", "PP")
    elif "Undang-Undang Dasar" in name:
        name = name.replace("Undang-Undang Dasar", "UUD")
    elif "Undang-Undang" in name:
        name = name.replace("Undang-Undang", "UU")
    elif "Ketetapan Presiden" in name:
        name = name.replace("Ketetapan Presiden", "Tapres")
    elif "Keputusan Presiden" in name:
        name = name.replace("Keputusan Presiden", "Keppres")
    return name
    
class Rel:
    def __init__(self, name: str):
        self.name = name
class hasLegalBasis(Rel):
    # Apa yang mendasari peraturan (mengingat)
    def __init__(self, name: str):
        super.__init__(name=name)

class Entity:
    def __init__(self, name: str):
        self.name = name
class LegalDocument(Entity):
    def __init__(self, name: str):
        new_name = abbreviate_name(name)
        super.__init__(name=new_name)

class Triple:
    def __init__(self, relation: Rel, tail: Entity):
        self.relation = relation
        self.tail = tail
        
class Extract:
    def __init__(self, triples: List[Triple] = []):
        self.triples = triples
        
class Abbrev:
    def __init__(self, triples: List[Triple] = []):
        self.triples = triples
                   
###Prompt
```
Extract([Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 18 Tahun 2002')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 7 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 83 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 38 Tahun 2018')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Menteri Agama Nomor 42 Tahun 2016')),])
```
###Output
extract = Extract([Triple(Rel('hasLegalBasis'), LegalDocument('UU Nomor 18 Tahun 2002')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Perpres Nomor 7 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Perpres Nomor 83 Tahun 2015')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Perpres Nomor 38 Tahun 2018')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Permen Agama Nomor 42 Tahun 2016')),])

IDENTIFIKASI SEBANYAK MUNGKIN TRIPLE. JANGAN MELAKUKAN EKSTRAKSI SELAIN RELATION YANG DITENTUKAN.

###Prompt
```
{prompt}
```
###Output
'''

# %%
s = 'tes'
s.replace('hi', 'hello')

# %%
print(perwali_opening)

# %% [markdown]
# ## Post Processing Opening

# %%
input_str_2 = """
 extract = Extract([Triple(Rel('hasEnactionOfficial'), Person('H. KAMIL SUGEMA')),
                   Triple(Rel('hasEnactionDate'), Date('1995-11-22')),
                   Triple(Rel('hasEnactionLocation'), City('Bantul')),
                   Triple(Rel('hasEnactionOffice'), Position('DEWAN PERWAKILAN RAKYAT DAERAH')),
                   Triple(Rel('hasPromulgationOfficial'), Person('SRI ROSO')),
                   Triple(Rel('hasPromulgationDate'), Date('1996-05-07')),
                   Triple(Rel('hasPromulgationLocation'), City('Bantul')),
                   Triple(Rel('hasPromulgationOffice'), Position('KABUPATEN DAERAH TINGKAT II BANTUL')),
                   Triple(Rel('Mengundangkan'), Person('H. KAMIL SUGEMA')),
                   Triple(Rel('hasEnactionOfficial'), Person('DRS. H. KMT PUTRONEGORO')),
                   Triple(Rel('hasEnactionDate'), Date('1996-05-13')),
                   Triple(Rel('hasEnactionLocation'), City('Bantul')),
                   Triple(Rel)     
 
 (KS    
 
     
   s h 0    
  
 
        ',      
,
   )  KSAL)  ,m pasa   k {SALYANY SAHA   HAPALEGH10   
SARASSSE)SARA)  SAN SE)
  
KARS0S0SHAT)     0SESMPHAN',N SNYS  00  
      )   
      
  
  s0  
000     00),0NLAMN   
 
) 
N NOMHYN 
)  SH0 0 

),  N),
   
   
80   potototot 0MN y    
                                                     s,000,0)  S)0 ya        y  S  00 
S 000)

   00  
  0  
0 
)   KE  
  
M 
   
  
KAPS,
SU            S),
   0),N),   ),),N),),   00 
), 
 

),
 
   
 
 
),),
    ),KATYN),N), 
    0N), kk), ,s,  ), KANS),KANY),SY),S MANY),SAN),NK),K), 0KLAKANY),                S  K),),),S),S),N)NY),K), KANKAPH),
),
),
),),
),K),S),
                                  K),  )  )    S) k)                N) SU)  )    ),KA  ), ),                ),k),S,    S   ,D  K S   S  PAN 0NAPA   K    s    S  S    SS)S)S  S POK PANSENTO     SAPDAPS S K S   B                  '),S'),000PerS000S),S',S'),NES'),  S',    H00),                en Ks)   B0                per'),S SN0)                0 M BN SN),N '000),0) (s)     0NAPS (s000)   0000  h000000), 0 M000)''000 p000,sSS SAM,0), 0N S00    0 (000S   0   0) (S)00)   h0                00)S00M00NSU,SMEMPen hom 0   
 
s y y
S)                  0),  ),000000),0000)
) )SLAK h), K    
 )                                                  

S)S,  
S 0                S y), 0,0  
SH0,0, 
) 0 k h h h,0,s,s,N,
,                                  ,s), 0PKK),KLAKLAK),'),),K),0KSPer),PerPer S y per per y menaK h h),SYS),),SAN),SKSK),S)S),N h                SLAKS, per h),S),SH00C,C,SAPS),CSLAK,K),K),),S),),),),),),S),),), Per90 h
S,S,  k, S,S,S h  S  S,S',S),   k),S h y per per per h h h h y,  ,S,',',S', h',S',  ),,0,),,'), y y KY), y), y  SANY)  , LA', per per per PPER', per per per per per per per per, per ),SS BS000000Per'), per men per  h 0S BSS0S0NSSPer,0),S), per'),  0), dal'),  00000
)




  00N),   h perNNN000000S          
            
        S  
  S                 h
  S0 SK000
 0)N y
 0 
  

                S  S       h00         - h     0





0  



    S h        
SA 





      
 00                   0 y at

              0N y
        


      M 
        K          K 
  K  00        KOM  
      
 
                    KOM      M  SAR  SAR  M    M      0S00M0MU 
    MENOMAR    NOM  S        SAN  SOM h  0        S0                      0              M  M  MATN  S
                                   k h00   h   h    SAN h0  S0                     hapi                 h        99                      '),00),0 h00   y   y0SAP at pas    900     BANS h y  ,SMES h),S0000    00  00'),0000  ), 
N0NK), 
KN y c  KNG 
),SOM
N)   h
),N),N),),),00),
),S0000)  0000N y h0000 h0000)    
9520000000)                K00)N)                )00000000NH)000N h h h
KOMSS)
),000) h { {00
 hom 0KAK 0000 0)00HY
),000NKM,KOM (HAMH   K



MHLOL  
   0      
 
  
     0  KA 0   0  0  100  BHOM 0K     KES  S  h  B 
      M  M  
KBHKHAL 0  0HOM 0 0      2 
                          HHSKAR h0H0SLAMUH0000000NYS h),0)0)000NES0HANHHANSAN'),   KOM b'),N),     h   h          S h0  N y  N,0M di   k y per y   k   at)N                     k                   k       dal  0 dal) ) dal)0                        
  N)   dal                     -   0   0),    00  '),'),'),    5h   0)0   k)  )0)




NN
   y  5N,S,N),NESN',
  NESN),),m055),),s00NAPS dalh0) dal h   -m0NESKAPN', 

,
,

om,
',
k', soujo),00h)N y metomomN')',
 {omomom per yh) y {h',
',
N',
la',                kungsom y h {lelelelelelele {h {al',202SY), per',N')N',S                  {N', dal {',N',s',peromom',s',
em',om',',
),
om )',S',0,SSSS,,, 



,0,B,K,

,
',B,B',


k',
k,
  

20    
      
  
000  
  

  S          000  N,  ,    ,  S0SAN',0,',',M,
NOM',KOHOM,0  0000  S',0',0',0  0',050000P00000  0  ',    00002020000000S00S, ', pasen,SYNAP,',    ',y',S', S. 0000,s',0000',0 y0 y,0,B,020000    0 y y y      y0    0  0',0  0000  ,               ,m { { y     0   y    K0    S   y y,S dal y0  N,S, y yBANSH,0,MNYAP      SYN    m      SAP000SAPS,K0 { {jo  KOMHOM       
k          SMAN,    Kom pas      KNN,  0,000N S k 
  ,om,  NOM  ',    NAPO,0N  ,,om,0,k SKAPNMKMN',
,0MUhi  KAPENOMYKAPN y0NN y pas  #8omokok,
KKSAPen KAPKAPSY,000l,N SYSYMYM,N,N,S,NOMHOM, KOMHOMNOM,NYYN,   0  ,  , 
,
 dal h,,S, SYK,K, YNOM,NOM   dal y   y dal       KN,   SYMOM,S, 0  ,

k 000   pas  000, 0,                0,N0,0,SAP000   KOM,S S,PENSY00000,N                  000   ,  N,SAP,S,0,s,K, ,  ,s,0000    S S0,s,0000    ,,0 ,0 0 N       )N, 0     3NY,m,N,y,N,  ,      ,,, k y, y,  S y y y,,, h, 0,0,0000000, y y,N, y',',', yl yp,0,y y memh  NY  ',   0 3 
 , 2 y,0,K,
, 0,K, S, 
,
,, SYSN y y   NYN y  , S,N, ,  y, y, N,N,S,YKN, KYMY                y  
,NYYNN,K,y   3N), y  N,N y    K 
,y y y y,SYYNYY,Y,KAN SAN,al,KANKSYYMYYYYNYN yMYK y y per yKN y y y KYNYHYKYKNI  YANSYKANYNANY   S  ,NAN SYK k S,S S,N,N yN y  00N y y y y y S     , y yN,
, S S,   ,                ,                   y   y   y   SY   y y,N,00 N0 y y y y y y y y y y y y y y,N, S,                                      ,  ,  ,  y,000,  y,0, y y y,0,0N y y y yN',',',                 ', SYS'),                00 y y                 ,0, y, y y000000 y0000, 0 0 0  0   y                   y),  y y y y, y', S', y y 0000,s,0, 200000, y y,0  y,om y y y y y y y y, y          , {s   0   y y y y y y y y y y y y00, y y y y y y y y y y y y',',',',,   s,        ,  ,  ,  ,  ,  ,,  ,  , 0,hay   y y yom   y y y    y   y    ,  ,  ,, 
,,  ,  ,,
,,
,
, 
  ,  ,  ,  ,  ,,,,,  ,  ,
,,,Y,
,y,om,
,
 ,om y,y),K),
,s,
,
, 
, 
 
,                 y),y 

),sY s  N,K,YAN,  ,s,S,  , y,
   M y y',N y y, y y  YYYYYAN    ,  ,  9  ),  ), Y  KAN,       ,om y y,0,s,   y y,,N,S,000,0, y y, y, y, S, S, S,     y y y      ,  ,  ,,s,, S   S y y y, y, SAL, y00),, y y y y,P,  y y y y y, y y y y y), per,,,,   y y,  , y0   y     y, y, y,   S0, S, y, K, y, y, yen', y,  ,  , y y y y   y  ),  , 2, y   y 0 
, y,N, S',    ),   y      ), ',',',  ),  y', ,  ,,,   ,,,,,,, N, y      ,  ,       ,,  Y',  Y        ,  , dal',,',', y', S', S   S y                 y y',  MN', dal y y y, y y y y y y y y      ,,  S  ),  ,            ,  ',',  ,  ,  ,  ,  ,  ,  ,  ,  ,      ,  ,        ,  YY,  , ,,  ,  , ,  ,  ,                        ,,  ),      ), y y  , y, y y      ,  ,  ,  NYM   y        N     )  ,      ,    ,,Y,y), ),                  ),),NY                  ),  ,KAR S), K),,   , M        ,M,S,               ,  ,  , y y y, y,   ,  , y y  Y       
 0  ),  ,  , ,  S,S,,,,                               ,,N y y y,O   y y y y,0,                   y,  ,, ,),   ,                  ,  ,                                                                                                    ), y,,)                                )                ,               ,0,,,,,K,Y,,Y,  ,                ',,N,N y),,),  ),),,),),,,,,),), s)               , SY SY),,),,,,,,,,,,  , ,N),,),,,,,,,),),),,,,,),,,,,,,, y,,,, y, 0),',N',S,N',  ),  , N',',,',N',N'),),),,,S, SY),  N),  ,  Y  S,  Y,0),',   y),                ',),','),), S,, y,  KAN,K, KNK),N',N',,,  ,  y                , S,S, y y,N y y), SK), K y', SY',),N),),      
,   S    ),  ),   S,,,,,, S,   y y p, P,M,,,,,    ,  ,,,,',,,  ,   y y,  ,,      ,    ,  , y,,      ,  ,                  ',                                                                         S y, K y, S, SAN SAP  S',, y',', y),                                  ,                                      ,  ,  5, SY S y                                , y),Y),NY),),   KYYY                                                                  ,),,                ',,,,                , y,,,, y,,,,, y, 0),, p y, 09, ',  ,,,  ,  ,  ,  ,,                ,                ',               ,,,0,               ,               , y,N,, p,0,, 
,               ,, y',,                                ,                , ),   )                   y y               ,  ),                   Y),,S,  ),               ,),                , p,B,,,,,,S,), y,M,N,,,,,,,,),,,,,,,),,),,,,,,0),,, y', yal',N),),,,0),,,,,,,,),
,,,),,),,),,K),,  , ,,,,,,,,,,,,,,,, ,,,,,,,,                ,,,,,,K, dal,,,,,,,,,,,,,),),N,N),N,N,,N Per,,',,,),,),),),),),),),),,,,,                ,S,S),',),               ,,,,,,,),,,,',),),,,N,N,,,,,,,,,,,,,,,,',,,,,),,,  ,,,),,),,,,0,',,',),,',), S,),  )  ',,                ,,,  ,  ,  , y)S',)
"""

# %%
inp = """
extract = Extract([Triple(Rel('hasCreator'), Position('Presiden Republik Indonesia')),
                   Triple(Rel('considers'), String('bahwa Proyek Semen Baturaja harus segera diselesaikan pembangunannya, untuk dapat digunakan bagi perkembangan ekonomi Indonesia')),
                   Triple(Rel('considers'), String('bahwa berdasarkan pertimbangan tersebut pada huruf a dipandang perlu Negara Republik Indonesia melakukan penyertaan modalnya dalam Perseroan Terbatas Semen Baturaja, berkedudukan di Baturaja, yang didirikan secara bersama oleh Perseroan Terbatas (PERSERO) Semen Gresik dan Perseroan Terbatas (PERSERO) Semen Padang dengan Akta Notaris J.F.B.T. SINJAL di Jakarta Nomor 34 tanggal 14 Nopember 1974 yang semula bermaksud melaksanakan pembangunan pabrik Semen Baturaja tersebut')),
                   Triple(Rel('considers'), String('bahwa untuk maksud tersebut pada huruf b, perlu Perseroan Terbatas Semen Baturaja disesuaikan dengan Perusahaan Perseroan (PERSERO) sebagaimana dimaksud dalam REFR DOCNM="69uu009" TGPTNM="ps2(3)">Pasal 2 ayat (3) Undang-undang Nomor 9 Tahun 1969, dengan ketentuan-ketentuan yang mengatur penyertaan modal Negara Republik Indonesia sesuai dengan ketentuan Pasal 2 ayat (1) Peraturan Pemerintah Nomor 12 Tahun 1969')),
                   Triple(Rel('hasDictum'), String('Menetapkan : PERATURAN PEMERINTAH TENTANG PENYERTAAN MODAL NEGARA REPUBLIK INDONESIA KE DALAM PERSEROAN TERBATAS SEMEN BATURAJA YANG BERGERAK DI BIDANG INDUSTRI SEMEN')),
                   Triple(Rel('regulationNumber'), String('10')),
                   Triple(Rel('regulationYear'), Int('1978')),])
""".strip()

inpt1 = """
extract = Extract([Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Dasar 1945')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Kitab Undang-undang Hukum Dagang (Staatsblad 1847 Nomor 23)')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Undang-undang Nomor 4 Tahun 1971 tentang Perubahan dan Penambahan Atas Ketentuan Pasal 54, Kitab Undang-undang Hukum Dagang Staatsblad 1847 Nomor 23')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Undang-undang Nomor 9 Tahun 1969 tentang Penetapan Peraturan Pemerintah Pengganti Undang-undang Nomor 1 Tahun 1969')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 12 Tahun 1969 tentang Perusahaan Perseroan (PERSERO)')),
                   Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 24 Tahun 1972 tentang Perubahan Atas Ketentuan Pasal 7 Peraturan Pemerintah Nomor 12 Tahun 1969 tentang Perusahaan Perseroan (PERSERO)'))])
""".strip()

# %%
import re

text = '''Extract([Triple(Rel('hasCreator'), Position('Presiden Republik Indonesia')),
                   Triple(Rel('considers'), String('bahwa Proyek Semen Baturaja harus segera diselesaikan pembangunannya, untuk dapat digunakan bagi perkembangan ekonomi Indonesia')),
                   Triple(Rel('considers'), String('bahwa berdasarkan pertimbangan tersebut pada huruf a dipandang perlu Negara Republik Indonesia melakukan penyertaan modalnya dalam Perseroan Terbatas Semen Baturaja, berkedudukan di Baturaja, yang didirikan secara bersama oleh Perseroan Terbatas (PERSERO) Semen Gresik dan Perseroan Terbatas (PERSERO) Semen Padang dengan Akta Notaris J.F.B.T. SINJAL di Jakarta Nomor 34 tanggal 14 Nopember 1974 yang semula bermaksud melaksanakan pembangunan pabrik Semen Baturaja tersebut')),
                   Triple(Rel('considers'), String('bahwa untuk maksud tersebut pada huruf b, perlu Perseroan Terbatas Semen Baturaja disesuaikan dengan Perusahaan Perseroan (PERSERO) sebagaimana dimaksud dalam REFR DOCNM="69uu009" TGPTNM="ps2(3)">Pasal 2 ayat (3) Undang-undang Nomor 9 Tahun 1969, dengan ketentuan-ketentuan yang mengatur penyertaan modal Negara Republik Indonesia sesuai dengan ketentuan Pasal 2 ayat (1) Peraturan Pemerintah Nomor 12 Tahun 1969')),
                   Triple(Rel('hasDictum'), String('Menetapkan : PERATURAN PEMERINTAH TENTANG PENYERTAAN MODAL NEGARA REPUBLIK INDONESIA KE DALAM PERSEROAN TERBATAS SEMEN BATURAJA YANG BERGERAK DI BIDANG INDUSTRI SEMEN')),
                   Triple(Rel('regulationNumber'), String('10')),
                   Triple(Rel('regulationYear'), Int('1978')),])'''

pattern = r"Triple\((Rel\('[^']+'\)),\s*(\w+\('[^']+'\)|\w+\('\d+'\))\)"

triples = re.findall(pattern, text)

formatted_triples = [(match[0], match[1]) for match in triples]

for triple in formatted_triples:
    print(triple)

# %%
import re

class Rel:
    def __init__(self, name):
        self.name = name

class LegalDocument:
    def __init__(self, name):
        self.name = name
        
class Person:
    def __init__(self, name: str):
        self.name = name
        
class Date:
    def __init__(self, value: str):
        self.value = value
        
class City:
    def __init__(self, name: str):
        self.name = name
        
class Position:
    def __init__(self, name: str):
        self.name = name

class Triple:
    def __init__(self, rel, obj):
        self.rel = rel
        self.obj = obj

class Extract:
    def __init__(self, triples):
        self.triples = triples

input_str = """
extract = Extract([Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 16 Tahun 1950')),
Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 17 Tahun 2003')),
Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 1 Tahun 2004')),
Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 5 Tahun 2014')),
Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 23 Tahun 2014')),
Triple(Rel('hasLegalBasis'), LegalDocument('Undang-Undang Nomor 30 Tahun 2014')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 56 Tahun 2005')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 58 Tahun 2005')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 41 Tahun 2009')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 53 Tahun 2010')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 69 Tahun 2010')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 46 Tahun 2011')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 18 Tahun 2016')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 11 Tahun 2017')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Pemerintah Nomor 12 Tahun 2017')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Presiden Nomor 52 Tahun 2009')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Menteri Dalam Negeri Nomor 13 Tahun 2006')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Kepala Badan Kepegawaian Negara Nomor 1 Tahun 2013')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Kepala Badan Kepegawaian Negara Nomor 24 Tahun 2017')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Daerah Kota Cirebon Nomor 12 Tahun 2015')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Daerah Kota Cirebon Nomor 6 Tahun 2016')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Daerah Kota Cirebon Nomor 7 Tahun 2016')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Daerah Kota Cirebon Nomor 9 Tahun 2016')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Wali Kota Cirebon Nomor 66 Tahun 2016')),
Triple(Rel('hasLegalBasis'), LegalDocument('Peraturan Wali Kota Cirebon Nomor 12 Tahun 2018')),
Triple(Rel('considers'), Literal(' bahwa   Pegawai   Negeri   Sipil   di    Lingkungan Pemerintah Daerah Kota  Cirebon, diberikan tambahan penghasilan pegawai berdasarkan prestasi kerja secara objektif, transparan, dan akuntabel', 'string')),
Triple(Rel('considers'), Literal('bahwa berdasarkan pertimbangan sebagaimana sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Wali Kota Cirebon tentang Pedoman Pemberian Tambahan Penghasilan Pegawai bagi Pegawai Negeri Sipil di Lingkungan Pemerintah Daerah Kota Cirebon', 'string')),
Triple(Rel('hasDictum'), Literal('Menetapkan : PERATURAN WALI KOTA CIREBON TENTANG PEDOMAN PEMBERIAN TAMBAHAN PENGHASILAN PEGAWAI BAGI PEGAWAI NEGERI DI LINGKUNGAN PEMERINTAH DAERAH KOTA CIREBON.', 'string')),
Triple(Rel('regulationNumber'), Literal('7', 'string')),
Triple(Rel('regulationYear'), Literal('2019', 'int')),])
"""

# Function to parse the input string
def parse_input_string(input_str):
    input_str = input_str.replace('extract = ', '')
    input_str = input_str.replace(',])', '')
    
    triples = []
    pattern = re.compile(r"Triple\(Rel\('(?P<rel>.*?)'\), (?P<obj_type>\w+)\('(?P<obj_value>.*?)'(?:, '(?P<obj_dtype>\w+)')?\)\)")
    
    for match in pattern.finditer(input_str):
        rel = match.group('rel')
        obj_type = match.group('obj_type')
        obj_value = match.group('obj_value')
        obj_dtype = match.group('obj_dtype')

        if obj_type == 'LegalDocument':
            obj = LegalDocument(obj_value)
        elif obj_type == 'Literal':
            obj = Literal(obj_value, obj_dtype)
        else:
            continue
        
        triples.append(Triple(Rel(rel), obj))
    
    return Extract(triples)

extract = parse_input_string(input_str_2)

result = []

for triple in extract.triples:
    if isinstance(triple.obj, LegalDocument):
        result.append({'Rel': triple.rel.name, 'LegalDocument': (triple.obj.name,)})
    elif isinstance(triple.obj, Person):
        result.append({'Rel': triple.rel.name, 'Person': (triple.obj.name,)})
    elif isinstance(triple.obj, City):
        result.append({'Rel': triple.rel.name, 'City': (triple.obj.name,)})
    elif isinstance(triple.obj, Position):
        result.append({'Rel': triple.rel.name, 'Position': (triple.obj.name,)})
    elif isinstance(triple.obj, Literal):
        result.append({'Rel': triple.rel.name, 'Literal': (triple.obj.value, triple.obj.dtype)})
    elif isinstance(triple.obj, Date):
        result.append({'Rel': triple.rel.name, 'Date': (triple.obj.value, "date")})


for item in result:
    print(item)

# %%
legal_document_mapping = {
    "Undang-Undang Nomor 16 Tahun 1950": "UU_1950_16",
    "Undang-Undang Nomor 17 Tahun 2003": "UU_2003_17",
    "Undang-Undang Nomor 1 Tahun 2004": "UU_2004_1",
    "Undang-Undang Nomor 5 Tahun 2014": "UU_2014_5",
    "Undang-Undang Nomor 23 Tahun 2014": "UU_2014_23",
    "Undang-Undang Nomor 30 Tahun 2014": "UU_2014_30",
    "Peraturan Pemerintah Nomor 56 Tahun 2005": "PP_2005_56",
    "Peraturan Pemerintah Nomor 58 Tahun 2005": "PP_2005_58",
    "Peraturan Pemerintah Nomor 41 Tahun 2009": "PP_2009_41",
    "Peraturan Pemerintah Nomor 53 Tahun 2010": "PP_2010_53",
    "Peraturan Pemerintah Nomor 69 Tahun 2010": "PP_2010_69",
    "Peraturan Pemerintah Nomor 46 Tahun 2011": "PP_2011_46",
    "Peraturan Pemerintah Nomor 18 Tahun 2016": "PP_2016_18",
    "Peraturan Pemerintah Nomor 11 Tahun 2017": "PP_2017_11",
    "Peraturan Pemerintah Nomor 12 Tahun 2017": "PP_2017_12",
    "Peraturan Presiden Nomor 52 Tahun 2009": "Perpres_2009_52",
    "Peraturan Menteri Dalam Negeri Nomor 13 Tahun 2006": "Permen_Dagri_2006_13",
    "Peraturan Kepala Badan Kepegawaian Negara Nomor 1 Tahun 2013": "Peraturan_BKN_2013_1",
    "Peraturan Kepala Badan Kepegawaian Negara Nomor 24 Tahun 2017": "Peraturan_BKN_2017_24",
    "Peraturan Daerah Kota Cirebon Nomor 12 Tahun 2015": "Perkot_Cirebon_2015_12",
    "Peraturan Daerah Kota Cirebon Nomor 6 Tahun 2016": "Perkot_Cirebon_2016_6",
    "Peraturan Daerah Kota Cirebon Nomor 7 Tahun 2016": "Perkot_Cirebon_2016_7",
    "Peraturan Daerah Kota Cirebon Nomor 9 Tahun 2016": "Perkot_Cirebon_2016_9",
    "Peraturan Wali Kota Cirebon Nomor 66 Tahun 2016": "Perwali_Cirebon_2016_66",
    "Peraturan Wali Kota Cirebon Nomor 12 Tahun 2018": "Perwali_Cirebon_2018_12",
}

triples = [
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Undang-Undang Nomor 16 Tahun 1950',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Undang-Undang Nomor 17 Tahun 2003',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Undang-Undang Nomor 1 Tahun 2004',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Undang-Undang Nomor 5 Tahun 2014',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Undang-Undang Nomor 23 Tahun 2014',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Undang-Undang Nomor 30 Tahun 2014',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 56 Tahun 2005',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 58 Tahun 2005',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 41 Tahun 2009',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 53 Tahun 2010',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 69 Tahun 2010',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 46 Tahun 2011',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 18 Tahun 2016',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 11 Tahun 2017',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 12 Tahun 2017',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Presiden Nomor 52 Tahun 2009',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Menteri Dalam Negeri Nomor 13 Tahun 2006',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Kepala Badan Kepegawaian Negara Nomor 1 Tahun 2013',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Kepala Badan Kepegawaian Negara Nomor 24 Tahun 2017',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Daerah Kota Cirebon Nomor 12 Tahun 2015',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Daerah Kota Cirebon Nomor 6 Tahun 2016',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Daerah Kota Cirebon Nomor 7 Tahun 2016',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Daerah Kota Cirebon Nomor 9 Tahun 2016',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Wali Kota Cirebon Nomor 66 Tahun 2016',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Wali Kota Cirebon Nomor 12 Tahun 2018',)},
    {'Rel': 'considers', 'Literal': (' bahwa   Pegawai   Negeri   Sipil   di    Lingkungan Pemerintah Daerah Kota  Cirebon, diberikan tambahan penghasilan pegawai berdasarkan prestasi kerja secara objektif, transparan, dan akuntabel', 'string')}
    {'Rel': 'considers', 'Literal': ('bahwa berdasarkan pertimbangan sebagaimana sebagaimana dimaksud dalam huruf a, perlu menetapkan Peraturan Wali Kota Cirebon tentang Pedoman Pemberian Tambahan Penghasilan Pegawai bagi Pegawai Negeri Sipil di Lingkungan Pemerintah Daerah Kota Cirebon', 'string')}
    {'Rel': 'hasDictum', 'Literal': ('Menetapkan : PERATURAN WALI KOTA CIREBON TENTANG PEDOMAN PEMBERIAN TAMBAHAN PENGHASILAN PEGAWAI BAGI PEGAWAI NEGERI DI LINGKUNGAN PEMERINTAH DAERAH KOTA CIREBON.', 'string')}
    {'Rel': 'regulationNumber', 'Literal': ('7', 'string')}
    {'Rel': 'regulationYear', 'Literal': ('2019', 'int')}
]

rdf_triples = []

current_regulation = "Perwali_Cirebon_2019_7"

def add_rdf_triple(subject, predicate, obj):
    rdf_triples.append(f"{subject} {predicate} {obj} .")

for triple in triples:
    rel = triple['Rel']
    legal_doc = triple['LegalDocument'][0]
    short_code = legal_document_mapping.get(legal_doc, None)
    
    if short_code:
        if rel == 'hasLegalBasis':
            add_rdf_triple(f"lexid:{current_regulation}", "lexid-s:hasLegalBasis", f"lexid:{short_code}")
            add_rdf_triple(f"lexid:{short_code}", "rdf:type", "lexid-s:LegalDocument")
            add_rdf_triple(f"lexid:{short_code}", "rdfs:label", f'"{legal_doc}"^^xsd:string')

add_rdf_triple(f"lexid:{current_regulation}", "rdf:type", "lexid-s:LegalDocument")
add_rdf_triple(f"lexid:{current_regulation}", "rdfs:label", '"Peraturan Walikota Cirebon Nomor 7 Tahun 2019"^^xsd:string')

for triple in rdf_triples:
    print(triple)

# %%
from rapidfuzz import process

# ref: https://medium.com/@kasperjuunge/rapidfuzz-explained-c26e93b6012d

replacements = {
    "Peraturan Daerah Provinsi": "Perprov",
    "Peraturan Wali Kota": "Perwali",
    "Peraturan Bupati": "Perbup",
    "Peraturan Kabupaten": "Perkab",
    "Peraturan Kota": "Perkot",
    
    "Peraturan Menteri Koordinator Bidang": "Permenko",
    
    "Keputusan Menteri": "Kepmen",
    "Peraturan Menteri": "Permen",
    "Peraturan Bersama": "PB",
    
    "Peraturan Presiden": "Perpres",
    "Peraturan Daerah": "Perda",
    "Peraturan Pemerintah": "PP",
    "Undang-Undang Dasar": "UUD",
    "Undang-Undang": "UU",
    "Ketetapan Presiden": "Tapres",
    "Keputusan Presiden": "Keppres",
        
    # permenko
    "Politik, Hukum, Dan Keamanan": "Polhukam",
    "Perekonomian": "Perekonomian",
    "Kesejahteraan Rakyat": "Kesra",
    "Kemaritiman": "Maritim",
    "Pembangunan Manusia Dan Kebudayaan": "PMK",
    

    "Menteri": "Men",
    "Ketua": "",
    "Kepala": "",
    "Kota": "",
    "Kabupaten": "",
    
    # kepmen, permen, pb
    "Agama": "Agama",
    "Kelautan Dan Perikanan": "KP",
    "Kehutanan": "Hut",
    "Lingkungan Hidup Dan Kehutanan": "LHK",
    "Badan Usaha Milik Negara": "BUMN",
    "Perencanaan Pembangunan Nasional/ Kepala Badan Perencanaan Pembangunan Nasional": "Bappenas",
    "Perhubungan": "Hub",
    "Pendayagunaan Aparatur Negara Dan Reformasi Birokrasi": "PANRB",
    "Pertanian": "Tan",
    "Energi Dan Sumber Daya Mineral": "ESDM",
    "Riset, Teknologi, Dan Pendidikan Tinggi": "Ristekdikti",
    "Riset Dan Teknologi": "Ristek",
    "Pemuda Dan Olahraga": "Pora",
    "Keuangan": "Keu",
    "Pariwisata": "Par",
    "Pertahanan": "Han",
    "Kebudayaan Dan Pariwisata": "Budpar",
    "Desa, Pembangunan Daerah Tertinggal, Dan Transmigrasi": "Desa",
    "Perdagangan": "Dag",
    "Riset Teknologi Dan Pendidikan Tinggi": "Ristekdikti",
    "Agraria Dan Tata Ruang/ Kepala Badan Pertanahan Nasional": "ATRBPN",
    "Pekerjaan Umum Dan Perumahan Rakyat": "PUPR",
    "Pekerjaan Umum": "PU",
    "Pendidikan Dan Kebudayaan": "Dikbud",
    "Kesehatan": "Kes",
    "Perindustrian": "Perin",
    "Tenaga Kerja Dan Transmigrasi": "Nakertrans",
    "Pariwisata Dan Ekonomi Kreatif": "Parekraf",
    "Pembangunan Daerah Tertinggal": "PDT",
    "Hukum Dan Hak Asasi Manusia": "Humham",
    "Perumahan Rakyat": "PR",
    "Pendidikan Nasional": "Dik",
    "Dalam Negeri": "Dagri",
    "Komunikasi Dan Informatika": "Kominfo",
    "Sosial": "Sos",
    "Koperasi Dan Usaha Kecil Dan Menengah": "Kopukm",
    "Pemberdayaan Perempuan Dan Perlindungan Anak": "PPPA",
    "Lingkungan Hidup": "LH",
    "Luar Negeri": "LU",
    "Sekretaris Negara": "Sesneg",
    "Ketenagakerjaan": "Naker",
    "Badan Pengawas Perdagangan Berjangka Komoditi": "Bappebti",
    "Badan Pusat Statistik": "BPS",
    "Lembaga Kebijakan Pengadaan Barang/jasa Pemerintah": "LKPP",
    "Perpustakaan Nasional": "Perpusnas",
    "Badan Tenaga Nuklir Nasional": "Batan",
    "Komisi Nasional Hak Asasi Manusia": "Komnas_HAM",
    "Badan Narkotika Nasional": "BNN",
    "Badan Pengawas Tenaga Nuklir": "Bapeten",
    "Komisi Pengawas Persaingan Usaha": "KPPU",
    "Komisi Informasi": "KI",
    "Badan Nasional Penanggulangan Bencana": "BNPB",
    "Pusat Pelaporan Dan Analisis Transaksi Keuangan": "PPATK",
    "Lembaga Ilmu Pengetahuan Indonesia": "LIPI",
    "Komisi Pemilihan Umum": "KPU",
    "Badan Pengatur Hilir Minyak Dan Gas Bumi": "BPH_Migas",
    "Badan Pengelola Keuangan Haji": "BPKH",
    "Badan Standardisasi Nasional": "BSN",
    "Badan Meteorologi, Klimatologi, Dan Geofisika": "BMKG",
    "Badan Nasional Penanggulangan Terorisme": "BNPT",
    "Arsip Nasional": "ANRI",
    "Lembaga Administrasi Negara": "LAN",
    "Sekretaris Jenderal Ombudsman": "Ombudsman",
    "Lembaga Perlindungan Saksi Dan Korban": "LPSK",
    "Badan Wakaf Indonesia": "BWI",
    "Dewan Perwakilan Daerah": "DPD",
    "Lembaga Penjamin Simpanan": "LPS",
    "Badan Pengkajian Dan Penerapan Teknologi": "BPPT",
    "Badan Siber Dan Sandi Negara": "BSSN",
    "Jaksa Agung": "Jagung",
    "Badan Kependudukan Dan Keluarga Berencana Nasional": "BKKBN",
    "Dewan Perwakilan Rakyat": "DPR",
    "Badan Nasional Penempatan Dan Perlindungan Tenaga Kerja Indonesia": "BNP2TKI",
    "Badan Pengawas Obat Dan Makanan": "BPOM",
    "Badan Pengawas Pemilihan Umum": "Bawaslu",
    "Komisi Aparatur Sipil Negara": "KASN",
    "Badan Nasional Pencarian Dan Pertolongan": "Basarnas",
    "Badan Kepegawaian Negara": "BKN",
    "Dewan Jaminan Sosial Nasional": "DJSN",
    "Badan Nasional Pengelola Perbatasan": "BNPP",
    "Badan Keamanan Laut": "Bakamla",
    "Badan Ekonomi Kreatif": "Bekraf",
    "Badan Pengawasan Keuangan Dan Pembangunan": "BPKP",
    "Kepolisian Negara": "Polri",
    "Komisi Pemberantasan Korupsi": "KPK",
    "Mahkamah Agung": "MA",
    "Badan Informasi Geospasial": "BIG",
    "Konsil Kedokteran Indonesia": "KKI",
    "Dewan Kawasan Perdagangan Bebas Dan Pelabuhan Bebas Batam": "PBBATAM",
    "Lembaga Penerbangan Dan Antariksa Nasional": "Lapan",
    "Sekretaris Kabinet": "Setkab",
    "Badan Koordinasi Penanaman Modal": "BKPM",
    "Otoritas Jasa Keuangan": "OJK",
    "Badan Amil Zakat Nasional": "Baznas",
    "Badan Pembinaan Ideologi Pancasila": "BPIP",
    "Badan Penyelenggara Jaminan Sosial Kesehatan Reppublik Indonesia": "BPJSKES",
    "Kepala Badan Pertanahan Nasional": "BPN",
    "Bank Indonesia": "BI",
    "Badan Pemeriksa Keuangan": "BPK",
    "Komisi Yudisial": "KY",
    "Dewan Kehormatan Penyelenggara Pemilihan Umum": "DKPP",
    "Badan Penyelenggara Jaminan Sosial Ketenagakerjaan": "BPJSTK",
    
    # provinsi
    "Jawa Timur": "Jatim",
    "Jawa Tengah": "Jateng",
    "Irian Jaya Barat": "Irba",
    "Jawa Barat": "Jabar",
    "Nusa Tenggara Timur": "NTT",
    "Sulawesi Utara": "Sulut",
    "Daerah Istimewa Yogyakarta": "Yogya",
    "Kalimantan Barat": "Kalbar",
    "Sulawesi Barat": "Sulbar",
    "Daerah Khusus Ibukota Jakarta": "DKI_Jakarta",
    "Kalimantan Tengah": "Kalteng",
    "Kepulauan Riau": "Kep_Riau",
    "Kalimantan Timur": "Kaltim",
    "Sumatera Selatan": "Sumsel",
    "Sumatera Barat": "Sumbar",
    "Sulawesi Tengah": "Sulteng",
    "Kalimantan Selatan": "Kalsel",
    "Nusa Tenggara Barat": "NTB",
    "Sumatera Utara": "Sumut",
    "Sulawesi Selatan": "Sulsel",
    "Kepulauan Bangka Belitung": "Kep_Babel"
}

def replace_similar(name, replacements, threshold=80):
    for pattern, replacement in replacements.items():
        name = name.replace('Republik Indonesia', '')
        match = process.extractOne(name, [pattern], score_cutoff=threshold)
        if match:
            name = name.replace(match[0], replacement)
    return name

name = "Peraturan Menteri Koordinator Bidang Kemaritiman Republik Indonesia"
updated_name = replace_similar(name, replacements)
print(updated_name)
# Out:
# Permenko Maritim

# %%
import re

def extract_no_year(string):
    string = string.replace('Nomor ', '')
    string = string.replace('Tahun ', '')
    lst = string.split(' ')
    lst = lst[::-1]
    return " ".join(lst)

legal_document_mapping = {
    "Undang-Undang Nomor 16 Tahun 1950": "UU_1950_16",
    "Undang-Undang Nomor 17 Tahun 2003": "UU_2003_17",
    "Undang-Undang Nomor 1 Tahun 2004": "UU_2004_1",
    "Undang-Undang Nomor 5 Tahun 2014": "UU_2014_5",
    "Undang-Undang Nomor 23 Tahun 2014": "UU_2014_23",
    "Undang-Undang Nomor 30 Tahun 2014": "UU_2014_30",
    "Peraturan Pemerintah Nomor 56 Tahun 2005": "PP_2005_56",
    "Peraturan Pemerintah Nomor 58 Tahun 2005": "PP_2005_58",
    "Peraturan Pemerintah Nomor 41 Tahun 2009": "PP_2009_41",
    "Peraturan Pemerintah Nomor 53 Tahun 2010": "PP_2010_53",
    "Peraturan Pemerintah Nomor 69 Tahun 2010": "PP_2010_69",
    "Peraturan Pemerintah Nomor 46 Tahun 2011": "PP_2011_46",
    "Peraturan Pemerintah Nomor 18 Tahun 2016": "PP_2016_18",
    "Peraturan Pemerintah Nomor 11 Tahun 2017": "PP_2017_11",
    "Peraturan Pemerintah Nomor 12 Tahun 2017": "PP_2017_12",
    "Peraturan Presiden Nomor 52 Tahun 2009": "Perpres_2009_52",
    "Peraturan Menteri Dalam Negeri Nomor 13 Tahun 2006": "Permen_Dagri_2006_13",
    "Peraturan Kepala Badan Kepegawaian Negara Nomor 1 Tahun 2013": "Peraturan_BKN_2013_1",
    "Peraturan Kepala Badan Kepegawaian Negara Nomor 24 Tahun 2017": "Peraturan_BKN_2017_24",
    "Peraturan Daerah Kota Cirebon Nomor 12 Tahun 2015": "Perkot_Cirebon_2015_12",
    "Peraturan Daerah Kota Cirebon Nomor 6 Tahun 2016": "Perkot_Cirebon_2016_6",
    "Peraturan Daerah Kota Cirebon Nomor 7 Tahun 2016": "Perkot_Cirebon_2016_7",
    "Peraturan Daerah Kota Cirebon Nomor 9 Tahun 2016": "Perkot_Cirebon_2016_9",
    "Peraturan Wali Kota Cirebon Nomor 66 Tahun 2016": "Perwali_Cirebon_2016_66",
    "Peraturan Wali Kota Cirebon Nomor 12 Tahun 2018": "Perwali_Cirebon_2018_12",
}

triples = [
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Undang-Undang Nomor 16 Tahun 1950',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Undang-Undang Nomor 17 Tahun 2003',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Undang-Undang Nomor 1 Tahun 2004',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Undang-Undang Nomor 5 Tahun 2014',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Undang-Undang Nomor 23 Tahun 2014',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Undang-Undang Nomor 30 Tahun 2014',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 56 Tahun 2005',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 58 Tahun 2005',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 41 Tahun 2009',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 53 Tahun 2010',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 69 Tahun 2010',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 46 Tahun 2011',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 18 Tahun 2016',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 11 Tahun 2017',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Pemerintah Nomor 12 Tahun 2017',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Presiden Nomor 52 Tahun 2009',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Menteri Dalam Negeri Nomor 13 Tahun 2006',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Kepala Badan Kepegawaian Negara Nomor 1 Tahun 2013',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Kepala Badan Kepegawaian Negara Nomor 24 Tahun 2017',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Daerah Kota Cirebon Nomor 12 Tahun 2015',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Daerah Kota Cirebon Nomor 6 Tahun 2016',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Daerah Kota Cirebon Nomor 7 Tahun 2016',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Daerah Kota Cirebon Nomor 9 Tahun 2016',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Wali Kota Cirebon Nomor 66 Tahun 2016',)},
    {'Rel': 'hasLegalBasis', 'LegalDocument': ('Peraturan Wali Kota Cirebon Nomor 12 Tahun 2018',)}
]

rdf_triples = []

current_regulation = "Perwali_Cirebon_2019_7"

def add_rdf_triple(subject, predicate, obj):
    rdf_triples.append(f"{subject} {predicate} {obj} .")

for triple in triples:
    rel = triple['Rel']
    ent = list(triple.keys())[1]
    ent_obj = list(triple.values())[1]
    
    if rel == 'hasLegalBasis':
        legal_doc = ent_obj[0]
        ents = legal_doc.split(' ')
        ent = replace_similar(" ".join(ents[:len(ents)-4]), replacements)
        num_year = extract_no_year(" ".join(ents[len(ents)-4:]))
#         short_code = f"{ent} {num_year}".replace(" ", "_")
        short_code = re.sub(r'\s+', '_', f"{ent} {num_year}")
        add_rdf_triple(f"lexid:{current_regulation}", "lexid-s:hasLegalBasis", f"lexid:{short_code}")
        add_rdf_triple(f"lexid:{short_code}", "rdf:type", "lexid-s:LegalDocument")
        add_rdf_triple(f"lexid:{short_code}", "rdfs:label", f'"{legal_doc}"^^xsd:string')

add_rdf_triple(f"lexid:{current_regulation}", "rdf:type", "lexid-s:LegalDocument")
add_rdf_triple(f"lexid:{current_regulation}", "rdfs:label", '"Peraturan Walikota Cirebon Nomor 7 Tahun 2019"^^xsd:string')

for triple in rdf_triples:
    print(triple)
# Out:
# lexid:Perwali_Cirebon_2019_7 lexid-s:hasLegalBasis lexid:UU_1950_16 .
# lexid:UU_1950_16 rdf:type lexid-s:LegalDocument .
# lexid:UU_1950_16 rdfs:label "Undang-Undang Nomor 16 Tahun 1950"^^xsd:string .
# lexid:Perwali_Cirebon_2019_7 lexid-s:hasLegalBasis lexid:UU_2003_17 .
# lexid:UU_2003_17 rdf:type lexid-s:LegalDocument .
# lexid:UU_2003_17 rdfs:label "Undang-Undang Nomor 17 Tahun 2003"^^xsd:string .
# lexid:Perwali_Cirebon_2019_7 lexid-s:hasLegalBasis lexid:UU_2004_1 .
# lexid:UU_2004_1 rdf:type lexid-s:LegalDocument .
# lexid:UU_2004_1 rdfs:label "Undang-Undang Nomor 1 Tahun 2004"^^xsd:string .
# lexid:Perwali_Cirebon_2019_7 lexid-s:hasLegalBasis lexid:UU_2014_5 .
# lexid:UU_2014_5 rdf:type lexid-s:LegalDocument .
# lexid:UU_2014_5 rdfs:label "Undang-Undang Nomor 5 Tahun 2014"^^xsd:string .
# lexid:Perwali_Cirebon_2019_7 lexid-s:hasLegalBasis lexid:UU_2014_23 .
# lexid:UU_2014_23 rdf:type lexid-s:LegalDocument .
# ...
