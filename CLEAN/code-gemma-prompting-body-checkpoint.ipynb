# %%
import os
import re

# %%
def list_files_in_directory(directory):
    files_list = []

    for entry in os.listdir(directory):
        full_path = os.path.join(directory, entry)

        if os.path.isfile(full_path):
            files_list.append(entry)

    return files_list

def extract_number(filename):
    match = re.search(r'-?\d+', filename)
    return int(match.group()) if match else None

def find_reg_outlines(files, directory):
    numbered_files = [(extract_number(file), file) for file in files if (extract_number(file)) != None]
    
    opening_file_tuple = min(numbered_files, key=lambda x: x[0])
    closing_file_tuple = max(numbered_files, key=lambda x: x[0])
    
    numbered_files.remove(opening_file_tuple)
    opening_file_1_tuple = min(numbered_files, key=lambda x: x[0])
    
    numbered_files.remove(opening_file_1_tuple)
    opening_file_2_tuple = min(numbered_files, key=lambda x: x[0])
    
    opening_file = opening_file_tuple[1]
    opening_file_1 = opening_file_1_tuple[1]
    opening_file_2 = opening_file_2_tuple[1]
    closing_file = closing_file_tuple[1]
    
    dct = {}
    dct['opening'] = os.path.join(directory, opening_file)
    dct['opening_1'] = os.path.join(directory, opening_file_1)
    dct['opening_2'] = os.path.join(directory, opening_file_2)
    dct['closing'] = os.path.join(directory, closing_file)
    dct['body_outline'] = os.path.join(directory, '_.txt')
        
    return dct

# %% [markdown]
# ## Teks

# %%
# ln/2019/pp4-2019bt      -->  PP_2019_4
# bn/2019/bn1047-2019     -->  Permen_Agama_2019_18
# perda/2019/perwal72019  -->  Perwali_Cirebon_2019_7

# %%
d = './dataset-final/new_split_txt/ln/2019/pp4-2019bt'
l = list_files_in_directory(d)
dct = find_reg_outlines(l, d)

with open(dct['body_outline'], "r", encoding="utf8") as file:
    lines = file.read()
    
print(lines)
# Out:
# BAB I
# KETENTUAN UMUM
#
# Pasal 1
# BAB II
# KEDUDUKAN, TUGAS, DAN FUNGSI
#
# Pasal 2
# Pasal 3
# BAB III
# ORGANISASI DAN KEANGGOTAAN
#
# Bagian Kesatu
# Keanggotaan
#
# Pasal 4
# Pasal 5
# Pasal 6
# Pasal 7
# Bagian Kedua
# Sekretariat
#
# Pasal 8
# BAB IV
# PENGANGKATAN DAN PEMBERHENTIAN ANGGOTA BPKN
#
# Pasal 9
# Pasal 10
# Pasal 11
# Pasal 12
# Pasal 13
# Pasal 14
# BAB V
# PENDANAAN
#
# Pasal 15
# Pasal 16
# BAB VI
# KETENTUAN PENUTUP
#
# Pasal 17
# Pasal 18

# %% [markdown]
# ## Turtle

# %%
import time

from rdflib import Graph

def extract_turtle(regulatory_id, directory):
    
    turtle_file_path = directory.replace('new_split_txt', 'new_5_turtle_files')
    turtle_file_path = turtle_file_path + '.ttl'
    
    try:
        g = Graph()
        g.parse(turtle_file_path, format='ttl')

        query = f"""
        prefix xsd: <http://www.w3.org/2001/XMLSchema#>
        prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        prefix dbo: <http://dbpedia.org/ontology/>
        prefix dct: <http://purl.org/dc/terms/>
        prefix owl: <http://www.w3.org/2002/07/owl#>
        prefix wd: <https://www.wikidata.org/wiki/>
        prefix lexid-s: <https://w3id.org/lex-id/schema/>
        prefix lexid: <https://w3id.org/lex-id/data/>

        construct {{
            # ?z ?p ?o .
            # ?o ?p1 ?o2 .
        }}
        where {{
            {{
                select distinct ?z ?p ?o
                where {{
                    lexid:{regulatory_id} (
                        dct:description 
                        | lexid-s:name  
                        | rdfs:label 
                        | rdf:type
                        | lexid-s:hasContent 
                        | lexid-s:isContentOf 
                        | lexid-s:hasPart 
                        | lexid-s:isPartOf
                    )* ?z .
                    # ?z ?p ?o .
                    FILTER (?p NOT IN (rdf:type
                                        , owl:sameAs
                                        , lexid-s:adds
                                        , lexid-s:hasAdditionContent
                                        , lexid-s:hasAdditionTarget
                                        , lexid-s:deletes
                                        , lexid-s:modifies
                                        , lexid-s:hasModificationContent
                                        , lexid-s:hasModificationTarget
                                        , lexid-s:hasAct
                                        , lexid-s:hasActType
                                        , lexid-s:hasElement
                                        , lexid-s:hasCondition
                                        , lexid-s:hasModality
                                        , lexid-s:hasObject
                                        , lexid-s:hasQualifier
                                        , lexid-s:hasQualifierType
                                        , lexid-s:hasQualifierValue
                                        , lexid-s:hasRule
                                        , lexid-s:hasSubject
                                        , lexid-s:isRuleOf
                                        , lexid-s:refersTo
                                        , lexid-s:amendedBy
                                        , lexid-s:amends
                                        , lexid-s:implementedBy
                                        , lexid-s:implements
                                        , lexid-s:repealedBy
                                        , lexid-s:repeals
                                        , lexid-s:undefined
                                        , lexid-s:hasEnactionDate 
                                        , lexid-s:hasEnactionLocation 
                                        , lexid-s:hasEnactionOffice 
                                        , lexid-s:hasEnactionOfficial 
                                        , lexid-s:hasPromulgationDate 
                                        , lexid-s:hasPromulgationLocation 
                                        , lexid-s:hasPromulgationOffice 
                                        , lexid-s:hasPromulgationOfficial 
                                        , lexid-s:hasPromulgationPlace 
                                        , lexid-s:hasCreator 
                                        , lexid-s:hasDictum 
                                        , lexid-s:hasCreator 
                                        , lexid-s:regulationNumber 
                                        , lexid-s:regulationYear
                                        , lexid-s:considers 
                                        , lexid-s:hasLegalBasis 
                                        , lexid-s:LegalBasisOf 
                                        ))
                }}
            }}
            OPTIONAL {{
                # ?o ?p1 ?o2 .
                FILTER (?p1 IN (rdf:type) && ?o2 NOT IN (owl:Thing
                                                        , lexid-s:LawAmandment
                                                        , lexid-s:Act
                                                        , lexid-s:AgencyRegulation
                                                        , lexid-s:AmendmentToTheConstitution
                                                        , lexid-s:CityOrdinance
                                                        , lexid-s:Constitution
                                                        , lexid-s:GovernmentRegulation
                                                        , lexid-s:GovernmentRegulationInLieuOfAct
                                                        , lexid-s:GovernorRegulation
                                                        , lexid-s:JointRegulation
                                                        , lexid-s:MayorRegulation
                                                        , lexid-s:MinisterialDecree
                                                        , lexid-s:MinisterialRegulation
                                                        , lexid-s:PeoplesConsultativeAssemblyResolution
                                                        , lexid-s:PresidentialDecree
                                                        , lexid-s:PresidentialRegulation
                                                        , lexid-s:ProvincialOrdinance
                                                        , lexid-s:RegencyOrdinance
                                                        , lexid-s:RegentRegulation
                                                        , lexid-s:LegalDocument
                                                        , lexid-s:LegalDocumentContent
                                                        , lexid-s:RuleExpression))
            }}
        }}
        """

        results = g.query(query)

        for result in results:
            subject = result[0].n3(g.namespace_manager)
            predicate = result[1].n3(g.namespace_manager)
            obj = result[2].n3(g.namespace_manager)
            res = F"{subject} {predicate} {obj} .\n"
            print(res)
        
    except Exception as e:
        print(e)

# %%
extract_turtle('PP_2019_4', d)
# Out:
# lexid:PP_2019_4_Section_14_3 lexid-s:name "(3)"^^xsd:string .
#
# lexid:PP_2019_4_Section_9_1 lexid-s:isPartOf lexid:PP_2019_4_Article_9 .
#
# lexid:PP_2019_4_Section_3_2_Letter_B rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_8_3 dct:description """Fungsi, tugas, dan tata kerja sekretariat sebagaimana
# dimaksud pada ayat (1) diatur dalam keputusan Ketua
# BPKN."""^^xsd:string .
#
# lexid:PP_2019_4_Chapter_II lexid-s:hasPart lexid:PP_2019_4_Article_3 .
#
# lexid:PP_2019_4_Section_8_3 lexid-s:name "(3)"^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_D dct:description "tidak pernah dihukum karena kejahatan."^^xsd:string .
#
# lexid:PP_2019_4_Article_6 lexid-s:isPartOf lexid:PP_2019_4_Part_III_KESATU .
#
# lexid:PP_2019_4_Section_4_1_Letter_A lexid-s:isPartOf lexid:PP_2019_4_Section_4_1 .
#
# lexid:PP_2019_4_Article_1_Number_0 dct:description "Dalam Peraturan Pemerintah ini yang dimaksud dengan V1, V2, V3, V4, V5, dan V6"^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_F rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_5_2 lexid-s:isPartOf lexid:PP_2019_4_Article_5 .
#
# lexid:PP_2019_4_Article_1_Number_2 rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Chapter_II lexid-s:hasPart lexid:PP_2019_4_Article_2 .
#
# lexid:PP_2019_4_Section_12_2_Letter_B rdfs:label "Huruf B"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_IV lexid-s:name "PENGANGKATAN DAN PEMBERHENTIAN ANGGOTA BPKN"^^xsd:string .
#
# lexid:PP_2019_4_Article_9 rdfs:label "Pasal 9 : Pasal 9"^^xsd:string .
#
# lexid:PP_2019_4_Article_17_Letter_C rdfs:label "PP 2019 4 Article 17 Letter C"^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1 dct:description """Anggota BPKN sebagaimana dimaksud dalam Pasal 4
# terdiri dari unsur:
# a. pemerintah;
# b. Pelaku Usaha;
# c. LPKSM;
# d. akademisi; dan
# e. tenaga ahli."""^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_2 rdfs:label "PP 2019 4 Article 1 Number 2"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_D rdfs:label "PP 2019 4 Section 3 2 Letter D"^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_5 rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_13_Letter_B rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_4_1 lexid-s:hasPart lexid:PP_2019_4_Section_4_1_Letter_C .
#
# lexid:PP_2019_4_Section_3_1 lexid-s:name "(1)"^^xsd:string .
#
# lexid:PP_2019_4_Section_10_4 lexid-s:name "(4)"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_1_Letter_B lexid-s:isPartOf lexid:PP_2019_4_Section_12_1 .
#
# lexid:PP_2019_4_Article_12 rdfs:label "Pasal 12 : Pasal 12"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_A rdfs:label "Huruf A"^^xsd:string .
#
# lexid:PP_2019_4_Article_11 lexid-s:hasPart lexid:PP_2019_4_Article_11_Letter_C .
#
# lexid:PP_2019_4_Section_3_2_Letter_D dct:description "mendorong berkembangnya LPKSM."^^xsd:string .
#
# lexid:PP_2019_4_Article_6 dct:description """Untuk dapat menjadi anggota BPKN harus memenuhi
# persyaratan:
# a. warga negara Republik Indonesia;
# b. berbadan sehat;
# c. berkelakuan baik;
# d. tidak pernah dihukum karena kejahatan;
# e. memiliki pengetahuan dan pengalaman di bidang
# Perlindungan Konsumen; dan
# f. berusia sekurang-kurangnya 30 (tiga puluh) tahun."""^^xsd:string .
#
# lexid:PP_2019_4_Part_III_KESATU lexid-s:name "Keanggotaan"^^xsd:string .
#
# lexid:PP_2019_4_Article_1 lexid-s:hasPart lexid:PP_2019_4_Article_1_Number_4 .
#
# lexid:PP_2019_4_Article_13_Letter_C rdfs:label "PP 2019 4 Article 13 Letter C"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_II rdf:type lexid-s:Chapter .
#
# lexid:PP_2019_4_Article_11 lexid-s:hasPart lexid:PP_2019_4_Article_11_Letter_B .
#
# lexid:PP_2019_4_Section_3_2_Letter_G rdfs:label "Huruf G"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_1_Letter_B rdfs:label "Huruf B"^^xsd:string .
#
# lexid:PP_2019_4_Section_4_1_Letter_A rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_4_3 lexid-s:name "(3)"^^xsd:string .
#
# lexid:PP_2019_4_Section_5_2 dct:description """Jumlah wakil setiap unsur yang menjadi anggota BPKN
# harus memperhatikan keseimbangan setiap unsur."""^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1_Letter_B rdfs:label "Huruf B"^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_1 rdfs:label "PP 2019 4 Article 1 Number 1"^^xsd:string .
#
# lexid:PP_2019_4_Article_11_Letter_C rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_3 lexid-s:hasPart lexid:PP_2019_4_Section_3_3 .
#
# lexid:PP_2019_4_Section_3_3 dct:description """Dalam melaksanakan tugas sebagaimana dimaksud
# pada ayat (2) BPKN dapat bekerja sama dengan
# organisasi Konsumen internasional."""^^xsd:string .
#
# lexid:PP_2019_4_Article_17_Letter_A rdfs:label "Huruf A"^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1_Letter_B rdfs:label "PP 2019 4 Section 5 1 Letter B"^^xsd:string .
#
# lexid:PP_2019_4_Article_1 lexid-s:isPartOf lexid:PP_2019_4_Chapter_I .
#
# lexid:PP_2019_4_Section_5_1 rdfs:label "ayat 1 : (1)"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_1_Letter_F dct:description "diberhentikan."^^xsd:string .
#
# lexid:PP_2019_4_Section_2_2 dct:description "BPKN merupakan lembaga nonstruktural."^^xsd:string .
#
# lexid:PP_2019_4_Article_14 lexid-s:hasPart lexid:PP_2019_4_Section_14_1 .
#
# lexid:PP_2019_4_Article_17_Letter_C rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_3_2 lexid-s:isPartOf lexid:PP_2019_4_Article_3 .
#
# lexid:PP_2019_4_Article_4 lexid-s:name "Pasal 4"^^xsd:string .
#
# lexid:PP_2019_4_Article_11_Letter_B lexid-s:isPartOf lexid:PP_2019_4_Article_11 .
#
# lexid:PP_2019_4_Article_1_Number_2 lexid-s:isPartOf lexid:PP_2019_4_Article_1 .
#
# lexid:PP_2019_4_Article_1_Number_3 rdfs:label "PP 2019 4 Article 1 Number 3"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_G rdfs:label "PP 2019 4 Section 3 2 Letter G"^^xsd:string .
#
# lexid:PP_2019_4_Article_13_Letter_A dct:description "Menteri mengajukan usul anggota BPKN yang akan diberhentikan kepada Presiden."^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1_Letter_B dct:description "Pelaku Usaha."^^xsd:string .
#
# lexid:PP_2019_4_Part_III_KESATU lexid-s:hasPart lexid:PP_2019_4_Article_4 .
#
# lexid:PP_2019_4_Section_5_1_Letter_C lexid-s:isPartOf lexid:PP_2019_4_Section_5_1 .
#
# lexid:PP_2019_4_Article_1_Number_0 rdfs:label "Angka 0"^^xsd:string .
#
# lexid:PP_2019_4_Article_15 lexid-s:name "Pasal 15"^^xsd:string .
#
# lexid:PP_2019_4_Section_2_2 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Chapter_IV lexid-s:isContentOf lexid:PP_2019_4 .
#
# lexid:PP_2019_4_Article_8 lexid-s:hasPart lexid:PP_2019_4_Section_8_3 .
#
# lexid:PP_2019_4_Article_6 lexid-s:hasPart lexid:PP_2019_4_Article_6_Letter_B .
#
# lexid:PP_2019_4_Article_6_Letter_A rdfs:label "Huruf A"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_II lexid-s:isContentOf lexid:PP_2019_4 .
#
# lexid:PP_2019_4_Section_4_2 lexid-s:name "(2)"^^xsd:string .
#
# lexid:PP_2019_4_Section_2_1 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Article_12 lexid-s:hasPart lexid:PP_2019_4_Section_12_1 .
#
# lexid:PP_2019_4_Article_6_Letter_D lexid-s:isPartOf lexid:PP_2019_4_Article_6 .
#
# lexid:PP_2019_4_Section_12_2 dct:description """Anggota BPKN yang diberhentikan sebagaimana
# dimaksud pada ayat (1) huruf f karena:
# a. terbukti melakukan tindak pidana berdasarkan
# putusan yang berkekuatan hukum tetap;
# b. tidak menghadiri rapat pleno sebanyak 3 (tiga) kali
# berturut-turut; dan/atau
# c. terbukti memberikan keterangan yang tidak benar
# pada saat seleksi."""^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_3 dct:description """Perlindungan Konsumen adalah segala upaya yang
# menjamin adanya kepastian hukum untuk memberi
# perlindungan kepada Konsumen. """^^xsd:string .
#
# lexid:PP_2019_4_Article_9 lexid-s:hasPart lexid:PP_2019_4_Section_9_2 .
#
# lexid:PP_2019_4_Article_6 lexid-s:hasPart lexid:PP_2019_4_Article_6_Letter_E .
#
# lexid:PP_2019_4_Section_12_2 lexid-s:name "(2)"^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_C rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Chapter_IV rdf:type lexid-s:Chapter .
#
# lexid:PP_2019_4_Article_13_Letter_C rdfs:label "Huruf C"^^xsd:string .
#
# lexid:PP_2019_4_Article_9 lexid-s:hasPart lexid:PP_2019_4_Section_9_1 .
#
# lexid:PP_2019_4_Section_5_1 lexid-s:hasPart lexid:PP_2019_4_Section_5_1_Letter_A .
#
# lexid:PP_2019_4_Section_12_2_Letter_B dct:description "tidak menghadiri rapat pleno sebanyak 3 (tiga) kali berturut-turut."^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_A lexid-s:isPartOf lexid:PP_2019_4_Section_3_2 .
#
# lexid:PP_2019_4_Section_14_5 lexid-s:name "(5)"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_1 lexid-s:hasPart lexid:PP_2019_4_Section_12_1_Letter_C .
#
# lexid:PP_2019_4_Section_4_1 lexid-s:hasPart lexid:PP_2019_4_Section_4_1_Letter_B .
#
# lexid:PP_2019_4_Section_16_3 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Article_3 lexid-s:hasPart lexid:PP_2019_4_Section_3_4 .
#
# lexid:PP_2019_4_Section_3_2_Letter_E rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_10_1 rdfs:label "ayat 1 : (1)"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_IV lexid-s:hasPart lexid:PP_2019_4_Article_9 .
#
# lexid:PP_2019_4_Section_2_3 dct:description """Dalam hal diperlukan, untuk meningkatkan kinerja,
# BPKN dapat membentuk perwakilan di ibukota daerah
# provinsi."""^^xsd:string .
#
# lexid:PP_2019_4_Article_11_Letter_A rdfs:label "PP 2019 4 Article 11 Letter A"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_1 rdfs:label "ayat 1 : (1)"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_C rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_12_2 lexid-s:isPartOf lexid:PP_2019_4_Article_12 .
#
# lexid:PP_2019_4_Section_8_1 lexid-s:isPartOf lexid:PP_2019_4_Article_8 .
#
# lexid:PP_2019_4_Section_14_2 lexid-s:name "(2)"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_III lexid-s:hasPart lexid:PP_2019_4_Part_III_KEDUA .
#
# lexid:PP_2019_4_Section_12_1_Letter_C dct:description "bertempat tinggal di luar wilayah negara Republik Indonesia."^^xsd:string .
#
# lexid:PP_2019_4_Article_17 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Section_3_2_Letter_D lexid-s:isPartOf lexid:PP_2019_4_Section_3_2 .
#
# lexid:PP_2019_4_Article_12 lexid-s:isPartOf lexid:PP_2019_4_Chapter_IV .
#
# lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_VI .
#
# lexid:PP_2019_4_Section_12_1_Letter_D rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_2 lexid-s:hasPart lexid:PP_2019_4_Section_2_3 .
#
# lexid:PP_2019_4_Section_3_3 rdfs:label "ayat 3 : (3)"^^xsd:string .
#
# lexid:PP_2019_4_Section_10_3 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Article_1 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Section_4_1_Letter_C rdfs:label "PP 2019 4 Section 4 1 Letter C"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2 lexid-s:hasPart lexid:PP_2019_4_Section_3_2_Letter_D .
#
# lexid:PP_2019_4_Article_6_Letter_C dct:description "berkelakuan baik."^^xsd:string .
#
# lexid:PP_2019_4_Section_8_2 lexid-s:isPartOf lexid:PP_2019_4_Article_8 .
#
# lexid:PP_2019_4_Section_8_1 rdfs:label "ayat 1 : (1)"^^xsd:string .
#
# lexid:PP_2019_4_Article_13 lexid-s:hasPart lexid:PP_2019_4_Article_13_Letter_B .
#
# lexid:PP_2019_4_Section_3_2_Letter_E rdfs:label "PP 2019 4 Section 3 2 Letter E"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_IV lexid-s:hasPart lexid:PP_2019_4_Article_13 .
#
# lexid:PP_2019_4_Article_1_Number_1 dct:description """Konsumen adalah setiap orang pemakai barang
# dan/atau jasa yang tersedia dalam masyarakat, baik
# bagi kepentingan diri sendiri, keluarga, orang lain,
# maupun makhluk hidup lain dan tidak untuk
# diperdagangkan. """^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_3 rdfs:label "Angka 3"^^xsd:string .
#
# lexid:PP_2019_4_Article_1 lexid-s:hasPart lexid:PP_2019_4_Article_1_Number_3 .
#
# lexid:PP_2019_4_Section_12_1_Letter_C rdfs:label "PP 2019 4 Section 12 1 Letter C"^^xsd:string .
#
# lexid:PP_2019_4_Article_17_Letter_B lexid-s:isPartOf lexid:PP_2019_4_Article_17 .
#
# lexid:PP_2019_4_Section_12_1_Letter_F rdfs:label "Huruf F"^^xsd:string .
#
# lexid:PP_2019_4_Article_18 dct:description """Peraturan Pemerintah ini mulai berlaku pada tanggal
# diundangkan."""^^xsd:string .
#
# lexid:PP_2019_4_Section_14_4 lexid-s:isPartOf lexid:PP_2019_4_Article_14 .
#
# lexid:PP_2019_4_Article_6_Letter_B rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_9_2 lexid-s:isPartOf lexid:PP_2019_4_Article_9 .
#
# lexid:PP_2019_4_Article_1 rdfs:label "Pasal 1 : Pasal 1"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_V lexid-s:name "PENDANAAN"^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_E rdfs:label "PP 2019 4 Article 6 Letter E"^^xsd:string .
#
# lexid:PP_2019_4_Article_11 lexid-s:name "Pasal 11"^^xsd:string .
#
# lexid:PP_2019_4_Article_13_Letter_B dct:description "Presiden melakukan konsultasi mengenai anggota BPKN yang akan diberhentikan sebagaimana dimaksud pada huruf a kepada Dewan Perwakilan Rakyat Republik Indonesia."^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_1 rdfs:label "Angka 1"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2 lexid-s:hasPart lexid:PP_2019_4_Section_3_2_Letter_C .
#
# lexid:PP_2019_4_Section_5_1_Letter_A dct:description "pemerintah."^^xsd:string .
#
# lexid:PP_2019_4_Part_III_KESATU lexid-s:hasPart lexid:PP_2019_4_Article_7 .
#
# lexid:PP_2019_4_Section_10_3 dct:description """Tim seleksi paling lambat dibentuk 10 (sepuluh) bulan
# sebelum berakhirnya masa jabatan anggota BPKN."""^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1_Letter_C dct:description "LPKSM."^^xsd:string .
#
# lexid:PP_2019_4_Article_14 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Article_8 lexid-s:hasPart lexid:PP_2019_4_Section_8_1 .
#
# lexid:PP_2019_4_Chapter_IV lexid-s:hasPart lexid:PP_2019_4_Article_14 .
#
# lexid:PP_2019_4_Section_12_1 lexid-s:hasPart lexid:PP_2019_4_Section_12_1_Letter_F .
#
# lexid:PP_2019_4_Article_10 lexid-s:hasPart lexid:PP_2019_4_Section_10_4 .
#
# lexid:PP_2019_4_Section_14_6 lexid-s:name "(6)"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_2 lexid-s:hasPart lexid:PP_2019_4_Section_12_2_Letter_B .
#
# lexid:PP_2019_4_Section_12_1_Letter_A rdfs:label "PP 2019 4 Section 12 1 Letter A"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_I lexid-s:name "KETENTUAN UMUM"^^xsd:string .
#
# lexid:PP_2019_4_Article_3 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Article_17_Letter_B rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_17_Letter_C rdfs:label "Huruf C"^^xsd:string .
#
# lexid:PP_2019_4_Section_4_1_Letter_A rdfs:label "Huruf A"^^xsd:string .
#
# lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_III .
#
# lexid:PP_2019_4_Article_6 lexid-s:hasPart lexid:PP_2019_4_Article_6_Letter_F .
#
# lexid:PP_2019_4_Article_6_Letter_F lexid-s:isPartOf lexid:PP_2019_4_Article_6 .
#
# lexid:PP_2019_4_Section_9_1 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Article_1_Number_4 dct:description """Badan Perlindungan Konsumen Nasional yang
# selanjutnya disingkat BPKN adalah badan yang
# dibentuk untuk membantu upaya pengembangan
# Perlindungan Konsumen. """^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1_Letter_E lexid-s:isPartOf lexid:PP_2019_4_Section_5_1 .
#
# lexid:PP_2019_4_Article_3 lexid-s:hasPart lexid:PP_2019_4_Section_3_1 .
#
# lexid:PP_2019_4_Section_3_2 lexid-s:hasPart lexid:PP_2019_4_Section_3_2_Letter_B .
#
# lexid:PP_2019_4_Article_6_Letter_F rdfs:label "PP 2019 4 Article 6 Letter F"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_2 lexid-s:hasPart lexid:PP_2019_4_Section_12_2_Letter_C .
#
# lexid:PP_2019_4_Section_10_1 dct:description """Dalam rangka pengusulan anggota BPKN, Menteri
# membentuk tim seleksi."""^^xsd:string .
#
# lexid:PP_2019_4_Section_2_3 lexid-s:isPartOf lexid:PP_2019_4_Article_2 .
#
# lexid:PP_2019_4_Article_13_Letter_B rdfs:label "PP 2019 4 Article 13 Letter B"^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1 lexid-s:isPartOf lexid:PP_2019_4_Article_5 .
#
# lexid:PP_2019_4_Section_5_1 lexid-s:name "(1)"^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_D rdfs:label "Huruf D"^^xsd:string .
#
# lexid:PP_2019_4_Section_14_1 lexid-s:name "(1)"^^xsd:string .
#
# lexid:PP_2019_4_Article_9 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Section_12_2 lexid-s:hasPart lexid:PP_2019_4_Section_12_2_Letter_A .
#
# lexid:PP_2019_4_Section_8_3 rdfs:label "ayat 3 : (3)"^^xsd:string .
#
# lexid:PP_2019_4_Article_2 lexid-s:hasPart lexid:PP_2019_4_Section_2_2 .
#
# lexid:PP_2019_4_Section_3_1 lexid-s:isPartOf lexid:PP_2019_4_Article_3 .
#
# lexid:PP_2019_4_Section_3_2_Letter_D rdfs:label "Huruf D"^^xsd:string .
#
# lexid:PP_2019_4_Section_10_4 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Article_6_Letter_C rdfs:label "Huruf C"^^xsd:string .
#
# lexid:PP_2019_4_Section_4_1_Letter_A dct:description "seorang ketua merangkap anggota."^^xsd:string .
#
# lexid:PP_2019_4_Article_8 lexid-s:hasPart lexid:PP_2019_4_Section_8_2 .
#
# lexid:PP_2019_4_Article_10 lexid-s:name "Pasal 10"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_1 dct:description """BPKN mempunyai fungsi memberikan saran dan
# pertimbangan kepada pemerintah dalam upaya
# mengembangkan Perlindungan Konsumen di Indonesia."""^^xsd:string .
#
# lexid:PP_2019_4_Article_16 lexid-s:hasPart lexid:PP_2019_4_Section_16_2 .
#
# lexid:PP_2019_4_Article_13_Letter_C dct:description "Presiden memberhentikan anggota BPKN."^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1_Letter_C rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_13_Letter_A lexid-s:isPartOf lexid:PP_2019_4_Article_13_Letter_B .
#
# lexid:PP_2019_4_Section_2_2 lexid-s:name "(2)"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_C rdfs:label "Huruf C"^^xsd:string .
#
# lexid:PP_2019_4_Article_1 lexid-s:hasPart lexid:PP_2019_4_Article_1_Number_5 .
#
# lexid:PP_2019_4_Article_13_Letter_B rdfs:label "Huruf B"^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_A dct:description "warga negara Republik Indonesia."^^xsd:string .
#
# lexid:PP_2019_4_Section_9_1 dct:description """Anggota BPKN diangkat dan diberhentikan oleh
# Presiden atas usul Menteri, setelah dikonsultasikan
# kepada Dewan Perwakilan Rakyat Republik Indonesia."""^^xsd:string .
#
# lexid:PP_2019_4_Chapter_III lexid-s:name "ORGANISASI DAN KEANGGOTAAN"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_F rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_4 lexid-s:hasPart lexid:PP_2019_4_Section_4_3 .
#
# lexid:PP_2019_4_Section_12_1 lexid-s:hasPart lexid:PP_2019_4_Section_12_1_Letter_E .
#
# lexid:PP_2019_4_Article_5 lexid-s:hasPart lexid:PP_2019_4_Section_5_2 .
#
# lexid:PP_2019_4_Article_6_Letter_A rdfs:label "PP 2019 4 Article 6 Letter A"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_II rdfs:label "BAB II : KEDUDUKAN, TUGAS, DAN FUNGSI"^^xsd:string .
#
# lexid:PP_2019_4_Section_10_1 lexid-s:name "(1)"^^xsd:string .
#
# lexid:PP_2019_4_Part_III_KESATU lexid-s:hasPart lexid:PP_2019_4_Article_6 .
#
# lexid:PP_2019_4_Article_17 lexid-s:hasPart lexid:PP_2019_4_Article_17_Letter_A .
#
# lexid:PP_2019_4_Section_16_2 rdfs:label "ayat 2 : (2)"^^xsd:string .
#
# lexid:PP_2019_4_Section_9_3 lexid-s:name "(3)"^^xsd:string .
#
# lexid:PP_2019_4_Section_14_3 rdfs:label "ayat 3 : (3)"^^xsd:string .
#
# lexid:PP_2019_4_Section_14_4 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_16_1 rdfs:label "ayat 1 : (1)"^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1_Letter_A rdfs:label "PP 2019 4 Section 5 1 Letter A"^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_E dct:description "memiliki pengetahuan dan pengalaman di bidang Perlindungan Konsumen."^^xsd:string .
#
# lexid:PP_2019_4_Article_5 lexid-s:name "Pasal 5"^^xsd:string .
#
# lexid:PP_2019_4_Article_10 lexid-s:hasPart lexid:PP_2019_4_Section_10_2 .
#
# lexid:PP_2019_4_Article_11_Letter_B dct:description "Presiden melakukan konsultasi mengenai calon anggota BPKN sebagaimana dimaksud pada huruf a kepada Dewan Perwakilan Rakyat Republik Indonesia."^^xsd:string .
#
# lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_I .
#
# lexid:PP_2019_4_Section_4_1_Letter_B rdfs:label "PP 2019 4 Section 4 1 Letter B"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_E rdfs:label "Huruf E"^^xsd:string .
#
# lexid:PP_2019_4_Article_18 rdfs:label "Pasal 18 : Pasal 18"^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_F rdfs:label "Huruf F"^^xsd:string .
#
# lexid:PP_2019_4_Article_18 lexid-s:isPartOf lexid:PP_2019_4_Chapter_VI .
#
# lexid:PP_2019_4_Article_1_Number_6 dct:description """Menteri adalah menteri yang menyelenggarakan urusan
# pemerintahan di bidang perdagangan."""^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_0 lexid-s:isPartOf lexid:PP_2019_4_Article_1 .
#
# lexid:PP_2019_4_Chapter_VI lexid-s:hasPart lexid:PP_2019_4_Article_17 .
#
# lexid:PP_2019_4_Section_5_1_Letter_A rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_14 lexid-s:hasPart lexid:PP_2019_4_Section_14_4 .
#
# lexid:PP_2019_4_Article_3 rdfs:label "Pasal 3 : Pasal 3"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_V lexid-s:hasPart lexid:PP_2019_4_Article_15 .
#
# lexid:PP_2019_4_Article_8 lexid-s:isPartOf lexid:PP_2019_4_Part_III_KEDUA .
#
# lexid:PP_2019_4_Article_13 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Section_12_1_Letter_E rdfs:label "Huruf E"^^xsd:string .
#
# lexid:PP_2019_4_Section_8_1 lexid-s:name "(1)"^^xsd:string .
#
# lexid:PP_2019_4_Section_14_1 rdfs:label "ayat 1 : (1)"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_III lexid-s:hasPart lexid:PP_2019_4_Part_III_KESATU .
#
# lexid:PP_2019_4_Section_8_2 dct:description """Sekretariat sebagaimana dimaksud pada ayat (1)
# dipimpin oleh seorang sekretaris yang diangkat oleh
# Ketua BPKN."""^^xsd:string .
#
# lexid:PP_2019_4_Section_4_1_Letter_A rdfs:label "PP 2019 4 Section 4 1 Letter A"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_1 lexid-s:isPartOf lexid:PP_2019_4_Article_12 .
#
# lexid:PP_2019_4_Section_9_2 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_5_1_Letter_A lexid-s:isPartOf lexid:PP_2019_4_Section_5_1 .
#
# lexid:PP_2019_4_Section_14_2 dct:description """Anggota BPKN pengganti antarwaktu sebagaimana
# dimaksud pada ayat (1) diusulkan oleh Menteri kepada
# Presiden berdasarkan daftar calon anggota BPKN yang
# memenuhi persyaratan dari tim seleksi sesuai dengan
# peringkat dan unsur anggota yang digantikan."""^^xsd:string .
#
# lexid:PP_2019_4_Article_4 rdfs:label "Pasal 4 : Pasal 4"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_V rdfs:label "BAB V : PENDANAAN"^^xsd:string .
#
# lexid:PP_2019_4_Article_5 lexid-s:isPartOf lexid:PP_2019_4_Part_III_KESATU .
#
# lexid:PP_2019_4_Section_12_1 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_3_2 lexid-s:hasPart lexid:PP_2019_4_Section_3_2_Letter_G .
#
# lexid:PP_2019_4_Chapter_VI lexid-s:isContentOf lexid:PP_2019_4 .
#
# lexid:PP_2019_4_Section_12_1_Letter_E rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_10_2 dct:description """Tim seleksi sebagaimana dimaksud pada ayat (1)
# bertugas menyampaikan calon yang memenuhi
# persyaratan untuk menjadi anggota BPKN kepada
# Menteri."""^^xsd:string .
#
# lexid:PP_2019_4_Article_1 lexid-s:hasPart lexid:PP_2019_4_Article_1_Number_1 .
#
# lexid:PP_2019_4_Section_2_1 rdfs:label "ayat 1 : (1)"^^xsd:string .
#
# lexid:PP_2019_4_Part_III_KESATU lexid-s:isPartOf lexid:PP_2019_4_Chapter_III .
#
# lexid:PP_2019_4_Article_16 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Article_1_Number_3 lexid-s:isPartOf lexid:PP_2019_4_Article_1 .
#
# lexid:PP_2019_4_Section_10_4 dct:description """Ketentuan lebih lanjut mengenai pembentukan tim
# seleksi calon anggota BPKN ditetapkan oleh Menteri."""^^xsd:string .
#
# lexid:PP_2019_4_Section_14_5 rdfs:label "ayat 5 : (5)"^^xsd:string .
#
# lexid:PP_2019_4_Article_17_Letter_B rdfs:label "Huruf B"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_B lexid-s:isPartOf lexid:PP_2019_4_Section_3_2 .
#
# lexid:PP_2019_4_Chapter_VI rdf:type lexid-s:Chapter .
#
# lexid:PP_2019_4_Section_2_1 dct:description """BPKN berkedudukan di Ibukota Negara Republik
# Indonesia dan bertanggungjawab kepada Presiden."""^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_2 dct:description """Pelaku Usaha adalah setiap orang perseorangan atau
# badan usaha, baik yang berbentuk badan hukum
# maupun bukan badan hukum yang didirikan dan
# berkedudukan atau melakukan kegiatan dalam wilayah
# hukum negara Republik Indonesia, baik sendiri
# maupun bersama-sama melalui perjanjian
# penyelenggaraan kegiatan usaha dalam berbagai bidang
# ekonomi. """^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1_Letter_C rdfs:label "Huruf C"^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_4 rdfs:label "PP 2019 4 Article 1 Number 4"^^xsd:string .
#
# lexid:PP_2019_4_Article_11 lexid-s:hasPart lexid:PP_2019_4_Article_11_Letter_A .
#
# lexid:PP_2019_4_Article_5 lexid-s:hasPart lexid:PP_2019_4_Section_5_1 .
#
# lexid:PP_2019_4_Article_7 lexid-s:isPartOf lexid:PP_2019_4_Part_III_KESATU .
#
# lexid:PP_2019_4_Article_11_Letter_B rdfs:label "Huruf B"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_1_Letter_D lexid-s:isPartOf lexid:PP_2019_4_Section_12_1 .
#
# lexid:PP_2019_4_Article_10 lexid-s:hasPart lexid:PP_2019_4_Section_10_1 .
#
# lexid:PP_2019_4_Article_6_Letter_B rdfs:label "Huruf B"^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1_Letter_D rdfs:label "PP 2019 4 Section 5 1 Letter D"^^xsd:string .
#
# lexid:PP_2019_4_Article_8 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Section_12_2_Letter_A rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_14_2 lexid-s:isPartOf lexid:PP_2019_4_Article_14 .
#
# lexid:PP_2019_4_Section_4_1_Letter_B lexid-s:isPartOf lexid:PP_2019_4_Section_4_1 .
#
# lexid:PP_2019_4_Section_16_2 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_5_1 lexid-s:hasPart lexid:PP_2019_4_Section_5_1_Letter_D .
#
# lexid:PP_2019_4_Article_13_Letter_A rdfs:label "PP 2019 4 Article 13 Letter A"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_1_Letter_C rdfs:label "Huruf C"^^xsd:string .
#
# lexid:PP_2019_4_Article_10 lexid-s:hasPart lexid:PP_2019_4_Section_10_3 .
#
# lexid:PP_2019_4_Section_3_2 lexid-s:hasPart lexid:PP_2019_4_Section_3_2_Letter_E .
#
# lexid:PP_2019_4_Section_5_1_Letter_E rdfs:label "Huruf E"^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_A lexid-s:isPartOf lexid:PP_2019_4_Article_6 .
#
# lexid:PP_2019_4_Article_16 rdfs:label "Pasal 16 : Pasal 16"^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_5 rdfs:label "Angka 5"^^xsd:string .
#
# lexid:PP_2019_4_Part_III_KESATU rdf:type lexid-s:Part .
#
# lexid:PP_2019_4_Section_3_2_Letter_C lexid-s:isPartOf lexid:PP_2019_4_Section_3_2 .
#
# lexid:PP_2019_4_Article_18 lexid-s:name "Pasal 18"^^xsd:string .
#
# lexid:PP_2019_4_Section_16_3 lexid-s:name "(3)"^^xsd:string .
#
# lexid:PP_2019_4_Article_11_Letter_C rdfs:label "Huruf C"^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1_Letter_E rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_13 lexid-s:hasPart lexid:PP_2019_4_Article_13_Letter_C .
#
# lexid:PP_2019_4_Section_3_2_Letter_G rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_5_1_Letter_D rdfs:label "Huruf D"^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_6 rdfs:label "Angka 6"^^xsd:string .
#
# lexid:PP_2019_4_Section_8_3 lexid-s:isPartOf lexid:PP_2019_4_Article_8 .
#
# lexid:PP_2019_4_Section_12_1 lexid-s:hasPart lexid:PP_2019_4_Section_12_1_Letter_B .
#
# lexid:PP_2019_4_Chapter_I lexid-s:isContentOf lexid:PP_2019_4 .
#
# lexid:PP_2019_4_Article_4 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Section_4_1_Letter_C lexid-s:isPartOf lexid:PP_2019_4_Section_4_1 .
#
# lexid:PP_2019_4_Section_10_1 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Part_III_KEDUA rdf:type lexid-s:Part .
#
# lexid:PP_2019_4_Section_2_3 rdfs:label "ayat 3 : (3)"^^xsd:string .
#
# lexid:PP_2019_4_Section_16_3 dct:description """Besaran honorarium dan fasilitas lainnya untuk
# sekretaris dan anggota sekretariat BPKN ditetapkan
# oleh Ketua BPKN setelah mendapatkan persetujuan
# dari menteri yang menyelenggarakan urusan
# pemerintah di bidang keuangan."""^^xsd:string .
#
# lexid:PP_2019_4_Section_8_2 rdfs:label "ayat 2 : (2)"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_VI rdfs:label "BAB VI : KETENTUAN PENUTUP"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2 lexid-s:hasPart lexid:PP_2019_4_Section_3_2_Letter_A .
#
# lexid:PP_2019_4_Article_9 lexid-s:name "Pasal 9"^^xsd:string .
#
# lexid:PP_2019_4_Section_4_1_Letter_B dct:description "seorang wakil ketua merangkap anggota."^^xsd:string .
#
# lexid:PP_2019_4_Article_11_Letter_B rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Chapter_I rdf:type lexid-s:Chapter .
#
# lexid:PP_2019_4_Section_12_2_Letter_A lexid-s:isPartOf lexid:PP_2019_4_Section_12_2 .
#
# lexid:PP_2019_4_Chapter_I lexid-s:hasPart lexid:PP_2019_4_Article_1 .
#
# lexid:PP_2019_4_Section_14_4 dct:description """Masa jabatan anggota BPKN pengganti antarwaktu
# sebagaimana dimaksud pada ayat (1) mengikuti sisa
# masa jabatan anggota yang digantikan."""^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_4 rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_1_Number_2 rdfs:label "Angka 2"^^xsd:string .
#
# lexid:PP_2019_4_Section_14_5 lexid-s:isPartOf lexid:PP_2019_4_Article_14 .
#
# lexid:PP_2019_4_Section_2_2 lexid-s:isPartOf lexid:PP_2019_4_Article_2 .
#
# lexid:PP_2019_4_Article_2 lexid-s:hasPart lexid:PP_2019_4_Section_2_1 .
#
# lexid:PP_2019_4_Section_12_1 lexid-s:hasPart lexid:PP_2019_4_Section_12_1_Letter_D .
#
# lexid:PP_2019_4_Article_1_Number_4 lexid-s:isPartOf lexid:PP_2019_4_Article_1 .
#
# lexid:PP_2019_4_Article_11_Letter_A dct:description "Menteri mengajukan usul calon anggota BPKN yang telah memenuhi persyaratan keanggotaan BPKN kepada Presiden."^^xsd:string .
#
# lexid:PP_2019_4_Section_3_3 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Article_8 lexid-s:name "Pasal 8"^^xsd:string .
#
# lexid:PP_2019_4_Article_6 lexid-s:hasPart lexid:PP_2019_4_Article_6_Letter_A .
#
# lexid:PP_2019_4_Section_14_2 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_2_1 lexid-s:isPartOf lexid:PP_2019_4_Article_2 .
#
# lexid:PP_2019_4_Section_2_1 lexid-s:name "(1)"^^xsd:string .
#
# lexid:PP_2019_4_Article_7 dct:description """Persyaratan sebagaimana dimaksud dalam Pasal 6
# dibuktikan dengan:
# a. kartu tanda kependudukan;
# b. surat keterangan sehat dari dokter;
# c. surat keterangan catatan kepolisian; dan
# d. bukti memiliki pengetahuan dan pengalaman di bidang
# Perlindungan Konsumen, yaitu:
# 1) unsur pemerintah, berupa surat pengangkatan
# pegawai negeri sipil dalam jabatan yang terkait
# Perlindungan Konsumen.
# 2) unsur Pelaku Usaha, berupa kepemilikan kartu
# anggota asosiasi atau perkumpulan atau organisasi
# Pelaku Usaha yang produknya terkait dengan
# Perlindungan Konsumen di Indonesia.
# 3) unsur LPKSM, berupa surat rekomendasi dari ketua
# LPKSM yang terdaftar dan diakui pemerintah.
# 4) unsur akademisi, berupa surat rekomendasi dari
# pimpinan perguruan tinggi yang menyatakan
# memiliki pengalaman paling sedikit 2 (dua) tahun di
# bidang Perlindungan Konsumen.
# 5) unsur tenaga ahli, berupa dokumen yang
# menyatakan keahlian atau menunjukkan
# pengalaman di bidang Perlindungan Konsumen yang
# disahkan oleh pejabat yang berwenang."""^^xsd:string .
#
# lexid:PP_2019_4_Article_1 lexid-s:name "Pasal 1"^^xsd:string .
#
# lexid:PP_2019_4_Article_5 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Article_13 lexid-s:name "Pasal 13"^^xsd:string .
#
# lexid:PP_2019_4_Section_16_1 lexid-s:name "(1)"^^xsd:string .
#
# lexid:PP_2019_4_Article_14 lexid-s:name "Pasal 14"^^xsd:string .
#
# lexid:PP_2019_4_Section_9_3 rdfs:label "ayat 3 : (3)"^^xsd:string .
#
# lexid:PP_2019_4_Section_14_3 lexid-s:isPartOf lexid:PP_2019_4_Article_14 .
#
# lexid:PP_2019_4_Article_2 rdfs:label "Pasal 2 : Pasal 2"^^xsd:string .
#
# lexid:PP_2019_4_Article_13 lexid-s:isPartOf lexid:PP_2019_4_Chapter_IV .
#
# lexid:PP_2019_4_Article_11_Letter_B lexid-s:hasPart lexid:PP_2019_4_Article_11_Letter_A .
#
# lexid:PP_2019_4_Section_16_1 lexid-s:isPartOf lexid:PP_2019_4_Article_16 .
#
# lexid:PP_2019_4_Article_9 lexid-s:hasPart lexid:PP_2019_4_Section_9_3 .
#
# lexid:PP_2019_4_Section_3_2_Letter_A dct:description "memberikan saran dan rekomendasi kepada pemerintah dalam rangka penyusunan kebijaksanaan di bidang Perlindungan Konsumen."^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1_Letter_A rdfs:label "Huruf A"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_2_Letter_B rdfs:label "PP 2019 4 Section 12 2 Letter B"^^xsd:string .
#
# lexid:PP_2019_4_Section_10_3 lexid-s:name "(3)"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_1_Letter_D dct:description "sakit secara terus menerus."^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_F dct:description "menerima pengaduan tentang Perlindungan Konsumen dari masyarakat, LPKSM, atau Pelaku Usaha."^^xsd:string .
#
# lexid:PP_2019_4_Section_5_2 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_10_4 rdfs:label "ayat 4 : (4)"^^xsd:string .
#
# lexid:PP_2019_4_Section_4_1 rdfs:label "ayat 1 : (1)"^^xsd:string .
#
# lexid:PP_2019_4_Article_7 lexid-s:name "Pasal 7"^^xsd:string .
#
# lexid:PP_2019_4_Section_4_3 rdfs:label "ayat 3 : (3)"^^xsd:string .
#
# lexid:PP_2019_4_Article_7 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Article_11_Letter_A lexid-s:isPartOf lexid:PP_2019_4_Article_11 .
#
# lexid:PP_2019_4_Section_12_2_Letter_C rdfs:label "PP 2019 4 Section 12 2 Letter C"^^xsd:string .
#
# lexid:PP_2019_4_Article_1 dct:description """Dalam Peraturan Pemerintah ini yang dimaksud dengan:
# 1. Konsumen adalah setiap orang pemakai barang
# dan/atau jasa yang tersedia dalam masyarakat, baik
# bagi kepentingan diri sendiri, keluarga, orang lain,
# maupun makhluk hidup lain dan tidak untuk
# diperdagangkan.
# 2. Pelaku Usaha adalah setiap orang perseorangan atau
# badan usaha, baik yang berbentuk badan hukum
# maupun bukan badan hukum yang didirikan dan
# berkedudukan atau melakukan kegiatan dalam wilayah
# hukum negara Republik Indonesia, baik sendiri
# maupun bersama-sama melalui perjanjian
# penyelenggaraan kegiatan usaha dalam berbagai bidang
# ekonomi.
# 3. Perlindungan Konsumen adalah segala upaya yang
# menjamin adanya kepastian hukum untuk memberi
# perlindungan kepada Konsumen.
# 4. Badan Perlindungan Konsumen Nasional yang
# selanjutnya disingkat BPKN adalah badan yang
# dibentuk untuk membantu upaya pengembangan
# Perlindungan Konsumen.
# 5. Lembaga Perlindungan Konsumen Swadaya Masyarakat
# yang selanjutnya disingkat LPKSM adalah lembaga non
# pemerintah yang terdaftar dan diakui oleh pemerintah
# yang mempunyai kegiatan menangani Perlindungan
# Konsumen.
# 6. Menteri adalah menteri yang menyelenggarakan urusan
# pemerintahan di bidang perdagangan."""^^xsd:string .
#
# lexid:PP_2019_4_Section_3_1 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_3_2_Letter_G dct:description "melakukan survei yang menyangkut kebutuhan Konsumen."^^xsd:string .
#
# lexid:PP_2019_4_Section_3_4 rdfs:label "ayat 4 : (4)"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_V rdf:type lexid-s:Chapter .
#
# lexid:PP_2019_4_Section_12_2_Letter_C dct:description "terbukti memberikan keterangan yang tidak benar pada saat seleksi."^^xsd:string .
#
# lexid:PP_2019_4_Section_10_2 rdfs:label "ayat 2 : (2)"^^xsd:string .
#
# lexid:PP_2019_4_Section_4_2 lexid-s:isPartOf lexid:PP_2019_4_Article_4 .
#
# lexid:PP_2019_4_Article_6 lexid-s:hasPart lexid:PP_2019_4_Article_6_Letter_C .
#
# lexid:PP_2019_4_Article_12 lexid-s:name "Pasal 12"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_4 lexid-s:isPartOf lexid:PP_2019_4_Article_3 .
#
# lexid:PP_2019_4_Article_6_Letter_C lexid-s:isPartOf lexid:PP_2019_4_Article_6 .
#
# lexid:PP_2019_4_Section_4_3 lexid-s:isPartOf lexid:PP_2019_4_Article_4 .
#
# lexid:PP_2019_4_Section_3_2_Letter_F rdfs:label "PP 2019 4 Section 3 2 Letter F"^^xsd:string .
#
# lexid:PP_2019_4_Section_10_3 lexid-s:isPartOf lexid:PP_2019_4_Article_10 .
#
# lexid:PP_2019_4_Section_3_2_Letter_F lexid-s:isPartOf lexid:PP_2019_4_Section_3_2 .
#
# lexid:PP_2019_4_Article_16 lexid-s:isPartOf lexid:PP_2019_4_Chapter_V .
#
# lexid:PP_2019_4_Article_10 rdfs:label "Pasal 10 : Pasal 10"^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_F dct:description "berusia sekurang-kurangnya 30 (tiga puluh) tahun."^^xsd:string .
#
# lexid:PP_2019_4_Section_4_2 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_3_2_Letter_C rdfs:label "PP 2019 4 Section 3 2 Letter C"^^xsd:string .
#
# lexid:PP_2019_4_Section_4_3 dct:description """Ketentuan lebih lanjut mengenai organisasi dan tata
# kerja BPKN diatur dengan Peraturan Ketua BPKN."""^^xsd:string .
#
# lexid:PP_2019_4_Section_12_1_Letter_D rdfs:label "Huruf D"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_IV lexid-s:hasPart lexid:PP_2019_4_Article_12 .
#
# lexid:PP_2019_4_Section_12_1_Letter_C lexid-s:isPartOf lexid:PP_2019_4_Section_12_1 .
#
# lexid:PP_2019_4_Section_3_2 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Article_1 lexid-s:hasPart lexid:PP_2019_4_Article_1_Number_6 .
#
# lexid:PP_2019_4_Article_4 lexid-s:hasPart lexid:PP_2019_4_Section_4_1 .
#
# lexid:PP_2019_4_Section_16_1 dct:description """Dalam melaksanakan tugas, ketua, wakil ketua, dan
# anggota BPKN diberikan hak keuangan dan fasilitas
# lainnya."""^^xsd:string .
#
# lexid:PP_2019_4_Article_10 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Article_11_Letter_A rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_12_1_Letter_B rdfs:label "PP 2019 4 Section 12 1 Letter B"^^xsd:string .
#
# lexid:PP_2019_4_Section_9_2 rdfs:label "ayat 2 : (2)"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_V lexid-s:isContentOf lexid:PP_2019_4 .
#
# lexid:PP_2019_4_Article_3 lexid-s:isPartOf lexid:PP_2019_4_Chapter_II .
#
# lexid:PP_2019_4_Section_8_2 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_12_2_Letter_A rdfs:label "Huruf A"^^xsd:string .
#
# lexid:PP_2019_4_Section_14_4 rdfs:label "ayat 4 : (4)"^^xsd:string .
#
# lexid:PP_2019_4_Section_16_3 lexid-s:isPartOf lexid:PP_2019_4_Article_16 .
#
# lexid:PP_2019_4_Article_7 rdfs:label "Pasal 7 : Pasal 7"^^xsd:string .
#
# lexid:PP_2019_4_Section_4_1_Letter_C dct:description "anggota BPKN paling sedikit 15 (lima belas) orang dan paling banyak 25 (dua puluh lima) orang anggota."^^xsd:string .
#
# lexid:PP_2019_4_Article_17_Letter_B dct:description "Peraturan Pemerintah Nomor 57 Tahun 2001 tentang Badan Perlindungan Konsumen Nasional (Lembaran Negara Republik Indonesia Tahun 2001 Nomor 102, Tambahan Lembaran Negara Republik Indonesia Nomor 4125) dicabut dan dinyatakan tidak berlaku."^^xsd:string .
#
# lexid:PP_2019_4_Article_17_Letter_A dct:description "Semua peraturan perundang-undangan yang merupakan peraturan pelaksanaan dari Peraturan Pemerintah Nomor 57 Tahun 2001 tentang Badan Perlindungan Konsumen Nasional (Lembaran Negara Republik Indonesia Tahun 2001 Nomor 102, Tambahan Lembaran Negara Republik Indonesia Nomor 4125), dinyatakan masih tetap berlaku sepanjang tidak bertentangan dengan ketentuan dalam Peraturan Pemerintah ini."^^xsd:string .
#
# lexid:PP_2019_4_Article_17 lexid-s:hasPart lexid:PP_2019_4_Article_17_Letter_C .
#
# lexid:PP_2019_4_Section_14_1 lexid-s:isPartOf lexid:PP_2019_4_Article_14 .
#
# lexid:PP_2019_4_Article_2 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Section_12_1_Letter_C rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_1_Number_3 rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_9_3 lexid-s:isPartOf lexid:PP_2019_4_Article_9 .
#
# lexid:PP_2019_4_Article_13_Letter_C rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_3_2_Letter_F rdfs:label "Huruf F"^^xsd:string .
#
# lexid:PP_2019_4_Article_11 rdfs:label "Pasal 11 : Pasal 11"^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_0 rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_14_5 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_9_2 lexid-s:name "(2)"^^xsd:string .
#
# lexid:PP_2019_4_Section_14_6 lexid-s:isPartOf lexid:PP_2019_4_Article_14 .
#
# lexid:PP_2019_4_Article_17 dct:description """Pada saat Peraturan Pemerintah ini mulai berlaku:
# a. Semua peraturan perundang-undangan yang
# merupakan peraturan pelaksanaan dari Peraturan
# Pemerintah Nomor 57 Tahun 2001 tentang Badan
# Perlindungan Konsumen Nasional (Lembaran Negara
# Republik Indonesia Tahun 2001 Nomor 102, Tambahan
# Lembaran Negara Republik Indonesia Nomor 4125),
# dinyatakan masih tetap berlaku sepanjang tidak
# bertentangan dengan ketentuan dalam Peraturan
# Pemerintah ini.
# b. Peraturan Pemerintah Nomor 57 Tahun 2001 tentang
# Badan Perlindungan Konsumen Nasional (Lembaran
# Negara Republik Indonesia Tahun 2001 Nomor 102,
# Tambahan Lembaran Negara Republik Indonesia Nomor
# 4125) dicabut dan dinyatakan tidak berlaku.
# c. Calon anggota BPKN yang telah memenuhi persyaratan
# dan telah disampaikan oleh Presiden kepada Dewan
# Perwakilan Rakyat Republik Indonesia sesuai dengan
# ketentuan yang diatur dalam Peraturan Pemerintah
# Nomor 57 Tahun 2001 tentang Badan Perlindungan
# Konsumen Nasional tetap dilanjutkan untuk konsultasi
# dan pengangkatannya."""^^xsd:string .
#
# lexid:PP_2019_4_Article_17 rdfs:label "Pasal 17 : Pasal 17"^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_C rdfs:label "PP 2019 4 Article 6 Letter C"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_B rdfs:label "PP 2019 4 Section 3 2 Letter B"^^xsd:string .
#
# lexid:PP_2019_4_Article_8 rdfs:label "Pasal 8 : Pasal 8"^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_B lexid-s:isPartOf lexid:PP_2019_4_Article_6 .
#
# lexid:PP_2019_4_Article_15 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Article_12 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Article_3 lexid-s:hasPart lexid:PP_2019_4_Section_3_2 .
#
# lexid:PP_2019_4_Article_1_Number_1 lexid-s:isPartOf lexid:PP_2019_4_Article_1 .
#
# lexid:PP_2019_4_Article_17_Letter_C lexid-s:isPartOf lexid:PP_2019_4_Article_17 .
#
# lexid:PP_2019_4_Section_12_1 rdfs:label "ayat 1 : (1)"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_2_Letter_A dct:description "terbukti melakukan tindak pidana berdasarkan putusan yang berkekuatan hukum tetap."^^xsd:string .
#
# lexid:PP_2019_4_Chapter_V lexid-s:hasPart lexid:PP_2019_4_Article_16 .
#
# lexid:PP_2019_4_Article_1_Number_5 lexid-s:isPartOf lexid:PP_2019_4_Article_1 .
#
# lexid:PP_2019_4_Section_3_2 lexid-s:hasPart lexid:PP_2019_4_Section_3_2_Letter_F .
#
# lexid:PP_2019_4_Article_18 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Section_14_4 lexid-s:name "(4)"^^xsd:string .
#
# lexid:PP_2019_4_Section_10_2 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_12_2_Letter_B rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_6_Letter_E rdfs:label "Huruf E"^^xsd:string .
#
# lexid:PP_2019_4_Part_III_KESATU rdfs:label "BAGIAN KESATU : Keanggotaan"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_E dct:description "menyebarluaskan informasi melalui media mengenai Perlindungan Konsumen dan memasyarakatkan sikap keberpihakan kepada Konsumen."^^xsd:string .
#
# lexid:PP_2019_4_Article_15 dct:description """Biaya untuk pelaksanaan tugas BPKN dibebankan kepada
# anggaran pendapatan dan belanja negara dan sumber lain
# yang sesuai dengan ketentuan peraturan perundang-
# undangan."""^^xsd:string .
#
# lexid:PP_2019_4_Section_16_1 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_12_1_Letter_D rdfs:label "PP 2019 4 Section 12 1 Letter D"^^xsd:string .
#
# lexid:PP_2019_4_Article_4 lexid-s:isPartOf lexid:PP_2019_4_Part_III_KESATU .
#
# lexid:PP_2019_4_Section_12_2 lexid-s:hasPart lexid:PP_2019_4_Section_12_1_Letter_F .
#
# lexid:PP_2019_4_Section_14_3 dct:description """Dalam hal daftar calon anggota BPKN dari unsur yang
# digantikan sebagaimana dimaksud pada ayat (2) tidak
# tersedia, Menteri mengusulkan calon anggota BPKN
# pengganti antarwaktu yang memenuhi persyaratan."""^^xsd:string .
#
# lexid:PP_2019_4_Section_3_4 lexid-s:name "(4)"^^xsd:string .
#
# lexid:PP_2019_4_Section_14_5 dct:description """Presiden mengangkat anggota BPKN pengganti
# antarwaktu berdasarkan hasil konsultasi dengan
# Dewan Perwakilan Rakyat Republik Indonesia."""^^xsd:string .
#
# lexid:PP_2019_4_Section_4_1_Letter_B rdfs:label "Huruf B"^^xsd:string .
#
# lexid:PP_2019_4_Article_14 lexid-s:isPartOf lexid:PP_2019_4_Chapter_IV .
#
# lexid:PP_2019_4_Article_16 lexid-s:name "Pasal 16"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_E lexid-s:isPartOf lexid:PP_2019_4_Section_3_2 .
#
# lexid:PP_2019_4_Section_8_1 dct:description """Untuk kelancaran pelaksanaan tugas, BPKN dibantu
# oleh sekretariat."""^^xsd:string .
#
# lexid:PP_2019_4_Section_12_1_Letter_B dct:description "mengundurkan diri atas permintaan sendiri."^^xsd:string .
#
# lexid:PP_2019_4_Article_11_Letter_B rdfs:label "PP 2019 4 Article 11 Letter B"^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_D rdfs:label "PP 2019 4 Article 6 Letter D"^^xsd:string .
#
# lexid:PP_2019_4_Section_16_2 lexid-s:name "(2)"^^xsd:string .
#
# lexid:PP_2019_4_Article_13_Letter_C lexid-s:isPartOf lexid:PP_2019_4_Article_13 .
#
# lexid:PP_2019_4_Article_1_Number_5 dct:description """Lembaga Perlindungan Konsumen Swadaya Masyarakat
# yang selanjutnya disingkat LPKSM adalah lembaga non
# pemerintah yang terdaftar dan diakui oleh pemerintah
# yang mempunyai kegiatan menangani Perlindungan
# Konsumen. """^^xsd:string .
#
# lexid:PP_2019_4_Article_11 dct:description """Pengangkatan anggota BPKN melalui tahapan sebagai
# berikut:
# a. Menteri mengajukan usul calon anggota BPKN yang telah
# memenuhi persyaratan keanggotaan BPKN kepada
# Presiden.
# b. Presiden melakukan konsultasi mengenai calon anggota
# BPKN sebagaimana dimaksud pada huruf a kepada
# Dewan Perwakilan Rakyat Republik Indonesia.
# c. Presiden mengangkat anggota BPKN."""^^xsd:string .
#
# lexid:PP_2019_4_Section_10_4 lexid-s:isPartOf lexid:PP_2019_4_Article_10 .
#
# lexid:PP_2019_4_Section_4_1_Letter_B rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_6_Letter_E rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_13_Letter_A lexid-s:isPartOf lexid:PP_2019_4_Article_13 .
#
# lexid:PP_2019_4_Section_4_2 rdfs:label "ayat 2 : (2)"^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1_Letter_B rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_5_1_Letter_D rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_16_3 rdfs:label "ayat 3 : (3)"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_2 rdfs:label "ayat 2 : (2)"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_1_Letter_E lexid-s:isPartOf lexid:PP_2019_4_Section_12_1 .
#
# lexid:PP_2019_4_Section_14_1 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Article_4 lexid-s:hasPart lexid:PP_2019_4_Section_4_2 .
#
# lexid:PP_2019_4_Section_9_1 lexid-s:name "(1)"^^xsd:string .
#
# lexid:PP_2019_4_Article_11 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Section_14_1 dct:description """Anggota BPKN yang berhenti atau diberhentikan
# sebelum masa jabatannya berakhir digantikan oleh
# anggota BPKN pengganti antarwaktu."""^^xsd:string .
#
# lexid:PP_2019_4_Section_5_2 rdfs:label "ayat 2 : (2)"^^xsd:string .
#
# lexid:PP_2019_4_Section_14_6 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Article_10 lexid-s:isPartOf lexid:PP_2019_4_Chapter_IV .
#
# lexid:PP_2019_4_Section_5_1_Letter_D lexid-s:isPartOf lexid:PP_2019_4_Section_5_1 .
#
# lexid:PP_2019_4_Article_9 lexid-s:isPartOf lexid:PP_2019_4_Chapter_IV .
#
# lexid:PP_2019_4_Section_12_1 dct:description """Keanggotaan BPKN berhenti karena:
# a. meninggal dunia;
# b. mengundurkan diri atas permintaan sendiri;
# c. bertempat tinggal di luar wilayah negara Republik
# Indonesia;
# d. sakit secara terus menerus;
# e. berakhir masa jabatan sebagai anggota; atau
# f. diberhentikan."""^^xsd:string .
#
# lexid:PP_2019_4_Article_6 rdfs:label "Pasal 6 : Pasal 6"^^xsd:string .
#
# lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_II .
#
# lexid:PP_2019_4_Section_4_1 lexid-s:name "(1)"^^xsd:string .
#
# lexid:PP_2019_4_Article_3 lexid-s:name "Pasal 3"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_IV lexid-s:hasPart lexid:PP_2019_4_Article_10 .
#
# lexid:PP_2019_4_Chapter_III rdfs:label "BAB III : ORGANISASI DAN KEANGGOTAAN"^^xsd:string .
#
# lexid:PP_2019_4_Article_5 rdfs:label "Pasal 5 : Pasal 5"^^xsd:string .
#
# lexid:PP_2019_4_Article_6 rdf:type lexid-s:Article .
#
# lexid:PP_2019_4_Article_13 lexid-s:hasPart lexid:PP_2019_4_Article_13_Letter_A .
#
# lexid:PP_2019_4_Chapter_VI lexid-s:name "KETENTUAN PENUTUP"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_2_Letter_A rdfs:label "PP 2019 4 Section 12 2 Letter A"^^xsd:string .
#
# lexid:PP_2019_4_Section_14_2 rdfs:label "ayat 2 : (2)"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_2_Letter_B lexid-s:isPartOf lexid:PP_2019_4_Section_12_2 .
#
# lexid:PP_2019_4_Section_4_1 dct:description """Susunan keanggotaan BPKN terdiri dari:
# a. seorang ketua merangkap anggota;
# b. seorang wakil ketua merangkap anggota; dan
# c. anggota BPKN paling sedikit 15 (lima belas) orang
# dan paling banyak 25 (dua puluh lima) orang
# anggota."""^^xsd:string .
#
# lexid:PP_2019_4_Article_14 rdfs:label "Pasal 14 : Pasal 14"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_4 dct:description """Ketentuan lebih lanjut mengenai pelaksanaan tugas
# BPKN sebagaimana dimaksud pada ayat (2) dan ayat (3)
# diatur dengan keputusan Ketua BPKN."""^^xsd:string .
#
# lexid:PP_2019_4_Article_17 lexid-s:isPartOf lexid:PP_2019_4_Chapter_VI .
#
# lexid:PP_2019_4_Article_14 lexid-s:hasPart lexid:PP_2019_4_Section_14_6 .
#
# lexid:PP_2019_4_Section_12_2_Letter_C rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_12_1_Letter_B rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_5_1_Letter_D dct:description "akademisi."^^xsd:string .
#
# lexid:PP_2019_4_Section_14_6 rdfs:label "ayat 6 : (6)"^^xsd:string .
#
# lexid:PP_2019_4_Article_17_Letter_B rdfs:label "PP 2019 4 Article 17 Letter B"^^xsd:string .
#
# lexid:PP_2019_4_Section_9_3 dct:description "Ketua dan wakil Ketua BPKN dipilih oleh anggota."^^xsd:string .
#
# lexid:PP_2019_4_Article_17_Letter_A lexid-s:isPartOf lexid:PP_2019_4_Article_17 .
#
# lexid:PP_2019_4_Section_3_2_Letter_D rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Chapter_IV rdfs:label "BAB IV : PENGANGKATAN DAN PEMBERHENTIAN ANGGOTA BPKN"^^xsd:string .
#
# lexid:PP_2019_4_Section_10_2 lexid-s:isPartOf lexid:PP_2019_4_Article_10 .
#
# lexid:PP_2019_4_Section_12_1 lexid-s:hasPart lexid:PP_2019_4_Section_12_1_Letter_A .
#
# lexid:PP_2019_4_Section_12_1_Letter_F lexid-s:isPartOf lexid:PP_2019_4_Section_12_1 .
#
# lexid:PP_2019_4_Article_1 lexid-s:hasPart lexid:PP_2019_4_Article_1_Number_0 .
#
# lexid:PP_2019_4_Article_6_Letter_B dct:description "berbadan sehat."^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1_Letter_E dct:description "tenaga ahli."^^xsd:string .
#
# lexid:PP_2019_4_Article_11_Letter_A lexid-s:isPartOf lexid:PP_2019_4_Article_11_Letter_B .
#
# lexid:PP_2019_4_Part_III_KEDUA lexid-s:isPartOf lexid:PP_2019_4_Chapter_III .
#
# lexid:PP_2019_4_Section_3_2_Letter_A rdfs:label "PP 2019 4 Section 3 2 Letter A"^^xsd:string .
#
# lexid:PP_2019_4_Section_9_1 rdfs:label "ayat 1 : (1)"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_1_Letter_A rdfs:label "Huruf A"^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1 lexid-s:hasPart lexid:PP_2019_4_Section_5_1_Letter_C .
#
# lexid:PP_2019_4_Section_2_3 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Article_14 lexid-s:hasPart lexid:PP_2019_4_Section_14_2 .
#
# lexid:PP_2019_4_Chapter_III rdf:type lexid-s:Chapter .
#
# lexid:PP_2019_4_Section_5_1_Letter_B lexid-s:isPartOf lexid:PP_2019_4_Section_5_1 .
#
# lexid:PP_2019_4_Article_13_Letter_B lexid-s:isPartOf lexid:PP_2019_4_Article_13 .
#
# lexid:PP_2019_4_Article_13_Letter_B lexid-s:hasPart lexid:PP_2019_4_Article_13_Letter_A .
#
# lexid:PP_2019_4_Section_5_1 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_3_2_Letter_A rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_3_2_Letter_G lexid-s:isPartOf lexid:PP_2019_4_Section_3_2 .
#
# lexid:PP_2019_4_Section_9_2 dct:description """Masa jabatan ketua, wakil ketua, dan anggota BPKN
# selama 3 (tiga) tahun dan dapat diangkat kembali
# untuk 1 (satu) kali masa jabatan berikutnya."""^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_A rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_12_1 lexid-s:name "(1)"^^xsd:string .
#
# lexid:PP_2019_4_Article_14 lexid-s:hasPart lexid:PP_2019_4_Section_14_3 .
#
# lexid:PP_2019_4_Section_10_3 rdfs:label "ayat 3 : (3)"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_1_Letter_F rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_11_Letter_A rdfs:label "Huruf A"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2 dct:description """Untuk menjalankan fungsi sebagaimana dimaksud
# pada ayat (1), BPKN bertugas:
# a. memberikan saran dan rekomendasi kepada
# pemerintah dalam rangka penyusunan
# kebijaksanaan di bidang Perlindungan Konsumen;
# b. melakukan penelitian dan pengkajian terhadap
# peraturan perundang-undangan yang berlaku di
# bidang Perlindungan Konsumen;
# c. melakukan penelitian terhadap barang dan/atau
# jasa yang menyangkut keselamatan Konsumen;
# d. mendorong berkembangnya LPKSM;
# e. menyebarluaskan informasi melalui media mengenai
# Perlindungan Konsumen dan memasyarakatkan
# sikap keberpihakan kepada Konsumen;
# f. menerima pengaduan tentang Perlindungan
# Konsumen dari masyarakat, LPKSM, atau Pelaku
# Usaha; dan
# g. melakukan survei yang menyangkut kebutuhan
# Konsumen."""^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_B dct:description "melakukan penelitian dan pengkajian terhadap peraturan perundang-undangan yang berlaku di bidang Perlindungan Konsumen."^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_6 rdfs:label "PP 2019 4 Article 1 Number 6"^^xsd:string .
#
# lexid:PP_2019_4_Article_2 lexid-s:name "Pasal 2"^^xsd:string .
#
# lexid:PP_2019_4_Section_4_1_Letter_C rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_17_Letter_A rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Part_III_KESATU lexid-s:hasPart lexid:PP_2019_4_Article_5 .
#
# lexid:PP_2019_4_Article_6 lexid-s:name "Pasal 6"^^xsd:string .
#
# lexid:PP_2019_4_Part_III_KEDUA lexid-s:name "Sekretariat"^^xsd:string .
#
# lexid:PP_2019_4_Section_4_2 dct:description """Untuk menunjang pelaksanaan tugas BPKN, anggota
# BPKN dapat dibagi dalam beberapa komisi sesuai
# dengan kebutuhan."""^^xsd:string .
#
# lexid:PP_2019_4_Section_5_2 lexid-s:name "(2)"^^xsd:string .
#
# lexid:PP_2019_4_Section_8_2 lexid-s:name "(2)"^^xsd:string .
#
# lexid:PP_2019_4_Section_14_6 dct:description """Pengangkatan anggota pengganti antarwaktu dilakukan
# apabila jumlah anggota BPKN kurang dari 15 (lima
# belas) orang."""^^xsd:string .
#
# lexid:PP_2019_4_Article_6_Letter_D rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_13 dct:description """Pemberhentian anggota BPKN melalui tahapan sebagai
# berikut:
# a. Menteri mengajukan usul anggota BPKN yang akan
# diberhentikan kepada Presiden.
# b. Presiden melakukan konsultasi mengenai anggota
# BPKN yang akan diberhentikan sebagaimana dimaksud
# pada huruf a kepada Dewan Perwakilan Rakyat
# Republik Indonesia.
# c. Presiden memberhentikan anggota BPKN."""^^xsd:string .
#
# lexid:PP_2019_4_Chapter_III lexid-s:isContentOf lexid:PP_2019_4 .
#
# lexid:PP_2019_4_Article_6_Letter_B rdfs:label "PP 2019 4 Article 6 Letter B"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_3 lexid-s:name "(3)"^^xsd:string .
#
# lexid:PP_2019_4_Article_13_Letter_A rdfs:label "Huruf A"^^xsd:string .
#
# lexid:PP_2019_4_Article_17 lexid-s:hasPart lexid:PP_2019_4_Article_17_Letter_B .
#
# lexid:PP_2019_4_Article_17 lexid-s:name "Pasal 17"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2 rdfs:label "ayat 2 : (2)"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_2 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_12_1_Letter_E dct:description "berakhir masa jabatan sebagai anggota."^^xsd:string .
#
# lexid:PP_2019_4_Article_15 lexid-s:isPartOf lexid:PP_2019_4_Chapter_V .
#
# lexid:PP_2019_4_Chapter_II lexid-s:name "KEDUDUKAN, TUGAS, DAN FUNGSI"^^xsd:string .
#
# lexid:PP_2019_4_Article_17_Letter_A rdfs:label "PP 2019 4 Article 17 Letter A"^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_6 rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_12_1_Letter_E rdfs:label "PP 2019 4 Section 12 1 Letter E"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_4 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_5_1_Letter_C rdfs:label "PP 2019 4 Section 5 1 Letter C"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_1_Letter_A lexid-s:isPartOf lexid:PP_2019_4_Section_12_1 .
#
# lexid:PP_2019_4_Article_11_Letter_C lexid-s:isPartOf lexid:PP_2019_4_Article_11 .
#
# lexid:PP_2019_4_Section_5_1_Letter_E rdfs:label "PP 2019 4 Section 5 1 Letter E"^^xsd:string .
#
# lexid:PP_2019_4_Article_16 lexid-s:hasPart lexid:PP_2019_4_Section_16_1 .
#
# lexid:PP_2019_4_Section_12_1_Letter_A dct:description "meninggal dunia."^^xsd:string .
#
# lexid:PP_2019_4_Section_9_3 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Part_III_KEDUA lexid-s:hasPart lexid:PP_2019_4_Article_8 .
#
# lexid:PP_2019_4_Section_12_1_Letter_F rdfs:label "PP 2019 4 Section 12 1 Letter F"^^xsd:string .
#
# lexid:PP_2019_4_Section_2_3 lexid-s:name "(3)"^^xsd:string .
#
# lexid:PP_2019_4_Section_16_2 dct:description """Besaran hak keuangan dan fasilitas lainnya bagi ketua,
# wakil ketua, dan anggota BPKN sebagaimana dimaksud
# pada ayat (1) ditetapkan dengan Peraturan Presiden."""^^xsd:string .
#
# lexid:PP_2019_4_Article_11_Letter_C rdfs:label "PP 2019 4 Article 11 Letter C"^^xsd:string .
#
# lexid:PP_2019_4_Section_4_1 lexid-s:hasPart lexid:PP_2019_4_Section_4_1_Letter_A .
#
# lexid:PP_2019_4_Section_3_2 lexid-s:name "(2)"^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_4 rdfs:label "Angka 4"^^xsd:string .
#
# lexid:PP_2019_4_Section_12_2_Letter_C lexid-s:isPartOf lexid:PP_2019_4_Section_12_2 .
#
# lexid:PP_2019_4_Article_13 rdfs:label "Pasal 13 : Pasal 13"^^xsd:string .
#
# lexid:PP_2019_4_Section_8_1 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_5_1 lexid-s:hasPart lexid:PP_2019_4_Section_5_1_Letter_E .
#
# lexid:PP_2019_4_Article_13_Letter_A rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Article_1_Number_1 rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Chapter_I rdfs:label "BAB I : KETENTUAN UMUM"^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_5 rdfs:label "PP 2019 4 Article 1 Number 5"^^xsd:string .
#
# lexid:PP_2019_4_Section_4_3 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Article_14 lexid-s:hasPart lexid:PP_2019_4_Section_14_5 .
#
# lexid:PP_2019_4_Article_2 lexid-s:isPartOf lexid:PP_2019_4_Chapter_II .
#
# lexid:PP_2019_4_Section_12_1_Letter_A rdf:type lexid-s:Item .
#
# lexid:PP_2019_4_Section_10_2 lexid-s:name "(2)"^^xsd:string .
#
# lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_IV .
#
# lexid:PP_2019_4_Article_12 lexid-s:hasPart lexid:PP_2019_4_Section_12_2 .
#
# lexid:PP_2019_4_Article_1 lexid-s:hasPart lexid:PP_2019_4_Article_1_Number_2 .
#
# lexid:PP_2019_4_Section_4_1 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_2_2 rdfs:label "ayat 2 : (2)"^^xsd:string .
#
# lexid:PP_2019_4_Section_4_1_Letter_C rdfs:label "Huruf C"^^xsd:string .
#
# lexid:PP_2019_4_Article_11 lexid-s:isPartOf lexid:PP_2019_4_Chapter_IV .
#
# lexid:PP_2019_4_Section_10_1 lexid-s:isPartOf lexid:PP_2019_4_Article_10 .
#
# lexid:PP_2019_4_Article_11_Letter_C dct:description "Presiden mengangkat anggota BPKN."^^xsd:string .
#
# lexid:PP_2019_4_Article_1_Number_6 lexid-s:isPartOf lexid:PP_2019_4_Article_1 .
#
# lexid:PP_2019_4_Section_3_3 lexid-s:isPartOf lexid:PP_2019_4_Article_3 .
#
# lexid:PP_2019_4_Section_14_3 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Article_16 lexid-s:hasPart lexid:PP_2019_4_Section_16_3 .
#
# lexid:PP_2019_4_Chapter_VI lexid-s:hasPart lexid:PP_2019_4_Article_18 .
#
# lexid:PP_2019_4 lexid-s:hasContent lexid:PP_2019_4_Chapter_V .
#
# lexid:PP_2019_4_Section_12_1_Letter_F lexid-s:isPartOf lexid:PP_2019_4_Section_12_2 .
#
# lexid:PP_2019_4_Section_8_3 rdf:type lexid-s:Section .
#
# lexid:PP_2019_4_Section_12_2_Letter_C rdfs:label "Huruf C"^^xsd:string .
#
# lexid:PP_2019_4_Chapter_IV lexid-s:hasPart lexid:PP_2019_4_Article_11 .
#
# lexid:PP_2019_4_Article_15 rdfs:label "Pasal 15 : Pasal 15"^^xsd:string .
#
# lexid:PP_2019_4_Article_17_Letter_C dct:description "Calon anggota BPKN yang telah memenuhi persyaratan dan telah disampaikan oleh Presiden kepada Dewan Perwakilan Rakyat Republik Indonesia sesuai dengan ketentuan yang diatur dalam Peraturan Pemerintah Nomor 57 Tahun 2001 tentang Badan Perlindungan Konsumen Nasional tetap dilanjutkan untuk konsultasi dan pengangkatannya."^^xsd:string .
#
# lexid:PP_2019_4_Section_16_2 lexid-s:isPartOf lexid:PP_2019_4_Article_16 .
#
# lexid:PP_2019_4_Article_6_Letter_E lexid-s:isPartOf lexid:PP_2019_4_Article_6 .
#
# lexid:PP_2019_4_Section_3_2_Letter_B rdfs:label "Huruf B"^^xsd:string .
#
# lexid:PP_2019_4_Section_5_1 lexid-s:hasPart lexid:PP_2019_4_Section_5_1_Letter_B .
#
# lexid:PP_2019_4_Part_III_KEDUA rdfs:label "BAGIAN KEDUA : Sekretariat"^^xsd:string .
#
# lexid:PP_2019_4_Section_3_2_Letter_C dct:description "melakukan penelitian terhadap barang dan/atau jasa yang menyangkut keselamatan Konsumen."^^xsd:string .
#
# lexid:PP_2019_4_Section_4_1 lexid-s:isPartOf lexid:PP_2019_4_Article_4 .
#
# lexid:PP_2019_4_Article_6 lexid-s:hasPart lexid:PP_2019_4_Article_6_Letter_D .

# %% [markdown]
# ## Intro

# %%
# !nvidia-smi
# Out:
# Thu May 23 07:52:04 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          On  |   00000000:07:00.0 Off |                    0 |
# | N/A   44C    P0            185W /  400W |   17379MiB /  40960MiB |     64%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA A100-SXM4-40GB          On  |   00000000:0F:00.0 Off |                    0 |
# | N/A   31C    P0             85W /  400W |    5508MiB /  40960MiB |     35%      Default |
# |                                         |                        |             Enabled* |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA A100-SXM4-40GB          On  |   00000000:47:00.0 Off |                    0 |
# | N/A   27C    P0             55W /  400W |       3MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   3  NVIDIA A100-SXM4-40GB          On  |   00000000:4E:00.0 Off |                    0 |
# | N/A   28C    P0             54W /  400W |       3MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   4  NVIDIA A100-SXM4-40GB          On  |   00000000:87:00.0 Off |                    0 |
# | N/A   39C    P0             64W /  400W |    1713MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   5  NVIDIA A100-SXM4-40GB          On  |   00000000:90:00.0 Off |                    0 |
# | N/A   32C    P0             54W /  400W |       3MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   6  NVIDIA A100-SXM4-40GB          On  |   00000000:B7:00.0 Off |                    0 |
# | N/A   31C    P0             54W /  400W |       3MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   7  NVIDIA A100-SXM4-40GB          On  |   00000000:BD:00.0 Off |                    0 |
# | N/A   46C    P0            267W /  400W |   35874MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'

# %%
from huggingface_hub import login

login(token = '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')
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

torch.random.manual_seed(0)

MODEL_NAME = "google/codegemma-7b-it"

model_f7 = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME, 
    device_map="cuda", 
    torch_dtype="auto",
    trust_remote_code=True, 
).half()

tokenizer_f7 = AutoTokenizer.from_pretrained(MODEL_NAME)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
pipe_f7 = pipeline(
    "text-generation",
    model=model_f7,
    tokenizer=tokenizer_f7,
    framework="pt",
)

generation_args = {
    "max_new_tokens": 5000,
    "return_full_text": False,
    "temperature": 0.0,
    "do_sample": False,
#     "repetition_penalty": 1.7,
#     "bos_token_id": 11,
#     "eos_token_id": 11,
#     "pad_token_id": 11,
#     "use_cache": False,
}

# %% [markdown]
# ## Body

# %% [markdown]
# # GPTQ

# %%
with open('./dataset-final/new_2_turtle_files/ln/2019/pp4-2019bt.ttl', 'r') as f:
    lines = f.readlines()

lines = lines[10:]

# %%
import torch

from transformers import AutoTokenizer, TextGenerationPipeline, AutoModelForCausalLM, pipeline
from auto_gptq import AutoGPTQForCausalLM, BaseQuantizeConfig
# Out:
# CUDA extension not installed.
# CUDA extension not installed.
